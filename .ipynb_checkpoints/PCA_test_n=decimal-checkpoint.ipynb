# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random

#dir = 'C:\\Users\\Richie Lee\\Desktop\\College\\1 San Jose State University\\9 2021 fall semester\\CMPE 188\\hw2&hw3\\photos\\train_set'
train_dir = './datasets/train_set/'

targets = ['buildings','forest','glacier','mountain','sea','street']
train_data = []
#load train set
for target in targets:
    train_path = os.path.join(train_dir,target)
    label = targets.index(target)
    for img in os.listdir(train_path):
        train_imgpath = os.path.join(train_path, img) #train_imgpath = './xxx/xxx/xxx.jpg'
        train_img = cv2.imread(train_imgpath)
        try:
            train_img = cv2.resize(train_img,(150,150)) #**very impoertant step
            train_image = np.array(train_img).flatten()
            train_data.append([train_image,label])
        except Exception as e:
            pass

len(train_data)
# Out:
# 14338

# %% [markdown]
# ## train data shuffled

# %%
random.shuffle(train_data)
train_data
# Out:
# [[array([175, 204, 218, ...,   0,  19,  64], dtype=uint8), 0],
#  [array([ 63,  62,  41, ..., 163, 147, 134], dtype=uint8), 0],
#  [array([168, 143, 139, ...,  69,  75,  82], dtype=uint8), 2],
#  [array([ 73,  92, 189, ...,  47,  39,  49], dtype=uint8), 4],
#  [array([104,  53,  27, ..., 149, 167, 100], dtype=uint8), 4],
#  [array([198, 151, 123, ...,  53,  46,  49], dtype=uint8), 5],
#  [array([251, 253, 254, ...,  89,  91,  91], dtype=uint8), 0],
#  [array([133, 145, 155, ...,  28,  20,  13], dtype=uint8), 2],
#  [array([221, 221, 221, ..., 115, 120, 118], dtype=uint8), 4],
#  [array([208, 198, 191, ..., 161, 135, 111], dtype=uint8), 2],
#  [array([148,  92,  57, ..., 190, 200, 210], dtype=uint8), 3],
#  [array([21, 33, 35, ...,  5, 73, 38], dtype=uint8), 1],
#  [array([240, 225, 216, ...,  38,  52,  51], dtype=uint8), 3],
#  [array([216, 209, 200, ...,  51,  24,   3], dtype=uint8), 3],
#  [array([189, 155, 131, ..., 167, 158, 161], dtype=uint8), 2],
#  [array([ 0,  7, 10, ...,  3,  7,  8], dtype=uint8), 0],
#  [array([247, 251, 240, ..., 154, 151, 123], dtype=uint8), 0],
#  [array([147, 146, 150, ...,  19,  17,  16], dtype=uint8), 5],
#  [array([104, 133, 137, ..., 137, 121, 105], dtype=uint8), 2],
#  [array([222, 217, 216, ..., 172, 174, 174], dtype=uint8), 0],
#  [array([36, 45, 25, ..., 48, 49, 47], dtype=uint8), 5],
#  [array([ 90,  98, 111, ..., 131, 122, 109], dtype=uint8), 5],
#  [array([221, 231, 231, ...,  72,  70,  92], dtype=uint8), 4],
#  [array([ 0,  0,  0, ..., 21, 21, 21], dtype=uint8), 5],
#  [array([ 60,  94, 147, ...,  13,  23,  40], dtype=uint8), 5],
#  [array([237, 196, 163, ...,   0,   9,  21], dtype=uint8), 3],
#  [array([ 42,  47, 150, ...,  98,  93,  94], dtype=uint8), 5],
#  [array([154, 135, 122, ..., 178, 226, 232], dtype=uint8), 0],
#  [array([50, 42, 52, ..., 51, 44, 49], dtype=uint8), 5],
#  [array([235, 151, 103, ...,  75, 103, 114], dtype=uint8), 3],
#  [array([160, 136, 124, ...,  39,  46,  39], dtype=uint8), 5],
#  [array([ 72,  40,  17, ..., 172, 163, 154], dtype=uint8), 2],
#  [array([ 61, 104,  93, ...,  53, 162, 153], dtype=uint8), 1],
#  [array([199, 167, 148, ...,   6,  23,  20], dtype=uint8), 3],
#  [array([228, 216, 214, ..., 147, 138, 128], dtype=uint8), 0],
#  [array([128, 119, 116, ..., 152, 154, 154], dtype=uint8), 2],
#  [array([245, 249, 250, ...,  99, 114, 117], dtype=uint8), 5],
#  [array([180, 127, 106, ..., 118,  85,  52], dtype=uint8), 2],
#  [array([232, 228, 223, ..., 115, 103,  49], dtype=uint8), 2],
#  [array([246, 241, 238, ...,  91,  61,  32], dtype=uint8), 2],
#  [array([ 5, 33, 14, ..., 30, 88, 93], dtype=uint8), 1],
#  [array([207, 163, 104, ...,  66,  49,  30], dtype=uint8), 3],
#  [array([204, 191, 193, ..., 123, 109, 110], dtype=uint8), 3],
#  [array([228, 141,  79, ...,   0,   7,  17], dtype=uint8), 0],
#  [array([230, 202, 191, ..., 100,  92, 102], dtype=uint8), 3],
#  [array([255, 251, 255, ..., 169, 130, 102], dtype=uint8), 2],
#  [array([36, 34, 34, ...,  8, 10, 10], dtype=uint8), 1],
#  [array([149,  81,   4, ...,  57,  21,  13], dtype=uint8), 3],
#  [array([197, 203, 210, ..., 178, 185, 194], dtype=uint8), 2],
#  [array([0, 1, 1, ..., 3, 1, 1], dtype=uint8), 4],
#  [array([201, 137,  52, ...,  57,  64,  97], dtype=uint8), 4],
#  [array([212, 149, 115, ...,  55,  60,  63], dtype=uint8), 0],
#  [array([ 50,  50,  50, ..., 159, 159, 159], dtype=uint8), 5],
#  [array([230, 204, 190, ...,  79,  80,  78], dtype=uint8), 0],
#  [array([217, 143,  79, ...,  56,  50,  45], dtype=uint8), 0],
#  [array([200, 189, 181, ...,   8,  23,  25], dtype=uint8), 3],
#  [array([47, 47, 47, ..., 42, 42, 42], dtype=uint8), 5],
#  [array([ 25,  34,  38, ..., 101, 113, 117], dtype=uint8), 0],
#  [array([198, 127,  63, ..., 143, 100,  57], dtype=uint8), 2],
#  [array([  4,   7,  21, ..., 109,  88,  86], dtype=uint8), 5],
#  [array([171, 149, 124, ..., 191, 175, 162], dtype=uint8), 2],
#  [array([ 74,  90,  67, ..., 136, 160, 180], dtype=uint8), 1],
#  [array([135,  53,  12, ...,   0,   3,   1], dtype=uint8), 0],
#  [array([ 60,  55,  64, ..., 251, 253, 253], dtype=uint8), 5],
#  [array([252, 230, 195, ...,  38, 125, 157], dtype=uint8), 0],
#  [array([239, 193, 145, ...,  93,  51,   9], dtype=uint8), 3],
#  [array([229, 227, 217, ...,   7,  94, 121], dtype=uint8), 3],
#  [array([153, 120,  70, ...,  16,  23,  16], dtype=uint8), 4],
#  [array([137,  95,  66, ...,  40,  20,  25], dtype=uint8), 5],
#  [array([223, 221, 213, ..., 200, 191, 182], dtype=uint8), 3],
#  [array([ 1,  1,  1, ..., 89, 89, 89], dtype=uint8), 5],
#  [array([ 84,  90, 109, ...,  16,  16,  28], dtype=uint8), 1],
#  [array([ 76,  85,  64, ..., 142, 147, 146], dtype=uint8), 5],
#  [array([213, 195, 172, ...,  15,  67,  74], dtype=uint8), 3],
#  [array([37, 28, 24, ..., 25, 50, 12], dtype=uint8), 1],
#  [array([199, 172, 151, ..., 110,  99,  77], dtype=uint8), 3],
#  [array([40, 43, 51, ..., 75, 73, 72], dtype=uint8), 5],
#  [array([222, 206, 164, ..., 124, 118,  59], dtype=uint8), 4],
#  [array([205, 186, 189, ...,  70,  71,  69], dtype=uint8), 4],
#  [array([239, 223, 207, ...,  16,  50,  40], dtype=uint8), 0],
#  [array([144, 133, 135, ...,  16,  29,  27], dtype=uint8), 3],
#  [array([142, 119, 104, ...,  82,  57,  25], dtype=uint8), 2],
#  [array([195, 171, 151, ...,  37,  42,  63], dtype=uint8), 5],
#  [array([173, 138, 105, ..., 220, 206, 210], dtype=uint8), 0],
#  [array([ 91,  99,  88, ..., 117, 154, 122], dtype=uint8), 1],
#  [array([172, 164, 164, ..., 119, 154, 168], dtype=uint8), 0],
#  [array([228, 232, 233, ..., 211, 209, 209], dtype=uint8), 2],
#  [array([255, 255, 255, ...,  49,  43,  38], dtype=uint8), 0],
#  [array([16, 12, 24, ...,  0,  2,  0], dtype=uint8), 0],
#  [array([191, 177, 159, ...,  42,  35,  26], dtype=uint8), 2],
#  [array([201, 203, 213, ..., 119, 113, 106], dtype=uint8), 3],
#  [array([253, 253, 253, ..., 233, 233, 239], dtype=uint8), 2],
#  [array([152, 131, 104, ...,   0,   0,   0], dtype=uint8), 0],
#  [array([171, 172, 168, ...,  18,  55,  81], dtype=uint8), 1],
#  [array([ 2, 34, 53, ...,  5, 17, 17], dtype=uint8), 5],
#  [array([203, 150, 147, ...,   4, 136, 119], dtype=uint8), 3],
#  [array([180, 151, 136, ...,  14,  14,  14], dtype=uint8), 4],
#  [array([58, 58, 58, ...,  0,  0,  0], dtype=uint8), 5],
#  [array([46, 63, 72, ..., 68, 87, 92], dtype=uint8), 2],
#  [array([159, 132,  95, ...,   0,   0,   0], dtype=uint8), 0],
#  [array([157,  69,  23, ..., 158, 167, 164], dtype=uint8), 0],
#  [array([154, 154, 154, ...,  57,  57,  57], dtype=uint8), 2],
#  [array([225, 209, 202, ...,  36,  43,  52], dtype=uint8), 4],
#  [array([222, 211, 203, ...,  34,  34,  34], dtype=uint8), 5],
#  [array([244, 185, 116, ...,   0,  47,  75], dtype=uint8), 3],
#  [array([151, 112,  80, ...,   0,   8,   7], dtype=uint8), 0],
#  [array([145, 154, 157, ...,  12,  29,  25], dtype=uint8), 1],
#  [array([214, 207, 198, ...,   0,  17,  21], dtype=uint8), 3],
#  [array([249, 228, 213, ...,  94,  89,  88], dtype=uint8), 5],
#  [array([243, 245, 245, ...,  11,  12,  10], dtype=uint8), 3],
#  [array([ 2,  0,  0, ..., 84, 61, 35], dtype=uint8), 4],
#  [array([222, 248, 255, ...,  79,  62,  49], dtype=uint8), 4],
#  [array([167, 161, 154, ...,  90,  87,  89], dtype=uint8), 2],
#  [array([152, 176, 176, ...,  66,  72,  85], dtype=uint8), 5],
#  [array([227, 205, 170, ...,  62,  52,  65], dtype=uint8), 4],
#  [array([  1,   1,   1, ..., 199, 199, 199], dtype=uint8), 5],
#  [array([252, 240, 234, ...,  80,  75,  66], dtype=uint8), 3],
#  [array([138, 127, 123, ...,  25,  20,  21], dtype=uint8), 0],
#  [array([98, 97, 83, ..., 70, 65, 66], dtype=uint8), 4],
#  [array([149, 149, 149, ...,  98,  98,  98], dtype=uint8), 4],
#  [array([216, 216, 216, ...,  56,  58,  59], dtype=uint8), 3],
#  [array([29, 61, 36, ..., 44, 72, 79], dtype=uint8), 1],
#  [array([250, 237, 235, ...,  35,  53,  54], dtype=uint8), 2],
#  [array([159, 151, 151, ..., 136, 131, 132], dtype=uint8), 2],
#  [array([78, 57, 59, ...,  0,  3,  7], dtype=uint8), 5],
#  [array([157, 140, 113, ...,  53,  54,  50], dtype=uint8), 2],
#  [array([216, 204, 192, ...,  28,  57,  71], dtype=uint8), 2],
#  [array([208, 201, 198, ...,  60,  50,  50], dtype=uint8), 1],
#  [array([188, 227, 229, ...,  78,  78,  72], dtype=uint8), 5],
#  [array([ 80,  96, 113, ..., 111, 180, 183], dtype=uint8), 1],
#  [array([106, 110, 104, ...,  17,  80,  54], dtype=uint8), 3],
#  [array([67, 78, 75, ..., 82, 87, 86], dtype=uint8), 5],
#  [array([ 98, 136, 140, ...,   0,   0,   1], dtype=uint8), 5],
#  [array([249, 200, 120, ..., 170, 145, 125], dtype=uint8), 2],
#  [array([111,  59,  47, ...,  13,  21,  20], dtype=uint8), 4],
#  [array([ 7, 16,  6, ...,  7,  6, 10], dtype=uint8), 1],
#  [array([54, 65, 55, ..., 14, 17, 15], dtype=uint8), 5],
#  [array([49, 22,  2, ..., 42, 97, 78], dtype=uint8), 3],
#  [array([245, 209, 173, ...,  34,  39,  37], dtype=uint8), 3],
#  [array([138,  55,  33, ...,   1,   1,   1], dtype=uint8), 4],
#  [array([228, 242, 240, ..., 136, 118,  89], dtype=uint8), 0],
#  [array([190, 124,  73, ...,  81,  78,  64], dtype=uint8), 0],
#  [array([174, 174, 174, ...,   3,   8,   7], dtype=uint8), 2],
#  [array([192, 186, 173, ..., 152, 152, 136], dtype=uint8), 2],
#  [array([254, 231, 216, ...,  32,  20,  14], dtype=uint8), 3],
#  [array([ 2,  0,  0, ..., 20, 49, 53], dtype=uint8), 0],
#  [array([240, 238, 238, ...,  84,  78,  79], dtype=uint8), 0],
#  [array([44, 49, 48, ...,  5,  7,  7], dtype=uint8), 5],
#  [array([ 7, 50, 35, ..., 10, 18, 25], dtype=uint8), 1],
#  [array([19, 26, 35, ..., 72, 67, 64], dtype=uint8), 5],
#  [array([92, 70, 58, ...,  0,  0, 17], dtype=uint8), 4],
#  [array([178, 157, 135, ..., 140, 156, 168], dtype=uint8), 3],
#  [array([221, 198, 182, ...,  70,  74,  75], dtype=uint8), 3],
#  [array([ 69, 155, 143, ...,  49, 102,  89], dtype=uint8), 1],
#  [array([185, 169, 163, ..., 148, 155, 158], dtype=uint8), 4],
#  [array([251, 249, 218, ...,  82,  88,  95], dtype=uint8), 0],
#  [array([255, 255, 255, ...,  53,  86,  79], dtype=uint8), 3],
#  [array([163, 179, 196, ...,  72,  62,  55], dtype=uint8), 0],
#  [array([21, 38, 41, ...,  3,  1,  1], dtype=uint8), 5],
#  [array([203, 181, 129, ...,  38,  98, 144], dtype=uint8), 5],
#  [array([236, 246, 240, ...,  17,  53,  59], dtype=uint8), 3],
#  [array([ 74,  59,  33, ..., 171, 161, 161], dtype=uint8), 2],
#  [array([162, 126, 108, ..., 248, 203, 190], dtype=uint8), 2],
#  [array([237, 248, 246, ...,  30,  19,  15], dtype=uint8), 0],
#  [array([95, 81, 83, ..., 84, 75, 71], dtype=uint8), 5],
#  [array([  5,  13,   3, ..., 128, 147, 160], dtype=uint8), 5],
#  [array([122, 144, 120, ...,  15,  27,  15], dtype=uint8), 1],
#  [array([244, 185, 139, ..., 198, 205, 222], dtype=uint8), 3],
#  [array([142,  75,   0, ..., 241, 234, 231], dtype=uint8), 3],
#  [array([ 26,  32,  31, ..., 201, 206, 205], dtype=uint8), 0],
#  [array([192, 158, 104, ...,  75,  59,  42], dtype=uint8), 4],
#  [array([212, 204, 187, ...,  35,  31,  67], dtype=uint8), 1],
#  [array([ 78,  55,  39, ..., 144, 116, 105], dtype=uint8), 2],
#  [array([130, 106,  78, ..., 158, 157, 159], dtype=uint8), 4],
#  [array([226, 221, 206, ...,   0,   5,   4], dtype=uint8), 3],
#  [array([72, 72, 72, ..., 22, 22, 22], dtype=uint8), 4],
#  [array([122, 121, 131, ...,  41,  43,  44], dtype=uint8), 4],
#  [array([1, 1, 1, ..., 4, 4, 4], dtype=uint8), 5],
#  [array([194, 113,  52, ..., 121,  76,  43], dtype=uint8), 2],
#  [array([21, 27, 32, ..., 27, 60, 75], dtype=uint8), 5],
#  [array([213, 125,  48, ..., 162, 145, 112], dtype=uint8), 2],
#  [array([ 79,  63,  47, ..., 102,  93,  83], dtype=uint8), 4],
#  [array([237, 230, 227, ..., 122, 118, 113], dtype=uint8), 0],
#  [array([ 74, 201, 192, ...,  15,  86, 113], dtype=uint8), 1],
#  [array([193, 178, 162, ...,  43,  28,  19], dtype=uint8), 3],
#  [array([201, 111,  40, ...,   0,  24,  58], dtype=uint8), 0],
#  [array([ 19,  24,  33, ..., 133, 177, 178], dtype=uint8), 1],
#  [array([  4,  46, 111, ...,  45,  43,  42], dtype=uint8), 5],
#  [array([112, 112, 112, ...,  81,  81,  81], dtype=uint8), 5],
#  [array([126, 136, 136, ...,  54, 208, 183], dtype=uint8), 1],
#  [array([128,  85,  46, ..., 193, 192, 194], dtype=uint8), 3],
#  [array([16, 36, 84, ..., 13,  0, 12], dtype=uint8), 5],
#  [array([250, 238, 232, ...,   4,  11,   8], dtype=uint8), 3],
#  [array([ 63,  85, 113, ...,  92, 105, 121], dtype=uint8), 5],
#  [array([133, 133, 133, ...,  12,  12,  12], dtype=uint8), 4],
#  [array([238, 229, 220, ...,   7,   8,  12], dtype=uint8), 4],
#  [array([231, 138,  69, ...,  45,  61,  74], dtype=uint8), 3],
#  [array([181, 180, 170, ..., 103,  97, 102], dtype=uint8), 4],
#  [array([231, 190, 158, ..., 130, 134, 139], dtype=uint8), 5],
#  [array([46, 46, 46, ..., 12, 12, 12], dtype=uint8), 2],
#  [array([206, 192, 193, ...,  54,  55,  46], dtype=uint8), 2],
#  [array([232, 210, 192, ...,  87,  76,  62], dtype=uint8), 2],
#  [array([209, 173, 143, ...,  19,  41,  39], dtype=uint8), 0],
#  [array([ 30,  30,  30, ..., 199, 199, 199], dtype=uint8), 3],
#  [array([202, 175, 141, ...,  32,  21,  23], dtype=uint8), 0],
#  [array([134,  81,  54, ..., 226, 224, 223], dtype=uint8), 2],
#  [array([223, 207, 194, ...,  50,  67,  70], dtype=uint8), 3],
#  [array([71, 87, 80, ..., 65, 69, 64], dtype=uint8), 5],
#  [array([ 36,  41,  44, ..., 140, 142, 166], dtype=uint8), 1],
#  [array([234, 255, 246, ..., 255, 253, 255], dtype=uint8), 0],
#  [array([ 3, 12, 15, ..., 59, 64, 67], dtype=uint8), 5],
#  [array([179, 169, 152, ...,  49,  37,  35], dtype=uint8), 3],
#  [array([ 28,  32,  37, ..., 143, 138,  93], dtype=uint8), 4],
#  [array([134, 192, 234, ...,   0,   0,   0], dtype=uint8), 4],
#  [array([ 59,  59,  59, ..., 165, 165, 165], dtype=uint8), 5],
#  [array([241, 215, 178, ...,   0,   2,  15], dtype=uint8), 1],
#  [array([187, 128,  88, ...,  15,  13,  12], dtype=uint8), 0],
#  [array([199, 243, 250, ...,  60, 170, 212], dtype=uint8), 1],
#  [array([234, 202, 173, ...,  80,  90, 100], dtype=uint8), 4],
#  [array([ 59,  68,  65, ..., 127, 120, 127], dtype=uint8), 1],
#  [array([27, 30, 58, ...,  0,  1,  0], dtype=uint8), 5],
#  [array([ 82,  56,  49, ..., 166, 154, 154], dtype=uint8), 4],
#  [array([203, 203, 203, ..., 234, 234, 234], dtype=uint8), 5],
#  [array([118,  95, 100, ..., 101,  79,  73], dtype=uint8), 4],
#  [array([214, 208, 203, ...,  30,  39,  42], dtype=uint8), 3],
#  [array([136, 127, 107, ...,   7,  63,  34], dtype=uint8), 1],
#  [array([186, 128,  76, ..., 119, 119, 103], dtype=uint8), 2],
#  [array([201, 126,  94, ...,  45,  38,  43], dtype=uint8), 0],
#  [array([189, 185, 180, ...,   0,   0,   0], dtype=uint8), 3],
#  [array([236, 160, 107, ...,  62,  87,  91], dtype=uint8), 3],
#  [array([116,  91,  81, ...,  42,  50,  57], dtype=uint8), 2],
#  [array([218, 199, 184, ..., 107, 102,  99], dtype=uint8), 4],
#  [array([214, 164, 104, ..., 116, 130, 119], dtype=uint8), 0],
#  [array([230, 193, 143, ...,  90,  72,  13], dtype=uint8), 2],
#  [array([169, 147, 122, ...,   0,   1,   0], dtype=uint8), 0],
#  [array([88, 99, 91, ..., 10, 40, 15], dtype=uint8), 1],
#  [array([30,  8,  3, ..., 57, 98, 53], dtype=uint8), 1],
#  [array([223, 214, 200, ..., 104,  98, 103], dtype=uint8), 5],
#  [array([174,  61, 195, ...,   0,   0,   0], dtype=uint8), 0],
#  [array([250, 240, 222, ..., 111,  87,  69], dtype=uint8), 0],
#  [array([131,  73,  51, ..., 117,  95,  89], dtype=uint8), 3],
#  [array([209, 176, 127, ...,  81, 122, 125], dtype=uint8), 3],
#  [array([104, 146, 165, ...,  94, 106, 124], dtype=uint8), 4],
#  [array([216, 124,  71, ...,  65,  53,  53], dtype=uint8), 3],
#  [array([ 31,  25,  30, ..., 146, 162, 205], dtype=uint8), 5],
#  [array([255, 254, 254, ...,  43,  54,  68], dtype=uint8), 1],
#  [array([126,  66,  20, ...,   3,   1,   1], dtype=uint8), 4],
#  [array([96, 96, 96, ..., 68, 68, 68], dtype=uint8), 5],
#  [array([ 63,  73,  91, ..., 129, 148, 155], dtype=uint8), 5],
#  [array([79, 77, 67, ..., 47, 90, 87], dtype=uint8), 1],
#  [array([215, 217, 217, ..., 252, 250, 249], dtype=uint8), 1],
#  [array([180, 142, 108, ..., 135, 127, 110], dtype=uint8), 2],
#  [array([192, 136,   5, ..., 203, 142,   0], dtype=uint8), 4],
#  [array([ 80, 114, 137, ...,  51,  62,  66], dtype=uint8), 5],
#  [array([134, 126, 137, ..., 102, 113, 151], dtype=uint8), 5],
#  [array([126,  83,  10, ...,   1,  27,   3], dtype=uint8), 4],
#  [array([ 0, 31, 24, ...,  1, 53, 13], dtype=uint8), 1],
#  [array([ 76,  82,  93, ...,  95,  99, 110], dtype=uint8), 5],
#  [array([247, 247, 247, ...,  55,  55,  55], dtype=uint8), 0],
#  [array([196, 178, 155, ..., 134,  99,  89], dtype=uint8), 3],
#  [array([228, 172, 107, ..., 216, 197, 154], dtype=uint8), 4],
#  [array([102, 107, 138, ...,  93, 107, 101], dtype=uint8), 5],
#  [array([198, 184, 172, ...,  27,  29,  29], dtype=uint8), 2],
#  [array([138, 132, 103, ...,  81, 100, 115], dtype=uint8), 5],
#  [array([24, 26, 26, ...,  2,  8, 27], dtype=uint8), 1],
#  [array([169, 178, 182, ...,  44,  46,  46], dtype=uint8), 5],
#  [array([184, 186, 167, ...,  26,  30,  31], dtype=uint8), 1],
#  [array([124, 108,  95, ...,  55,  54,  56], dtype=uint8), 4],
#  [array([16, 20, 15, ..., 76, 82, 89], dtype=uint8), 5],
#  [array([ 24,  41,  68, ...,  45,  71, 107], dtype=uint8), 0],
#  [array([255, 255, 255, ...,  55,  36,  15], dtype=uint8), 0],
#  [array([ 12,  33,  48, ..., 104, 100,  82], dtype=uint8), 5],
#  [array([199, 187, 187, ...,  57,  81, 117], dtype=uint8), 1],
#  [array([243, 240, 236, ...,  38,  37,  39], dtype=uint8), 4],
#  [array([189, 146, 127, ..., 167, 189, 200], dtype=uint8), 4],
#  [array([193, 168, 134, ...,  47,  45,  45], dtype=uint8), 0],
#  [array([144, 139, 141, ..., 128, 134, 139], dtype=uint8), 5],
#  [array([158, 102,  73, ...,  60,  58,  58], dtype=uint8), 2],
#  [array([215, 115,  61, ..., 116, 110, 111], dtype=uint8), 5],
#  [array([227, 222, 224, ...,  56,  57,  53], dtype=uint8), 2],
#  [array([234, 182, 146, ..., 174, 160, 131], dtype=uint8), 4],
#  [array([244, 225, 217, ...,   0,   0,   0], dtype=uint8), 3],
#  [array([244, 219, 203, ...,  20,  75, 106], dtype=uint8), 3],
#  [array([23, 64, 32, ..., 32, 51, 30], dtype=uint8), 1],
#  [array([229, 168, 134, ...,  63,  64,  62], dtype=uint8), 3],
#  [array([247, 230, 217, ...,  56,  91, 125], dtype=uint8), 0],
#  [array([151, 131, 114, ...,   0,   3,   4], dtype=uint8), 0],
#  [array([21, 66, 70, ...,  0, 50, 50], dtype=uint8), 1],
#  [array([ 27,  66, 141, ...,  10,   4,   5], dtype=uint8), 1],
#  [array([250, 180,  73, ..., 255, 255, 255], dtype=uint8), 3],
#  [array([71, 73, 73, ..., 31, 33, 33], dtype=uint8), 5],
#  [array([254, 205, 143, ...,   9,  20,  10], dtype=uint8), 3],
#  [array([161, 197, 221, ...,  52,  59,  74], dtype=uint8), 5],
#  [array([162, 162, 162, ...,  48,  48,  48], dtype=uint8), 0],
#  [array([220, 176, 129, ...,  52,  68,  57], dtype=uint8), 2],
#  [array([231, 174, 113, ...,   1,  16,  19], dtype=uint8), 3],
#  [array([ 75, 136, 122, ...,  13, 102,  69], dtype=uint8), 1],
#  [array([174, 141,  96, ..., 124, 141, 150], dtype=uint8), 4],
#  [array([  0,  13,  24, ..., 127, 118, 109], dtype=uint8), 5],
#  [array([167, 151, 134, ...,  17,  41,  29], dtype=uint8), 0],
#  [array([220, 221, 219, ...,   7,  32,  28], dtype=uint8), 3],
#  [array([87, 61, 44, ..., 32, 22, 15], dtype=uint8), 2],
#  [array([220, 115,  72, ...,  30,  87, 109], dtype=uint8), 3],
#  [array([30, 97, 68, ..., 19, 50, 49], dtype=uint8), 1],
#  [array([ 64,  96,  79, ..., 125, 177, 153], dtype=uint8), 2],
#  [array([253, 253, 253, ...,  29,  39,  33], dtype=uint8), 2],
#  [array([118, 113, 112, ...,  29,  38,  41], dtype=uint8), 4],
#  [array([211, 211, 211, ...,  21,  21,  21], dtype=uint8), 5],
#  [array([161,  90,  40, ...,  33,  22,  14], dtype=uint8), 2],
#  [array([140, 158, 151, ...,  78, 174, 150], dtype=uint8), 1],
#  [array([ 64,  86, 111, ...,  90,  74,  81], dtype=uint8), 1],
#  [array([220, 187, 172, ...,  81,  72,  58], dtype=uint8), 2],
#  [array([235, 233, 223, ...,  63,  58,  57], dtype=uint8), 5],
#  [array([ 3,  3,  3, ..., 18, 18, 18], dtype=uint8), 5],
#  [array([26,  0,  0, ..., 26,  0,  0], dtype=uint8), 3],
#  [array([200, 160, 141, ..., 240, 231, 227], dtype=uint8), 2],
#  [array([133,  95,  63, ...,  20,  29,  33], dtype=uint8), 2],
#  [array([209, 205, 200, ...,  65,  58,  49], dtype=uint8), 2],
#  [array([173, 135, 101, ..., 135, 114,  82], dtype=uint8), 2],
#  [array([204, 199, 196, ...,  49,  50,  54], dtype=uint8), 5],
#  [array([218, 216, 215, ..., 182, 186, 181], dtype=uint8), 2],
#  [array([0, 8, 7, ..., 0, 1, 0], dtype=uint8), 5],
#  [array([ 97, 114, 110, ...,  78,  96,  89], dtype=uint8), 1],
#  [array([194, 141, 104, ..., 129, 113,  96], dtype=uint8), 2],
#  [array([13, 13, 13, ...,  9,  7,  7], dtype=uint8), 0],
#  [array([ 6,  6,  6, ..., 75, 75, 75], dtype=uint8), 0],
#  [array([229, 236, 233, ...,  10,  22,  32], dtype=uint8), 1],
#  [array([172, 116,  81, ...,  79,  91,  97], dtype=uint8), 0],
#  [array([170, 174, 175, ..., 137, 138, 129], dtype=uint8), 5],
#  [array([190, 105,  57, ...,  37,  42,  51], dtype=uint8), 3],
#  [array([159, 224, 232, ..., 112, 124, 118], dtype=uint8), 5],
#  [array([ 37, 132, 172, ...,  63,  79,  86], dtype=uint8), 5],
#  [array([14,  2,  8, ..., 10, 12, 12], dtype=uint8), 1],
#  [array([154,  40,  27, ...,  37,  31,  32], dtype=uint8), 3],
#  [array([237, 239, 233, ..., 144, 160, 167], dtype=uint8), 2],
#  [array([ 50,  52,  52, ..., 115, 116, 114], dtype=uint8), 2],
#  [array([237, 190, 134, ..., 241, 239, 238], dtype=uint8), 3],
#  [array([ 91,  89,  89, ..., 183, 177, 178], dtype=uint8), 0],
#  [array([225, 201, 189, ...,   5,  25,  26], dtype=uint8), 3],
#  [array([188, 204, 197, ..., 139, 166, 157], dtype=uint8), 4],
#  [array([ 23,  87, 112, ...,  94, 137, 154], dtype=uint8), 5],
#  [array([ 71,  62,  48, ..., 119, 113, 106], dtype=uint8), 2],
#  [array([253, 255, 255, ...,  66,  69,  54], dtype=uint8), 3],
#  [array([21, 12,  8, ..., 44, 80, 90], dtype=uint8), 0],
#  [array([122, 180, 186, ...,  72,  84,  94], dtype=uint8), 5],
#  [array([182, 149, 153, ...,   6,  22,  39], dtype=uint8), 1],
#  [array([205, 255, 248, ...,  32,  71,  46], dtype=uint8), 1],
#  [array([155, 103,  56, ..., 119, 102,  93], dtype=uint8), 2],
#  [array([ 28,  66,  60, ...,  51, 100,  72], dtype=uint8), 1],
#  [array([250, 141,  35, ..., 153, 156, 160], dtype=uint8), 3],
#  [array([3, 3, 3, ..., 0, 0, 0], dtype=uint8), 0],
#  [array([4, 9, 7, ..., 0, 4, 3], dtype=uint8), 3],
#  [array([ 16,  40,  30, ...,  11, 107,  53], dtype=uint8), 1],
#  [array([246, 240, 233, ..., 201, 210, 220], dtype=uint8), 3],
#  [array([ 3, 31,  2, ..., 48, 60, 64], dtype=uint8), 1],
#  [array([175, 197, 233, ..., 125, 130, 133], dtype=uint8), 5],
#  [array([155, 142, 126, ...,  96,  93,  62], dtype=uint8), 2],
#  [array([50, 50, 50, ...,  0,  0,  0], dtype=uint8), 5],
#  [array([11, 13,  7, ..., 62, 56, 49], dtype=uint8), 5],
#  [array([143,  84,  39, ..., 183, 228, 255], dtype=uint8), 0],
#  [array([158, 163, 162, ...,  42,  37,  36], dtype=uint8), 5],
#  [array([132, 104,  73, ...,   4,   1,   3], dtype=uint8), 4],
#  [array([213, 216, 207, ...,   0,  12,   1], dtype=uint8), 3],
#  [array([193, 115,  39, ..., 142, 124,  71], dtype=uint8), 2],
#  [array([ 94,  59,  15, ..., 178, 178, 184], dtype=uint8), 2],
#  [array([146, 130, 117, ...,  29,  20,  10], dtype=uint8), 2],
#  [array([118, 118, 118, ...,   0,   0,   0], dtype=uint8), 0],
#  [array([164, 147, 126, ...,  10,   5,  14], dtype=uint8), 4],
#  [array([163, 126, 130, ...,  45,  32,  30], dtype=uint8), 4],
#  [array([226, 189, 145, ...,  26,  44,  45], dtype=uint8), 3],
#  [array([201, 198, 193, ...,  36,  53,  62], dtype=uint8), 0],
#  [array([255, 255, 255, ..., 143, 110,   0], dtype=uint8), 2],
#  [array([236, 165,  97, ..., 133, 140, 143], dtype=uint8), 5],
#  [array([220, 216, 205, ...,  58,  61,  52], dtype=uint8), 0],
#  [array([122, 125, 130, ...,  11,  20,  30], dtype=uint8), 4],
#  [array([221, 222, 196, ...,  89, 148, 164], dtype=uint8), 4],
#  [array([ 49, 108,  63, ...,  16,  26,  14], dtype=uint8), 1],
#  [array([138, 111,  90, ..., 111, 170, 185], dtype=uint8), 4],
#  [array([212, 165, 113, ...,  25,  59,  52], dtype=uint8), 2],
#  [array([152,  94,  45, ..., 253, 253, 253], dtype=uint8), 3],
#  [array([247, 196,  40, ..., 169, 173, 174], dtype=uint8), 0],
#  [array([223, 201, 173, ..., 126, 129, 143], dtype=uint8), 5],
#  [array([255, 255, 255, ...,  84,  79,  80], dtype=uint8), 5],
#  [array([188, 196, 186, ...,  21,  44,  40], dtype=uint8), 3],
#  [array([147, 153, 158, ...,  42,  36,  23], dtype=uint8), 3],
#  [array([64, 90, 50, ..., 19, 46, 26], dtype=uint8), 1],
#  [array([252, 252, 252, ...,  11,  12,  10], dtype=uint8), 3],
#  [array([169, 170, 144, ...,  87,  98,  82], dtype=uint8), 3],
#  [array([253, 211, 176, ...,  55, 100, 133], dtype=uint8), 3],
#  [array([ 0, 43, 27, ..., 36, 86, 76], dtype=uint8), 1],
#  [array([112,  66,  32, ...,   4,  11,  14], dtype=uint8), 4],
#  [array([ 94, 127,  93, ...,  17,  71,  36], dtype=uint8), 1],
#  [array([245, 228, 219, ..., 190, 174, 157], dtype=uint8), 2],
#  [array([231, 213, 206, ...,  25,  66,  89], dtype=uint8), 0],
#  [array([194, 199, 198, ...,  18,  26,  33], dtype=uint8), 4],
#  [array([130, 138, 137, ...,  31,  33,  33], dtype=uint8), 1],
#  [array([ 4,  5,  9, ..., 58, 60, 61], dtype=uint8), 5],
#  [array([205, 219, 207, ...,   2,   5,   9], dtype=uint8), 3],
#  [array([205, 187, 210, ..., 244, 228, 246], dtype=uint8), 0],
#  [array([252, 203, 165, ...,   1,   1,   1], dtype=uint8), 3],
#  [array([252, 255, 253, ..., 123, 142, 147], dtype=uint8), 0],
#  [array([ 53,  37,  14, ...,  77,  96, 109], dtype=uint8), 0],
#  [array([ 10, 105,  78, ...,   0,  49,  46], dtype=uint8), 1],
#  [array([ 62,  69,  84, ..., 132, 151, 172], dtype=uint8), 5],
#  [array([111,  64,  37, ...,  36,  69,  88], dtype=uint8), 4],
#  [array([114, 118, 137, ...,  81, 106, 108], dtype=uint8), 5],
#  [array([207, 166, 143, ...,  30,  21,  24], dtype=uint8), 2],
#  [array([99, 55, 32, ..., 29, 32, 37], dtype=uint8), 4],
#  [array([208, 204, 203, ...,  93,  82,  84], dtype=uint8), 4],
#  [array([253, 241, 231, ...,  43,  31,  21], dtype=uint8), 0],
#  [array([117, 128, 118, ..., 183, 187, 188], dtype=uint8), 5],
#  [array([149,  96,  63, ...,  51,  71,  82], dtype=uint8), 2],
#  [array([138,  78,   8, ...,  87,  88,  92], dtype=uint8), 4],
#  [array([1, 1, 1, ..., 8, 7, 9], dtype=uint8), 5],
#  [array([227, 218, 215, ...,  91,  98, 115], dtype=uint8), 4],
#  [array([232, 227, 228, ...,  65, 104,  79], dtype=uint8), 3],
#  [array([182, 181, 183, ...,  21,  23,  23], dtype=uint8), 4],
#  [array([245, 246, 230, ...,  47,  49,  37], dtype=uint8), 5],
#  [array([118, 136, 159, ...,  17,  21,  22], dtype=uint8), 3],
#  [array([203, 169, 145, ...,  30,  47,  50], dtype=uint8), 3],
#  [array([127, 139, 141, ...,  95,  92, 101], dtype=uint8), 5],
#  [array([225, 211, 213, ..., 254, 254, 254], dtype=uint8), 2],
#  [array([45, 26, 23, ..., 91, 76, 73], dtype=uint8), 2],
#  [array([ 3, 12, 15, ..., 22, 20, 19], dtype=uint8), 1],
#  [array([127, 136, 146, ...,  61,  62,  60], dtype=uint8), 5],
#  [array([34, 13,  5, ..., 45, 26, 23], dtype=uint8), 4],
#  [array([251, 201, 111, ...,   0,   0,   0], dtype=uint8), 3],
#  [array([99, 43, 14, ..., 75, 32, 15], dtype=uint8), 2],
#  [array([233, 187, 146, ...,  74,  78,  73], dtype=uint8), 5],
#  [array([223, 207, 178, ...,  84, 128, 169], dtype=uint8), 3],
#  [array([215, 162, 112, ..., 129, 133, 134], dtype=uint8), 2],
#  [array([46, 54, 43, ..., 23, 74, 60], dtype=uint8), 1],
#  [array([ 69,  87, 124, ...,  56,  67,  99], dtype=uint8), 5],
#  [array([ 89,  85,  84, ...,  59,  85, 101], dtype=uint8), 4],
#  [array([ 94,  44,  22, ..., 118, 115, 110], dtype=uint8), 4],
#  [array([54, 49, 48, ..., 13, 13, 13], dtype=uint8), 5],
#  [array([152, 206, 176, ...,  14,  32,  43], dtype=uint8), 1],
#  [array([11,  7,  6, ..., 61, 45, 39], dtype=uint8), 2],
#  [array([180, 119,  55, ..., 183, 198, 200], dtype=uint8), 4],
#  [array([ 91, 125, 119, ..., 115, 111, 116], dtype=uint8), 0],
#  [array([174, 116,  74, ...,  29,  38,  48], dtype=uint8), 3],
#  [array([145, 164, 185, ...,   4,  19,  15], dtype=uint8), 5],
#  [array([31, 33, 43, ..., 19, 17, 17], dtype=uint8), 5],
#  [array([141, 152, 150, ..., 116, 130, 118], dtype=uint8), 2],
#  [array([ 85, 135, 155, ..., 162, 163, 167], dtype=uint8), 5],
#  [array([19, 48, 69, ..., 41, 51, 61], dtype=uint8), 5],
#  [array([124, 133, 143, ...,  41,  44,  52], dtype=uint8), 5],
#  [array([173, 183, 190, ..., 203, 246, 255], dtype=uint8), 5],
#  [array([221, 172, 126, ...,  17,  16,  18], dtype=uint8), 3],
#  [array([ 79,  58,  43, ..., 150, 204, 245], dtype=uint8), 4],
#  [array([ 86,  90,  95, ...,  35, 112,  98], dtype=uint8), 1],
#  [array([73, 73, 79, ..., 49, 61, 67], dtype=uint8), 1],
#  [array([224, 103,   0, ...,   0,   0,   0], dtype=uint8), 0],
#  [array([ 94, 119, 123, ...,  15,  43,  73], dtype=uint8), 1],
#  [array([234, 202, 183, ..., 157, 154, 149], dtype=uint8), 3],
#  [array([244, 208, 148, ..., 169, 175, 186], dtype=uint8), 3],
#  [array([168, 157, 153, ..., 210, 215, 214], dtype=uint8), 2],
#  [array([173, 180, 173, ..., 117, 139, 164], dtype=uint8), 4],
#  [array([233, 215, 198, ..., 209, 192, 173], dtype=uint8), 3],
#  [array([135, 111,  91, ..., 106,  96,  89], dtype=uint8), 4],
#  [array([  1,  10,   0, ..., 175, 191, 234], dtype=uint8), 5],
#  [array([108,  80,  45, ..., 249, 245, 240], dtype=uint8), 2],
#  [array([104, 133, 137, ..., 137, 121, 105], dtype=uint8), 2],
#  [array([238, 230, 223, ..., 158, 150, 103], dtype=uint8), 4],
#  [array([158, 148,  71, ...,  27,  60,  99], dtype=uint8), 4],
#  [array([ 28,  85,  77, ...,  41,  75, 111], dtype=uint8), 1],
#  [array([228, 207, 192, ...,  32,  48,  54], dtype=uint8), 3],
#  [array([175, 170, 172, ..., 114, 120, 127], dtype=uint8), 2],
#  [array([186, 154, 125, ...,   8,  10,  10], dtype=uint8), 0],
#  [array([177, 128,  78, ...,  33,  35,  35], dtype=uint8), 3],
#  [array([244, 239, 238, ...,  75,  49,  62], dtype=uint8), 5],
#  [array([212, 201, 197, ..., 112,  83,  68], dtype=uint8), 3],
#  [array([117, 153, 183, ...,  61,  72,  99], dtype=uint8), 5],
#  [array([169, 161, 161, ...,   0,  10,  10], dtype=uint8), 3],
#  [array([50, 51, 49, ..., 92, 84, 84], dtype=uint8), 0],
#  [array([168, 167, 169, ...,   0,   2,   2], dtype=uint8), 3],
#  [array([ 48,  22,  16, ..., 180, 186, 131], dtype=uint8), 2],
#  [array([17, 26, 23, ..., 45, 49, 60], dtype=uint8), 1],
#  [array([113,  67,  73, ...,  17,  50,  59], dtype=uint8), 3],
#  [array([153, 128, 138, ...,  53,  79,  61], dtype=uint8), 1],
#  [array([ 7,  9, 10, ..., 26, 25, 27], dtype=uint8), 5],
#  [array([250, 250, 250, ...,  43,  46,  50], dtype=uint8), 5],
#  [array([117,  75,  46, ...,  72,  47,  43], dtype=uint8), 3],
#  [array([129, 103, 117, ...,  62,  62,  78], dtype=uint8), 0],
#  [array([242, 219, 211, ...,  72,  88,  71], dtype=uint8), 2],
#  [array([124, 124, 136, ...,   2,   0,   0], dtype=uint8), 1],
#  [array([215, 206, 203, ...,  77,  70,  53], dtype=uint8), 2],
#  [array([93, 47,  0, ..., 60, 71, 68], dtype=uint8), 4],
#  [array([144, 144, 144, ...,   0,   0,   0], dtype=uint8), 5],
#  [array([212, 223, 220, ...,  57,  87,  88], dtype=uint8), 0],
#  [array([102,  83,  78, ...,   0,   0,   3], dtype=uint8), 4],
#  [array([179, 152, 186, ...,   8,  12,  17], dtype=uint8), 4],
#  [array([29, 52, 84, ..., 27, 51, 71], dtype=uint8), 5],
#  [array([207, 154, 121, ..., 189, 180, 177], dtype=uint8), 2],
#  [array([ 0,  5,  0, ...,  2, 22, 10], dtype=uint8), 1],
#  [array([ 0, 72, 14, ...,  7, 63, 10], dtype=uint8), 1],
#  [array([61,  8,  5, ..., 12, 52, 94], dtype=uint8), 5],
#  [array([237, 220, 217, ..., 193, 188, 197], dtype=uint8), 3],
#  [array([ 23,  26,  34, ...,  92, 143, 159], dtype=uint8), 1],
#  [array([181, 181, 181, ..., 127, 127, 127], dtype=uint8), 4],
#  [array([225, 221, 220, ...,  84,  82,  82], dtype=uint8), 0],
#  [array([228, 184, 125, ...,  87,  86,  60], dtype=uint8), 4],
#  [array([245, 245, 245, ...,  47,  68,  90], dtype=uint8), 0],
#  [array([167, 167, 167, ..., 134, 134, 134], dtype=uint8), 4],
#  [array([216, 228, 232, ...,  34,  25,   5], dtype=uint8), 4],
#  [array([218, 211, 218, ...,  16,  61,  65], dtype=uint8), 5],
#  [array([230, 208, 197, ..., 220, 206, 208], dtype=uint8), 4],
#  [array([225, 239, 237, ...,  69,  65,  54], dtype=uint8), 0],
#  [array([ 32,  25,  22, ..., 101,  89,  77], dtype=uint8), 2],
#  [array([38, 36, 28, ..., 14, 20, 25], dtype=uint8), 4],
#  [array([237, 178, 132, ...,  11,   9,   9], dtype=uint8), 3],
#  [array([ 0,  7,  4, ..., 36, 41, 42], dtype=uint8), 5],
#  [array([ 24,   8,   0, ..., 165, 149, 120], dtype=uint8), 2],
#  [array([224, 198, 174, ...,  57,  75,  76], dtype=uint8), 0],
#  [array([200, 216, 233, ..., 102,  81,  53], dtype=uint8), 4],
#  [array([235, 218, 215, ...,  73,  62,  65], dtype=uint8), 0],
#  [array([107,  97,  97, ...,  64,  63,  65], dtype=uint8), 4],
#  [array([170,  86,  38, ..., 230, 225, 224], dtype=uint8), 3],
#  [array([ 58,  70,  70, ...,  72, 120, 122], dtype=uint8), 1],
#  [array([11, 21, 21, ..., 57, 62, 53], dtype=uint8), 0],
#  [array([  8,  22,  18, ..., 123,  74,  36], dtype=uint8), 2],
#  [array([192, 187, 184, ...,  35,  74,  88], dtype=uint8), 3],
#  [array([112,  83, 122, ...,  54,  72, 135], dtype=uint8), 5],
#  [array([213, 251, 251, ...,  44,  26,  15], dtype=uint8), 5],
#  [array([122,  63,  17, ...,   0,  14,  30], dtype=uint8), 4],
#  [array([192, 201, 198, ...,   8,  18,  35], dtype=uint8), 4],
#  [array([153, 132, 124, ...,  80, 101,  93], dtype=uint8), 1],
#  [array([206, 194, 176, ...,  93,  86,  77], dtype=uint8), 3],
#  [array([194, 173, 151, ..., 185, 162, 136], dtype=uint8), 5],
#  [array([224, 209, 193, ...,  20,  22,  22], dtype=uint8), 2],
#  [array([253, 240, 218, ...,  88,  96,  96], dtype=uint8), 3],
#  [array([ 44,  55,  47, ..., 177, 187, 204], dtype=uint8), 5],
#  [array([183, 178, 163, ...,  26,  44,  31], dtype=uint8), 2],
#  [array([237, 208, 181, ..., 171, 156, 137], dtype=uint8), 2],
#  [array([214, 210, 209, ...,   9,  34,  38], dtype=uint8), 3],
#  [array([242, 227, 224, ...,  35,  41,  40], dtype=uint8), 2],
#  [array([ 83,  65,  28, ..., 159, 141, 104], dtype=uint8), 4],
#  [array([98, 87, 55, ...,  5,  2, 11], dtype=uint8), 0],
#  [array([252, 229, 207, ...,  27,  31,  20], dtype=uint8), 3],
#  [array([20, 20, 14, ..., 74, 75, 89], dtype=uint8), 1],
#  [array([24, 48, 30, ..., 36, 35, 45], dtype=uint8), 1],
#  [array([210, 212, 213, ...,  27,  68,  60], dtype=uint8), 2],
#  [array([142, 115, 111, ..., 161, 166, 165], dtype=uint8), 2],
#  [array([ 59,  74,  66, ..., 114, 120, 127], dtype=uint8), 2],
#  [array([76, 74, 64, ..., 61, 67, 62], dtype=uint8), 1],
#  [array([ 86,  94,  94, ..., 137, 118, 113], dtype=uint8), 5],
#  [array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), 4],
#  [array([196, 132,  68, ...,  32,  26,  19], dtype=uint8), 2],
#  [array([164, 206, 218, ...,   0,   0,   0], dtype=uint8), 3],
#  [array([30, 37, 30, ...,  8, 20, 48], dtype=uint8), 5],
#  [array([49, 52, 66, ...,  0,  0,  0], dtype=uint8), 5],
#  [array([174, 147, 113, ..., 236, 242, 225], dtype=uint8), 4],
#  [array([98, 49, 11, ..., 67, 64, 66], dtype=uint8), 3],
#  [array([0, 3, 5, ..., 0, 1, 0], dtype=uint8), 5],
#  [array([161, 161, 161, ..., 100, 100, 100], dtype=uint8), 4],
#  [array([250, 255, 246, ...,  64,  78,  76], dtype=uint8), 3],
#  [array([ 49, 103, 126, ..., 129, 149, 154], dtype=uint8), 0],
#  [array([226, 226, 226, ...,   0,   0,   0], dtype=uint8), 1],
#  [array([8, 4, 0, ..., 1, 2, 0], dtype=uint8), 5],
#  [array([ 10,  23,   7, ...,  94, 114, 145], dtype=uint8), 1],
#  [array([149, 146, 148, ...,  26,  28,  28], dtype=uint8), 5],
#  [array([128, 113,  94, ..., 124, 125, 123], dtype=uint8), 0],
#  [array([197, 185, 183, ...,   9,   9,   9], dtype=uint8), 3],
#  [array([ 39,  52,  68, ...,  65, 122, 147], dtype=uint8), 5],
#  [array([ 4,  0,  8, ..., 15, 45, 64], dtype=uint8), 5],
#  [array([ 51,  46,  43, ..., 183, 177, 178], dtype=uint8), 1],
#  [array([47, 45, 44, ..., 10,  3, 18], dtype=uint8), 1],
#  [array([217, 212, 209, ..., 173, 176, 184], dtype=uint8), 4],
#  [array([ 15,  16,   6, ..., 201, 185, 186], dtype=uint8), 5],
#  [array([228, 215, 207, ...,  38,  52,  41], dtype=uint8), 2],
#  [array([186, 210, 216, ...,   0,   0,   0], dtype=uint8), 3],
#  [array([197, 162, 142, ...,  44,  41,  36], dtype=uint8), 4],
#  [array([164, 160, 155, ...,  85,  85,  85], dtype=uint8), 3],
#  [array([80, 77, 79, ..., 61, 72, 76], dtype=uint8), 3],
#  [array([143, 142, 132, ..., 112,  90,  65], dtype=uint8), 2],
#  [array([223, 203, 185, ..., 161, 154, 134], dtype=uint8), 2],
#  [array([175, 162, 160, ...,  22,  33,  37], dtype=uint8), 1],
#  [array([18,  7, 23, ..., 79, 96, 75], dtype=uint8), 1],
#  [array([40, 40, 26, ..., 88, 82, 77], dtype=uint8), 1],
#  [array([212, 217, 218, ...,   9,  26,  52], dtype=uint8), 1],
#  [array([210, 131,   4, ...,   1,   0,   7], dtype=uint8), 3],
#  [array([26, 20, 21, ...,  9,  9,  9], dtype=uint8), 0],
#  [array([217, 218, 216, ..., 166, 163, 155], dtype=uint8), 2],
#  [array([114, 153, 115, ...,   0,  48,  34], dtype=uint8), 1],
#  [array([226, 216, 198, ..., 118, 140, 151], dtype=uint8), 0],
#  [array([248, 248, 248, ..., 140, 151, 183], dtype=uint8), 0],
#  [array([ 82, 141, 143, ...,  61, 105, 122], dtype=uint8), 5],
#  [array([252, 161, 110, ..., 108,  78,  67], dtype=uint8), 3],
#  [array([242, 250, 250, ..., 110, 104,  63], dtype=uint8), 5],
#  [array([135,  79,   0, ...,  18,   5,   3], dtype=uint8), 3],
#  [array([131, 156, 172, ...,   2,  16,  14], dtype=uint8), 0],
#  [array([ 97,  83,  87, ...,  97, 187, 157], dtype=uint8), 2],
#  [array([244, 184, 148, ...,  94,  69,  49], dtype=uint8), 2],
#  [array([246, 241, 216, ...,   6,  45,  29], dtype=uint8), 2],
#  [array([83, 85, 86, ..., 89, 87, 86], dtype=uint8), 4],
#  [array([157,  79,   3, ..., 165, 111, 134], dtype=uint8), 3],
#  [array([202, 151,  88, ...,   0,  10,   4], dtype=uint8), 3],
#  [array([ 0,  0, 14, ...,  6,  6,  6], dtype=uint8), 5],
#  [array([212, 206, 207, ..., 163, 144, 139], dtype=uint8), 4],
#  [array([150, 125,  93, ...,  27,  22,  23], dtype=uint8), 4],
#  [array([51, 63, 99, ..., 18, 13, 15], dtype=uint8), 0],
#  [array([193, 153, 118, ..., 167, 178, 182], dtype=uint8), 2],
#  [array([231, 218, 192, ..., 183, 230, 255], dtype=uint8), 4],
#  [array([185, 176, 166, ...,  27,  32,  31], dtype=uint8), 4],
#  [array([237, 125,  72, ...,  19,  62,  47], dtype=uint8), 3],
#  [array([255, 255, 254, ..., 118, 111, 114], dtype=uint8), 2],
#  [array([182, 125,  80, ...,   9,   0,   0], dtype=uint8), 2],
#  [array([ 0,  9,  0, ..., 22, 52, 23], dtype=uint8), 1],
#  [array([173, 127,  80, ...,  85,  75,  35], dtype=uint8), 4],
#  [array([251, 255, 246, ...,  34,  29,  28], dtype=uint8), 5],
#  [array([190, 170, 169, ...,  68, 132, 137], dtype=uint8), 3],
#  [array([232, 254, 255, ..., 231, 250, 255], dtype=uint8), 1],
#  [array([147, 147, 147, ...,  39,  39,  39], dtype=uint8), 0],
#  [array([70, 29, 66, ..., 52, 12, 37], dtype=uint8), 0],
#  [array([227, 229, 223, ..., 121, 157, 143], dtype=uint8), 1],
#  [array([222, 200, 189, ...,  41,  80,  82], dtype=uint8), 3],
#  [array([177,  62,   1, ...,  49,  83,  99], dtype=uint8), 3],
#  [array([  9, 135,  39, ...,  57, 137,  78], dtype=uint8), 1],
#  [array([250, 233, 230, ...,  21,  27,  32], dtype=uint8), 0],
#  [array([139, 147, 146, ...,  80,  65,  49], dtype=uint8), 4],
#  [array([155, 143, 125, ..., 166, 157, 143], dtype=uint8), 2],
#  [array([166, 137, 100, ..., 241, 237, 236], dtype=uint8), 2],
#  [array([219, 139, 114, ...,  58,  77, 138], dtype=uint8), 0],
#  [array([204, 190, 178, ..., 133, 129, 128], dtype=uint8), 5],
#  [array([233, 191, 146, ..., 100, 115, 118], dtype=uint8), 3],
#  [array([ 88, 149, 183, ..., 117, 151, 211], dtype=uint8), 5],
#  [array([217, 208, 204, ...,  42,  75,  90], dtype=uint8), 3],
#  [array([ 40, 107, 140, ...,  18,   9,   6], dtype=uint8), 0],
#  [array([232, 209, 163, ...,   0,  44,   0], dtype=uint8), 1],
#  [array([152, 225, 253, ..., 106, 160, 183], dtype=uint8), 1],
#  [array([112,  68,  39, ...,  19,  14,  11], dtype=uint8), 3],
#  [array([145, 145, 145, ...,  92,  92,  92], dtype=uint8), 5],
#  [array([119, 104,  85, ...,  23,   0,  82], dtype=uint8), 0],
#  [array([134, 122, 120, ...,  29,   3,   3], dtype=uint8), 4],
#  [array([254, 228, 211, ...,  26,  23,  68], dtype=uint8), 0],
#  [array([219, 209, 209, ...,  88,  88,  82], dtype=uint8), 2],
#  [array([223, 195, 171, ...,   2,   4,   5], dtype=uint8), 3],
#  [array([ 82, 172, 142, ..., 110, 150, 155], dtype=uint8), 1],
#  [array([ 9,  9,  9, ..., 74, 74, 74], dtype=uint8), 5],
#  [array([82, 84, 84, ..., 51, 57, 76], dtype=uint8), 1],
#  [array([ 98,  94,  83, ..., 123, 117, 106], dtype=uint8), 5],
#  [array([ 96, 205, 189, ...,  65, 150, 136], dtype=uint8), 1],
#  [array([148, 135, 119, ...,   3,  32,  37], dtype=uint8), 1],
#  [array([138, 138, 138, ...,  24,  24,  24], dtype=uint8), 5],
#  [array([79, 61, 20, ..., 12, 21, 30], dtype=uint8), 4],
#  [array([211, 214, 218, ...,  48,  54,  53], dtype=uint8), 3],
#  [array([222, 252, 255, ...,   0,  10,  27], dtype=uint8), 1],
#  [array([228, 139,  88, ...,  76,  58,  47], dtype=uint8), 2],
#  [array([211, 175, 165, ...,  35,  66,  59], dtype=uint8), 3],
#  [array([ 0, 93, 16, ...,  0, 34,  6], dtype=uint8), 1],
#  [array([188, 161, 151, ...,  86,  78,  78], dtype=uint8), 3],
#  [array([234, 192, 149, ...,  84, 107, 103], dtype=uint8), 3],
#  [array([88, 79, 99, ..., 54, 47, 50], dtype=uint8), 0],
#  [array([254, 195, 126, ...,  59,  87, 104], dtype=uint8), 0],
#  [array([209, 187, 182, ..., 136, 114, 108], dtype=uint8), 2],
#  [array([148, 130, 119, ...,   5,  10,   9], dtype=uint8), 3],
#  [array([183, 140, 167, ...,  85,  60,  70], dtype=uint8), 4],
#  [array([252, 250, 250, ...,  26,  12,  23], dtype=uint8), 3],
#  [array([10, 14,  8, ..., 30, 42, 44], dtype=uint8), 1],
#  [array([ 15,  34,  25, ..., 107, 108,  99], dtype=uint8), 5],
#  [array([237, 239, 240, ...,  85,  90,  99], dtype=uint8), 5],
#  [array([114, 109, 118, ...,  92, 105,  97], dtype=uint8), 1],
#  [array([9, 5, 4, ..., 0, 0, 0], dtype=uint8), 0],
#  [array([ 87,  95, 112, ...,  85,  79,  74], dtype=uint8), 5],
#  [array([ 60,  90, 109, ...,  14,  23,  43], dtype=uint8), 5],
#  [array([157, 145, 141, ...,  16,  21,  24], dtype=uint8), 3],
#  [array([255, 249, 240, ...,  83,  70,  78], dtype=uint8), 3],
#  [array([70, 84, 96, ...,  3,  2,  0], dtype=uint8), 5],
#  [array([ 56,  75, 120, ...,   3,   6,  27], dtype=uint8), 5],
#  [array([206, 199, 196, ..., 120, 140, 157], dtype=uint8), 0],
#  [array([95, 70, 68, ..., 92, 95, 86], dtype=uint8), 2],
#  [array([22, 31, 41, ..., 11, 23, 23], dtype=uint8), 1],
#  [array([63, 63, 63, ..., 52, 52, 52], dtype=uint8), 1],
#  [array([225, 165, 143, ...,  29,  42,  68], dtype=uint8), 3],
#  [array([178, 146, 111, ...,  45,  46,  42], dtype=uint8), 0],
#  [array([222, 227, 230, ...,   3,  22,  43], dtype=uint8), 1],
#  [array([  0,  69,  47, ...,  47, 189, 154], dtype=uint8), 1],
#  [array([187,  72,   5, ..., 189, 200, 214], dtype=uint8), 4],
#  [array([ 35,  66,  57, ...,  68, 132, 132], dtype=uint8), 1],
#  [array([170, 125, 111, ..., 175,  93,  68], dtype=uint8), 3],
#  [array([ 14,  11,  26, ...,  58, 118,  84], dtype=uint8), 0],
#  [array([218, 200, 183, ...,  89,  78,  70], dtype=uint8), 0],
#  [array([181, 160, 122, ...,  13,  58,  69], dtype=uint8), 3],
#  [array([196, 117,  78, ...,  43,  51,  51], dtype=uint8), 3],
#  [array([213, 189, 165, ...,  14,  23,  26], dtype=uint8), 3],
#  [array([108, 115, 110, ...,  80,  75,  74], dtype=uint8), 5],
#  [array([252, 190, 136, ..., 163, 196, 216], dtype=uint8), 0],
#  [array([154, 154, 154, ...,  14,  14,  14], dtype=uint8), 5],
#  [array([189, 143,  85, ..., 176, 134,  97], dtype=uint8), 2],
#  [array([160, 159, 155, ..., 156, 149, 134], dtype=uint8), 2],
#  [array([253, 171,  93, ...,  72,  72,  72], dtype=uint8), 2],
#  [array([196, 137, 105, ..., 106, 128, 139], dtype=uint8), 0],
#  [array([198, 191, 188, ...,   1,   4,   2], dtype=uint8), 3],
#  [array([ 65,  82,  73, ..., 195, 193, 213], dtype=uint8), 1],
#  [array([33, 63, 50, ..., 19, 22, 13], dtype=uint8), 1],
#  [array([135,  85,   2, ...,  42,  51,  71], dtype=uint8), 2],
#  [array([114, 139, 119, ...,  70,  66,  65], dtype=uint8), 1],
#  [array([229, 197, 156, ..., 123, 100,  74], dtype=uint8), 3],
#  [array([223, 229, 228, ...,   2,   3,   7], dtype=uint8), 4],
#  [array([146, 128, 117, ...,  39,  34,  33], dtype=uint8), 5],
#  [array([44, 54, 42, ..., 50, 56, 39], dtype=uint8), 1],
#  [array([16, 38, 50, ..., 42, 67, 87], dtype=uint8), 5],
#  [array([137, 125, 115, ...,  35,  39,  44], dtype=uint8), 4],
#  [array([233, 199, 146, ...,  47,  40,  37], dtype=uint8), 0],
#  [array([255, 247, 243, ..., 121, 170, 180], dtype=uint8), 3],
#  [array([ 82,  82,  82, ..., 145, 145, 145], dtype=uint8), 5],
#  [array([229, 206, 168, ...,  41,  34,  14], dtype=uint8), 4],
#  [array([42, 54, 24, ..., 20, 35,  3], dtype=uint8), 4],
#  [array([ 72,  74,  82, ...,  21,  58, 116], dtype=uint8), 1],
#  [array([92, 45, 17, ..., 59, 53, 54], dtype=uint8), 3],
#  [array([91, 63, 39, ...,  0,  0,  0], dtype=uint8), 0],
#  [array([196, 178, 167, ...,  37,  43,  48], dtype=uint8), 0],
#  [array([210, 197, 183, ...,  92, 102, 119], dtype=uint8), 5],
#  [array([6, 0, 5, ..., 2, 0, 1], dtype=uint8), 5],
#  [array([191, 133,  27, ..., 206, 233, 247], dtype=uint8), 4],
#  [array([253, 253, 253, ...,   8,  29,  31], dtype=uint8), 3],
#  [array([10,  9, 13, ..., 78, 93, 65], dtype=uint8), 1],
#  [array([222, 196, 214, ...,  37,  54,  87], dtype=uint8), 0],
#  [array([205, 192, 184, ...,  26,  26,  26], dtype=uint8), 4],
#  [array([107,  96,  92, ...,  37,  33,  28], dtype=uint8), 2],
#  [array([ 21,  31,  38, ..., 151, 163, 165], dtype=uint8), 5],
#  [array([216, 206, 218, ..., 178, 184, 183], dtype=uint8), 1],
#  [array([240, 226, 208, ..., 210, 205, 190], dtype=uint8), 2],
#  [array([250, 234, 218, ..., 199, 204, 203], dtype=uint8), 5],
#  [array([220, 225, 228, ..., 130, 126, 125], dtype=uint8), 2],
#  [array([193, 172, 164, ..., 116, 102,  96], dtype=uint8), 2],
#  [array([39, 46, 49, ...,  5,  5,  5], dtype=uint8), 5],
#  [array([243, 225, 218, ...,   5,   9,  10], dtype=uint8), 0],
#  [array([234, 208, 178, ...,  28,  27,  29], dtype=uint8), 0],
#  [array([ 22,  22,  16, ..., 162, 138, 120], dtype=uint8), 2],
#  [array([197, 191, 178, ..., 169, 142, 138], dtype=uint8), 0],
#  [array([145, 126, 119, ...,  94,  78,  65], dtype=uint8), 2],
#  [array([255, 254, 249, ..., 108,  89,  82], dtype=uint8), 5],
#  [array([47, 76, 60, ..., 28, 44, 33], dtype=uint8), 1],
#  [array([215, 232, 255, ..., 255, 255, 226], dtype=uint8), 0],
#  [array([90, 66, 48, ..., 47, 30, 11], dtype=uint8), 3],
#  [array([211, 187, 187, ...,   1,   9,   8], dtype=uint8), 2],
#  [array([ 0,  4,  3, ...,  5, 14, 17], dtype=uint8), 5],
#  [array([198, 167, 144, ...,  58,  40,  33], dtype=uint8), 4],
#  [array([202, 212, 222, ...,  80,  78,  78], dtype=uint8), 3],
#  [array([74, 75, 73, ..., 72, 73, 71], dtype=uint8), 5],
#  [array([177, 122,  83, ...,  69,  76,  69], dtype=uint8), 5],
#  [array([147, 128, 120, ...,  17,  54, 106], dtype=uint8), 4],
#  [array([196, 226, 221, ...,  10,  55,  68], dtype=uint8), 2],
#  [array([180, 159, 132, ...,  23,  46,  41], dtype=uint8), 3],
#  [array([196, 161, 158, ..., 137, 142, 145], dtype=uint8), 5],
#  [array([22, 22, 22, ..., 21, 21, 21], dtype=uint8), 5],
#  [array([43, 54, 81, ..., 37, 37, 37], dtype=uint8), 5],
#  [array([252, 246, 217, ...,  94, 109, 118], dtype=uint8), 3],
#  [array([199, 112,  45, ...,  76,  56,  45], dtype=uint8), 0],
#  [array([255, 255, 255, ...,  29,  42,  50], dtype=uint8), 3],
#  [array([ 41,  73,  62, ..., 215, 193, 211], dtype=uint8), 1],
#  [array([ 5,  9, 10, ..., 11,  5,  0], dtype=uint8), 5],
#  [array([219, 189, 154, ...,  92,  78,  82], dtype=uint8), 4],
#  [array([20, 21, 19, ..., 19, 26, 29], dtype=uint8), 1],
#  [array([235, 211, 181, ...,  20,  18,  17], dtype=uint8), 2],
#  [array([255, 255, 255, ..., 182, 182, 182], dtype=uint8), 0],
#  [array([188, 149, 105, ...,  64,  56,  49], dtype=uint8), 2],
#  [array([239, 212, 198, ...,  87,  91,  92], dtype=uint8), 0],
#  [array([40, 46, 41, ..., 73, 97, 57], dtype=uint8), 1],
#  [array([117,  85,  74, ...,  97,  80,  71], dtype=uint8), 4],
#  [array([ 56,  67,  71, ..., 195, 195, 195], dtype=uint8), 4],
#  [array([139, 151, 155, ...,  55,  72,  75], dtype=uint8), 1],
#  [array([181, 182, 173, ...,  11,  25,  13], dtype=uint8), 2],
#  [array([ 0,  3,  1, ...,  0, 50, 72], dtype=uint8), 4],
#  [array([153, 159, 166, ...,  41,  51,  68], dtype=uint8), 1],
#  [array([28, 32, 26, ..., 83, 74, 65], dtype=uint8), 1],
#  [array([220, 159,  95, ...,  35,  23,  17], dtype=uint8), 3],
#  [array([103,  81,  75, ...,  57,  49,  59], dtype=uint8), 0],
#  [array([226, 168, 126, ...,  57,  45,  35], dtype=uint8), 0],
#  [array([102,  61,  28, ...,  64,  76,  76], dtype=uint8), 2],
#  [array([225, 213, 203, ..., 139, 137, 127], dtype=uint8), 2],
#  [array([203, 184, 169, ..., 151, 143, 120], dtype=uint8), 4],
#  [array([ 3, 10,  5, ...,  4,  3,  5], dtype=uint8), 5],
#  [array([240, 240, 240, ..., 174, 174, 174], dtype=uint8), 4],
#  [array([128,  90,  58, ...,  31,  20,  16], dtype=uint8), 0],
#  [array([101,  72,  67, ...,  79,  74,  59], dtype=uint8), 2],
#  [array([149, 136, 128, ...,  71,  57,  38], dtype=uint8), 3],
#  [array([227, 222, 221, ..., 108, 117, 127], dtype=uint8), 0],
#  [array([205, 198, 171, ..., 245, 245, 233], dtype=uint8), 4],
#  [array([ 38,  87, 109, ..., 132, 123, 113], dtype=uint8), 5],
#  [array([188, 182, 175, ..., 117, 110, 107], dtype=uint8), 2],
#  [array([194, 138,  97, ..., 102,  93,  83], dtype=uint8), 2],
#  [array([174, 147,  91, ...,  31,  61,  48], dtype=uint8), 2],
#  [array([37, 90, 77, ...,  0, 14, 13], dtype=uint8), 1],
#  [array([244, 224, 207, ..., 142, 142, 136], dtype=uint8), 3],
#  [array([196, 178, 167, ...,  24,  35,  39], dtype=uint8), 3],
#  [array([152, 123,  92, ...,   4,   4,   4], dtype=uint8), 3],
#  [array([ 84,  85,  76, ..., 130, 139, 142], dtype=uint8), 5],
#  [array([240, 235, 232, ..., 143, 140, 142], dtype=uint8), 0],
#  [array([253, 253, 253, ...,  91,  85,  66], dtype=uint8), 0],
#  [array([211, 159,  99, ..., 215, 222, 219], dtype=uint8), 4],
#  [array([181, 186, 185, ...,  54,  50,  61], dtype=uint8), 4],
#  [array([198, 151,  90, ..., 118, 109,  52], dtype=uint8), 2],
#  [array([164, 147, 108, ..., 143, 135, 136], dtype=uint8), 4],
#  [array([0, 1, 0, ..., 0, 0, 0], dtype=uint8), 5],
#  [array([210, 100,  12, ...,  83,  66,  47], dtype=uint8), 2],
#  [array([239, 230, 220, ...,  31,  99,  92], dtype=uint8), 2],
#  [array([234, 239, 238, ...,  77,  74,  76], dtype=uint8), 5],
#  [array([231, 188, 145, ..., 202, 201, 197], dtype=uint8), 3],
#  [array([208, 197, 199, ..., 233, 204, 199], dtype=uint8), 3],
#  [array([150, 151, 149, ...,  29,  30,  28], dtype=uint8), 4],
#  [array([250, 254, 249, ..., 121, 133, 111], dtype=uint8), 2],
#  [array([ 30,  36,  31, ...,  76,  88, 106], dtype=uint8), 1],
#  [array([161, 218, 255, ...,  38,  39,  53], dtype=uint8), 1],
#  [array([66, 76, 86, ..., 71, 77, 90], dtype=uint8), 4],
#  [array([ 96, 102, 113, ...,  96, 106, 124], dtype=uint8), 5],
#  [array([237, 193, 152, ...,  26,  79,  66], dtype=uint8), 0],
#  [array([226, 115,   0, ...,  87,  91,  92], dtype=uint8), 4],
#  [array([ 0,  4,  3, ...,  5, 14, 17], dtype=uint8), 5],
#  [array([224, 171, 120, ...,   7,   7,   7], dtype=uint8), 3],
#  [array([212, 182, 153, ...,   9,  11,  11], dtype=uint8), 4],
#  [array([114, 104, 120, ...,  54,  68, 246], dtype=uint8), 5],
#  [array([ 47, 181, 215, ...,   9,  32,  47], dtype=uint8), 1],
#  [array([226, 203, 181, ..., 230, 241, 245], dtype=uint8), 4],
#  [array([59, 58, 62, ..., 38, 38, 38], dtype=uint8), 1],
#  [array([220, 232, 242, ...,  98,  90,  97], dtype=uint8), 5],
#  [array([  4,   4,   4, ..., 130, 130, 130], dtype=uint8), 5],
#  [array([196, 125,  81, ...,  87,  87,  87], dtype=uint8), 0],
#  [array([147, 129, 106, ..., 173, 152, 131], dtype=uint8), 2],
#  [array([117, 127, 134, ..., 133, 137, 138], dtype=uint8), 0],
#  [array([47, 63, 79, ..., 33, 44, 42], dtype=uint8), 0],
#  [array([110, 110, 110, ...,  65,  65,  65], dtype=uint8), 0],
#  [array([218, 200, 189, ..., 147, 131, 115], dtype=uint8), 2],
#  [array([214, 135,  56, ..., 171, 153,  94], dtype=uint8), 0],
#  [array([55, 51, 63, ...,  9,  1,  1], dtype=uint8), 3],
#  [array([179, 126,  93, ...,  69,  84,  87], dtype=uint8), 2],
#  [array([229, 213, 207, ...,  52,  82,  69], dtype=uint8), 3],
#  [array([217, 212, 213, ..., 164, 173, 177], dtype=uint8), 3],
#  [array([19, 29, 17, ...,  7, 12, 11], dtype=uint8), 1],
#  [array([117, 128, 125, ...,   0,  96,  49], dtype=uint8), 1],
#  [array([ 31,  32,  30, ...,  84,  87, 115], dtype=uint8), 5],
#  [array([211, 162,  86, ..., 128,  92,  54], dtype=uint8), 4],
#  [array([ 83,  58,  72, ...,  54, 104,  92], dtype=uint8), 0],
#  [array([59, 64, 73, ..., 47, 61, 80], dtype=uint8), 5],
#  [array([ 36,  41,  44, ..., 125, 123, 142], dtype=uint8), 4],
#  [array([228, 197, 200, ..., 198, 125,   4], dtype=uint8), 2],
#  [array([251, 194, 139, ..., 190, 222, 187], dtype=uint8), 0],
#  [array([14, 39, 59, ...,  0,  0,  5], dtype=uint8), 5],
#  [array([29, 57, 57, ..., 36, 41, 50], dtype=uint8), 1],
#  [array([189, 123,  52, ...,   9,  19,  29], dtype=uint8), 5],
#  [array([240, 245, 246, ..., 112, 143, 112], dtype=uint8), 1],
#  [array([ 48,  16,  10, ..., 254, 255, 253], dtype=uint8), 2],
#  [array([214, 204, 204, ..., 119, 113, 114], dtype=uint8), 5],
#  [array([100, 111, 115, ..., 113, 132, 145], dtype=uint8), 0],
#  [array([94, 72, 66, ...,  0,  0,  0], dtype=uint8), 3],
#  [array([230, 209, 201, ...,  55,  49,  42], dtype=uint8), 3],
#  [array([152, 152, 152, ...,  34,  34,  34], dtype=uint8), 0],
#  [array([139, 184, 197, ...,  77,  72,  74], dtype=uint8), 5],
#  [array([150,  24,   0, ...,  21,   1,   0], dtype=uint8), 3],
#  [array([70, 36, 36, ..., 29, 30, 34], dtype=uint8), 5],
#  [array([199, 190, 187, ...,  41,  42,  46], dtype=uint8), 4],
#  [array([63, 54, 11, ..., 69, 60, 23], dtype=uint8), 4],
#  [array([33, 93, 75, ..., 20, 35,  8], dtype=uint8), 1],
#  [array([124, 108,  91, ...,  77,  83,  72], dtype=uint8), 3],
#  [array([253, 255, 255, ...,  24,  36,  38], dtype=uint8), 3],
#  [array([207, 157, 104, ..., 137, 161, 173], dtype=uint8), 4],
#  [array([169, 167, 167, ...,   7,   2,   4], dtype=uint8), 0],
#  [array([ 21,  23,  17, ...,  84,  83, 109], dtype=uint8), 1],
#  [array([208, 215, 218, ...,  22,  74,  64], dtype=uint8), 3],
#  [array([216, 162, 115, ..., 112, 110, 130], dtype=uint8), 3],
#  [array([186, 155, 116, ...,  82,  86,  81], dtype=uint8), 2],
#  [array([130,  96,  60, ...,  91, 120, 127], dtype=uint8), 0],
#  [array([205, 183, 155, ...,  62,  77,  93], dtype=uint8), 2],
#  [array([155, 166, 164, ...,   0,   4,  24], dtype=uint8), 1],
#  [array([252, 218, 188, ...,  27,  29,  23], dtype=uint8), 3],
#  [array([234, 187, 131, ..., 237, 226, 222], dtype=uint8), 2],
#  [array([208, 197, 189, ..., 215, 202, 200], dtype=uint8), 2],
#  [array([190, 185, 186, ...,  80,  76,  65], dtype=uint8), 1],
#  [array([212, 217, 220, ..., 126, 140, 158], dtype=uint8), 5],
#  [array([147, 147, 147, ...,  31,  31,  31], dtype=uint8), 1],
#  [array([249, 194, 143, ..., 214, 251, 255], dtype=uint8), 3],
#  [array([ 3, 71, 16, ..., 29, 42, 44], dtype=uint8), 1],
#  [array([ 90,  98, 111, ..., 131, 122, 109], dtype=uint8), 5],
#  [array([226, 146,   0, ...,  22,  46, 160], dtype=uint8), 4],
#  [array([ 76,  50,  36, ..., 127, 105,  99], dtype=uint8), 2],
#  [array([194, 140,  93, ...,   0,  24,  14], dtype=uint8), 3],
#  [array([166, 163, 165, ..., 171, 137, 114], dtype=uint8), 5],
#  [array([143, 175, 250, ..., 104, 109, 148], dtype=uint8), 4],
#  [array([145, 147, 148, ...,  15,  20,  29], dtype=uint8), 0],
#  [array([235, 227, 220, ..., 114, 103,  73], dtype=uint8), 2],
#  [array([104,  77,  43, ..., 102,  70,  27], dtype=uint8), 3],
#  [array([222, 162, 110, ...,  10,  30,  25], dtype=uint8), 3],
#  [array([ 46,  65, 102, ...,  38,  71, 104], dtype=uint8), 4],
#  [array([240, 219, 204, ...,  63, 108,  81], dtype=uint8), 3],
#  [array([170, 108,  70, ..., 241, 232, 229], dtype=uint8), 3],
#  [array([229, 167, 127, ...,  19,  22,  20], dtype=uint8), 2],
#  [array([191, 144, 106, ...,  64,  65,  63], dtype=uint8), 0],
#  [array([143,  79,  24, ...,  18,  17,  26], dtype=uint8), 0],
#  [array([ 97, 126, 130, ...,  25,  45,  46], dtype=uint8), 1],
#  [array([199, 202, 207, ...,  31,  35,  46], dtype=uint8), 3],
#  [array([ 1, 46, 57, ...,  0,  4,  0], dtype=uint8), 1],
#  [array([110, 110, 110, ...,  63,  63,  63], dtype=uint8), 5],
#  [array([219, 210, 200, ...,  86,  79,  62], dtype=uint8), 2],
#  [array([229, 232, 230, ..., 183, 175, 168], dtype=uint8), 2],
#  [array([103,  98,  99, ...,  53,  47,  48], dtype=uint8), 5],
#  [array([216, 206, 199, ..., 206, 211, 210], dtype=uint8), 2],
#  [array([167, 143, 123, ..., 150, 135, 126], dtype=uint8), 3],
#  [array([ 25,  35, 113, ...,  16,  21,  42], dtype=uint8), 4],
#  [array([ 31, 167,  49, ...,  27,  74,  25], dtype=uint8), 1],
#  [array([109, 125, 108, ...,  55, 162, 129], dtype=uint8), 1],
#  [array([254, 253, 255, ..., 255, 255, 255], dtype=uint8), 0],
#  [array([231, 212, 179, ..., 112, 116,  20], dtype=uint8), 4],
#  [array([72, 69, 65, ..., 37, 42, 40], dtype=uint8), 5],
#  [array([21, 55, 31, ..., 21, 37, 50], dtype=uint8), 1],
#  [array([ 55, 111, 136, ...,  45,  48,  56], dtype=uint8), 5],
#  [array([179, 128,  85, ..., 123,  98,  78], dtype=uint8), 4],
#  [array([245, 179, 131, ...,  15,  62,  59], dtype=uint8), 2],
#  [array([242, 242, 242, ..., 108, 108, 108], dtype=uint8), 5],
#  [array([207, 204, 189, ...,   0,   8,   8], dtype=uint8), 4],
#  [array([109, 100, 127, ...,  21,  27,  32], dtype=uint8), 4],
#  [array([ 17,  11,   6, ..., 156, 157, 161], dtype=uint8), 5],
#  [array([ 1, 10, 14, ..., 45, 69, 93], dtype=uint8), 1],
#  [array([181, 126,  69, ..., 154, 144, 134], dtype=uint8), 2],
#  [array([216, 200, 187, ..., 160, 140, 123], dtype=uint8), 2],
#  [array([234, 230, 219, ...,  96,  94,  83], dtype=uint8), 3],
#  [array([ 14,  26,  68, ...,  65,  92, 166], dtype=uint8), 5],
#  [array([201, 155, 124, ...,  14,   8,   3], dtype=uint8), 4],
#  [array([189, 160, 146, ..., 129, 111,  80], dtype=uint8), 2],
#  [array([239, 228, 238, ...,  25,  41,  87], dtype=uint8), 5],
#  [array([ 99, 126, 136, ..., 195, 126,  63], dtype=uint8), 0],
#  [array([208, 196, 202, ..., 121, 142, 163], dtype=uint8), 0],
#  [array([144,  93,  50, ...,  76, 110, 134], dtype=uint8), 2],
#  [array([255, 247, 243, ..., 121, 170, 180], dtype=uint8), 3],
#  [array([195, 143,  97, ..., 112,  87,  67], dtype=uint8), 3],
#  [array([136, 134, 156, ..., 129, 123, 140], dtype=uint8), 1],
#  [array([ 44, 153, 127, ...,   0,  21,  22], dtype=uint8), 1],
#  [array([193, 219, 225, ...,   4,   6,   6], dtype=uint8), 5],
#  [array([198, 203, 202, ...,  33,  28,  27], dtype=uint8), 5],
#  [array([1, 1, 1, ..., 1, 1, 1], dtype=uint8), 5],
#  [array([243, 196, 165, ..., 189, 155, 131], dtype=uint8), 5],
#  [array([151, 120,  95, ...,  18,  46,  40], dtype=uint8), 0],
#  [array([235, 219, 166, ...,  28,  23,  22], dtype=uint8), 3],
#  [array([233, 206, 186, ..., 210, 206, 217], dtype=uint8), 2],
#  [array([170, 189, 180, ..., 166, 200, 194], dtype=uint8), 0],
#  [array([247, 251, 252, ...,  39,  64,  84], dtype=uint8), 3],
#  [array([36, 51, 60, ..., 15, 30, 33], dtype=uint8), 5],
#  [array([178, 136, 107, ...,  49,  60,  82], dtype=uint8), 4],
#  [array([6, 6, 6, ..., 4, 4, 4], dtype=uint8), 1],
#  [array([206, 175, 130, ...,  59,  61,  39], dtype=uint8), 3],
#  [array([185, 147, 112, ...,  21,  36,  45], dtype=uint8), 0],
#  [array([20, 38, 45, ..., 80, 84, 85], dtype=uint8), 5],
#  [array([251, 255, 252, ..., 151, 152, 126], dtype=uint8), 2],
#  [array([179, 153, 137, ...,  75,  54,  27], dtype=uint8), 3],
#  [array([241, 246, 237, ..., 246, 248, 248], dtype=uint8), 4],
#  [array([225, 198, 194, ...,  40,  31,  34], dtype=uint8), 0],
#  [array([ 70, 123,  90, ...,  79,  81,  99], dtype=uint8), 1],
#  [array([224, 156,  49, ...,  55,  59,  64], dtype=uint8), 3],
#  [array([182, 124,  72, ..., 166, 170, 175], dtype=uint8), 2],
#  [array([223, 186, 124, ...,  78, 107, 128], dtype=uint8), 4],
#  [array([0, 0, 3, ..., 0, 2, 5], dtype=uint8), 5],
#  [array([ 48,  50,  50, ..., 117, 122, 123], dtype=uint8), 5],
#  [array([180,  91,   0, ..., 230, 234, 235], dtype=uint8), 0],
#  [array([254, 253, 255, ...,  11,  18, 145], dtype=uint8), 0],
#  [array([151,  94,   9, ...,  38,  37,  33], dtype=uint8), 2],
#  [array([239, 239, 239, ...,  69,  69,  69], dtype=uint8), 0],
#  [array([67, 74, 89, ..., 23, 10,  8], dtype=uint8), 5],
#  [array([209, 213,  17, ...,  42,  35,   2], dtype=uint8), 4],
#  [array([ 74, 127, 124, ...,   0,  11,  13], dtype=uint8), 1],
#  [array([ 0, 28, 44, ..., 18, 52, 76], dtype=uint8), 0],
#  [array([135, 129, 122, ...,  32,  63,  60], dtype=uint8), 1],
#  [array([234, 204, 163, ..., 149, 148, 110], dtype=uint8), 3],
#  [array([231, 214, 211, ...,  22,  63,  65], dtype=uint8), 3],
#  [array([138,  94,  77, ..., 212, 236, 242], dtype=uint8), 4],
#  [array([131, 155, 161, ...,  13,  14,  12], dtype=uint8), 3],
#  [array([66, 63, 55, ..., 13, 11, 10], dtype=uint8), 2],
#  [array([219, 175, 152, ...,  96, 127, 160], dtype=uint8), 4],
#  [array([175, 197, 233, ..., 125, 130, 133], dtype=uint8), 5],
#  [array([239, 248, 252, ...,  23, 120, 156], dtype=uint8), 3],
#  [array([200, 150,  98, ...,  14,  12,   2], dtype=uint8), 3],
#  [array([173, 165, 148, ...,  83, 110, 131], dtype=uint8), 4],
#  [array([142, 144, 154, ...,   3,   7,   8], dtype=uint8), 2],
#  [array([252, 248, 254, ..., 126, 151, 167], dtype=uint8), 3],
#  [array([3, 3, 3, ..., 6, 8, 9], dtype=uint8), 2],
#  [array([136, 118,  95, ..., 103,  80,  88], dtype=uint8), 1],
#  [array([ 63,  89, 103, ...,   2,  19,  38], dtype=uint8), 4],
#  [array([ 84,  84,  84, ..., 109, 109, 109], dtype=uint8), 1],
#  [array([251, 245, 238, ..., 162, 178, 195], dtype=uint8), 5],
#  [array([229, 173, 114, ..., 202, 186, 179], dtype=uint8), 3],
#  [array([18,  5, 19, ..., 21, 12, 25], dtype=uint8), 0],
#  [array([211, 163, 135, ...,  30,  22,  22], dtype=uint8), 3],
#  [array([203, 198, 177, ..., 199, 196, 181], dtype=uint8), 4],
#  [array([ 93,  89,  94, ..., 255, 207, 182], dtype=uint8), 0],
#  [array([13, 25, 37, ...,  0,  2, 14], dtype=uint8), 5],
#  [array([207, 232, 198, ...,  10,  46,  34], dtype=uint8), 2],
#  [array([150, 134, 118, ..., 186, 190, 179], dtype=uint8), 0],
#  [array([134, 149, 118, ..., 106, 122,  99], dtype=uint8), 4],
#  [array([219, 202, 189, ...,  27,  51,  43], dtype=uint8), 3],
#  [array([214, 188, 182, ...,  51,  44,  51], dtype=uint8), 2],
#  [array([246, 234, 224, ...,  16,  24,  41], dtype=uint8), 4],
#  [array([169,  91,  44, ...,  46,  84, 102], dtype=uint8), 3],
#  [array([198, 124,  58, ..., 249, 249, 249], dtype=uint8), 2],
#  [array([126, 114,  74, ..., 110, 140, 167], dtype=uint8), 4],
#  [array([184, 145, 101, ...,  32,  35,  43], dtype=uint8), 0],
#  [array([16, 36, 47, ..., 39, 45, 40], dtype=uint8), 5],
#  [array([196, 144, 128, ..., 163, 166, 171], dtype=uint8), 2],
#  [array([222, 228, 217, ...,  35,  53,  64], dtype=uint8), 1],
#  [array([180, 121,  89, ...,   0,   0,  11], dtype=uint8), 0],
#  [array([253, 161, 108, ...,  39,  30,  17], dtype=uint8), 2],
#  [array([223, 252, 255, ...,  34, 127, 183], dtype=uint8), 1],
#  ...]

# %% [markdown]
# ## train data shuffled

# %%
train_features = []
train_labels = []

for train_feature, train_label in train_data:
    train_features.append(train_feature)
    train_labels.append(train_label)

# %%
np_train_features = np.array(train_features)
np_train_labels = np.array(train_labels)

# %%
np_train_features
# Out:
# array([[175, 204, 218, ...,   0,  19,  64],
#        [ 63,  62,  41, ..., 163, 147, 134],
#        [168, 143, 139, ...,  69,  75,  82],
#        ...,
#        [246, 235, 185, ...,  72,  68,  43],
#        [ 34,  35,  39, ...,  41,  47,  46],
#        [ 73, 101,  58, ...,   0,   6,   0]], dtype=uint8)

# %%
np_train_features = np_train_features.astype(np.int32)

# %%
print('total data shape: ',np_train_features.shape)
print('total labels shape: ', np_train_labels.shape)
# Out:
# total data shape:  (14338, 67500)
# total labels shape:  (14338,)

# %% [markdown]
# ## Dementionality reduction PCA(0.95)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.95, svd_solver='full')

# %%
np_train_features_pca = pca.fit_transform(np_train_features)
np_train_features_pca
# Out:
# array([[ 1.43357470e+04,  6.36444241e+03,  2.40931522e+03, ...,
#          7.24276115e+01,  8.59633886e+01,  1.28014267e+02],
#        [-1.05746639e+04, -6.14260723e+03,  3.60922897e+03, ...,
#          2.72152533e+00,  1.86000564e+01, -2.04003292e+01],
#        [-8.35706369e+03,  2.07693928e+03,  7.32362015e+02, ...,
#          5.32858099e+01, -3.30045616e+01,  1.98856919e-01],
#        ...,
#        [-3.15894191e+02, -9.29710945e+03, -1.81382557e+03, ...,
#          1.67898981e+01, -3.46515435e+01,  2.41341214e+01],
#        [ 8.72145811e+03, -8.65005729e+01, -1.42483717e+02, ...,
#          8.60948664e+00, -8.11800694e+01,  1.48383083e+01],
#        [-7.86589940e+03,  2.81488580e+03, -8.79976881e+02, ...,
#         -8.12239603e-01, -2.96996392e+00, -4.51691997e+00]])

# %%
np_train_features_pca.shape
# Out:
# (14338, 3772)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(np_train_features_pca, np_train_labels)

# %%
X_train.shape
# Out:
# (10753, 3772)

# %%
from sklearn.svm import SVC
model = SVC(C=3)

# %%
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.6691771269177127

# %%
y_predict = model.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict,target_names=targets))
# Out:
#               precision    recall  f1-score   support
#
#    buildings       0.61      0.54      0.58       595
#       forest       0.83      0.81      0.82       527
#      glacier       0.67      0.70      0.68       650
#     mountain       0.63      0.68      0.65       644
#          sea       0.60      0.54      0.57       567
#       street       0.69      0.75      0.72       602
#
#     accuracy                           0.67      3585
#    macro avg       0.67      0.67      0.67      3585
# weighted avg       0.67      0.67      0.67      3585

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
CM = confusion_matrix(y_test, y_predict)
ax = plt.axes()
sn.set(font_scale=1.4)
sn.heatmap(CM, annot=True,annot_kws={"size": 16},  xticklabels=targets, yticklabels=targets, ax = ax, fmt="d",cmap="YlGnBu")
ax.set_title('Confusion matrix')
plt.show()

# %% [markdown]
# ## Dementionality reduction PCA(0.8)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.8, svd_solver='full')

# %%
np_train_features_pca = pca.fit_transform(np_train_features)
np_train_features_pca
# Out:
# array([[ 6.33381466e+02,  5.75215244e+03,  1.47911475e+03, ...,
#         -2.65276155e+02,  2.76125576e+02,  1.14344349e+02],
#        [ 1.03645993e+04,  5.02897849e+02,  2.36990346e+03, ...,
#         -1.93515535e+02,  2.06180823e+02, -1.89082520e+02],
#        [-5.81473011e+03,  2.35582331e+03,  2.34163672e+03, ...,
#         -1.83402480e+02, -1.78549922e+01, -3.37581956e+01],
#        ...,
#        [-6.27472491e+02, -8.90088658e+03, -2.69628451e+03, ...,
#          4.83108042e+01, -9.96511409e+01,  1.21241244e+02],
#        [ 5.92028199e+03,  2.15710808e+03, -3.28821108e+03, ...,
#          1.05154287e+02,  6.16534199e+01, -2.19235622e+01],
#        [ 1.48730484e+04, -1.45595460e+02, -1.62646780e+03, ...,
#         -4.58510040e+01,  1.60127016e+02, -1.43895364e+01]])

# %%
np_train_features_pca.shape
# Out:
# (14338, 338)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(np_train_features_pca, np_train_labels, test_size=0.2510810433812247)

# %%
X_test.shape
# Out:
# (3600, 338)

# %%
from sklearn.svm import SVC
model = SVC(C=4)

# %% [markdown]
# ### C= 8: score = 0.67083
# ### C= 5: score = 0.67583
# ### C =4: score = 0.67666  <-
# ### C= 3: score = 0.67250

# %%
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.6766666666666666

# %%
y_predict = model.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict,target_names=targets))
# Out:
#               precision    recall  f1-score   support
#
#    buildings       0.62      0.56      0.59       584
#       forest       0.82      0.84      0.83       548
#      glacier       0.68      0.67      0.68       643
#     mountain       0.61      0.71      0.66       624
#          sea       0.58      0.49      0.53       577
#       street       0.71      0.75      0.73       624
#
#     accuracy                           0.67      3600
#    macro avg       0.67      0.67      0.67      3600
# weighted avg       0.67      0.67      0.67      3600

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
CM = confusion_matrix(y_test, y_predict)
ax = plt.axes()
sn.set(font_scale=1.4)
sn.heatmap(CM, annot=True,annot_kws={"size": 16},  xticklabels=targets, yticklabels=targets, ax = ax, fmt="d",cmap="YlGnBu")
ax.set_title('Confusion matrix')
plt.show()

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
#load test set
test_data = []
test_dir = './datasets/test_set/'

for img in os.listdir(test_dir):
    path = os.path.join(test_dir, img)
    test_img = cv2.imread(path)
    
    try:
        test_img = cv2.resize(test_img,(150,150))
        image = np.array(test_img).flatten()
        test_data.append([image,img])
    except Exception as e:
        pass

len(test_data)
# Out:
# 3600

# %%
test_data
# Out:
# [[array([  4,   7,  21, ..., 109,  88,  86], dtype=uint8),
#   '1000 - Copy - Copy.jpg'],
#  [array([222, 194, 160, ...,  75, 107, 126], dtype=uint8), '10113.jpg'],
#  [array([250, 250, 250, ...,  59,  63,  74], dtype=uint8), '10144.jpg'],
#  [array([104,  94,  47, ...,  67,  70,  78], dtype=uint8), '10151.jpg'],
#  [array([241, 246, 244, ..., 124, 101, 109], dtype=uint8), '10161.jpg'],
#  [array([153, 106,  44, ...,  30,  20,  20], dtype=uint8), '10210.jpg'],
#  [array([230, 199, 146, ...,  80, 198, 179], dtype=uint8), '1024.jpg'],
#  [array([95, 78, 69, ..., 42, 45, 59], dtype=uint8), '1025.jpg'],
#  [array([ 0,  6,  4, ..., 13,  6, 13], dtype=uint8), '10318.jpg'],
#  [array([ 30,  30,  30, ..., 100, 100, 100], dtype=uint8), '10374.jpg'],
#  [array([ 53,  32,   4, ..., 122,  99,  73], dtype=uint8), '10383.jpg'],
#  [array([ 95,  46,  14, ...,  56,  92, 116], dtype=uint8),
#   '1040 - Copy - Copy.jpg'],
#  [array([162, 162, 162, ...,   7,   7,   7], dtype=uint8),
#   '10448 - Copy - Copy.jpg'],
#  [array([ 63,  67,  72, ..., 148, 159, 167], dtype=uint8),
#   '10524 - Copy - Copy.jpg'],
#  [array([243, 241, 240, ...,  99,  98, 107], dtype=uint8),
#   '10540 - Copy - Copy.jpg'],
#  [array([163, 163, 163, ...,  56,  56,  56], dtype=uint8),
#   '10547 - Copy - Copy.jpg'],
#  [array([100,  93, 120, ...,  76,  93, 120], dtype=uint8), '10563.jpg'],
#  [array([217, 200, 197, ...,   9,  24,  27], dtype=uint8), '10564.jpg'],
#  [array([203, 203, 203, ..., 234, 234, 234], dtype=uint8),
#   '10613 - Copy - Copy.jpg'],
#  [array([231, 190, 158, ..., 130, 134, 139], dtype=uint8),
#   '10633 - Copy - Copy.jpg'],
#  [array([239, 228, 238, ...,  25,  41,  87], dtype=uint8),
#   '10643 - Copy - Copy.jpg'],
#  [array([191, 155, 117, ...,  28,  94, 119], dtype=uint8),
#   '1067 - Copy (2).jpg'],
#  [array([191, 155, 117, ...,  28,  94, 119], dtype=uint8),
#   '1067 - Copy - Copy.jpg'],
#  [array([213, 199, 187, ...,   4,   6,   7], dtype=uint8), '1069 - Copy.jpg'],
#  [array([195, 154, 115, ...,  46,  47,  43], dtype=uint8),
#   '10691 - Copy - Copy.jpg'],
#  [array([  3,   8,  23, ..., 105, 144, 172], dtype=uint8),
#   '10697 - Copy - Copy.jpg'],
#  [array([62, 46, 47, ...,  0,  1,  1], dtype=uint8),
#   '1085 - Copy (2) - Copy.jpg'],
#  [array([  0,   7,   5, ...,  92,  75, 108], dtype=uint8),
#   '10925 - Copy - Copy.jpg'],
#  [array([ 14,  13,  17, ..., 139, 141, 151], dtype=uint8),
#   '10927 - Copy - Copy.jpg'],
#  [array([121,  76,   3, ..., 101, 110, 113], dtype=uint8), '1093 - Copy.jpg'],
#  [array([ 22,  22,  22, ..., 143, 143, 143], dtype=uint8),
#   '10938 - Copy - Copy.jpg'],
#  [array([112, 112, 112, ..., 160, 160, 160], dtype=uint8),
#   '10972 - Copy - Copy.jpg'],
#  [array([209, 200, 191, ...,  34,  35,  55], dtype=uint8),
#   '10985 - Copy - Copy.jpg'],
#  [array([223, 221, 210, ...,  93,  90,  85], dtype=uint8),
#   '11019 - Copy - Copy.jpg'],
#  [array([195, 205, 222, ...,  39,  56,  82], dtype=uint8),
#   '11027 - Copy - Copy.jpg'],
#  [array([254, 254, 254, ..., 196, 187, 178], dtype=uint8),
#   '1103 - Copy (2) - Copy.jpg'],
#  [array([230, 228, 234, ..., 118, 106, 106], dtype=uint8), '11085.jpg'],
#  [array([145, 164, 185, ...,   4,  19,  15], dtype=uint8),
#   '11086 - Copy - Copy.jpg'],
#  [array([212, 203, 194, ..., 161, 149, 145], dtype=uint8), '11089.jpg'],
#  [array([24, 24, 24, ...,  9,  9,  9], dtype=uint8),
#   '11096 - Copy - Copy.jpg'],
#  [array([190, 149, 116, ..., 157, 168, 176], dtype=uint8),
#   '11116 - Copy - Copy.jpg'],
#  [array([205, 231, 225, ...,  46, 135, 139], dtype=uint8), '1115.jpg'],
#  [array([177, 168, 165, ...,  81,  79,  79], dtype=uint8),
#   '11154 - Copy - Copy.jpg'],
#  [array([175, 181, 186, ...,  20,  41,  63], dtype=uint8), '11165 - Copy.jpg'],
#  [array([202, 212, 219, ...,  79,  74,  73], dtype=uint8),
#   '11169 - Copy - Copy.jpg'],
#  [array([135, 107,  96, ..., 175, 165, 165], dtype=uint8), '11177 - Copy.jpg'],
#  [array([189, 150, 118, ...,  16,  42,  42], dtype=uint8), '11185 - Copy.jpg'],
#  [array([166, 153, 121, ..., 109,  83,  67], dtype=uint8), '11200 - Copy.jpg'],
#  [array([180, 139,  94, ...,   1,   5,   0], dtype=uint8), '11217 - Copy.jpg'],
#  [array([167, 156, 148, ..., 121, 119, 101], dtype=uint8), '11241 - Copy.jpg'],
#  [array([242, 242, 254, ...,  97,  86,  58], dtype=uint8), '11283 - Copy.jpg'],
#  [array([176, 158, 121, ..., 205, 196, 192], dtype=uint8), '11287 - Copy.jpg'],
#  [array([255, 247, 243, ..., 121, 170, 180], dtype=uint8),
#   '1133 - Copy (2).jpg'],
#  [array([255, 247, 243, ..., 121, 170, 180], dtype=uint8),
#   '1133 - Copy - Copy - Copy.jpg'],
#  [array([144, 126, 119, ..., 106, 118, 120], dtype=uint8), '11333 - Copy.jpg'],
#  [array([202, 166, 142, ..., 214, 190, 184], dtype=uint8), '11368 - Copy.jpg'],
#  [array([183, 121,  51, ..., 125, 107,  66], dtype=uint8), '11385 - Copy.jpg'],
#  [array([171,  94,   1, ..., 196, 186, 168], dtype=uint8), '11426 - Copy.jpg'],
#  [array([157, 157, 151, ..., 148, 145, 114], dtype=uint8), '11432 - Copy.jpg'],
#  [array([150, 150, 150, ..., 134, 134, 134], dtype=uint8), '11438 - Copy.jpg'],
#  [array([89, 89, 77, ...,  0, 10,  0], dtype=uint8), '11455 - Copy.jpg'],
#  [array([ 51,  13,   8, ..., 177, 179, 187], dtype=uint8), '11456 - Copy.jpg'],
#  [array([204, 168, 138, ..., 179, 149, 120], dtype=uint8), '11468 - Copy.jpg'],
#  [array([161, 123,  93, ..., 187, 178, 168], dtype=uint8), '11475 - Copy.jpg'],
#  [array([217, 178, 150, ...,  34,  26,  13], dtype=uint8), '11482 - Copy.jpg'],
#  [array([242, 242, 206, ...,  26,  36,  24], dtype=uint8), '11487.jpg'],
#  [array([185,  89,  49, ...,  43,  44,  42], dtype=uint8), '11515 - Copy.jpg'],
#  [array([ 51,  28,   2, ..., 194, 148,  84], dtype=uint8),
#   '1177 - Copy (2) - Copy.jpg'],
#  [array([239, 244, 245, ..., 249, 249, 249], dtype=uint8), '11807 - Copy.jpg'],
#  [array([212, 130,  75, ...,  20,   9,   5], dtype=uint8), '11810 - Copy.jpg'],
#  [array([224, 236, 248, ..., 119,  95,  77], dtype=uint8), '11844 - Copy.jpg'],
#  [array([66, 44, 39, ..., 69, 54, 51], dtype=uint8), '11859 - Copy.jpg'],
#  [array([130, 131, 127, ...,  19,  25,  32], dtype=uint8), '11861 - Copy.jpg'],
#  [array([155, 141, 119, ...,   0,   0,   0], dtype=uint8), '11880 - Copy.jpg'],
#  [array([237, 135, 113, ..., 126, 202, 208], dtype=uint8), '11888 - Copy.jpg'],
#  [array([223, 213, 206, ...,  58,  53,  54], dtype=uint8),
#   '1189 - Copy (2) - Copy.jpg'],
#  [array([225, 191, 167, ..., 186, 139,  95], dtype=uint8), '11905 - Copy.jpg'],
#  [array([229, 223, 212, ..., 154, 182, 217], dtype=uint8), '11922 - Copy.jpg'],
#  [array([185, 173, 149, ...,  72, 120, 132], dtype=uint8), '11932.jpg'],
#  [array([112, 192, 133, ...,   9,  85,  31], dtype=uint8), '11969.jpg'],
#  [array([255, 190, 151, ...,  13,  39,  51], dtype=uint8), '11974 - Copy.jpg'],
#  [array([188, 149, 110, ...,  68,  46,  18], dtype=uint8), '11980 - Copy.jpg'],
#  [array([ 66, 198, 161, ...,  22,  96,  92], dtype=uint8), '12059.jpg'],
#  [array([ 9, 14, 12, ..., 15, 22, 17], dtype=uint8), '12126.jpg'],
#  [array([ 61, 161, 133, ...,  20,  69,  47], dtype=uint8), '12129.jpg'],
#  [array([57, 39,  0, ..., 41, 49, 66], dtype=uint8), '12213.jpg'],
#  [array([218, 137,  69, ...,  31,   7,   1], dtype=uint8), '12218 - Copy.jpg'],
#  [array([226, 224, 223, ...,   4,   9,  10], dtype=uint8), '12252 - Copy.jpg'],
#  [array([216, 212, 201, ...,  47,  42,  44], dtype=uint8), '12256 - Copy.jpg'],
#  [array([253, 249, 225, ..., 101, 103, 104], dtype=uint8),
#   '1229 - Copy (2) - Copy.jpg'],
#  [array([246, 241, 238, ...,  91,  61,  32], dtype=uint8),
#   '1233 - Copy (2) - Copy.jpg'],
#  [array([249, 237, 235, ..., 149, 144, 135], dtype=uint8), '12339 - Copy.jpg'],
#  [array([61, 64, 68, ...,  3, 15, 17], dtype=uint8), '12353 - Copy.jpg'],
#  [array([216, 167, 111, ...,  38,  64,  64], dtype=uint8),
#   '1237 - Copy - Copy.jpg'],
#  [array([158, 156, 132, ...,  80,  81,  61], dtype=uint8), '12391 - Copy.jpg'],
#  [array([219, 139, 114, ...,  58,  77, 138], dtype=uint8), '12400 - Copy.jpg'],
#  [array([ 26,   8,  21, ..., 228, 225, 227], dtype=uint8), '12404.jpg'],
#  [array([ 59,  45,  39, ..., 143, 109,  80], dtype=uint8),
#   '1243 - Copy (2) - Copy.jpg'],
#  [array([106, 107, 105, ...,  72,  72,  72], dtype=uint8), '12506.jpg'],
#  [array([207, 201, 188, ...,   6,  11,  10], dtype=uint8), '12518 - Copy.jpg'],
#  [array([252, 212, 164, ...,  95, 104, 117], dtype=uint8),
#   '1252 - Copy (2).jpg'],
#  [array([252, 212, 164, ...,  95, 104, 117], dtype=uint8),
#   '1252 - Copy - Copy.jpg'],
#  [array([218, 202, 185, ...,  49,  45,  44], dtype=uint8), '12522 - Copy.jpg'],
#  [array([170, 134,  96, ...,  76,  69,  76], dtype=uint8), '12526.jpg'],
#  [array([249, 234, 215, ...,  77, 131, 101], dtype=uint8), '12529.jpg'],
#  [array([198, 222, 210, ...,   8,  50,  62], dtype=uint8), '12534.jpg'],
#  [array([ 19,  56,  52, ..., 224, 214, 230], dtype=uint8), '12539.jpg'],
#  [array([122, 158, 188, ...,   6,   8,   9], dtype=uint8), '12548.jpg'],
#  [array([149, 156, 153, ...,  25, 120,  93], dtype=uint8), '12572.jpg'],
#  [array([ 6,  6,  6, ..., 11, 20, 29], dtype=uint8), '12576.jpg'],
#  [array([179, 114,  69, ..., 196, 197, 195], dtype=uint8), '12580.jpg'],
#  [array([183, 164, 156, ..., 213, 206, 203], dtype=uint8), '12647.jpg'],
#  [array([158, 142, 130, ...,   0,   0,   0], dtype=uint8), '12657.jpg'],
#  [array([158, 136, 125, ..., 168, 180, 186], dtype=uint8), '12660.jpg'],
#  [array([22, 25, 29, ...,  0, 31, 27], dtype=uint8), '12664.jpg'],
#  [array([ 4, 55,  0, ..., 25, 38, 22], dtype=uint8), '12672.jpg'],
#  [array([102,  52,  24, ..., 193, 198, 197], dtype=uint8), '12691.jpg'],
#  [array([114,  87,   0, ..., 156, 142,  84], dtype=uint8), '12761.jpg'],
#  [array([204, 153,  90, ...,  52,  85, 111], dtype=uint8),
#   '1284 - Copy - Copy.jpg'],
#  [array([70, 29, 66, ..., 52, 12, 37], dtype=uint8), '12913.jpg'],
#  [array([213, 201, 189, ..., 228, 211, 198], dtype=uint8), '12955.jpg'],
#  [array([210, 183, 146, ...,  68,  53,  44], dtype=uint8), '13048.jpg'],
#  [array([251, 244, 205, ..., 212, 180, 127], dtype=uint8), '13052.jpg'],
#  [array([117, 116,  96, ..., 135, 140, 101], dtype=uint8), '13056.jpg'],
#  [array([188, 186, 175, ..., 118, 126, 116], dtype=uint8), '13059.jpg'],
#  [array([ 13,  11,  10, ..., 180, 178, 177], dtype=uint8), '13083.jpg'],
#  [array([ 46,  77,  78, ...,  97,  97, 103], dtype=uint8), '1311 - Copy.jpg'],
#  [array([216, 216, 216, ...,  56,  58,  59], dtype=uint8),
#   '1314 - Copy - Copy.jpg'],
#  [array([254, 254, 254, ...,   5,   5,   5], dtype=uint8), '1317 - Copy.jpg'],
#  [array([192, 135,  83, ...,  62,  58,  47], dtype=uint8), '13191 - Copy.jpg'],
#  [array([77, 70, 75, ..., 56, 67, 65], dtype=uint8), '1325 - Copy.jpg'],
#  [array([139,  67,  60, ...,  33,  42,  75], dtype=uint8), '13258 - Copy.jpg'],
#  [array([ 2,  3,  7, ..., 33, 36, 11], dtype=uint8), '13315.jpg'],
#  [array([255, 228, 207, ...,  30,  49,  54], dtype=uint8),
#   '1333 - Copy - Copy - Copy.jpg'],
#  [array([ 90,  90,  90, ..., 121, 121, 121], dtype=uint8),
#   '13368 - Copy - Copy.jpg'],
#  [array([248, 206, 169, ...,  84,  88,  83], dtype=uint8), '13371 - Copy.jpg'],
#  [array([153, 131,  95, ...,  18,  37,  18], dtype=uint8),
#   '13396 - Copy - Copy.jpg'],
#  [array([122,  96,  84, ..., 223, 201, 183], dtype=uint8), '1343 - Copy.jpg'],
#  [array([178, 167, 187, ...,  20,  21,  35], dtype=uint8), '13463.jpg'],
#  [array([221, 209, 199, ..., 161, 149, 149], dtype=uint8), '13474 - Copy.jpg'],
#  [array([44, 74, 91, ..., 16, 16, 16], dtype=uint8),
#   '13492 - Copy - Copy.jpg'],
#  [array([40, 51, 55, ..., 46, 49, 64], dtype=uint8),
#   '13650 - Copy - Copy.jpg'],
#  [array([ 31,  32,  30, ...,  84,  87, 115], dtype=uint8),
#   '13655 - Copy - Copy.jpg'],
#  [array([128, 157, 154, ...,   7,   7,   7], dtype=uint8),
#   '13659 - Copy - Copy.jpg'],
#  [array([167,  96,  39, ...,   4,  16,  18], dtype=uint8),
#   '1366 - Copy (2).jpg'],
#  [array([19, 24, 22, ..., 70, 72, 72], dtype=uint8),
#   '13682 - Copy - Copy.jpg'],
#  [array([236, 195, 146, ..., 110, 107, 103], dtype=uint8),
#   '13747 - Copy - Copy.jpg'],
#  [array([124, 124, 124, ..., 222, 222, 222], dtype=uint8),
#   '13750 - Copy - Copy.jpg'],
#  [array([128, 132, 133, ...,  34,  35,  45], dtype=uint8),
#   '13791 - Copy - Copy.jpg'],
#  [array([172, 105,  60, ...,   9,  18,  86], dtype=uint8),
#   '13793 - Copy - Copy.jpg'],
#  [array([ 90,  97, 114, ..., 142, 136, 117], dtype=uint8),
#   '13794 - Copy - Copy.jpg'],
#  [array([197, 159, 124, ...,  56,  70,  76], dtype=uint8),
#   '1391 - Copy - Copy (3).jpg'],
#  [array([152, 255, 255, ...,  12,  72,  71], dtype=uint8), '14371.jpg'],
#  [array([189, 219, 190, ...,   0,  12,   8], dtype=uint8), '14488.jpg'],
#  [array([191, 226, 216, ...,  63, 119, 106], dtype=uint8), '14510.jpg'],
#  [array([ 42,  31,  34, ..., 104, 173, 182], dtype=uint8), '14584.jpg'],
#  [array([123, 125, 126, ...,   1,   1,   1], dtype=uint8), '146 - Copy.jpg'],
#  [array([255, 255, 229, ...,  71,  77,  76], dtype=uint8), '14686.jpg'],
#  [array([157, 159, 130, ...,  95, 121,  68], dtype=uint8), '14714.jpg'],
#  [array([157, 134, 108, ...,  58,  49,  46], dtype=uint8), '1473 - Copy.jpg'],
#  [array([149,  76,   8, ...,  79,  82,  43], dtype=uint8), '14803 - Copy.jpg'],
#  [array([204, 198, 193, ...,  47,  47,  47], dtype=uint8), '14825 - Copy.jpg'],
#  [array([205, 186, 173, ...,  16,  11,  13], dtype=uint8), '14831 - Copy.jpg'],
#  [array([ 30,  28,  34, ..., 118, 101,  62], dtype=uint8), '14833 - Copy.jpg'],
#  [array([165, 161, 143, ...,  88,  70,  59], dtype=uint8), '14836 - Copy.jpg'],
#  [array([ 0, 31, 36, ..., 50, 70, 75], dtype=uint8), '14861.jpg'],
#  [array([49, 63, 57, ..., 42, 55, 57], dtype=uint8), '14872.jpg'],
#  [array([ 0, 47, 48, ...,  0, 10,  9], dtype=uint8), '14873.jpg'],
#  [array([175, 100,   2, ..., 209, 195, 176], dtype=uint8), '14917.jpg'],
#  [array([210, 198, 194, ..., 188, 181, 178], dtype=uint8), '14920.jpg'],
#  [array([73, 90, 69, ...,  6,  5, 14], dtype=uint8), '14931.jpg'],
#  [array([37, 65, 59, ...,  2, 49, 40], dtype=uint8), '14980.jpg'],
#  [array([62, 64, 52, ..., 50, 64, 53], dtype=uint8), '15037.jpg'],
#  [array([92, 78, 56, ..., 46, 52, 59], dtype=uint8), '15055 - Copy.jpg'],
#  [array([216, 221, 230, ...,   0,  43,  88], dtype=uint8), '15058.jpg'],
#  [array([244, 237, 234, ...,  10,  19,  29], dtype=uint8), '15059 - Copy.jpg'],
#  [array([110,  97,  89, ...,  51,  58,  67], dtype=uint8), '15096 - Copy.jpg'],
#  [array([206, 176, 147, ...,  64,  57,  60], dtype=uint8), '15097 - Copy.jpg'],
#  [array([124, 124, 124, ...,  97,  97,  97], dtype=uint8), '15124 - Copy.jpg'],
#  [array([43, 37, 30, ...,  9, 21, 49], dtype=uint8), '15214 - Copy.jpg'],
#  [array([237, 214, 152, ...,  27,  22,  21], dtype=uint8), '1558 - Copy.jpg'],
#  [array([204, 207, 212, ...,   9,  57,  61], dtype=uint8),
#   '1559 - Copy - Copy.jpg'],
#  [array([191, 191, 191, ...,  87,  88,  86], dtype=uint8), '16013 - Copy.jpg'],
#  [array([203, 199, 194, ...,  28,  26,  56], dtype=uint8), '1607 - Copy.jpg'],
#  [array([147, 146, 150, ...,  19,  17,  16], dtype=uint8), '16157 - Copy.jpg'],
#  [array([23, 11,  5, ..., 11,  9,  9], dtype=uint8), '16175 - Copy.jpg'],
#  [array([231, 211, 194, ..., 158, 153, 150], dtype=uint8), '1621 - Copy.jpg'],
#  [array([21, 27, 32, ..., 27, 60, 75], dtype=uint8), '16253 - Copy.jpg'],
#  [array([255, 255, 255, ...,  63,  58,  60], dtype=uint8), '16258 - Copy.jpg'],
#  [array([  0,  20,  45, ..., 160, 167, 187], dtype=uint8), '16261 - Copy.jpg'],
#  [array([18, 18, 18, ..., 18, 18, 18], dtype=uint8), '164 - Copy - Copy.jpg'],
#  [array([ 75,  75,  75, ..., 154, 154, 154], dtype=uint8),
#   '16525 - Copy - Copy.jpg'],
#  [array([ 47,  45,  34, ..., 111, 122, 112], dtype=uint8),
#   '166 - Copy - Copy.jpg'],
#  [array([248, 253, 254, ...,  17,  17,  17], dtype=uint8), '16703 - Copy.jpg'],
#  [array([147, 153, 158, ...,  42,  36,  23], dtype=uint8),
#   '1685 - Copy - Copy.jpg'],
#  [array([ 93, 143, 143, ...,  13,  17,  18], dtype=uint8), '16913.jpg'],
#  [array([232, 227, 229, ...,  52,  67,  76], dtype=uint8), '16927.jpg'],
#  [array([241, 222, 189, ..., 176, 180, 155], dtype=uint8), '16932 - Copy.jpg'],
#  [array([ 22, 179,  65, ...,  18,  35,  31], dtype=uint8), '16975.jpg'],
#  [array([13,  5,  5, ..., 15, 16, 14], dtype=uint8), '16977.jpg'],
#  [array([203, 224, 202, ...,  18,  24,  59], dtype=uint8), '17034.jpg'],
#  [array([239, 223, 200, ..., 174, 184, 202], dtype=uint8), '17102.jpg'],
#  [array([ 81, 127,  91, ...,  29,  36,  39], dtype=uint8), '17141.jpg'],
#  [array([113, 183, 152, ...,  52,  92, 134], dtype=uint8), '17144.jpg'],
#  [array([254, 213, 180, ...,  79, 178, 168], dtype=uint8), '17205.jpg'],
#  [array([199, 202, 200, ...,   0,  13,  11], dtype=uint8), '17207.jpg'],
#  [array([ 50,  50,  68, ...,  97, 151, 192], dtype=uint8), '17214.jpg'],
#  [array([32, 32, 32, ...,  4,  4,  4], dtype=uint8), '17222.jpg'],
#  [array([213, 202, 198, ...,  44,  47,  52], dtype=uint8), '17240.jpg'],
#  [array([221, 137,  61, ...,  24, 106,  88], dtype=uint8), '17242.jpg'],
#  [array([215, 208, 189, ...,  39,  61,  96], dtype=uint8), '17277.jpg'],
#  [array([0, 0, 1, ..., 0, 0, 0], dtype=uint8), '17317.jpg'],
#  [array([153, 216, 190, ..., 201, 182, 201], dtype=uint8), '17378.jpg'],
#  [array([252, 251, 247, ...,  42,  37,  28], dtype=uint8), '17379.jpg'],
#  [array([13, 20, 15, ..., 39, 49, 43], dtype=uint8), '17396.jpg'],
#  [array([65, 46, 63, ..., 63, 76, 98], dtype=uint8), '17454.jpg'],
#  [array([ 0, 21, 15, ..., 23, 55, 50], dtype=uint8), '17464.jpg'],
#  [array([126, 102,  90, ...,   0,  92,  21], dtype=uint8), '17586.jpg'],
#  [array([ 67,  78, 128, ...,   3,   5,  16], dtype=uint8), '17615.jpg'],
#  [array([239, 242, 240, ..., 200, 180, 169], dtype=uint8), '17617.jpg'],
#  [array([244, 244, 244, ...,  23,  22,  26], dtype=uint8), '17725.jpg'],
#  [array([201, 145,  96, ...,  72,  75,  60], dtype=uint8), '17740 - Copy.jpg'],
#  [array([186, 132,  67, ...,  25,   5,   0], dtype=uint8), '17756.jpg'],
#  [array([222, 183, 128, ...,  33,  51,  52], dtype=uint8), '17767.jpg'],
#  [array([  7,   7,   7, ..., 171, 171, 171], dtype=uint8), '17864 - Copy.jpg'],
#  [array([224, 236, 242, ..., 204, 211, 214], dtype=uint8), '17868 - Copy.jpg'],
#  [array([103,  75,  64, ...,  71,  85,  57], dtype=uint8), '17906 - Copy.jpg'],
#  [array([186, 132, 102, ...,  88,  58,  39], dtype=uint8), '17932 - Copy.jpg'],
#  [array([149, 153, 211, ..., 180, 180, 192], dtype=uint8), '18072 - Copy.jpg'],
#  [array([196, 119,   3, ...,  17,   7,   0], dtype=uint8), '1813 - Copy.jpg'],
#  [array([255, 255, 255, ..., 254, 254, 254], dtype=uint8), '18157 - Copy.jpg'],
#  [array([125, 125, 125, ...,  34,  34,  34], dtype=uint8), '18166 - Copy.jpg'],
#  [array([2, 2, 2, ..., 1, 2, 0], dtype=uint8), '18234 - Copy.jpg'],
#  [array([16, 15, 17, ..., 54, 49, 50], dtype=uint8), '18235 - Copy.jpg'],
#  [array([190, 105,  57, ...,  37,  42,  51], dtype=uint8),
#   '1825 - Copy - Copy.jpg'],
#  [array([211, 154,  31, ...,   0,   0,  10], dtype=uint8),
#   '1826 - Copy - Copy.jpg'],
#  [array([ 8,  8, 14, ..., 40, 44, 49], dtype=uint8), '18283 - Copy.jpg'],
#  [array([185, 147, 112, ...,  21,  36,  45], dtype=uint8), '18289 - Copy.jpg'],
#  [array([ 49,  42,  15, ...,  88,  97, 107], dtype=uint8), '18331 - Copy.jpg'],
#  [array([178, 136, 101, ...,  25,  15,  21], dtype=uint8), '18335 - Copy.jpg'],
#  [array([22, 33, 31, ..., 40, 44, 45], dtype=uint8), '18419 - Copy.jpg'],
#  [array([242, 240, 240, ...,  57,  70,  72], dtype=uint8), '18456 - Copy.jpg'],
#  [array([254, 254, 254, ..., 255, 255, 255], dtype=uint8), '18496 - Copy.jpg'],
#  [array([130, 104,  90, ...,  38,  50,  54], dtype=uint8), '18550 - Copy.jpg'],
#  [array([ 1,  1,  1, ..., 17, 15, 34], dtype=uint8), '18593 - Copy.jpg'],
#  [array([174, 108,  55, ...,  56,  74,  97], dtype=uint8), '18668 - Copy.jpg'],
#  [array([217, 102,  52, ..., 144,  85,  65], dtype=uint8), '18756 - Copy.jpg'],
#  [array([ 94,  79,  53, ..., 161, 192, 213], dtype=uint8), '18758 - Copy.jpg'],
#  [array([91, 82, 73, ...,  6,  4,  4], dtype=uint8), '18854 - Copy.jpg'],
#  [array([28, 36, 36, ..., 20, 23, 31], dtype=uint8), '18883 - Copy.jpg'],
#  [array([  7, 162,  88, ...,  16,  34,  27], dtype=uint8), '18945.jpg'],
#  [array([24, 83, 52, ..., 19, 40, 37], dtype=uint8), '18947.jpg'],
#  [array([4, 4, 4, ..., 3, 4, 2], dtype=uint8), '18955.jpg'],
#  [array([158, 158, 158, ..., 102, 102, 102], dtype=uint8), '18992 - Copy.jpg'],
#  [array([ 0, 17,  5, ..., 12, 48, 12], dtype=uint8), '19075.jpg'],
#  [array([251, 255, 255, ...,  23, 106,  97], dtype=uint8), '1909 - Copy.jpg'],
#  [array([222, 223, 219, ...,  16,  28,  38], dtype=uint8), '19122.jpg'],
#  [array([222, 221, 211, ...,  61, 121, 127], dtype=uint8), '19127 - Copy.jpg'],
#  [array([179, 209, 220, ..., 156, 208, 238], dtype=uint8), '19140.jpg'],
#  [array([236, 217, 209, ...,  52,  52,  52], dtype=uint8), '19144.jpg'],
#  [array([234, 223, 219, ...,  17,  28,  25], dtype=uint8), '19150 - Copy.jpg'],
#  [array([ 32,  45,  37, ...,  35,  59, 111], dtype=uint8), '19153 - Copy.jpg'],
#  [array([200, 176, 156, ...,  15,  34,  37], dtype=uint8), '19156.jpg'],
#  [array([156, 104,  64, ...,  64,  42,  14], dtype=uint8), '19171.jpg'],
#  [array([69, 56, 48, ..., 13, 12,  8], dtype=uint8), '19176.jpg'],
#  [array([214, 177, 151, ..., 157, 152, 137], dtype=uint8), '19185.jpg'],
#  [array([254, 241, 225, ..., 187, 182, 191], dtype=uint8), '19187.jpg'],
#  [array([ 62, 117, 108, ...,  21,  58,  62], dtype=uint8), '19196.jpg'],
#  [array([136, 139, 144, ..., 222, 224, 234], dtype=uint8),
#   '192 - Copy - Copy.jpg'],
#  [array([231, 231, 231, ...,  82,  82,  82], dtype=uint8), '19267.jpg'],
#  [array([157,  69,  23, ..., 158, 167, 164], dtype=uint8), '19293 - Copy.jpg'],
#  [array([175, 142,  92, ...,  98, 114,  96], dtype=uint8), '19294.jpg'],
#  [array([129,  88,  33, ...,  53,  53,  53], dtype=uint8), '19304.jpg'],
#  [array([186, 186, 186, ...,  22,  10,  10], dtype=uint8), '19323.jpg'],
#  [array([213, 118,   1, ..., 123, 122, 108], dtype=uint8), '19328.jpg'],
#  [array([  9, 111,  16, ...,  23,  62,  17], dtype=uint8), '19359.jpg'],
#  [array([105,  74,  41, ...,   4,   4,   4], dtype=uint8), '19398.jpg'],
#  [array([153,  92,  48, ..., 173, 186, 194], dtype=uint8), '19407 - Copy.jpg'],
#  [array([157,  94,  73, ...,   4,   4,   4], dtype=uint8), '19447 - Copy.jpg'],
#  [array([159, 159, 159, ...,  26,  26,  26], dtype=uint8), '19584 - Copy.jpg'],
#  [array([255, 255, 251, ...,  58,  62,  67], dtype=uint8), '19638 - Copy.jpg'],
#  [array([182, 117,  73, ..., 100, 108, 108], dtype=uint8), '19693.jpg'],
#  [array([120, 118, 154, ..., 127, 122, 123], dtype=uint8),
#   '197 - Copy - Copy.jpg'],
#  [array([152, 127, 107, ..., 174, 158, 145], dtype=uint8), '19705.jpg'],
#  [array([117, 117, 117, ...,  51,  52,  50], dtype=uint8), '19789 - Copy.jpg'],
#  [array([179, 153, 116, ...,  61,  66,  65], dtype=uint8), '19854.jpg'],
#  [array([169,  79,  49, ..., 217, 238, 253], dtype=uint8), '19896 - Copy.jpg'],
#  [array([237, 194, 185, ...,  97, 104, 107], dtype=uint8), '19901 - Copy.jpg'],
#  [array([35, 36, 34, ..., 27, 32, 30], dtype=uint8), '19913 - Copy.jpg'],
#  [array([133, 138,  17, ...,  10,  18,   0], dtype=uint8), '19937.jpg'],
#  [array([195, 137,  72, ..., 106, 116, 110], dtype=uint8), '19967.jpg'],
#  [array([213, 164, 124, ..., 100,  61,   0], dtype=uint8), '20027 - Copy.jpg'],
#  [array([222, 219, 211, ...,   1,  42,  45], dtype=uint8), '2005 - Copy.jpg'],
#  [array([246, 252, 251, ...,  35,  44,  48], dtype=uint8), '20054 - Copy.jpg'],
#  [array([ 37,  41,  30, ..., 115, 114, 124], dtype=uint8), '20056.jpg'],
#  [array([174, 119,  92, ..., 251, 241, 234], dtype=uint8), '20057.jpg'],
#  [array([248, 245, 231, ..., 142, 140, 132], dtype=uint8), '20058.jpg'],
#  [array([136, 129, 120, ...,  98,  95,  80], dtype=uint8), '20059.jpg'],
#  [array([222, 182, 110, ..., 148, 153, 126], dtype=uint8), '20060.jpg'],
#  [array([247, 233, 227, ...,  34,  45,  49], dtype=uint8), '20061.jpg'],
#  [array([195, 147, 113, ...,  49,  52,  56], dtype=uint8), '20062.jpg'],
#  [array([238, 173, 145, ...,  37,  46,  36], dtype=uint8), '20064.jpg'],
#  [array([ 23,  65, 108, ..., 118, 144, 130], dtype=uint8), '20066.jpg'],
#  [array([159, 190, 205, ...,  22,  26,  31], dtype=uint8), '20067.jpg'],
#  [array([170,  96,  48, ..., 138, 137, 139], dtype=uint8), '20068.jpg'],
#  [array([ 10,  10,  10, ..., 181, 181, 181], dtype=uint8), '20069.jpg'],
#  [array([ 57,  79, 114, ...,  17,  21,  16], dtype=uint8), '20070.jpg'],
#  [array([169, 113,  84, ...,  36,  28,  29], dtype=uint8), '20071.jpg'],
#  [array([214, 147,  60, ...,  65,  87, 112], dtype=uint8), '20072.jpg'],
#  [array([145,  81,  40, ...,  17,  18,  22], dtype=uint8), '20073.jpg'],
#  [array([191, 188, 180, ...,  16,  73,  64], dtype=uint8), '20074.jpg'],
#  [array([ 4, 31, 22, ..., 40, 35, 34], dtype=uint8), '20075.jpg'],
#  [array([144,  90,  79, ...,  18,  58, 164], dtype=uint8), '20076.jpg'],
#  [array([210, 177, 157, ...,  91,  75,  58], dtype=uint8), '20077.jpg'],
#  [array([239, 158,  97, ...,  29,  83,  70], dtype=uint8), '20078.jpg'],
#  [array([13,  4,  0, ...,  9,  6,  2], dtype=uint8), '20079.jpg'],
#  [array([ 63,  86, 101, ...,  89,  95, 100], dtype=uint8), '20080.jpg'],
#  [array([201, 109,  74, ...,   2,   2,   2], dtype=uint8), '20081.jpg'],
#  [array([122, 163, 158, ...,  74, 134, 128], dtype=uint8), '20082.jpg'],
#  [array([255, 255, 255, ..., 126, 128, 146], dtype=uint8), '20083.jpg'],
#  [array([136, 167, 166, ...,  43,  38,  39], dtype=uint8), '20084.jpg'],
#  [array([255, 255, 254, ...,  68,  85,  82], dtype=uint8), '20085.jpg'],
#  [array([178, 153, 157, ...,  94,  61,  35], dtype=uint8), '20087.jpg'],
#  [array([148, 148, 148, ...,  85,  85,  85], dtype=uint8), '20088.jpg'],
#  [array([  2,  21,  12, ...,  91, 137, 161], dtype=uint8), '20089.jpg'],
#  [array([ 99, 111, 121, ...,  46,  42,  41], dtype=uint8), '20090.jpg'],
#  [array([90, 96, 91, ..., 15, 20, 19], dtype=uint8), '20091.jpg'],
#  [array([250, 234, 228, ..., 144, 130, 111], dtype=uint8), '20092.jpg'],
#  [array([216, 211, 208, ...,   0,   0,   0], dtype=uint8), '20093.jpg'],
#  [array([221, 149,  71, ..., 126, 131, 130], dtype=uint8), '20094.jpg'],
#  [array([ 51,  57,  46, ..., 148, 159, 126], dtype=uint8), '20095.jpg'],
#  [array([119, 121, 129, ..., 102, 101, 110], dtype=uint8), '20096.jpg'],
#  [array([30, 91, 33, ...,  0, 44,  4], dtype=uint8), '20098.jpg'],
#  [array([163, 124,  79, ...,  94,  89,  90], dtype=uint8), '20099.jpg'],
#  [array([124, 134,  74, ...,  31,  31,  31], dtype=uint8), '20100.jpg'],
#  [array([191, 186, 187, ...,  91,  91,  97], dtype=uint8), '20106.jpg'],
#  [array([168, 120,  78, ...,  27,  56,  61], dtype=uint8), '20107.jpg'],
#  [array([ 8, 62, 49, ..., 15, 27, 31], dtype=uint8), '20108.jpg'],
#  [array([187, 139, 103, ...,  26,  36,  36], dtype=uint8), '20109.jpg'],
#  [array([211, 199, 193, ...,  42,  46,  47], dtype=uint8), '20111.jpg'],
#  [array([249, 215, 199, ..., 234, 236, 236], dtype=uint8), '20112.jpg'],
#  [array([158, 152, 139, ...,   0,   4,   3], dtype=uint8), '20113.jpg'],
#  [array([ 62,  83, 105, ..., 160, 135, 119], dtype=uint8), '20114.jpg'],
#  [array([212, 196, 184, ...,  43,  50,  53], dtype=uint8), '20115.jpg'],
#  [array([137,  26,   0, ...,  75,  51,  63], dtype=uint8), '20116.jpg'],
#  [array([225, 220, 219, ...,  54,  63,  73], dtype=uint8), '20117.jpg'],
#  [array([246, 251, 250, ...,   0,   7,  10], dtype=uint8), '20120.jpg'],
#  [array([252, 205, 151, ...,  90, 157, 172], dtype=uint8), '20123.jpg'],
#  [array([141, 107,  83, ..., 117,  77,  52], dtype=uint8), '20124.jpg'],
#  [array([178, 182, 206, ..., 128, 130, 148], dtype=uint8), '20126.jpg'],
#  [array([ 2,  6,  0, ..., 59, 54, 75], dtype=uint8), '20127.jpg'],
#  [array([228, 233, 234, ...,   3,   8,   6], dtype=uint8), '20129.jpg'],
#  [array([235, 239, 244, ..., 168, 194, 211], dtype=uint8), '20131.jpg'],
#  [array([242, 169,  89, ...,  97, 109, 111], dtype=uint8), '20133.jpg'],
#  [array([ 35, 114, 147, ...,   0,   0,  35], dtype=uint8), '20134.jpg'],
#  [array([244, 244, 244, ..., 162, 167, 170], dtype=uint8), '20136.jpg'],
#  [array([ 52,  81, 102, ...,  75,  80,  79], dtype=uint8), '20137.jpg'],
#  [array([236, 218, 187, ..., 111, 148, 138], dtype=uint8), '20138.jpg'],
#  [array([188, 148, 119, ...,   9,  10,   8], dtype=uint8), '20140.jpg'],
#  [array([148, 137, 115, ..., 134, 121,  95], dtype=uint8), '20142.jpg'],
#  [array([242, 247, 248, ...,  46,  41,  43], dtype=uint8), '20144.jpg'],
#  [array([64, 87, 89, ..., 35, 26, 23], dtype=uint8), '20147.jpg'],
#  [array([ 95, 123, 123, ..., 232, 237, 240], dtype=uint8), '20148.jpg'],
#  [array([222, 222, 222, ..., 217, 217, 217], dtype=uint8), '20150.jpg'],
#  [array([ 59, 150,  95, ...,   0, 112,  14], dtype=uint8), '20151.jpg'],
#  [array([95, 75, 80, ..., 85, 82, 97], dtype=uint8), '20152.jpg'],
#  [array([251, 216, 143, ...,  16,  16,  10], dtype=uint8), '20153.jpg'],
#  [array([228, 223, 224, ...,  41,  51,  68], dtype=uint8), '20154.jpg'],
#  [array([188, 177, 163, ..., 110, 145, 159], dtype=uint8), '20157.jpg'],
#  [array([38, 49, 76, ..., 40, 80, 99], dtype=uint8), '20158.jpg'],
#  [array([ 72,  72,  72, ..., 242, 242, 242], dtype=uint8), '20159.jpg'],
#  [array([163,  91,  57, ..., 162, 132, 121], dtype=uint8), '20160.jpg'],
#  [array([  4,  11,   8, ..., 125, 161, 207], dtype=uint8), '20161.jpg'],
#  [array([ 6,  4, 10, ...,  1, 10, 20], dtype=uint8), '20162.jpg'],
#  [array([185,  97,  43, ...,  36,  30,  25], dtype=uint8), '20163.jpg'],
#  [array([1, 0, 2, ..., 6, 6, 6], dtype=uint8), '20164.jpg'],
#  [array([139, 136, 128, ..., 177, 201, 223], dtype=uint8), '20165.jpg'],
#  [array([124, 130, 129, ...,   9,  17,  17], dtype=uint8), '20166.jpg'],
#  [array([141, 131, 101, ...,  10,   9,  13], dtype=uint8), '20167.jpg'],
#  [array([189, 147, 104, ...,  37,  22,   6], dtype=uint8), '20168.jpg'],
#  [array([123,  56,  29, ...,  46,  39,  36], dtype=uint8), '20170.jpg'],
#  [array([109,  92,  83, ..., 191, 179, 177], dtype=uint8), '20171.jpg'],
#  [array([167, 108,  52, ..., 176, 189, 197], dtype=uint8), '20172.jpg'],
#  [array([ 45, 104,  76, ...,  44,  65,  96], dtype=uint8), '20173.jpg'],
#  [array([111, 125, 137, ...,  18,  11,   8], dtype=uint8), '20174.jpg'],
#  [array([66, 57, 60, ..., 51, 72, 63], dtype=uint8), '20175.jpg'],
#  [array([240, 192, 144, ...,  14,  30,  19], dtype=uint8), '20176.jpg'],
#  [array([160, 191, 212, ...,  37,  37,  37], dtype=uint8), '20177.jpg'],
#  [array([124, 145, 160, ...,  26,  45,  60], dtype=uint8), '20178.jpg'],
#  [array([255, 253, 249, ...,  79,  78,  82], dtype=uint8), '20179.jpg'],
#  [array([190, 199, 202, ...,  27,  31,  32], dtype=uint8), '20181.jpg'],
#  [array([21, 21, 21, ..., 16, 16, 16], dtype=uint8), '20183.jpg'],
#  [array([56, 60, 61, ..., 56, 56, 56], dtype=uint8), '20184.jpg'],
#  [array([ 47,  15,   2, ..., 109, 136, 127], dtype=uint8), '20185.jpg'],
#  [array([ 1,  0, 10, ...,  7, 21, 19], dtype=uint8), '20186.jpg'],
#  [array([137,  86,  46, ..., 187, 178, 165], dtype=uint8), '20187.jpg'],
#  [array([125,  81,  40, ...,   6,   4,   4], dtype=uint8), '20189.jpg'],
#  [array([130, 122, 122, ...,  88,  88,  88], dtype=uint8), '20190.jpg'],
#  [array([ 43,  40,  35, ..., 137, 136, 138], dtype=uint8), '20191.jpg'],
#  [array([ 51, 106, 149, ...,  63,  59,  64], dtype=uint8), '20194.jpg'],
#  [array([81, 54, 33, ..., 35, 30, 29], dtype=uint8), '20195.jpg'],
#  [array([ 76,  79,  83, ..., 216, 216, 216], dtype=uint8), '20198.jpg'],
#  [array([216, 142,  84, ...,  42,  39,  35], dtype=uint8), '20202.jpg'],
#  [array([196, 125,  62, ..., 183, 159, 137], dtype=uint8), '20204.jpg'],
#  [array([175,  65,   0, ...,   2,   6,  11], dtype=uint8), '20206.jpg'],
#  [array([0, 2, 0, ..., 3, 5, 5], dtype=uint8), '20207.jpg'],
#  [array([118, 132, 138, ...,  80,  83,  88], dtype=uint8), '20209.jpg'],
#  [array([195, 157, 153, ..., 213, 192, 190], dtype=uint8), '20210.jpg'],
#  [array([253, 236, 249, ...,  56,  68,  70], dtype=uint8), '20211.jpg'],
#  [array([184, 165, 157, ...,  89,  88,  74], dtype=uint8), '20212.jpg'],
#  [array([31, 10, 43, ..., 35, 12, 34], dtype=uint8), '20216.jpg'],
#  [array([239, 244, 245, ..., 146, 142, 177], dtype=uint8), '20218.jpg'],
#  [array([ 92, 135, 184, ...,  94,  96,  96], dtype=uint8), '20221.jpg'],
#  [array([123, 150, 184, ...,  91,  71,  66], dtype=uint8), '20222.jpg'],
#  [array([  0, 156,  83, ...,   4,  67,  27], dtype=uint8), '20225.jpg'],
#  [array([232, 222, 222, ...,  12,  37,  39], dtype=uint8), '20226.jpg'],
#  [array([182, 125,  74, ..., 131, 153, 158], dtype=uint8), '20227.jpg'],
#  [array([164, 151, 149, ..., 123, 141, 164], dtype=uint8), '20228.jpg'],
#  [array([22, 38, 51, ..., 22, 55, 74], dtype=uint8), '20229.jpg'],
#  [array([179, 135,  94, ..., 129, 132, 130], dtype=uint8), '20230.jpg'],
#  [array([ 0,  0, 30, ..., 26, 36, 43], dtype=uint8), '20231.jpg'],
#  [array([226, 222, 227, ...,  43,  50,  53], dtype=uint8), '20232.jpg'],
#  [array([114, 123, 133, ..., 118, 101,  98], dtype=uint8), '20234.jpg'],
#  [array([130, 116, 104, ...,  67,  65,  64], dtype=uint8), '20236.jpg'],
#  [array([2, 2, 2, ..., 6, 8, 8], dtype=uint8), '20238.jpg'],
#  [array([178, 126,  96, ...,  34,  46,  48], dtype=uint8), '20240.jpg'],
#  [array([234, 224, 236, ..., 222, 214, 225], dtype=uint8), '20241.jpg'],
#  [array([137, 125, 115, ..., 145, 139, 156], dtype=uint8), '20242.jpg'],
#  [array([207, 158, 108, ..., 116,  88,  53], dtype=uint8), '20243.jpg'],
#  [array([192, 149, 106, ...,  98, 110, 116], dtype=uint8), '20245.jpg'],
#  [array([210, 210, 210, ..., 144, 144, 144], dtype=uint8), '20246.jpg'],
#  [array([154, 137, 116, ...,  25,  21,   0], dtype=uint8), '20247.jpg'],
#  [array([133,  64,  25, ..., 159, 133,  97], dtype=uint8), '20249.jpg'],
#  [array([5, 3, 3, ..., 4, 6, 6], dtype=uint8), '20250.jpg'],
#  [array([ 60, 192, 125, ...,  10, 188, 121], dtype=uint8), '20252.jpg'],
#  [array([225, 154,  90, ..., 195, 134,  72], dtype=uint8), '20253.jpg'],
#  [array([231, 244, 242, ..., 251, 251, 251], dtype=uint8), '20255.jpg'],
#  [array([57, 58, 62, ..., 64, 66, 76], dtype=uint8), '20256.jpg'],
#  [array([170, 116,  55, ..., 170, 164, 157], dtype=uint8), '20257.jpg'],
#  [array([17, 18, 38, ...,  0, 13, 81], dtype=uint8), '20259.jpg'],
#  [array([ 26, 121, 107, ...,  16,  19,  17], dtype=uint8), '20260.jpg'],
#  [array([76, 88, 88, ..., 10,  0,  4], dtype=uint8), '20261.jpg'],
#  [array([40, 20,  2, ...,  2,  2,  2], dtype=uint8), '20264.jpg'],
#  [array([244, 204, 152, ..., 145, 130,  91], dtype=uint8), '20265.jpg'],
#  [array([ 35,  86, 178, ..., 186, 176, 182], dtype=uint8), '20266.jpg'],
#  [array([130, 118, 108, ..., 118, 116, 115], dtype=uint8), '20267.jpg'],
#  [array([ 90,  88,  88, ..., 177, 174, 176], dtype=uint8), '20268.jpg'],
#  [array([43, 43, 43, ...,  0,  0,  0], dtype=uint8), '20269.jpg'],
#  [array([ 1,  6, 67, ...,  6,  8,  8], dtype=uint8), '20270.jpg'],
#  [array([129,  85,   1, ...,  67, 104, 148], dtype=uint8), '20271.jpg'],
#  [array([232, 231, 227, ...,  28,  27,  31], dtype=uint8), '20272.jpg'],
#  [array([176, 120,  65, ..., 104, 111, 120], dtype=uint8), '20273.jpg'],
#  [array([18, 16, 16, ...,  4,  4,  4], dtype=uint8), '20274.jpg'],
#  [array([194, 149, 106, ...,  42,  32,  22], dtype=uint8), '20275.jpg'],
#  [array([248, 248, 248, ...,  23,  26,  24], dtype=uint8), '20276.jpg'],
#  [array([253, 221, 186, ..., 112, 107,  98], dtype=uint8), '20277.jpg'],
#  [array([224, 159,  98, ...,  65,  39,  22], dtype=uint8), '20281.jpg'],
#  [array([250, 230, 213, ...,  27,  41,  39], dtype=uint8), '20282.jpg'],
#  [array([219, 197, 186, ...,  12,  10,   9], dtype=uint8), '20283.jpg'],
#  [array([224, 230, 229, ...,  33,  65,  88], dtype=uint8), '20285.jpg'],
#  [array([107,  87,  82, ...,  20,  23,  21], dtype=uint8), '20286.jpg'],
#  [array([81, 56, 46, ..., 58, 58, 58], dtype=uint8), '20287.jpg'],
#  [array([ 64,  92, 230, ...,   6,  10, 128], dtype=uint8), '20288.jpg'],
#  [array([152, 125,  91, ...,  92, 106, 128], dtype=uint8), '20289.jpg'],
#  [array([215, 206, 202, ...,  96, 115, 136], dtype=uint8), '20292.jpg'],
#  [array([183, 100,  78, ...,  56,  54,  73], dtype=uint8), '20293.jpg'],
#  [array([166, 159, 142, ...,  75,  98,  94], dtype=uint8), '20294.jpg'],
#  [array([37, 37, 37, ..., 49, 53, 81], dtype=uint8), '20296.jpg'],
#  [array([254, 143,  43, ...,  62,  57,  58], dtype=uint8), '20297.jpg'],
#  [array([165, 192, 188, ...,  55,  61,  74], dtype=uint8), '20299.jpg'],
#  [array([212, 212, 212, ...,  49,  49,  49], dtype=uint8), '20300.jpg'],
#  [array([183, 187, 198, ..., 143, 147, 166], dtype=uint8), '20303.jpg'],
#  [array([175, 131, 114, ...,   2,  22,  33], dtype=uint8), '20304.jpg'],
#  [array([174, 167, 158, ...,  33,  38,  37], dtype=uint8), '20305.jpg'],
#  [array([46, 65, 86, ..., 56, 79, 74], dtype=uint8), '20306.jpg'],
#  [array([238, 234, 240, ..., 231, 225, 220], dtype=uint8), '20307.jpg'],
#  [array([191, 146,  95, ...,  70,  76,  89], dtype=uint8), '20309.jpg'],
#  [array([151, 120,  97, ..., 250, 247, 242], dtype=uint8), '20310.jpg'],
#  [array([24, 41, 44, ..., 11, 39, 46], dtype=uint8), '20311.jpg'],
#  [array([141, 141, 141, ...,  83,  83,  83], dtype=uint8), '20313.jpg'],
#  [array([86, 79, 76, ..., 40, 29, 31], dtype=uint8), '20314.jpg'],
#  [array([249, 255, 243, ...,   0,  63,  52], dtype=uint8), '20315.jpg'],
#  [array([246, 195, 155, ...,  55,  36,  21], dtype=uint8), '20316.jpg'],
#  [array([251, 228, 196, ..., 139, 186, 207], dtype=uint8), '20317.jpg'],
#  [array([151, 151, 151, ...,  90,  90,  90], dtype=uint8), '20318.jpg'],
#  [array([ 3,  3,  3, ...,  0, 32, 19], dtype=uint8), '20319.jpg'],
#  [array([202, 172, 161, ..., 193, 184, 181], dtype=uint8), '20320.jpg'],
#  [array([ 11,  19,  19, ...,  39, 190, 145], dtype=uint8), '20322.jpg'],
#  [array([ 40,  30,  23, ..., 107,  96,  82], dtype=uint8), '20326.jpg'],
#  [array([245, 244, 246, ...,  99, 147, 151], dtype=uint8), '20327.jpg'],
#  [array([147, 147, 147, ...,  45,  45,  45], dtype=uint8), '20328.jpg'],
#  [array([141, 100,  67, ..., 127, 130, 138], dtype=uint8), '20329.jpg'],
#  [array([153, 147, 142, ...,  14,  19,  18], dtype=uint8), '20330.jpg'],
#  [array([ 0,  3, 12, ..., 62, 68, 79], dtype=uint8), '20331.jpg'],
#  [array([41, 51, 39, ..., 49, 38, 30], dtype=uint8), '20332.jpg'],
#  [array([213, 170, 131, ...,  13,  10,   6], dtype=uint8), '20333.jpg'],
#  [array([231, 223, 216, ...,  60,  74,  86], dtype=uint8), '20334.jpg'],
#  [array([37, 43, 72, ...,  4,  2,  2], dtype=uint8), '20335.jpg'],
#  [array([255, 247, 255, ..., 196, 186, 198], dtype=uint8), '20336.jpg'],
#  [array([14,  2,  8, ...,  2,  9, 24], dtype=uint8), '20337.jpg'],
#  [array([254, 254, 254, ...,  68,  99, 124], dtype=uint8), '20341.jpg'],
#  [array([228, 255, 235, ..., 106, 108, 118], dtype=uint8), '20342.jpg'],
#  [array([129, 212, 210, ..., 114, 120, 109], dtype=uint8), '20343.jpg'],
#  [array([196, 192, 187, ...,  21,  21,  21], dtype=uint8), '20344.jpg'],
#  [array([94, 84, 90, ..., 20, 14,  9], dtype=uint8), '20345.jpg'],
#  [array([215, 221, 234, ..., 170, 157, 149], dtype=uint8), '20346.jpg'],
#  [array([210, 171, 126, ...,  21,   1,   0], dtype=uint8), '20347.jpg'],
#  [array([94, 90, 89, ...,  1,  1,  1], dtype=uint8), '20348.jpg'],
#  [array([152, 112,  83, ...,  26,  24,  14], dtype=uint8), '20350.jpg'],
#  [array([208, 177, 156, ...,  37,  27,  27], dtype=uint8), '20352.jpg'],
#  [array([171, 149, 124, ...,  29,  27,  39], dtype=uint8), '20353.jpg'],
#  [array([186, 167, 154, ...,  46,  58,  62], dtype=uint8), '20355.jpg'],
#  [array([ 88,  48,   0, ..., 184, 179, 170], dtype=uint8), '20356.jpg'],
#  [array([3, 3, 0, ..., 2, 0, 0], dtype=uint8), '20357.jpg'],
#  [array([160, 133, 119, ...,  17,  18,  16], dtype=uint8), '20358.jpg'],
#  [array([24, 30, 35, ..., 24, 29, 32], dtype=uint8), '20359.jpg'],
#  [array([162, 127, 117, ..., 188, 179, 176], dtype=uint8), '20362.jpg'],
#  [array([219, 190, 183, ...,  16,  19,  17], dtype=uint8), '20363.jpg'],
#  [array([24, 24, 42, ..., 56, 65, 74], dtype=uint8), '20365.jpg'],
#  [array([ 0,  0, 11, ..., 10, 14, 15], dtype=uint8), '20366.jpg'],
#  [array([146, 100,  69, ...,  40,  37,  33], dtype=uint8), '20367.jpg'],
#  [array([ 0, 13, 20, ..., 43, 56, 64], dtype=uint8), '20370.jpg'],
#  [array([181, 176, 178, ...,  60,  46,  17], dtype=uint8), '20371.jpg'],
#  [array([157, 142, 126, ..., 181, 170, 166], dtype=uint8), '20372.jpg'],
#  [array([122,  52,  15, ..., 150, 143, 146], dtype=uint8), '20373.jpg'],
#  [array([ 0,  3,  1, ..., 38, 31, 22], dtype=uint8), '20374.jpg'],
#  [array([150, 135,  63, ...,  30,  19,  11], dtype=uint8), '20378.jpg'],
#  [array([106,  93, 101, ..., 111, 113, 114], dtype=uint8), '20379.jpg'],
#  [array([217, 205, 187, ..., 108,  93,  84], dtype=uint8), '20380.jpg'],
#  [array([186, 163, 125, ...,  10,   2,   3], dtype=uint8), '20382.jpg'],
#  [array([ 72,  55, 152, ..., 164, 196, 225], dtype=uint8), '20383.jpg'],
#  [array([ 32, 157,  83, ..., 127, 159, 170], dtype=uint8), '20384.jpg'],
#  [array([108,  74,  45, ..., 164, 141, 115], dtype=uint8), '20386.jpg'],
#  [array([111,  96,  63, ...,  37, 142, 156], dtype=uint8), '20387.jpg'],
#  [array([ 9,  4,  5, ..., 13, 32, 37], dtype=uint8), '20388.jpg'],
#  [array([ 19,  25,  38, ...,  90,  97, 112], dtype=uint8), '20389.jpg'],
#  [array([252, 197, 158, ...,  80,  59,  51], dtype=uint8), '20390.jpg'],
#  [array([206, 179, 153, ...,  45,  80,  83], dtype=uint8), '20392.jpg'],
#  [array([ 46,  44,  34, ..., 197, 201, 189], dtype=uint8), '20393.jpg'],
#  [array([253, 255, 254, ..., 119, 121, 122], dtype=uint8), '20394.jpg'],
#  [array([252, 167,  75, ...,  84, 106, 147], dtype=uint8), '20395.jpg'],
#  [array([255, 255, 255, ...,  11,  66,  47], dtype=uint8), '20397.jpg'],
#  [array([217, 201, 184, ...,  67,  72,  71], dtype=uint8), '20398.jpg'],
#  [array([72, 72, 72, ..., 39, 39, 39], dtype=uint8), '20400.jpg'],
#  [array([153, 147, 140, ...,  35,  59,  81], dtype=uint8), '20401.jpg'],
#  [array([129,  85,  56, ...,  11,   4,   7], dtype=uint8), '20402.jpg'],
#  [array([106, 107, 105, ..., 125, 130, 131], dtype=uint8), '20405.jpg'],
#  [array([146, 137, 127, ..., 146, 143, 135], dtype=uint8), '20406.jpg'],
#  [array([146, 108,  76, ..., 108, 104,  93], dtype=uint8), '20408.jpg'],
#  [array([197, 197, 197, ..., 103, 103,  97], dtype=uint8), '20409.jpg'],
#  [array([62, 56, 27, ..., 15, 46, 37], dtype=uint8), '20411.jpg'],
#  [array([41, 44, 29, ..., 29, 26, 18], dtype=uint8), '20413.jpg'],
#  [array([184, 165, 160, ..., 139, 125, 103], dtype=uint8), '20414.jpg'],
#  [array([215, 195, 190, ...,   7,  26,  39], dtype=uint8), '20416.jpg'],
#  [array([11, 37, 49, ...,  0, 18, 31], dtype=uint8), '20417.jpg'],
#  [array([212, 204, 197, ..., 102,  96,  77], dtype=uint8), '20418.jpg'],
#  [array([247, 236, 216, ...,  70,  89,  97], dtype=uint8), '20419.jpg'],
#  [array([169, 155, 137, ...,  10,  15,  14], dtype=uint8), '20421.jpg'],
#  [array([135,  97,  55, ..., 136, 148, 142], dtype=uint8), '20423.jpg'],
#  [array([225, 210, 194, ...,  52, 127, 125], dtype=uint8), '20424.jpg'],
#  [array([254, 201, 191, ...,  22,  53,  56], dtype=uint8), '20425.jpg'],
#  [array([169,  91,  44, ..., 136, 142, 141], dtype=uint8), '20427.jpg'],
#  [array([242, 242, 242, ...,  39,  39,  39], dtype=uint8), '20430.jpg'],
#  [array([79, 83, 94, ..., 35, 33, 32], dtype=uint8), '20431.jpg'],
#  [array([99, 96, 98, ..., 60, 58, 58], dtype=uint8), '20432.jpg'],
#  [array([208, 206, 196, ..., 157, 150, 131], dtype=uint8), '20433.jpg'],
#  [array([214, 203, 205, ...,  32,  61,  58], dtype=uint8), '20435.jpg'],
#  [array([154,  78,  36, ...,   9,   6,   2], dtype=uint8), '20436.jpg'],
#  [array([251, 252, 248, ...,  40, 107, 134], dtype=uint8), '20438.jpg'],
#  [array([11, 35, 33, ..., 11, 17, 24], dtype=uint8), '20439.jpg'],
#  [array([255, 255, 255, ...,  62,  78,  90], dtype=uint8), '20440.jpg'],
#  [array([39, 38, 40, ..., 18, 25, 28], dtype=uint8), '20441.jpg'],
#  [array([221, 224, 229, ...,  59,  61,  71], dtype=uint8), '20443.jpg'],
#  [array([126,  30,  14, ...,  39,  49,  33], dtype=uint8), '20444.jpg'],
#  [array([215, 209, 180, ...,  20,  27,  12], dtype=uint8), '20446.jpg'],
#  [array([ 21,  60,  35, ...,  26, 100,  70], dtype=uint8), '20447.jpg'],
#  [array([ 24,  37,  29, ...,  86,  95, 104], dtype=uint8), '20448.jpg'],
#  [array([114,  47,  22, ...,  60,  68,  67], dtype=uint8), '20449.jpg'],
#  [array([222, 182, 123, ...,  68, 106, 118], dtype=uint8), '20450.jpg'],
#  [array([233, 231, 223, ...,  68,  81,  95], dtype=uint8), '20454.jpg'],
#  [array([126,  61,   0, ...,   3,  20,  11], dtype=uint8), '20455.jpg'],
#  [array([178, 140, 110, ...,  83,  59,  39], dtype=uint8), '20457.jpg'],
#  [array([ 59,  63,  64, ..., 112, 107, 104], dtype=uint8), '20458.jpg'],
#  [array([123,  78,  75, ...,  26,  19,  32], dtype=uint8), '20459.jpg'],
#  [array([183, 177, 172, ...,  23,  21,  27], dtype=uint8), '20460.jpg'],
#  [array([119,  85,  56, ..., 158, 167, 180], dtype=uint8), '20461.jpg'],
#  [array([227, 221, 226, ...,  12,   6,   0], dtype=uint8), '20464.jpg'],
#  [array([165, 168, 173, ...,  44,  38,  33], dtype=uint8), '20465.jpg'],
#  [array([136,  67,  28, ..., 178, 169, 165], dtype=uint8), '20467.jpg'],
#  [array([211, 102,   0, ..., 148, 162, 128], dtype=uint8), '20472.jpg'],
#  [array([222, 187, 153, ...,   6,   1,   2], dtype=uint8), '20473.jpg'],
#  [array([223, 225, 219, ...,  88, 113, 133], dtype=uint8), '20474.jpg'],
#  [array([180,  98,  63, ...,  42,  48,  47], dtype=uint8), '20475.jpg'],
#  [array([107,  90,  39, ...,  50,  66,  78], dtype=uint8), '20476.jpg'],
#  [array([170, 154, 155, ..., 179, 175, 164], dtype=uint8), '20477.jpg'],
#  [array([248, 224, 212, ...,   0,  21,  23], dtype=uint8), '20479.jpg'],
#  [array([131, 131, 131, ...,  68,  68,  68], dtype=uint8), '20480.jpg'],
#  [array([146,  84,  20, ...,  37,  49,  49], dtype=uint8), '20482.jpg'],
#  [array([204, 192, 186, ...,  66,  67,  65], dtype=uint8), '20484.jpg'],
#  [array([ 3, 34, 25, ...,  0,  0,  7], dtype=uint8), '20485.jpg'],
#  [array([32, 29, 21, ..., 18, 23, 21], dtype=uint8), '20486.jpg'],
#  [array([250, 251, 255, ...,  74,  73,  77], dtype=uint8), '20487.jpg'],
#  [array([239, 241, 242, ..., 157, 163, 162], dtype=uint8), '20489.jpg'],
#  [array([232, 218, 189, ..., 172, 167, 158], dtype=uint8), '20490.jpg'],
#  [array([ 33,  68,  54, ..., 208, 210, 210], dtype=uint8), '20491.jpg'],
#  [array([16, 18, 19, ..., 50, 66, 65], dtype=uint8), '20493.jpg'],
#  [array([201, 124, 128, ...,   0,   0,   8], dtype=uint8), '20494.jpg'],
#  [array([152, 118,  95, ..., 206, 199, 196], dtype=uint8), '20495.jpg'],
#  [array([231, 208, 163, ...,  10,  15,  13], dtype=uint8), '20497.jpg'],
#  [array([77, 77, 77, ..., 26, 26, 26], dtype=uint8), '20498.jpg'],
#  [array([ 43,  54,  62, ...,  61, 102, 104], dtype=uint8), '20502.jpg'],
#  [array([ 43,  53,  63, ...,  69, 121, 157], dtype=uint8), '20504.jpg'],
#  [array([ 89,  99, 106, ..., 192, 194, 194], dtype=uint8), '20508.jpg'],
#  [array([ 32,  45,  43, ..., 155, 176, 143], dtype=uint8), '20510.jpg'],
#  [array([145,  61,  33, ...,  14,  36,  24], dtype=uint8), '20511.jpg'],
#  [array([255, 255, 246, ...,  87,  91,  66], dtype=uint8), '20512.jpg'],
#  [array([208, 199, 190, ..., 168, 157, 153], dtype=uint8), '20513.jpg'],
#  [array([166,  93,  33, ...,   0,   3,   3], dtype=uint8), '20515.jpg'],
#  [array([155, 153, 153, ...,  40,  66,  80], dtype=uint8), '20516.jpg'],
#  [array([119,  63,   4, ..., 236, 234, 234], dtype=uint8), '20517.jpg'],
#  [array([234, 222, 210, ..., 135, 156, 183], dtype=uint8), '20519.jpg'],
#  [array([41, 46, 44, ...,  8,  3,  0], dtype=uint8), '20520.jpg'],
#  [array([217,  90,   0, ...,  66,  42,  44], dtype=uint8), '20522.jpg'],
#  [array([219, 154,  86, ...,   0,   1,   5], dtype=uint8), '20524.jpg'],
#  [array([233, 211, 193, ..., 130, 118, 106], dtype=uint8), '20527.jpg'],
#  [array([194, 117,  55, ..., 145, 156, 176], dtype=uint8), '20528.jpg'],
#  [array([213, 194,  65, ...,   7,  37,  78], dtype=uint8), '20530.jpg'],
#  [array([200, 129,  79, ...,  48,  24,  18], dtype=uint8), '20531.jpg'],
#  [array([17, 40, 32, ...,  0,  4,  0], dtype=uint8), '20533.jpg'],
#  [array([213, 213, 213, ...,   2,   2,   2], dtype=uint8), '20534.jpg'],
#  [array([237, 199, 175, ...,  92,  97,  96], dtype=uint8), '20535.jpg'],
#  [array([255, 255, 255, ..., 174, 191, 204], dtype=uint8), '20536.jpg'],
#  [array([254, 255, 253, ..., 255, 255, 255], dtype=uint8), '20537.jpg'],
#  [array([50, 33,  0, ..., 21, 43, 38], dtype=uint8), '20539.jpg'],
#  [array([191, 154, 110, ..., 189, 183, 178], dtype=uint8), '20540.jpg'],
#  [array([209, 111,   0, ..., 159, 191, 204], dtype=uint8), '20541.jpg'],
#  [array([ 2, 11,  8, ..., 24, 35, 32], dtype=uint8), '20544.jpg'],
#  [array([232, 212, 201, ..., 136, 146, 153], dtype=uint8), '20545.jpg'],
#  [array([250, 245, 246, ...,  57, 103,  97], dtype=uint8), '20546.jpg'],
#  [array([243, 188, 161, ...,   0,   0,   0], dtype=uint8), '20549.jpg'],
#  [array([194, 155, 123, ...,   9,  19,   3], dtype=uint8), '20550.jpg'],
#  [array([53, 26, 12, ..., 46, 49, 53], dtype=uint8), '20553.jpg'],
# ...
#  [array([189, 148, 123, ...,  18,  70,  77], dtype=uint8), '20740.jpg'],
#  [array([161, 145, 138, ...,  57,  67,  84], dtype=uint8), '20741.jpg'],
#  [array([147,  97,  55, ..., 165, 162, 164], dtype=uint8), '20742.jpg'],
#  [array([202, 129,  55, ...,   8,  56,  58], dtype=uint8), '20745.jpg'],
#  [array([232, 215, 206, ...,  82,  84,  84], dtype=uint8), '20746.jpg'],
#  [array([  8,  14,  33, ...,  91, 122, 191], dtype=uint8), '20748.jpg'],
#  [array([ 84, 101, 114, ...,  87, 103, 119], dtype=uint8), '20750.jpg'],
#  [array([227, 212, 210, ..., 141, 132,  99], dtype=uint8), '20751.jpg'],
#  [array([253, 250, 246, ..., 136, 132, 127], dtype=uint8), '20752.jpg'],
#  [array([76, 64, 54, ..., 21, 27, 16], dtype=uint8), '20753.jpg'],
#  [array([ 0,  8,  8, ...,  0, 19, 19], dtype=uint8), '20754.jpg'],
#  [array([ 56,  76,  77, ..., 106, 104, 116], dtype=uint8), '20756.jpg'],
#  [array([162, 142, 124, ...,  29,  24,  15], dtype=uint8), '20757.jpg'],
#  [array([239, 214, 188, ..., 228, 191, 157], dtype=uint8), '20759.jpg'],
#  [array([ 48,  43,  40, ..., 115, 188, 126], dtype=uint8), '20761.jpg'],
#  [array([177, 136,  74, ...,  90,  96, 103], dtype=uint8), '20762.jpg'],
#  [array([215, 186, 159, ..., 165, 160, 157], dtype=uint8), '20763.jpg'],
#  [array([222, 218, 160, ...,  40,  31,  27], dtype=uint8), '20764.jpg'],
#  [array([109, 100,  96, ...,  67,  64,  56], dtype=uint8), '20765.jpg'],
#  [array([247, 202, 168, ...,  22,  28,  35], dtype=uint8), '20766.jpg'],
#  [array([215, 208, 191, ...,  58, 110, 123], dtype=uint8), '20767.jpg'],
#  [array([ 84,  68,  55, ..., 103, 141, 173], dtype=uint8), '20769.jpg'],
#  [array([144, 115,  84, ...,  16,  39,  47], dtype=uint8), '20770.jpg'],
#  [array([ 50,  59,  93, ...,  53, 109, 120], dtype=uint8), '20771.jpg'],
#  [array([  0, 136,  76, ...,   0,   7,  81], dtype=uint8), '20774.jpg'],
#  [array([236, 191, 130, ...,  52,  50,  50], dtype=uint8), '20776.jpg'],
#  [array([124, 121, 130, ...,  19,  22,  30], dtype=uint8), '20777.jpg'],
#  [array([16, 33, 29, ..., 20, 61, 56], dtype=uint8), '20779.jpg'],
#  [array([255, 255, 255, ...,  45,  75,  80], dtype=uint8), '20781.jpg'],
#  [array([200, 255, 192, ..., 238, 249, 223], dtype=uint8), '20782.jpg'],
#  [array([207, 200, 175, ..., 141,  97,  74], dtype=uint8), '20783.jpg'],
#  [array([ 58, 113,  50, ...,  39,  53,  49], dtype=uint8), '20785.jpg'],
#  [array([219, 167, 121, ...,  95,  97,  97], dtype=uint8), '20788.jpg'],
#  [array([ 45,  99,  69, ...,  55,  75, 100], dtype=uint8), '20794.jpg'],
#  [array([75, 56, 19, ...,  4,  0,  0], dtype=uint8), '20796.jpg'],
#  [array([ 98, 116, 133, ..., 161, 154, 157], dtype=uint8), '20798.jpg'],
#  [array([184, 128,  87, ...,   4,  21,  18], dtype=uint8), '20799.jpg'],
#  [array([145, 188, 185, ...,  26,  59,  74], dtype=uint8), '20800.jpg'],
#  [array([ 0, 13, 22, ...,  0,  0, 22], dtype=uint8), '20801.jpg'],
#  [array([160, 142, 131, ..., 160, 133, 112], dtype=uint8), '20802.jpg'],
#  [array([179, 191, 195, ...,   0,   9,   3], dtype=uint8), '20804.jpg'],
#  [array([255, 255, 255, ...,  42,  50,  57], dtype=uint8), '20805.jpg'],
#  [array([110, 130, 135, ..., 196, 207, 205], dtype=uint8), '20806.jpg'],
#  [array([60, 74, 72, ...,  7,  0,  0], dtype=uint8), '20807.jpg'],
#  [array([207, 205, 171, ...,  56,  65,  52], dtype=uint8), '20808.jpg'],
#  [array([253, 252, 248, ..., 128, 123, 124], dtype=uint8), '20810.jpg'],
#  [array([205, 187, 180, ...,  42,  46,  47], dtype=uint8), '20811.jpg'],
#  [array([11, 13, 13, ...,  6,  8,  8], dtype=uint8), '20812.jpg'],
#  [array([26, 36, 53, ..., 34, 36, 36], dtype=uint8), '20813.jpg'],
#  [array([109, 110,  78, ..., 222, 220, 209], dtype=uint8), '20815.jpg'],
#  [array([ 70,  76,  53, ..., 108,  81,  60], dtype=uint8), '20816.jpg'],
#  [array([ 6,  6,  6, ...,  2,  3, 31], dtype=uint8), '20818.jpg'],
#  [array([204, 217, 203, ..., 169, 176, 173], dtype=uint8), '20819.jpg'],
#  [array([134,  49,  27, ..., 222, 173, 163], dtype=uint8), '20820.jpg'],
#  [array([193, 180, 182, ..., 124, 121, 123], dtype=uint8), '20821.jpg'],
#  [array([108, 100,  83, ...,   8,  17,  21], dtype=uint8), '20822.jpg'],
#  [array([28, 28, 28, ..., 40, 40, 40], dtype=uint8), '20825.jpg'],
#  [array([28, 31, 29, ..., 13, 13, 13], dtype=uint8), '20826.jpg'],
#  [array([252, 242, 225, ...,  47,  52,  53], dtype=uint8), '20828.jpg'],
#  [array([25,  9, 10, ..., 25, 53, 33], dtype=uint8), '20831.jpg'],
#  [array([188, 222, 246, ..., 134, 136, 136], dtype=uint8), '20832.jpg'],
#  [array([113, 108, 109, ...,   8,  40,  29], dtype=uint8), '20833.jpg'],
#  [array([202, 203, 201, ..., 210, 211, 207], dtype=uint8), '20834.jpg'],
#  [array([ 37,  41,  52, ..., 106,  95,  91], dtype=uint8), '20835.jpg'],
#  [array([106, 111, 136, ...,  76,  65,  67], dtype=uint8), '20838.jpg'],
#  [array([215, 199, 176, ...,   8,   8,   8], dtype=uint8), '20840.jpg'],
#  [array([244, 239, 224, ...,  88,  67,  40], dtype=uint8), '20841.jpg'],
#  [array([ 73,  55,  38, ..., 212, 207, 206], dtype=uint8), '20842.jpg'],
#  [array([ 16,  32,  49, ...,  80, 100, 125], dtype=uint8), '20843.jpg'],
#  [array([177, 168, 155, ..., 122, 113,  79], dtype=uint8), '20844.jpg'],
#  [array([93, 93, 93, ...,  5,  5,  5], dtype=uint8), '20846.jpg'],
#  [array([245, 207, 153, ...,  61,  62,  53], dtype=uint8), '20847.jpg'],
#  [array([127, 144, 157, ...,   8,  12,  13], dtype=uint8), '20848.jpg'],
#  [array([174, 168, 169, ...,   0,   4,   5], dtype=uint8), '20851.jpg'],
#  [array([214, 132,  67, ...,  21, 104,  65], dtype=uint8), '20853.jpg'],
#  [array([69, 70, 74, ..., 72, 71, 51], dtype=uint8), '20854.jpg'],
#  [array([210, 209, 211, ...,  92,  90,  82], dtype=uint8), '20856.jpg'],
#  [array([139,  99,  70, ..., 203, 218, 227], dtype=uint8), '20857.jpg'],
#  [array([125, 125, 125, ...,  89,  89,  89], dtype=uint8), '20858.jpg'],
#  [array([141,  83,  34, ..., 202, 187, 184], dtype=uint8), '20860.jpg'],
#  [array([104, 104, 104, ..., 168, 168, 168], dtype=uint8), '20863.jpg'],
#  [array([203, 112,  67, ..., 102, 109, 118], dtype=uint8), '20864.jpg'],
#  [array([252, 252, 252, ...,  36,  32,  31], dtype=uint8), '20866.jpg'],
#  [array([222, 173, 127, ...,   7,  23,  30], dtype=uint8), '20867.jpg'],
#  [array([199, 182, 161, ..., 199, 189, 179], dtype=uint8), '20868.jpg'],
#  [array([165, 163, 155, ...,  12,  32,  37], dtype=uint8), '20869.jpg'],
#  [array([214, 218, 223, ...,   0,   2,   0], dtype=uint8), '20870.jpg'],
#  [array([230, 219, 215, ...,  11,  20,  29], dtype=uint8), '20871.jpg'],
#  [array([206, 216, 210, ..., 108, 112, 100], dtype=uint8), '20872.jpg'],
#  [array([163, 159, 154, ..., 206, 203, 158], dtype=uint8), '20873.jpg'],
#  [array([152, 173, 164, ...,   8,   7,   3], dtype=uint8), '20874.jpg'],
#  [array([226, 227, 225, ...,  72, 102, 119], dtype=uint8), '20876.jpg'],
#  [array([247, 219, 165, ..., 109, 103, 108], dtype=uint8), '20878.jpg'],
#  [array([131, 144, 130, ...,   3,   9,  14], dtype=uint8), '20879.jpg'],
#  [array([255, 244, 241, ...,  81,  69,  41], dtype=uint8), '20882.jpg'],
#  [array([215, 189, 153, ..., 158, 167, 171], dtype=uint8), '20884.jpg'],
#  [array([18, 38, 19, ..., 16, 16, 16], dtype=uint8), '20885.jpg'],
#  [array([117,  69,  33, ..., 204, 208, 209], dtype=uint8), '20887.jpg'],
#  [array([28, 31, 29, ..., 55, 61, 66], dtype=uint8), '20888.jpg'],
#  [array([189, 136,  99, ...,  57,  12,   0], dtype=uint8), '20889.jpg'],
#  [array([205, 154, 114, ...,  40,  64,  52], dtype=uint8), '20890.jpg'],
#  [array([244, 244, 244, ..., 158, 158, 158], dtype=uint8), '20892.jpg'],
#  [array([111, 111, 111, ...,  53,  53,  53], dtype=uint8), '20893.jpg'],
#  [array([51, 59, 58, ...,  9,  0,  0], dtype=uint8), '20894.jpg'],
#  [array([255, 255, 255, ...,  48,  60,  64], dtype=uint8), '20895.jpg'],
#  [array([153, 127, 115, ..., 157, 144, 130], dtype=uint8), '20896.jpg'],
#  [array([253, 250, 245, ...,  92,  98,  97], dtype=uint8), '20897.jpg'],
#  [array([238, 207, 182, ..., 117, 128, 132], dtype=uint8), '20898.jpg'],
#  [array([ 21,  15,  16, ..., 136, 141, 132], dtype=uint8), '20899.jpg'],
#  [array([67, 76, 56, ..., 17, 20, 24], dtype=uint8), '20900.jpg'],
#  [array([ 45,  47,  47, ..., 122, 124, 124], dtype=uint8), '20903.jpg'],
#  [array([254, 255, 253, ..., 159, 165, 146], dtype=uint8), '20904.jpg'],
#  [array([129, 118, 110, ...,  95, 101, 106], dtype=uint8), '20905.jpg'],
#  [array([188, 153, 110, ..., 139, 129, 112], dtype=uint8), '20906.jpg'],
#  [array([169,  55,  15, ...,   4,   4,   4], dtype=uint8), '20907.jpg'],
#  [array([154, 112,  59, ...,  57, 119, 159], dtype=uint8), '20908.jpg'],
#  [array([152, 112,  77, ...,  12,  19,  14], dtype=uint8), '20909.jpg'],
#  [array([193, 182, 178, ..., 109, 108,  87], dtype=uint8), '20910.jpg'],
#  [array([216, 178, 144, ..., 124, 125,  75], dtype=uint8), '20911.jpg'],
#  [array([ 26,  13,  59, ..., 118, 119, 123], dtype=uint8), '20915.jpg'],
#  [array([139, 175, 163, ...,   0,  86,  40], dtype=uint8), '20916.jpg'],
#  [array([ 92,  35,  10, ..., 146, 120,  84], dtype=uint8), '20917.jpg'],
#  [array([249, 254, 252, ..., 107, 113, 102], dtype=uint8), '20918.jpg'],
#  [array([58, 47, 43, ..., 29, 21, 21], dtype=uint8), '20921.jpg'],
#  [array([141, 141, 135, ...,  26,  28,  38], dtype=uint8), '20922.jpg'],
#  [array([241, 244, 248, ...,  25,  33,  33], dtype=uint8), '20924.jpg'],
#  [array([ 0, 10,  0, ..., 54, 54, 60], dtype=uint8), '20925.jpg'],
#  [array([211, 175, 137, ...,  70,  65,  56], dtype=uint8), '20926.jpg'],
#  [array([125, 202, 165, ...,  88, 147, 103], dtype=uint8), '20927.jpg'],
#  [array([246, 242, 241, ..., 154, 150, 149], dtype=uint8), '20928.jpg'],
#  [array([ 5,  5,  5, ..., 35, 35, 35], dtype=uint8), '20929.jpg'],
#  [array([ 5, 36, 15, ...,  3,  1,  1], dtype=uint8), '20930.jpg'],
#  [array([ 2,  0,  0, ..., 77, 74, 76], dtype=uint8), '20931.jpg'],
#  [array([175, 165, 148, ...,  91,  82,  72], dtype=uint8), '20933.jpg'],
#  [array([119, 119, 119, ..., 100, 100, 100], dtype=uint8), '20934.jpg'],
#  [array([ 0,  0,  0, ..., 30, 34, 63], dtype=uint8), '20935.jpg'],
#  [array([ 65,  86,  88, ..., 162, 131, 140], dtype=uint8), '20937.jpg'],
#  [array([ 22, 122,  40, ...,   0,  33,  18], dtype=uint8), '20938.jpg'],
#  [array([130,  73,  51, ..., 133,  91,  72], dtype=uint8), '20940.jpg'],
#  [array([151, 151, 151, ...,  40,  40,  40], dtype=uint8), '20941.jpg'],
#  [array([106,   0,   0, ..., 176,   0,   0], dtype=uint8), '20942.jpg'],
#  [array([193, 190, 185, ..., 143, 143, 137], dtype=uint8), '20944.jpg'],
#  [array([96, 57, 29, ..., 53, 62, 75], dtype=uint8), '20946.jpg'],
#  [array([159, 133, 121, ..., 139, 191, 168], dtype=uint8), '20947.jpg'],
#  [array([179, 163, 156, ...,  94,  97, 101], dtype=uint8), '20948.jpg'],
#  [array([245, 233, 227, ..., 144, 136, 119], dtype=uint8), '20949.jpg'],
#  [array([168,  95,  43, ..., 195, 179, 172], dtype=uint8), '20950.jpg'],
#  [array([254, 254, 254, ...,  65,  77,  81], dtype=uint8), '20952.jpg'],
#  [array([249, 148,  96, ..., 132, 121, 124], dtype=uint8), '20953.jpg'],
#  [array([87, 87, 71, ...,  1,  7,  6], dtype=uint8), '20954.jpg'],
#  [array([173, 165, 166, ...,  72,  78,  85], dtype=uint8), '20955.jpg'],
#  [array([216, 214, 213, ...,   5,   8,  16], dtype=uint8), '20958.jpg'],
#  [array([165, 134, 109, ..., 207, 206, 208], dtype=uint8), '20959.jpg'],
#  [array([ 13,  23,  17, ..., 113, 113, 113], dtype=uint8), '20960.jpg'],
#  [array([197, 162, 129, ...,  70, 110,  98], dtype=uint8), '20961.jpg'],
#  [array([225, 204, 196, ..., 136, 147, 151], dtype=uint8), '20962.jpg'],
#  [array([60, 53, 50, ..., 66, 68, 68], dtype=uint8), '20963.jpg'],
#  [array([48, 40, 40, ..., 24, 40, 46], dtype=uint8), '20965.jpg'],
#  [array([106, 106, 106, ..., 104, 104, 104], dtype=uint8), '20966.jpg'],
#  [array([1, 2, 0, ..., 0, 0, 0], dtype=uint8), '20968.jpg'],
#  [array([177, 177, 177, ...,  16,  16,  16], dtype=uint8), '20970.jpg'],
#  [array([155, 155, 155, ...,   7,  29,  35], dtype=uint8), '20971.jpg'],
#  [array([28,  9, 26, ..., 59, 57, 63], dtype=uint8), '20972.jpg'],
#  [array([179,  99,  38, ...,  61,  66,  65], dtype=uint8), '20974.jpg'],
#  [array([233, 220, 204, ...,  46,  66,  83], dtype=uint8), '20975.jpg'],
#  [array([135,  96,  51, ...,  10,  40,  41], dtype=uint8), '20976.jpg'],
#  [array([ 25,  36,  33, ...,  84, 103,  94], dtype=uint8), '20978.jpg'],
#  [array([203, 128,  60, ...,  68,  97, 136], dtype=uint8), '20980.jpg'],
#  [array([67, 32, 28, ..., 14,  9, 10], dtype=uint8), '20981.jpg'],
#  [array([190, 163, 129, ...,  82, 109, 136], dtype=uint8), '20982.jpg'],
#  [array([166, 109,  83, ..., 189, 194, 193], dtype=uint8), '20983.jpg'],
#  [array([ 96, 109, 117, ..., 152, 141, 137], dtype=uint8), '20984.jpg'],
#  [array([199, 191, 184, ..., 110, 105, 104], dtype=uint8), '20985.jpg'],
#  [array([176, 162, 144, ..., 101, 135,  98], dtype=uint8), '20986.jpg'],
#  [array([223, 205, 198, ..., 148, 152, 153], dtype=uint8), '20988.jpg'],
#  [array([63, 39, 17, ..., 24, 18, 19], dtype=uint8), '20989.jpg'],
#  [array([167, 110,  31, ...,  44, 165, 121], dtype=uint8), '20991.jpg'],
#  [array([195, 204, 191, ...,   0,   0,   0], dtype=uint8), '20992.jpg'],
#  [array([20, 29, 26, ..., 91, 96, 94], dtype=uint8), '20994.jpg'],
#  [array([148, 148, 148, ...,  60,  60,  60], dtype=uint8), '20995.jpg'],
#  [array([ 93, 138,  99, ...,  26,  65,  80], dtype=uint8), '20996.jpg'],
#  [array([242, 241, 237, ...,  89,  88,  68], dtype=uint8), '20998.jpg'],
#  [array([165, 105,  53, ...,  91,  91,  91], dtype=uint8), '20999.jpg'],
#  [array([231, 221, 221, ..., 251, 254, 252], dtype=uint8), '21000.jpg'],
#  [array([ 28, 143,  64, ...,  13,  58,  25], dtype=uint8), '21001.jpg'],
#  [array([160, 176, 188, ..., 104, 100, 106], dtype=uint8), '21004.jpg'],
#  [array([69, 63, 56, ...,  0,  0,  0], dtype=uint8), '21006.jpg'],
#  [array([39, 36, 32, ..., 72, 77, 80], dtype=uint8), '21007.jpg'],
#  [array([128, 124, 113, ...,  77,  66,  44], dtype=uint8), '21008.jpg'],
#  [array([188,  94,  41, ..., 135, 156, 194], dtype=uint8), '21011.jpg'],
#  [array([166, 143,  43, ...,   0,   0,  56], dtype=uint8), '21012.jpg'],
#  [array([189, 103,  57, ...,  13,  11,  10], dtype=uint8), '21013.jpg'],
#  [array([162, 203, 212, ...,   3,   5,  23], dtype=uint8), '21014.jpg'],
#  [array([ 59, 171,  77, ...,  53, 172,  57], dtype=uint8), '21016.jpg'],
#  [array([249, 245, 240, ...,  69,  41,  24], dtype=uint8), '21017.jpg'],
#  [array([ 0, 55,  0, ...,  2, 18,  7], dtype=uint8), '21018.jpg'],
#  [array([218, 161, 140, ...,  21,  39,  40], dtype=uint8), '21019.jpg'],
#  [array([16, 18, 26, ..., 28, 46, 63], dtype=uint8), '21020.jpg'],
#  [array([209, 180, 173, ..., 219, 208, 204], dtype=uint8), '21022.jpg'],
#  [array([183, 126,  87, ...,   8,  39,  24], dtype=uint8), '21024.jpg'],
#  [array([213, 191, 166, ...,  84,  73,  43], dtype=uint8), '21025.jpg'],
#  [array([220, 220, 220, ...,  23,  29,  28], dtype=uint8), '21027.jpg'],
#  [array([158, 201, 222, ...,   0,   1,   2], dtype=uint8), '21032.jpg'],
#  [array([168, 173, 174, ...,  38,  47,  50], dtype=uint8), '21034.jpg'],
#  [array([205, 157,  79, ...,  45,  35,  17], dtype=uint8), '21035.jpg'],
#  [array([158, 236, 252, ...,  24,  23,  27], dtype=uint8), '21036.jpg'],
#  [array([182, 175, 172, ..., 123, 136, 138], dtype=uint8), '21037.jpg'],
#  [array([183, 104,  55, ...,  82, 114, 133], dtype=uint8), '21038.jpg'],
#  [array([228, 205, 183, ...,  80, 102, 108], dtype=uint8), '21040.jpg'],
#  [array([237, 221, 204, ...,  29,  31,  31], dtype=uint8), '21041.jpg'],
#  [array([192, 138,  78, ...,  40,  40,  40], dtype=uint8), '21042.jpg'],
#  [array([129,  82,  38, ...,  68,  53,  34], dtype=uint8), '21043.jpg'],
#  [array([217, 211, 216, ...,  28,  34,  39], dtype=uint8), '21044.jpg'],
#  [array([105,  64,   0, ...,   3,  20,  23], dtype=uint8), '21045.jpg'],
#  [array([81, 81, 87, ..., 21, 27, 38], dtype=uint8), '21046.jpg'],
#  [array([165, 156, 152, ...,   0,   0,   6], dtype=uint8), '21047.jpg'],
#  [array([255, 255, 249, ..., 140, 136,  87], dtype=uint8), '21049.jpg'],
#  [array([6, 1, 3, ..., 0, 0, 8], dtype=uint8), '21052.jpg'],
#  [array([ 74,  43,  18, ..., 164, 155, 142], dtype=uint8), '21053.jpg'],
#  [array([13, 31, 14, ...,  2, 40, 52], dtype=uint8), '21054.jpg'],
#  [array([249, 202, 150, ...,  73,  83,  83], dtype=uint8), '21055.jpg'],
#  [array([ 7,  0, 10, ...,  2,  0,  1], dtype=uint8), '21058.jpg'],
#  ...]

# %%
test_features = []
image_ids = []

for test_feature, image_id in test_data:
    test_features.append(test_feature)
    image_ids.append(image_id)

# %%
np_test_features = np.array(test_features)
np_image_ids = np.array(image_ids)

# %%
np_test_features.shape
# Out:
# (3600, 67500)

# %%
np_test_features_pca = pca.transform(np_test_features)
np_test_features_pca.shape
# Out:
# (3600, 338)

# %%
model.get_params
# Out:
# <bound method BaseEstimator.get_params of SVC(C=4)>

# %%
kaggle_predict = model.predict(np_test_features_pca)

# %%
kaggle_predict
# Out:
# array([5, 0, 0, ..., 2, 1, 2])

# %%
import pandas as pd
df = pd.DataFrame()
df['Id'] = np_image_ids
df['Category'] = kaggle_predict

# %%
numList = list(range(0,3599))

# %%
df['numlist'] = numList

# %%
df.to_csv('PCA_svm_prediction_v1.7.csv')
csv = pd.read_csv('PCA_svm_prediction_v1.7.csv')
csv
# Out:
#       Unnamed: 0                          Id  Category
# 0              0      1000 - Copy - Copy.jpg         5
# 1              1                   10113.jpg         0
# 2              2                   10144.jpg         0
# 3              3                   10151.jpg         0
# 4              4                   10161.jpg         0
# ...          ...                         ...       ...
# 3595        3595              991 - Copy.jpg         0
# 3596        3596  9943 - Copy (2) - Copy.jpg         2
# 3597        3597  9951 - Copy (2) - Copy.jpg         2
# 3598        3598                     997.jpg         1
# 3599        3599   998 - Copy (2) - Copy.jpg         2
#
# [3600 rows x 3 columns]
