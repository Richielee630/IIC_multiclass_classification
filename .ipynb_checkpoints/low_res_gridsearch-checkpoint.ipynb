# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random

dir = 'C:\\Users\\Richie Lee\\Desktop\\College\\1 San Jose State University\\9 2021 fall semester\\CMPE 188\\hw2&hw3\\photos\\train_set'
train_dir = './low_res/train_set/'

targets = ['buildings','forest','glacier','mountain','sea','street']
train_data = []
#load train set
for target in targets:
    train_path = os.path.join(train_dir,target)
    label = targets.index(target)
    for img in os.listdir(train_path):
        train_imgpath = os.path.join(train_path, img) #train_imgpath = './xxx/xxx/xxx.jpg'
        train_img = cv2.imread(train_imgpath)
        try:
            train_img = cv2.resize(train_img,(150,150)) #**very impoertant step
            train_image = np.array(train_img).flatten()
            train_data.append([train_image,label])
        except Exception as e:
            pass

len(train_data)
# Out:
# 14338

# %%
random.shuffle(train_data)
train_data
# Out:
# [[array([145, 103,  50, ...,  70,  84,  90], dtype=uint8), 4],
#  [array([ 63, 129, 110, ...,  42, 136, 112], dtype=uint8), 1],
#  [array([135,  48,  28, ...,  64,  66,  84], dtype=uint8), 2],
#  [array([ 67, 101,  91, ...,  75, 100, 104], dtype=uint8), 5],
#  [array([ 53,  79,  93, ..., 133, 141, 140], dtype=uint8), 5],
#  [array([194, 164, 153, ...,  94,  78,  72], dtype=uint8), 4],
#  [array([150, 110,  75, ..., 146, 160, 166], dtype=uint8), 4],
#  [array([128,  78,  26, ..., 224, 216, 217], dtype=uint8), 2],
#  [array([146, 140, 133, ...,  88,  82,  75], dtype=uint8), 2],
#  [array([243, 237, 230, ..., 156,  92,  27], dtype=uint8), 2],
#  [array([22, 23, 19, ...,  0, 27, 96], dtype=uint8), 5],
#  [array([4, 4, 4, ..., 0, 0, 0], dtype=uint8), 5],
#  [array([190, 105,   1, ..., 127, 126,  75], dtype=uint8), 4],
#  [array([242, 242, 242, ...,  91, 145, 162], dtype=uint8), 3],
#  [array([239, 242, 233, ...,  68,  97, 111], dtype=uint8), 3],
#  [array([27,  0,  4, ...,  0, 28, 65], dtype=uint8), 5],
#  [array([113, 110,  95, ...,  86, 124, 136], dtype=uint8), 3],
#  [array([122, 248, 253, ...,  34,  85, 128], dtype=uint8), 1],
#  [array([ 81, 104, 120, ...,  10,  24,  30], dtype=uint8), 5],
#  [array([ 0, 59, 12, ..., 12, 37, 41], dtype=uint8), 1],
#  [array([45, 42, 38, ..., 81, 89, 88], dtype=uint8), 5],
#  [array([111,  86,  82, ...,  47,  44,  53], dtype=uint8), 0],
#  [array([119, 113, 106, ...,  55,  59,  24], dtype=uint8), 2],
#  [array([101, 115, 121, ...,  89,  83,  76], dtype=uint8), 5],
#  [array([243, 224, 189, ...,  83,  77,  70], dtype=uint8), 2],
#  [array([251, 226, 222, ...,   0,   0,   0], dtype=uint8), 3],
#  [array([186,  96,   7, ...,  63,  65,  83], dtype=uint8), 5],
#  [array([227, 219, 220, ..., 231, 247, 253], dtype=uint8), 4],
#  [array([232, 232, 232, ...,  24,  24,  24], dtype=uint8), 3],
#  [array([38,  5,  2, ..., 31,  6,  2], dtype=uint8), 5],
#  [array([200, 184, 178, ..., 198, 198, 198], dtype=uint8), 3],
#  [array([112,  95,  86, ...,  29,  26,  11], dtype=uint8), 4],
#  [array([124,  94,  69, ...,  74, 114, 142], dtype=uint8), 0],
#  [array([128,  78,  26, ..., 198, 198, 198], dtype=uint8), 2],
#  [array([160, 126, 173, ...,  33,  37,  72], dtype=uint8), 4],
#  [array([205, 179, 179, ..., 100, 124, 154], dtype=uint8), 5],
#  [array([120, 104,  98, ...,  87, 119, 148], dtype=uint8), 4],
#  [array([ 0, 20, 40, ..., 23, 50, 71], dtype=uint8), 0],
#  [array([ 1,  0,  7, ..., 36, 33, 42], dtype=uint8), 0],
#  [array([173, 131,  78, ...,  36,  36,  36], dtype=uint8), 5],
#  [array([228, 212, 206, ...,  32,  40,  39], dtype=uint8), 0],
#  [array([210, 168, 145, ...,  29,  54,  58], dtype=uint8), 3],
#  [array([172, 156, 150, ..., 127, 124, 109], dtype=uint8), 2],
#  [array([207, 199, 200, ..., 147, 130, 133], dtype=uint8), 2],
#  [array([ 61,  91, 116, ...,   7,  13,  20], dtype=uint8), 0],
#  [array([26, 26, 26, ..., 91, 91, 91], dtype=uint8), 5],
#  [array([248, 254, 255, ..., 118, 114,  73], dtype=uint8), 5],
#  [array([244, 224, 219, ..., 112, 106,  99], dtype=uint8), 2],
#  [array([133, 127, 132, ..., 125, 117, 118], dtype=uint8), 2],
#  [array([255, 237, 240, ..., 110, 122,  86], dtype=uint8), 2],
#  [array([6, 6, 6, ..., 0, 0, 0], dtype=uint8), 5],
#  [array([255, 161, 108, ...,  44,  31,  17], dtype=uint8), 2],
#  [array([100, 147, 101, ...,   0,  27,   6], dtype=uint8), 1],
#  [array([255, 203, 156, ...,  15,  23,  22], dtype=uint8), 3],
#  [array([234, 200, 146, ...,  46,  40,  33], dtype=uint8), 0],
#  [array([152,  86,  37, ..., 102,  87,  55], dtype=uint8), 2],
#  [array([223, 212, 222, ...,   7,   7,   7], dtype=uint8), 0],
#  [array([ 0, 11,  1, ..., 14, 27, 35], dtype=uint8), 1],
#  [array([129, 129, 129, ..., 216, 222, 229], dtype=uint8), 5],
#  [array([162, 126, 132, ...,  50,  31,  34], dtype=uint8), 4],
#  [array([173, 181, 180, ...,  17,  61,  54], dtype=uint8), 3],
#  [array([167, 238, 218, ...,  63,  74,  64], dtype=uint8), 1],
#  [array([238, 211, 190, ...,  36,  36,  36], dtype=uint8), 4],
#  [array([240, 234, 227, ..., 189, 179, 131], dtype=uint8), 2],
#  [array([ 51, 152, 230, ...,  93, 160, 235], dtype=uint8), 4],
#  [array([192, 176, 170, ...,  37,  29,  30], dtype=uint8), 3],
#  [array([119,  60,  10, ..., 236, 236, 236], dtype=uint8), 2],
#  [array([251, 245, 238, ...,  53,  56,  47], dtype=uint8), 2],
#  [array([251, 245, 238, ..., 113, 119, 126], dtype=uint8), 0],
#  [array([240, 240, 240, ...,  76,  73,  58], dtype=uint8), 0],
#  [array([147, 147, 147, ...,  90,  90,  90], dtype=uint8), 5],
#  [array([255, 255, 252, ...,  76,  70,  89], dtype=uint8), 1],
#  [array([179, 171, 172, ..., 134, 131, 140], dtype=uint8), 5],
#  [array([ 7,  0,  0, ..., 27, 27, 27], dtype=uint8), 1],
#  [array([148, 105,  78, ..., 155, 145, 121], dtype=uint8), 2],
#  [array([18, 15,  0, ...,  8, 16, 15], dtype=uint8), 5],
#  [array([223, 215, 216, ...,  68,  55,  41], dtype=uint8), 2],
#  [array([251, 226, 222, ...,   8,   8,   8], dtype=uint8), 2],
#  [array([105, 102, 111, ..., 216, 213, 222], dtype=uint8), 0],
#  [array([127, 132, 131, ...,  34,  59,  55], dtype=uint8), 1],
#  [array([131, 118, 104, ...,  21,  35,  41], dtype=uint8), 2],
#  [array([180, 187, 207, ...,  51,  69,  92], dtype=uint8), 1],
#  [array([9, 0, 3, ..., 7, 2, 0], dtype=uint8), 4],
#  [array([235, 229, 222, ...,   7,  96, 133], dtype=uint8), 3],
#  [array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), 4],
#  [array([0, 0, 6, ..., 0, 3, 0], dtype=uint8), 4],
#  [array([ 39,  48,  58, ...,  70,  99, 113], dtype=uint8), 5],
#  [array([212, 145,  88, ...,   9,  26,  23], dtype=uint8), 2],
#  [array([220, 207, 193, ...,  20,  49,  63], dtype=uint8), 2],
#  [array([163, 119,  78, ...,  11,  14,   5], dtype=uint8), 0],
#  [array([248, 248, 248, ...,  33,  39,  46], dtype=uint8), 3],
#  [array([ 47,  38,  51, ...,  95, 116, 131], dtype=uint8), 0],
#  [array([185, 152, 149, ..., 157, 151,  92], dtype=uint8), 2],
#  [array([242, 218, 188, ...,  47,  83,  77], dtype=uint8), 3],
#  [array([ 25,  25,  25, ..., 107, 113, 120], dtype=uint8), 5],
#  [array([202, 162, 114, ..., 149, 127, 115], dtype=uint8), 3],
#  [array([243, 235, 236, ...,   7,  21,  27], dtype=uint8), 3],
#  [array([ 97,  84,  70, ..., 115, 144, 181], dtype=uint8), 4],
#  [array([106,  93,  79, ...,  87,  95,  94], dtype=uint8), 2],
#  [array([  0,   0,   0, ..., 119, 119, 119], dtype=uint8), 5],
#  [array([36, 50, 68, ..., 51, 57, 64], dtype=uint8), 5],
#  [array([178, 178, 178, ...,  20,  20,  20], dtype=uint8), 4],
#  [array([252, 252, 252, ..., 252, 252, 252], dtype=uint8), 0],
#  [array([218, 172, 154, ...,  67,  73,  80], dtype=uint8), 5],
#  [array([ 15,  16,  37, ...,  58,  84, 130], dtype=uint8), 5],
#  [array([237, 207,  94, ..., 181, 167,   7], dtype=uint8), 4],
#  [array([172, 105,  48, ...,  23,  15,  16], dtype=uint8), 4],
#  [array([95, 61, 45, ..., 37, 45, 44], dtype=uint8), 0],
#  [array([218, 210, 211, ...,   6,   6,   6], dtype=uint8), 0],
#  [array([6, 9, 0, ..., 8, 8, 8], dtype=uint8), 1],
#  [array([74, 47, 26, ...,  5, 30, 34], dtype=uint8), 3],
#  [array([237, 223, 205, ...,  12,   4,   5], dtype=uint8), 4],
#  [array([120, 120, 120, ...,  10,  10,  10], dtype=uint8), 5],
#  [array([61, 55, 48, ...,  7,  3, 38], dtype=uint8), 1],
#  [array([225, 174, 148, ...,  90, 101, 115], dtype=uint8), 4],
#  [array([123,  64,  14, ...,  11,   5,   0], dtype=uint8), 2],
#  [array([ 66, 143, 216, ...,  58,  74,  81], dtype=uint8), 4],
#  [array([166, 107,  57, ..., 106, 133, 154], dtype=uint8), 3],
#  [array([ 50,  52,  60, ...,  51, 113, 129], dtype=uint8), 1],
#  [array([ 0,  4, 13, ...,  0,  5, 12], dtype=uint8), 1],
#  [array([255, 255, 255, ...,  40,  65,  69], dtype=uint8), 3],
#  [array([142, 107,  97, ...,   9,  12,   3], dtype=uint8), 3],
#  [array([201,  90,  40, ..., 195, 181, 175], dtype=uint8), 0],
#  [array([213, 178, 145, ..., 185, 206, 221], dtype=uint8), 0],
#  [array([113, 106, 127, ...,  89,  86,  95], dtype=uint8), 5],
#  [array([198, 164, 110, ...,  48,  78,  65], dtype=uint8), 3],
#  [array([176, 168, 169, ...,  74,  39,  19], dtype=uint8), 4],
#  [array([ 0,  2, 35, ...,  6,  3, 12], dtype=uint8), 1],
#  [array([205, 173, 144, ...,  95, 101, 108], dtype=uint8), 3],
#  [array([141, 108, 105, ..., 131, 106, 102], dtype=uint8), 2],
#  [array([140, 153, 151, ..., 161, 158, 167], dtype=uint8), 5],
#  [array([185, 150, 130, ...,  25,  28,  19], dtype=uint8), 3],
#  [array([ 4, 26,  7, ..., 41, 52, 42], dtype=uint8), 1],
#  [array([217, 190, 169, ...,  88,  72,  66], dtype=uint8), 0],
#  [array([181, 146, 126, ..., 179, 187, 186], dtype=uint8), 3],
#  [array([104, 115, 143, ..., 126, 118, 119], dtype=uint8), 5],
#  [array([207, 185, 173, ...,  21,  35,  41], dtype=uint8), 2],
#  [array([238, 242, 236, ..., 130, 106,  76], dtype=uint8), 3],
#  [array([147, 147, 159, ...,  12,  56,  49], dtype=uint8), 1],
#  [array([209, 123,  53, ...,  72,  56,  50], dtype=uint8), 2],
#  [array([193,  79,  38, ..., 123, 152, 166], dtype=uint8), 0],
#  [array([200, 200, 200, ...,  81,  75,  68], dtype=uint8), 2],
#  [array([216, 210, 229, ...,  30,  27,  36], dtype=uint8), 0],
#  [array([211, 205, 198, ...,  73,  70,  55], dtype=uint8), 2],
#  [array([  9, 126,  11, ...,  40,  60,  48], dtype=uint8), 1],
#  [array([250, 210, 175, ...,  30,  47,  44], dtype=uint8), 2],
#  [array([ 89, 114, 118, ...,  70,  84,  90], dtype=uint8), 3],
#  [array([54, 38, 32, ..., 99, 83, 77], dtype=uint8), 2],
#  [array([18,  0,  0, ...,  0,  0,  0], dtype=uint8), 4],
#  [array([255, 244, 238, ..., 116, 162, 173], dtype=uint8), 3],
#  [array([210, 132,  61, ..., 141, 147, 154], dtype=uint8), 2],
#  [array([240, 240, 240, ...,  78,  78,  78], dtype=uint8), 5],
#  [array([44, 78, 72, ..., 94, 72, 60], dtype=uint8), 5],
#  [array([148, 145, 141, ...,   5,  13,  12], dtype=uint8), 2],
#  [array([  0,  99,  56, ..., 148, 181, 184], dtype=uint8), 1],
#  [array([200, 200, 200, ..., 161, 172, 162], dtype=uint8), 2],
#  [array([188, 124,  59, ...,  46, 109,  99], dtype=uint8), 3],
#  [array([ 27,  59,  28, ...,  48, 140,  91], dtype=uint8), 1],
#  [array([157, 171, 177, ...,  75,  89,  95], dtype=uint8), 5],
#  [array([178,  92,  46, ...,  61,  53,  54], dtype=uint8), 3],
#  [array([62, 62, 62, ..., 51, 51, 51], dtype=uint8), 5],
#  [array([10, 16, 23, ..., 20, 20, 20], dtype=uint8), 5],
#  [array([209, 161, 127, ..., 118, 126, 125], dtype=uint8), 2],
#  [array([221, 229, 228, ..., 113, 113, 113], dtype=uint8), 2],
#  [array([250, 223, 189, ...,  36,  36,  36], dtype=uint8), 3],
#  [array([203, 203, 203, ...,  14,  25,  15], dtype=uint8), 0],
#  [array([239, 233, 226, ..., 143, 143, 143], dtype=uint8), 0],
#  [array([ 0,  9,  0, ..., 20, 20, 20], dtype=uint8), 1],
#  [array([50, 50, 50, ..., 43, 43, 43], dtype=uint8), 5],
#  [array([234, 210, 180, ..., 175, 157, 134], dtype=uint8), 2],
#  [array([245, 210, 190, ...,  90,  87,  72], dtype=uint8), 0],
#  [array([ 82, 102,  90, ...,   6,  31,  27], dtype=uint8), 5],
#  [array([226, 220, 213, ...,  47,  41,  34], dtype=uint8), 1],
#  [array([248, 248, 248, ...,  69,  69,  69], dtype=uint8), 0],
#  [array([217, 185, 156, ...,  41,  60,  75], dtype=uint8), 3],
#  [array([173, 173, 173, ...,  64,  67,  58], dtype=uint8), 4],
#  [array([74, 70, 82, ..., 20, 35, 68], dtype=uint8), 5],
#  [array([251, 255, 249, ...,  89,  34,  27], dtype=uint8), 3],
#  [array([203, 181, 169, ...,   0,   8,   7], dtype=uint8), 3],
#  [array([243, 237, 230, ...,  53,  67,  73], dtype=uint8), 2],
#  [array([200, 200, 200, ...,  65,  73,  72], dtype=uint8), 3],
#  [array([227, 189, 101, ...,   2,   2,   2], dtype=uint8), 3],
#  [array([14, 14, 14, ..., 65, 65, 65], dtype=uint8), 5],
#  [array([246, 249, 240, ...,  25,  25,  25], dtype=uint8), 0],
#  [array([197, 218, 233, ...,  78,  60,  37], dtype=uint8), 4],
#  [array([189,  94,  50, ..., 176, 176, 176], dtype=uint8), 3],
#  [array([146, 128, 105, ..., 154, 148, 141], dtype=uint8), 0],
#  [array([ 67, 122,  73, ...,   0,  55,   4], dtype=uint8), 1],
#  [array([243, 237, 230, ...,  50,  83,  62], dtype=uint8), 3],
#  [array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), 5],
#  [array([3, 8, 7, ..., 0, 0, 0], dtype=uint8), 0],
#  [array([220, 193, 172, ...,  79,  68,  78], dtype=uint8), 3],
#  [array([172, 162, 138, ...,   4,   4,   4], dtype=uint8), 4],
#  [array([36, 47, 37, ..., 11, 11, 11], dtype=uint8), 5],
#  [array([245, 232, 218, ...,   0,   0,   0], dtype=uint8), 3],
#  [array([ 7,  0,  0, ..., 66, 50, 44], dtype=uint8), 5],
#  [array([175, 127,  32, ..., 172, 193, 231], dtype=uint8), 4],
#  [array([225, 171, 130, ...,  16,  16,  16], dtype=uint8), 3],
#  [array([ 28,  55,  76, ...,  42,  74, 103], dtype=uint8), 5],
#  [array([99, 87, 85, ..., 55, 55, 55], dtype=uint8), 5],
#  [array([242, 152,  64, ...,  27,  29,  47], dtype=uint8), 0],
#  [array([189, 176, 162, ...,  47,  85,  97], dtype=uint8), 2],
#  [array([77, 64, 50, ...,  0, 10, 16], dtype=uint8), 0],
#  [array([187, 112,  56, ..., 108, 108, 108], dtype=uint8), 3],
#  [array([ 41,  48,  75, ..., 121, 127, 134], dtype=uint8), 0],
#  [array([212, 213, 197, ...,  12,  23,  13], dtype=uint8), 2],
#  [array([156, 121, 111, ..., 119, 139, 127], dtype=uint8), 2],
#  [array([143, 143, 143, ...,   6,   6,   6], dtype=uint8), 0],
#  [array([168, 147, 120, ...,  36,  44,  43], dtype=uint8), 0],
#  [array([107,  85,  73, ...,  77,  85,  84], dtype=uint8), 4],
#  [array([180, 126,  85, ...,  56,  59,  50], dtype=uint8), 5],
#  [array([200, 138,  92, ...,  57,  78,  93], dtype=uint8), 3],
#  [array([106, 109, 100, ..., 107, 124, 121], dtype=uint8), 4],
#  [array([ 7,  7, 21, ...,  5, 11, 18], dtype=uint8), 5],
#  [array([173, 173, 173, ...,  91,  91,  91], dtype=uint8), 5],
#  [array([73, 77, 65, ...,  5, 13, 12], dtype=uint8), 4],
#  [array([53, 55, 73, ..., 33, 41, 40], dtype=uint8), 5],
#  [array([ 38, 163, 143, ...,  20,  62, 131], dtype=uint8), 1],
#  [array([221, 182, 173, ...,  24,  27,  18], dtype=uint8), 2],
#  [array([222, 243, 240, ..., 217, 242, 246], dtype=uint8), 1],
#  [array([46, 72, 59, ..., 14, 49, 69], dtype=uint8), 1],
#  [array([206, 166, 131, ...,  75,  86,  76], dtype=uint8), 4],
#  [array([165, 101,  77, ..., 177, 212, 232], dtype=uint8), 2],
#  [array([16,  8, 18, ...,  8, 14, 21], dtype=uint8), 0],
#  [array([146, 137, 163, ..., 113, 100,  86], dtype=uint8), 0],
#  [array([255, 255, 255, ...,   2,  19,  40], dtype=uint8), 0],
#  [array([179, 164, 132, ...,  32,  26,  19], dtype=uint8), 4],
#  [array([244, 244, 244, ...,  42,  42,  42], dtype=uint8), 5],
#  [array([216, 208, 201, ...,  57,  70,  78], dtype=uint8), 4],
#  [array([14,  6,  7, ..., 18, 21, 12], dtype=uint8), 1],
#  [array([114,  84,  73, ...,  91,  75,  69], dtype=uint8), 4],
#  [array([179, 173, 166, ...,  30,  30,  30], dtype=uint8), 4],
#  [array([ 13,  74,  38, ...,  92, 118,  88], dtype=uint8), 1],
#  [array([202, 172, 161, ..., 136, 136, 136], dtype=uint8), 2],
#  [array([191, 169, 157, ...,  82, 107, 111], dtype=uint8), 4],
#  [array([221, 200, 162, ..., 101, 118, 139], dtype=uint8), 0],
#  [array([228, 212, 206, ...,  59,  59,  59], dtype=uint8), 0],
#  [array([  0,  22,  43, ..., 162, 162, 162], dtype=uint8), 5],
#  [array([138, 120,  73, ...,  12,  12,  12], dtype=uint8), 5],
#  [array([ 61,  61,  61, ..., 119, 119, 119], dtype=uint8), 1],
#  [array([39, 53, 59, ..., 40, 65, 69], dtype=uint8), 5],
#  [array([185, 191, 198, ..., 105, 126, 141], dtype=uint8), 2],
#  [array([147, 102,  59, ..., 156, 185, 222], dtype=uint8), 4],
#  [array([89, 54, 34, ..., 87, 68, 71], dtype=uint8), 4],
#  [array([217, 229, 231, ...,  36,  23,   9], dtype=uint8), 4],
#  [array([242, 236, 229, ..., 108, 126, 149], dtype=uint8), 5],
#  [array([136,  63,  25, ..., 127, 101,  55], dtype=uint8), 2],
#  [array([253, 189, 208, ...,  19,  33,  39], dtype=uint8), 1],
#  [array([ 5, 13, 12, ...,  4,  7, 22], dtype=uint8), 1],
#  [array([172, 170, 189, ..., 200, 181, 184], dtype=uint8), 3],
#  [array([240, 240, 240, ..., 116, 116, 116], dtype=uint8), 5],
#  [array([230, 230, 230, ...,   0,  19,  40], dtype=uint8), 5],
#  [array([170, 146, 116, ..., 209, 196, 182], dtype=uint8), 4],
#  [array([ 90, 104,  86, ...,  12,  26,  32], dtype=uint8), 5],
#  [array([46, 52, 59, ..., 47, 41, 34], dtype=uint8), 5],
#  [array([155, 116,  47, ...,  88, 156, 179], dtype=uint8), 3],
#  [array([62, 62, 62, ..., 22, 22, 22], dtype=uint8), 0],
#  [array([94, 79, 47, ..., 76, 63, 49], dtype=uint8), 4],
#  [array([100,  43,  11, ...,  63,  77,  83], dtype=uint8), 2],
#  [array([ 53,  83,  70, ...,  30, 142, 165], dtype=uint8), 1],
#  [array([ 44,  52,  69, ...,  60, 120, 144], dtype=uint8), 5],
#  [array([255, 255, 255, ...,  73, 133, 132], dtype=uint8), 3],
#  [array([133, 154, 169, ...,  92, 116, 146], dtype=uint8), 5],
#  [array([32, 57, 37, ...,  0, 10,  0], dtype=uint8), 1],
#  [array([243, 245, 216, ...,  49,  49,  49], dtype=uint8), 0],
#  [array([184, 155, 118, ...,  44,  47,  38], dtype=uint8), 5],
#  [array([ 14,  14,  14, ...,  44, 100,  57], dtype=uint8), 1],
#  [array([ 8, 45, 13, ...,  8, 19,  9], dtype=uint8), 1],
#  [array([224, 179, 111, ...,  56,  40,  34], dtype=uint8), 2],
#  [array([69, 59, 89, ..., 46, 46, 46], dtype=uint8), 5],
#  [array([236, 223, 209, ...,  79,  73,  66], dtype=uint8), 2],
#  [array([  0,  12,  24, ..., 140, 124, 118], dtype=uint8), 5],
#  [array([127,  77,   1, ...,  20,   4,   0], dtype=uint8), 3],
#  [array([248, 255, 255, ...,  82,  88,  95], dtype=uint8), 5],
#  [array([197, 103,   4, ..., 235, 197,  33], dtype=uint8), 4],
#  [array([255, 255, 255, ..., 124, 132, 131], dtype=uint8), 0],
#  [array([120, 140, 128, ...,   0,  31,   0], dtype=uint8), 1],
#  [array([244, 246, 254, ...,  91,  67,  37], dtype=uint8), 4],
#  [array([196, 190, 183, ..., 110, 110, 110], dtype=uint8), 0],
#  [array([192, 192, 192, ...,  19,  19,  19], dtype=uint8), 4],
#  [array([196, 196, 196, ...,  44,  38,  31], dtype=uint8), 4],
#  [array([195, 123,  59, ..., 145, 100,  57], dtype=uint8), 2],
#  [array([108, 161, 152, ...,  17,  25,  24], dtype=uint8), 1],
#  [array([ 0,  4,  0, ..., 36, 36, 36], dtype=uint8), 1],
#  [array([ 95,  73,  61, ..., 124,  94,  83], dtype=uint8), 2],
#  [array([ 91,  66,  62, ..., 115,  93,  81], dtype=uint8), 2],
#  [array([166, 166, 166, ...,  87,  94, 119], dtype=uint8), 1],
#  [array([ 36,  36,  36, ..., 139, 139, 139], dtype=uint8), 2],
#  [array([34, 94, 76, ..., 11, 19, 18], dtype=uint8), 1],
#  [array([ 96, 117, 114, ...,  69,  77,  76], dtype=uint8), 5],
#  [array([158, 158, 158, ..., 195, 172, 116], dtype=uint8), 2],
#  [array([152,  95,  63, ..., 103, 104,  95], dtype=uint8), 2],
#  [array([252, 242, 218, ...,  25,  46,  61], dtype=uint8), 1],
#  [array([12,  2,  0, ...,  0,  1,  0], dtype=uint8), 3],
#  [array([205, 208, 199, ..., 232, 232, 232], dtype=uint8), 5],
#  [array([180, 111,  62, ...,  66,  66,  66], dtype=uint8), 2],
#  [array([96, 96, 96, ..., 43, 43, 43], dtype=uint8), 5],
#  [array([175, 167, 168, ..., 113, 113, 113], dtype=uint8), 2],
#  [array([93, 50, 23, ...,  6, 14, 13], dtype=uint8), 2],
#  [array([233, 240, 197, ...,   2,   2,   2], dtype=uint8), 0],
#  [array([235, 229, 222, ..., 146, 128, 105], dtype=uint8), 2],
#  [array([249, 204, 161, ...,  41, 103,  67], dtype=uint8), 3],
#  [array([204, 204, 204, ..., 169, 177, 176], dtype=uint8), 5],
#  [array([255, 239, 192, ..., 116, 173, 182], dtype=uint8), 3],
#  [array([132,  71,   0, ..., 177, 185, 184], dtype=uint8), 2],
#  [array([50, 68, 39, ...,  6, 16, 33], dtype=uint8), 1],
#  [array([227, 168, 118, ...,  58,  66,  65], dtype=uint8), 3],
#  [array([20, 31, 45, ..., 30, 36, 43], dtype=uint8), 5],
#  [array([255, 255, 255, ..., 255, 255, 249], dtype=uint8), 5],
#  [array([126, 180, 145, ...,   9,  39,  50], dtype=uint8), 1],
#  [array([ 2, 35, 38, ...,  6, 54, 12], dtype=uint8), 1],
#  [array([ 6, 20, 26, ..., 54, 57, 48], dtype=uint8), 5],
#  [array([255, 255, 255, ..., 116, 137, 152], dtype=uint8), 0],
#  [array([ 43, 123, 178, ...,   7,  13,  20], dtype=uint8), 5],
#  [array([170, 146, 116, ..., 209, 196, 182], dtype=uint8), 4],
#  [array([ 79, 173, 142, ...,  47,  47,  47], dtype=uint8), 1],
#  [array([49, 49, 49, ..., 55, 55, 55], dtype=uint8), 5],
#  [array([57, 57, 57, ..., 97, 97, 97], dtype=uint8), 5],
#  [array([231, 225, 218, ...,  91,  97, 104], dtype=uint8), 5],
#  [array([246, 200, 169, ...,   8,   5,  14], dtype=uint8), 3],
#  [array([179, 153, 141, ..., 180, 195, 227], dtype=uint8), 2],
#  [array([196, 180, 174, ...,  18,  12,   5], dtype=uint8), 2],
#  [array([129, 168, 166, ...,  26,  40, 106], dtype=uint8), 1],
#  [array([ 31, 136,  73, ...,  13,  21,  20], dtype=uint8), 1],
#  [array([ 25,  25,  25, ...,  96, 104, 103], dtype=uint8), 5],
#  [array([245, 233, 229, ...,  36,  42,  25], dtype=uint8), 4],
#  [array([ 23,  33,  27, ..., 255, 255, 255], dtype=uint8), 5],
#  [array([158, 205, 197, ..., 100, 136, 130], dtype=uint8), 1],
#  [array([251, 255, 220, ...,  13,  19,  26], dtype=uint8), 0],
#  [array([9, 9, 9, ..., 2, 2, 2], dtype=uint8), 1],
#  [array([83, 42,  3, ...,  4,  4,  4], dtype=uint8), 4],
#  [array([127, 104,  82, ...,  65,  18,  34], dtype=uint8), 4],
#  [array([168, 162, 125, ..., 136, 115,  77], dtype=uint8), 4],
#  [array([167, 110,  55, ...,  28,  28,  28], dtype=uint8), 4],
#  [array([160, 103,  71, ..., 235, 227, 228], dtype=uint8), 2],
#  [array([220, 207, 193, ...,  16,  16,  16], dtype=uint8), 3],
#  [array([172, 132,  97, ..., 100,  61,  23], dtype=uint8), 4],
#  [array([121,  91,   2, ..., 154, 140,  82], dtype=uint8), 0],
#  [array([203, 195, 196, ...,  36,  36,  36], dtype=uint8), 4],
#  [array([179, 154, 138, ...,  80,  72,  73], dtype=uint8), 3],
#  [array([245, 253, 252, ...,  39,  26,  12], dtype=uint8), 3],
#  [array([245, 225, 207, ..., 202, 160, 107], dtype=uint8), 2],
#  [array([ 3, 16, 14, ..., 23, 33, 50], dtype=uint8), 1],
#  [array([170,  80,   0, ...,  78,  62,  56], dtype=uint8), 2],
#  [array([163, 187, 175, ...,  67,  94, 115], dtype=uint8), 1],
#  [array([5, 0, 0, ..., 5, 5, 5], dtype=uint8), 3],
#  [array([178, 181, 185, ..., 214, 249, 255], dtype=uint8), 5],
#  [array([236, 220, 214, ...,  20,  49,  63], dtype=uint8), 2],
#  [array([156,  83,  45, ...,  13,  13,  13], dtype=uint8), 0],
#  [array([ 60, 123, 113, ...,  31,  45,  51], dtype=uint8), 1],
#  [array([177, 132,  89, ...,  11,  19,  18], dtype=uint8), 3],
#  [array([154, 127, 106, ..., 104, 104, 104], dtype=uint8), 5],
#  [array([203, 181, 169, ...,  12,  48,  42], dtype=uint8), 3],
#  [array([186, 143, 116, ...,  20,  12,  13], dtype=uint8), 1],
#  [array([156,  87,  38, ...,  82,  88,  95], dtype=uint8), 2],
#  [array([202, 206, 171, ..., 222, 172, 120], dtype=uint8), 0],
#  [array([156, 140, 134, ...,  40,  47,  72], dtype=uint8), 4],
#  [array([238, 232, 225, ..., 180, 184, 149], dtype=uint8), 4],
#  [array([146, 106,  71, ...,  55,  55,  55], dtype=uint8), 2],
#  [array([233, 189, 196, ...,   5,  16,   6], dtype=uint8), 4],
#  [array([200, 184, 178, ..., 128, 128, 128], dtype=uint8), 0],
#  [array([207, 142, 127, ..., 122, 114, 115], dtype=uint8), 4],
#  [array([175,  97,  50, ..., 114, 149, 169], dtype=uint8), 4],
#  [array([185, 137, 103, ...,  22,  14,  15], dtype=uint8), 0],
#  [array([189, 189, 189, ..., 116, 116, 116], dtype=uint8), 4],
#  [array([210, 239, 253, ...,  57,  57,  57], dtype=uint8), 5],
#  [array([201, 169, 140, ...,  48,  48,  48], dtype=uint8), 2],
#  [array([120, 126, 133, ...,   8, 116,  73], dtype=uint8), 3],
#  [array([240, 240, 240, ..., 115, 115, 115], dtype=uint8), 5],
#  [array([242, 215, 194, ...,  52,  39,  25], dtype=uint8), 0],
#  [array([216, 216, 216, ...,  63,  71,  70], dtype=uint8), 5],
#  [array([15, 42, 38, ..., 43, 87, 80], dtype=uint8), 1],
#  [array([180, 167, 165, ..., 113, 106,  73], dtype=uint8), 2],
#  [array([224, 197, 176, ...,  97,  89,  90], dtype=uint8), 5],
#  [array([29, 64, 84, ...,  0, 19, 40], dtype=uint8), 1],
#  [array([88, 88, 88, ..., 50, 67, 88], dtype=uint8), 0],
#  [array([142, 129, 115, ...,  43,  35,  36], dtype=uint8), 5],
#  [array([243, 240, 225, ...,  41,  44,  35], dtype=uint8), 5],
#  [array([ 98, 100, 108, ...,  55,  47,  48], dtype=uint8), 5],
#  [array([126, 106,  71, ...,   9,   9,   9], dtype=uint8), 0],
#  [array([214, 106,  11, ..., 123, 129, 136], dtype=uint8), 4],
#  [array([56, 38, 37, ...,  7,  1,  0], dtype=uint8), 2],
#  [array([  0,   0,  24, ..., 144, 162, 209], dtype=uint8), 5],
#  [array([216, 216, 216, ...,  54,  60,  67], dtype=uint8), 3],
#  [array([223, 217, 210, ..., 190, 161, 124], dtype=uint8), 2],
#  [array([199, 191, 192, ...,  24,  24,  24], dtype=uint8), 4],
#  [array([125, 204, 171, ...,  40,  96,  53], dtype=uint8), 1],
#  [array([199, 191, 192, ...,   7,  15,  14], dtype=uint8), 4],
#  [array([13, 13, 13, ..., 20, 32, 72], dtype=uint8), 1],
#  [array([130,  84,  53, ..., 183, 185, 203], dtype=uint8), 2],
#  [array([196, 151, 108, ..., 122, 128, 135], dtype=uint8), 3],
#  [array([224, 224, 224, ...,  82,  89, 114], dtype=uint8), 2],
#  [array([150, 129, 168, ...,  15,  26,  16], dtype=uint8), 0],
#  [array([251, 255, 255, ..., 133, 141, 140], dtype=uint8), 2],
#  [array([ 62,  70,  53, ...,  66,  99, 102], dtype=uint8), 1],
#  [array([70, 83, 81, ..., 14, 25, 39], dtype=uint8), 1],
#  [array([171,  93,  46, ...,  97, 105, 104], dtype=uint8), 3],
#  [array([85, 77, 78, ..., 55, 52, 61], dtype=uint8), 5],
#  [array([126,  99,  78, ...,  54,  46,  47], dtype=uint8), 2],
#  [array([232, 232, 232, ..., 102, 123, 138], dtype=uint8), 3],
#  [array([106,  76,  51, ...,  27,  29,  70], dtype=uint8), 1],
#  [array([ 0, 48, 30, ...,  3, 75, 63], dtype=uint8), 1],
#  [array([156,  83,  45, ..., 131, 152, 167], dtype=uint8), 4],
#  [array([135, 189, 206, ...,  44,  69,  73], dtype=uint8), 0],
#  [array([206, 209, 213, ...,  19,  19,  19], dtype=uint8), 5],
#  [array([83, 72, 28, ..., 33,  8,  4], dtype=uint8), 0],
#  [array([ 0,  1,  8, ..., 53, 59, 66], dtype=uint8), 0],
#  [array([234, 197, 153, ...,  99, 103, 104], dtype=uint8), 5],
#  [array([206, 203, 188, ...,  92,  79,  65], dtype=uint8), 3],
#  [array([164, 172, 162, ...,  28,  36,  35], dtype=uint8), 0],
#  [array([33, 33, 33, ..., 81, 75, 68], dtype=uint8), 5],
#  [array([247, 232, 223, ..., 224, 221, 206], dtype=uint8), 2],
#  [array([36, 61, 87, ..., 80, 74, 93], dtype=uint8), 5],
#  [array([167, 167, 179, ...,  27,  33,  40], dtype=uint8), 0],
#  [array([192, 142,  90, ..., 225, 219, 212], dtype=uint8), 2],
#  [array([196, 169, 148, ...,  43,  51,  50], dtype=uint8), 3],
#  [array([12, 22, 39, ..., 41, 35, 28], dtype=uint8), 5],
#  [array([156,  83,  45, ...,  13,  13,  13], dtype=uint8), 0],
#  [array([167, 192, 196, ...,  26,  25,  51], dtype=uint8), 1],
#  [array([222, 145, 112, ...,  90, 105, 161], dtype=uint8), 0],
#  [array([ 19,  12,   0, ...,   8, 172, 214], dtype=uint8), 4],
#  [array([ 80,  80,  80, ..., 144, 144, 144], dtype=uint8), 0],
#  [array([172, 122,  70, ...,  73, 116, 135], dtype=uint8), 3],
#  [array([ 90,  44,  26, ..., 194, 175, 178], dtype=uint8), 2],
#  [array([178, 141,  97, ...,  46,  46,  46], dtype=uint8), 5],
#  [array([254, 216, 162, ...,   0,   0,   0], dtype=uint8), 3],
#  [array([255, 255, 255, ...,  81,  52,  15], dtype=uint8), 0],
#  [array([  0,   0,   0, ...,  23,  88, 103], dtype=uint8), 2],
#  [array([152, 152, 152, ...,  25,  25,  25], dtype=uint8), 4],
#  [array([152,  92,  68, ...,  98,  85,  71], dtype=uint8), 4],
#  [array([184, 130,  89, ..., 141, 147, 154], dtype=uint8), 5],
#  [array([150, 108,  66, ...,  77,  83,  90], dtype=uint8), 4],
#  [array([ 65,  79,  61, ..., 154, 143, 153], dtype=uint8), 1],
#  [array([219, 215, 250, ...,  97,  97,  97], dtype=uint8), 5],
#  [array([213, 108,  41, ...,  29,  73,  66], dtype=uint8), 4],
#  [array([175, 207, 236, ..., 107, 125, 148], dtype=uint8), 0],
#  [array([164, 151, 137, ..., 121, 131, 148], dtype=uint8), 0],
#  [array([252, 245, 212, ...,   8,  53,  20], dtype=uint8), 3],
#  [array([180,  39,   2, ..., 198, 206, 205], dtype=uint8), 2],
#  [array([185, 153, 124, ...,   8,   8,   8], dtype=uint8), 0],
#  [array([204, 204, 204, ...,  14,  14,  14], dtype=uint8), 4],
#  [array([147,  85,  45, ..., 122, 115,  82], dtype=uint8), 2],
#  [array([207, 129,  58, ...,   3,  14,   4], dtype=uint8), 2],
#  [array([199, 205, 212, ..., 184, 192, 191], dtype=uint8), 5],
#  [array([12,  2,  0, ..., 25, 81, 38], dtype=uint8), 1],
#  [array([181, 189, 188, ...,  80,  80,  80], dtype=uint8), 4],
#  [array([30, 61, 64, ...,  7,  4, 13], dtype=uint8), 1],
#  [array([203, 153, 101, ...,   4,   4,   4], dtype=uint8), 0],
#  [array([194, 189, 164, ...,  81, 114, 117], dtype=uint8), 3],
#  [array([216, 219, 210, ...,  57,  71,  77], dtype=uint8), 3],
#  [array([ 0, 19,  4, ...,  1, 40, 25], dtype=uint8), 1],
#  [array([47, 31, 25, ..., 95, 85, 61], dtype=uint8), 5],
#  [array([212, 199, 185, ...,   4,   4,   4], dtype=uint8), 3],
#  [array([  2,   0,   9, ...,  62, 100, 118], dtype=uint8), 5],
#  [array([168, 111,  79, ...,  99, 105, 112], dtype=uint8), 5],
#  [array([219, 211, 212, ...,   0,   1,   0], dtype=uint8), 2],
#  [array([187, 181, 174, ..., 131, 115, 109], dtype=uint8), 2],
#  [array([144,  84,  60, ..., 125,  92,  89], dtype=uint8), 4],
#  [array([127, 108,  73, ..., 145, 159, 141], dtype=uint8), 4],
#  [array([232, 219, 221, ...,   1,   9,   8], dtype=uint8), 3],
#  [array([198, 185, 171, ...,  99,  81,  58], dtype=uint8), 2],
#  [array([103, 103, 103, ...,  42,  42,  42], dtype=uint8), 5],
#  [array([154, 169, 208, ...,  86,  90, 131], dtype=uint8), 0],
#  [array([235, 227, 228, ...,  39,  45,  52], dtype=uint8), 0],
#  [array([148, 135, 121, ...,   7,   7,   7], dtype=uint8), 2],
#  [array([239, 233, 226, ..., 120, 105,  73], dtype=uint8), 2],
#  [array([128, 114, 142, ..., 111, 103, 104], dtype=uint8), 3],
#  [array([148,  22,  21, ...,  74,  80,  87], dtype=uint8), 4],
#  [array([111, 103, 104, ...,   7,   7,   7], dtype=uint8), 5],
#  [array([201, 126,  70, ...,  63,  38,  34], dtype=uint8), 5],
#  [array([176, 122,  81, ..., 131, 134, 125], dtype=uint8), 4],
#  [array([255, 255, 255, ...,  62,  62,  62], dtype=uint8), 5],
#  [array([251, 245, 238, ..., 106, 106, 106], dtype=uint8), 4],
#  [array([135,  76,  26, ...,   0,  23,  19], dtype=uint8), 4],
#  [array([106, 109, 100, ...,   5,  13,  12], dtype=uint8), 1],
#  [array([255, 221, 163, ...,  49,  36,  22], dtype=uint8), 5],
#  [array([105,  81,  51, ...,   4,   4,   4], dtype=uint8), 3],
#  [array([26, 29, 20, ..., 25, 54, 68], dtype=uint8), 0],
#  [array([221, 246, 250, ...,  73,  70,  79], dtype=uint8), 0],
#  [array([200, 184, 178, ...,  74,  77,  68], dtype=uint8), 3],
#  [array([212, 193, 196, ...,   0,  10,   0], dtype=uint8), 1],
#  [array([243, 232, 188, ...,  75,  43,  14], dtype=uint8), 3],
#  [array([227, 219, 220, ..., 124, 121, 106], dtype=uint8), 2],
#  [array([139, 121,  98, ...,  17,  31,  37], dtype=uint8), 4],
#  [array([221, 191, 166, ..., 180, 148, 119], dtype=uint8), 5],
#  [array([173, 202, 239, ...,  74,  74,  74], dtype=uint8), 0],
#  [array([232, 249, 255, ...,  50,  53,  44], dtype=uint8), 4],
#  [array([ 0,  1, 37, ...,  0, 10, 27], dtype=uint8), 5],
#  [array([199, 179, 174, ...,  31,  30,  56], dtype=uint8), 0],
#  [array([ 18,  26,  25, ..., 127, 135, 134], dtype=uint8), 5],
#  [array([208, 157, 107, ..., 123,  94,  57], dtype=uint8), 2],
#  [array([ 89, 103,  85, ...,  83,  67,  61], dtype=uint8), 1],
#  [array([7, 0, 0, ..., 7, 0, 0], dtype=uint8), 5],
#  [array([163, 109,  68, ..., 180, 167, 153], dtype=uint8), 2],
#  [array([255, 255, 227, ...,  85,  70,  38], dtype=uint8), 2],
#  [array([199, 184, 152, ...,  12,  12,  12], dtype=uint8), 0],
#  [array([200, 131,  82, ...,  95,  52,  25], dtype=uint8), 3],
#  [array([132, 185, 198, ...,  56,  40,  34], dtype=uint8), 5],
#  [array([246, 246, 255, ...,   3,   0,   9], dtype=uint8), 0],
#  [array([153, 140, 126, ...,  16,  42,  72], dtype=uint8), 4],
#  [array([223, 158, 127, ...,  88, 141, 132], dtype=uint8), 3],
#  [array([ 0, 20, 40, ..., 23, 50, 71], dtype=uint8), 0],
#  [array([178, 165, 151, ...,  46,  46,  46], dtype=uint8), 3],
#  [array([242, 248, 231, ...,  14,  34,  22], dtype=uint8), 2],
#  [array([ 56, 121, 119, ..., 157, 171, 177], dtype=uint8), 5],
#  [array([195, 187, 188, ...,  20,  20,  20], dtype=uint8), 4],
#  [array([179, 152, 156, ...,  37,  29,  30], dtype=uint8), 3],
#  [array([231, 225, 218, ...,  21,  27,  34], dtype=uint8), 3],
#  [array([112, 122, 116, ...,  35,  41,  48], dtype=uint8), 5],
#  [array([193, 193, 193, ..., 137, 137, 137], dtype=uint8), 5],
#  [array([255, 255, 255, ...,  44,  94,  70], dtype=uint8), 3],
#  [array([ 9,  9,  9, ..., 68, 68, 68], dtype=uint8), 2],
#  [array([72, 29,  2, ...,  9,  9,  9], dtype=uint8), 3],
#  [array([ 84,  84,  84, ..., 160, 189, 203], dtype=uint8), 5],
#  [array([73, 30,  3, ..., 27, 33, 40], dtype=uint8), 4],
#  [array([221, 221, 221, ...,  52,  66,  72], dtype=uint8), 3],
#  [array([233, 204, 167, ...,   6,   6,   6], dtype=uint8), 4],
#  [array([194, 244, 250, ...,  33,  33,  33], dtype=uint8), 4],
#  [array([184, 134,  82, ...,  29,  29,  29], dtype=uint8), 3],
#  [array([34, 26, 27, ..., 12, 20, 19], dtype=uint8), 1],
#  [array([ 39, 151,  67, ...,  14,  98,  50], dtype=uint8), 1],
#  [array([208, 208, 208, ...,   2,   2,   2], dtype=uint8), 5],
#  [array([206, 197, 187, ...,  67,  35,   6], dtype=uint8), 4],
#  [array([185, 156, 119, ...,  74,  48,   2], dtype=uint8), 4],
#  [array([ 64,  40,  10, ..., 123, 108,  76], dtype=uint8), 2],
#  [array([195, 197, 215, ...,  32,  34,  52], dtype=uint8), 5],
#  [array([243, 237, 230, ..., 125, 104,  66], dtype=uint8), 2],
#  [array([133,  98,  65, ...,  32,  16,  10], dtype=uint8), 4],
#  [array([0, 0, 6, ..., 0, 0, 0], dtype=uint8), 4],
#  [array([255, 248, 219, ..., 152, 179, 175], dtype=uint8), 3],
#  [array([ 0,  0, 15, ..., 33, 25, 26], dtype=uint8), 5],
#  [array([34, 34, 34, ..., 69, 69, 69], dtype=uint8), 5],
#  [array([32, 32, 32, ..., 60, 60, 60], dtype=uint8), 5],
#  [array([67, 59, 60, ..., 21, 29, 28], dtype=uint8), 1],
#  [array([248, 247, 251, ...,  10,  10,  10], dtype=uint8), 3],
#  [array([33, 82, 38, ..., 15, 53, 47], dtype=uint8), 1],
#  [array([30, 54, 42, ..., 20, 35, 67], dtype=uint8), 1],
#  [array([255, 255, 255, ..., 177, 181, 146], dtype=uint8), 0],
#  [array([ 52,  61,  74, ...,  74,  95, 133], dtype=uint8), 5],
#  [array([236, 230, 235, ..., 212, 226, 232], dtype=uint8), 3],
#  [array([223, 220, 205, ...,  11,  17,  24], dtype=uint8), 3],
#  [array([194, 206, 212, ...,   9,   9,   9], dtype=uint8), 1],
#  [array([249, 204, 161, ...,  42,  36,  29], dtype=uint8), 0],
#  [array([165, 159, 152, ...,   7,  35,   0], dtype=uint8), 1],
#  [array([185, 210, 214, ...,  35,  49,  55], dtype=uint8), 4],
#  [array([46, 21,  0, ...,  0, 52, 83], dtype=uint8), 5],
#  [array([169, 190, 191, ...,   0,   0,   0], dtype=uint8), 4],
#  [array([185, 182, 167, ...,  73, 108, 128], dtype=uint8), 4],
#  [array([170, 136,  82, ...,  17,  50,  35], dtype=uint8), 3],
#  [array([253, 211, 158, ...,  99,  99,  99], dtype=uint8), 0],
#  [array([144, 128, 122, ..., 109, 117, 116], dtype=uint8), 2],
#  [array([ 37,  48,  38, ..., 149, 152, 143], dtype=uint8), 1],
#  [array([40, 96, 53, ..., 28, 36, 35], dtype=uint8), 1],
#  [array([239, 213, 176, ...,  12,  15,   6], dtype=uint8), 3],
#  [array([188, 172, 166, ..., 155, 134,  96], dtype=uint8), 2],
#  [array([179, 120,  70, ...,  97,  97,  97], dtype=uint8), 4],
#  [array([ 70,  94,  82, ..., 111, 100, 110], dtype=uint8), 2],
#  [array([134,  91,  64, ..., 176, 176, 176], dtype=uint8), 2],
#  [array([200, 136,  71, ..., 151, 151, 151], dtype=uint8), 3],
#  [array([245, 216, 179, ..., 178, 186, 185], dtype=uint8), 5],
#  [array([235, 229, 222, ...,  34,  81,  65], dtype=uint8), 3],
#  [array([188, 191, 182, ..., 153, 156, 147], dtype=uint8), 2],
#  [array([169, 166, 151, ...,  30,  30,  30], dtype=uint8), 0],
#  [array([ 0,  0,  0, ..., 11, 11, 11], dtype=uint8), 2],
#  [array([ 73, 165, 176, ...,  44,  88,  82], dtype=uint8), 1],
#  [array([14, 13, 39, ..., 10,  7, 16], dtype=uint8), 5],
#  [array([190, 153, 109, ..., 103,  76,  55], dtype=uint8), 0],
#  [array([ 20, 116,  62, ...,  15,  45,  32], dtype=uint8), 1],
#  [array([168, 155, 141, ...,   4,  12,  11], dtype=uint8), 0],
#  [array([171, 165, 158, ...,  25,  31,  38], dtype=uint8), 0],
#  [array([175, 113,  73, ..., 134, 112, 100], dtype=uint8), 2],
#  [array([172, 194, 222, ...,  93,  99, 106], dtype=uint8), 0],
#  [array([187, 184, 169, ...,  55,  45,  21], dtype=uint8), 0],
#  [array([ 31,  37,  44, ..., 128, 128, 128], dtype=uint8), 5],
#  [array([132,  78,  37, ...,  41,  49,  48], dtype=uint8), 2],
#  [array([127, 107,  76, ...,  30,  30,  30], dtype=uint8), 4],
#  [array([42, 87, 54, ..., 14, 76, 40], dtype=uint8), 1],
#  [array([178, 141,  97, ...,   9,  72,  80], dtype=uint8), 3],
#  [array([149, 200, 210, ...,  29,  10,  13], dtype=uint8), 1],
#  [array([144, 144, 144, ...,   5,   5,   5], dtype=uint8), 3],
#  [array([197, 226, 230, ...,   5,  22,  19], dtype=uint8), 0],
#  [array([ 34,  34,  34, ..., 147, 147, 147], dtype=uint8), 5],
#  [array([141, 102,  40, ...,  25,  33,  32], dtype=uint8), 2],
#  [array([119,  63,   4, ..., 240, 240, 240], dtype=uint8), 2],
#  [array([200, 154, 123, ..., 103, 103, 103], dtype=uint8), 2],
#  [array([208, 195, 181, ..., 165, 143, 131], dtype=uint8), 3],
#  [array([245, 200, 157, ...,  28,  12,   6], dtype=uint8), 2],
#  [array([132, 124, 111, ...,  81,  83, 101], dtype=uint8), 1],
#  [array([196, 196, 196, ..., 148, 156, 155], dtype=uint8), 0],
#  [array([161, 195, 185, ...,   0,  30,  24], dtype=uint8), 1],
#  [array([236, 236, 236, ...,  23,  15,  16], dtype=uint8), 3],
#  [array([237, 189, 155, ...,  23,  23,  23], dtype=uint8), 0],
#  [array([107,  48,   0, ..., 173, 179, 186], dtype=uint8), 2],
#  [array([255, 253, 239, ...,  38,  44,  51], dtype=uint8), 1],
#  [array([125, 133, 132, ...,  92,  84,  85], dtype=uint8), 1],
#  [array([209, 209, 209, ...,  35,  41,  48], dtype=uint8), 0],
#  [array([127,  68,  18, ...,   4,  14,  31], dtype=uint8), 4],
#  [array([184, 171, 157, ...,  75, 104, 118], dtype=uint8), 4],
#  [array([195, 170, 166, ...,  85,  77,  78], dtype=uint8), 2],
#  [array([52, 42, 42, ...,  3,  3,  3], dtype=uint8), 0],
#  [array([231, 169, 129, ..., 119,  93,  47], dtype=uint8), 4],
#  [array([  1,   1,   1, ..., 104, 104, 104], dtype=uint8), 0],
#  [array([212, 196, 190, ...,   0,   8,   7], dtype=uint8), 3],
#  [array([208, 158, 106, ..., 108,  76,  47], dtype=uint8), 2],
#  [array([237, 140,  76, ..., 125, 122, 107], dtype=uint8), 3],
#  [array([105, 172, 140, ...,   1,  28,  24], dtype=uint8), 1],
#  [array([148, 130, 107, ..., 240, 199, 190], dtype=uint8), 2],
#  [array([18, 26, 25, ..., 59, 61, 79], dtype=uint8), 1],
#  [array([200, 150,  74, ...,   9,  54,  45], dtype=uint8), 3],
#  [array([237, 188, 138, ...,  29,  21,  22], dtype=uint8), 0],
#  [array([ 87, 171, 247, ...,   1,   7,  14], dtype=uint8), 4],
#  [array([225, 186, 124, ...,  18,  61,  80], dtype=uint8), 3],
#  [array([231, 225, 218, ...,  97,  89,  90], dtype=uint8), 5],
#  [array([247, 235, 207, ...,  40,  42,  60], dtype=uint8), 3],
#  [array([222, 189, 163, ...,  96,  69,  48], dtype=uint8), 3],
#  [array([255, 255, 255, ...,  14,  76,  40], dtype=uint8), 0],
#  [array([245, 161,  72, ..., 149, 149, 149], dtype=uint8), 3],
#  [array([255, 243, 229, ..., 232, 219, 205], dtype=uint8), 2],
#  [array([178, 145, 142, ..., 152, 127, 123], dtype=uint8), 3],
#  [array([117,  93,  63, ...,  93,  71,  59], dtype=uint8), 2],
#  [array([207, 219, 225, ...,  18,  29,  19], dtype=uint8), 1],
#  [array([249, 195, 165, ..., 128, 122, 115], dtype=uint8), 2],
#  [array([195, 189, 182, ...,  95, 101, 108], dtype=uint8), 0],
#  [array([80, 53, 32, ...,  2,  2,  2], dtype=uint8), 3],
#  [array([25, 46, 43, ..., 46, 90, 91], dtype=uint8), 1],
#  [array([154, 148, 141, ...,  18,  26,  25], dtype=uint8), 3],
#  [array([176, 109,  52, ..., 248, 248, 248], dtype=uint8), 2],
#  [array([195, 189, 182, ...,   4,   4,   4], dtype=uint8), 3],
#  [array([137, 150, 124, ..., 109,  90,  93], dtype=uint8), 1],
#  [array([255, 216, 173, ..., 115, 176, 166], dtype=uint8), 0],
#  [array([114, 178, 142, ...,  19,  46,  42], dtype=uint8), 1],
#  [array([106,  93,  95, ..., 143, 170, 191], dtype=uint8), 1],
#  [array([230, 187, 148, ...,   3,   3,   3], dtype=uint8), 4],
#  [array([224, 211, 197, ...,  22,  91,  64], dtype=uint8), 0],
#  [array([175, 113,  73, ..., 106, 105, 107], dtype=uint8), 2],
#  [array([208, 208, 208, ...,   2,   2,   2], dtype=uint8), 5],
#  [array([95, 95, 95, ..., 18, 18, 18], dtype=uint8), 0],
#  [array([ 50,  23,   2, ..., 201, 204, 195], dtype=uint8), 4],
#  [array([ 66, 105, 133, ...,  41,  47,  54], dtype=uint8), 5],
#  [array([251, 176, 108, ...,  11,  19,  18], dtype=uint8), 2],
#  [array([198, 171, 150, ..., 165, 144, 106], dtype=uint8), 2],
#  [array([223, 217, 210, ...,  41,  51,  99], dtype=uint8), 3],
#  [array([15, 91, 49, ...,  3, 14,  4], dtype=uint8), 1],
#  [array([101, 161, 160, ..., 129, 182, 225], dtype=uint8), 1],
#  [array([200, 203, 194, ..., 138, 131,  98], dtype=uint8), 2],
#  [array([244, 228, 222, ...,  57,  54,  63], dtype=uint8), 2],
#  [array([ 0,  6, 18, ...,  0,  0,  0], dtype=uint8), 3],
#  [array([ 75,  92, 101, ..., 145, 148, 139], dtype=uint8), 5],
#  [array([166, 139, 118, ...,  97, 124, 145], dtype=uint8), 4],
#  [array([218, 153,  45, ...,  53,  89,  83], dtype=uint8), 3],
#  [array([41, 84, 81, ...,  0,  5,  2], dtype=uint8), 1],
#  [array([186, 181, 196, ..., 172, 183, 173], dtype=uint8), 0],
#  [array([239, 164, 108, ...,  58,  83,  87], dtype=uint8), 3],
#  [array([217, 180, 166, ...,  73, 130, 139], dtype=uint8), 3],
#  [array([ 20, 114,  79, ...,  73, 114, 139], dtype=uint8), 1],
#  [array([216, 216, 216, ...,  17,  17,  17], dtype=uint8), 3],
#  [array([168, 117,  67, ..., 188, 202, 208], dtype=uint8), 0],
#  [array([ 0, 66, 42, ...,  5, 26, 41], dtype=uint8), 1],
#  [array([192, 170, 158, ..., 118, 132, 138], dtype=uint8), 3],
#  [array([251, 218, 215, ..., 199, 199, 199], dtype=uint8), 2],
#  [array([237, 221, 215, ...,  63,  77,  83], dtype=uint8), 3],
#  [array([184, 171, 157, ...,  22,  42,  30], dtype=uint8), 2],
#  [array([164,  96,  23, ...,  85,  93,  92], dtype=uint8), 5],
#  [array([10, 16, 23, ..., 25, 31, 38], dtype=uint8), 5],
#  [array([255, 249, 235, ...,  11,  11,  11], dtype=uint8), 0],
#  [array([250, 210, 162, ...,  47,  47,  47], dtype=uint8), 3],
#  [array([61, 61, 61, ..., 36, 36, 36], dtype=uint8), 5],
#  [array([155, 202, 186, ...,  39,  78,  63], dtype=uint8), 1],
#  [array([ 5, 23, 46, ...,  5,  5,  5], dtype=uint8), 1],
#  [array([106, 133, 129, ...,  32,  42,  59], dtype=uint8), 1],
#  [array([137, 148, 138, ...,  85,  77,  78], dtype=uint8), 4],
#  [array([89, 89, 89, ..., 34, 34, 34], dtype=uint8), 0],
#  [array([149, 143, 136, ...,  85, 102, 123], dtype=uint8), 1],
#  [array([61, 42, 45, ...,  4,  4,  4], dtype=uint8), 2],
#  [array([224, 174, 122, ...,  48,  65,  62], dtype=uint8), 3],
#  [array([168, 101,  44, ..., 109,  72,  28], dtype=uint8), 2],
#  [array([ 0, 19, 51, ..., 56, 70, 76], dtype=uint8), 1],
#  [array([155, 196, 255, ..., 100,  81,  84], dtype=uint8), 5],
#  [array([224, 160,  95, ...,  88,  98, 115], dtype=uint8), 5],
#  [array([210, 180, 169, ..., 112, 147, 167], dtype=uint8), 3],
#  [array([ 0, 42, 75, ..., 82, 82, 82], dtype=uint8), 5],
#  [array([150, 150, 150, ...,  84,  84,  84], dtype=uint8), 5],
#  [array([123,  91,  62, ..., 128, 122, 115], dtype=uint8), 0],
#  [array([ 92, 212, 158, ...,  24,  71,  55], dtype=uint8), 1],
#  [array([198, 190, 183, ...,  44, 121, 100], dtype=uint8), 1],
#  [array([177, 155, 143, ...,  16,  16,  16], dtype=uint8), 3],
#  [array([232, 235, 226, ...,  28,  28,  28], dtype=uint8), 4],
#  [array([ 53,  87,  81, ..., 210, 224, 230], dtype=uint8), 1],
#  [array([ 86,  96, 113, ...,  56,  56,  56], dtype=uint8), 5],
#  [array([127, 127, 127, ...,   9,   9,   9], dtype=uint8), 1],
#  [array([178, 178, 178, ...,  89,  89,  89], dtype=uint8), 5],
#  [array([211, 203, 204, ...,  76,  93,  90], dtype=uint8), 0],
#  [array([203, 197, 190, ...,  93, 101, 100], dtype=uint8), 0],
#  [array([ 4, 15,  5, ...,  0, 31, 21], dtype=uint8), 1],
#  [array([ 50, 108,  83, ...,   0,  35,  44], dtype=uint8), 1],
#  [array([130, 151, 166, ...,  38,  44,  51], dtype=uint8), 0],
#  [array([243, 223, 218, ...,  93,  93,  93], dtype=uint8), 5],
#  [array([252, 252, 252, ...,  30,  38,  37], dtype=uint8), 2],
#  [array([216, 203, 189, ..., 145, 123, 111], dtype=uint8), 2],
#  [array([ 0, 16,  0, ..., 44, 55, 52], dtype=uint8), 1],
#  [array([ 98,  87,  55, ..., 103, 163, 162], dtype=uint8), 3],
#  [array([118, 118, 118, ...,  56,  64,  63], dtype=uint8), 0],
#  [array([157, 165, 164, ..., 134, 151, 148], dtype=uint8), 4],
#  [array([239, 236, 221, ...,   7,   7,   7], dtype=uint8), 0],
#  [array([230, 218, 214, ...,   8,  28,  16], dtype=uint8), 3],
#  [array([251, 255, 249, ...,  70,  81,  71], dtype=uint8), 1],
#  [array([26, 33, 58, ..., 19, 25, 32], dtype=uint8), 5],
#  [array([187, 179, 180, ..., 151, 154, 145], dtype=uint8), 2],
#  [array([255, 255, 249, ...,  13,  20, 147], dtype=uint8), 0],
#  [array([165, 164, 232, ...,  41,  59,  82], dtype=uint8), 5],
#  [array([ 0, 30, 26, ..., 68, 74, 81], dtype=uint8), 5],
#  [array([255, 255, 255, ...,  44,  44,  44], dtype=uint8), 0],
#  [array([240, 224, 218, ...,  49,  67,  90], dtype=uint8), 0],
#  [array([188, 134,  93, ...,  85,  59,  13], dtype=uint8), 4],
#  [array([  0,   0,  19, ..., 105, 105, 105], dtype=uint8), 5],
#  [array([161, 183,  95, ...,  55,  52,  37], dtype=uint8), 1],
#  [array([198, 167, 152, ...,   0,  35,  69], dtype=uint8), 5],
#  [array([62, 59, 68, ..., 93, 75, 52], dtype=uint8), 5],
#  [array([ 30, 155, 106, ..., 124, 221, 255], dtype=uint8), 1],
#  [array([246, 241, 210, ..., 104, 104, 104], dtype=uint8), 5],
#  [array([207, 199, 200, ...,  12,  12,  12], dtype=uint8), 4],
#  [array([218, 126,  73, ...,  38,  19,  22], dtype=uint8), 5],
#  [array([251, 253, 223, ...,  75,  53,  41], dtype=uint8), 3],
#  [array([ 71,  83, 123, ...,  43,  53,  70], dtype=uint8), 0],
#  [array([172, 162, 138, ...,  34,  44,  61], dtype=uint8), 4],
#  [array([236, 236, 236, ...,  11,  19,  18], dtype=uint8), 3],
#  [array([ 98,  98,  98, ...,  20,  73, 116], dtype=uint8), 3],
#  [array([246, 143,  81, ...,   0,  13,  18], dtype=uint8), 0],
#  [array([143, 166, 162, ...,  48,  48,  48], dtype=uint8), 5],
#  [array([255, 240, 234, ..., 116, 108, 109], dtype=uint8), 5],
#  [array([243, 173,  90, ...,  75,  83,  90], dtype=uint8), 3],
#  [array([255, 254, 255, ...,  82,  82,  82], dtype=uint8), 4],
#  [array([47, 93, 70, ..., 51, 97, 91], dtype=uint8), 1],
#  [array([230, 225, 200, ..., 132, 117,  85], dtype=uint8), 2],
#  [array([202, 168, 114, ..., 202, 162, 127], dtype=uint8), 2],
#  [array([190, 163, 142, ...,   0,   1,   0], dtype=uint8), 2],
#  [array([248, 232, 226, ..., 178, 156, 144], dtype=uint8), 2],
#  [array([ 0,  3, 23, ...,  2,  2,  2], dtype=uint8), 5],
#  [array([250, 229, 191, ..., 220, 183, 139], dtype=uint8), 2],
#  [array([134, 121, 107, ..., 209, 191, 168], dtype=uint8), 2],
#  [array([23, 23, 23, ..., 38, 27, 13], dtype=uint8), 0],
#  [array([107,  80,  59, ...,  80,  88,  87], dtype=uint8), 5],
#  [array([230, 193, 149, ...,  86, 103, 100], dtype=uint8), 3],
#  [array([207, 199, 200, ...,  55,  58,  49], dtype=uint8), 4],
#  [array([160, 156, 168, ...,  68,  65,  74], dtype=uint8), 5],
#  [array([125,  77,  43, ..., 167, 155, 115], dtype=uint8), 2],
#  [array([223, 220, 205, ...,  49,  63,  69], dtype=uint8), 2],
#  [array([155, 132, 110, ...,   0,   0,   0], dtype=uint8), 3],
#  [array([228, 228, 228, ...,  20,  20,  20], dtype=uint8), 5],
#  [array([193, 199, 206, ...,   4,   4,   4], dtype=uint8), 3],
#  [array([107,  85,  73, ..., 188, 175, 161], dtype=uint8), 2],
#  [array([242, 220, 208, ..., 158, 137,  99], dtype=uint8), 2],
#  [array([249, 252, 255, ..., 255, 255, 255], dtype=uint8), 1],
#  [array([165, 133, 104, ..., 125, 131, 138], dtype=uint8), 3],
#  [array([ 95, 102, 119, ...,  78, 118, 146], dtype=uint8), 4],
#  [array([143,  90,  57, ..., 179, 171, 172], dtype=uint8), 2],
#  [array([242, 242, 226, ...,  25,  25,  25], dtype=uint8), 2],
#  [array([164, 107,  75, ...,  55,  55,  55], dtype=uint8), 2],
#  [array([ 0, 10, 25, ..., 74, 76, 94], dtype=uint8), 5],
#  [array([232, 203, 166, ...,  57,  78,  93], dtype=uint8), 4],
#  [array([240, 224, 218, ...,  35,  49,  31], dtype=uint8), 2],
#  [array([255, 217, 150, ...,  18,  18,  18], dtype=uint8), 3],
#  [array([187, 190, 181, ...,  39,  50,  40], dtype=uint8), 1],
#  [array([140, 133, 130, ...,   9,  15,  22], dtype=uint8), 5],
#  [array([204, 154, 102, ...,  42,  36,  29], dtype=uint8), 3],
#  [array([181, 127,  86, ..., 151, 144, 111], dtype=uint8), 2],
#  [array([ 94, 108, 114, ..., 205, 213, 212], dtype=uint8), 0],
#  [array([238, 195, 186, ...,  27,  90,  80], dtype=uint8), 3],
#  [array([214, 174, 139, ...,  76,  33,   6], dtype=uint8), 3],
#  [array([ 66, 145, 132, ...,  33,  50,  47], dtype=uint8), 1],
#  [array([106, 106, 106, ...,  36,  23,   9], dtype=uint8), 0],
#  [array([ 51,  51,  51, ..., 167, 152, 120], dtype=uint8), 2],
#  [array([49, 48, 52, ..., 58, 57, 83], dtype=uint8), 4],
#  [array([198, 198, 198, ..., 164, 164, 164], dtype=uint8), 0],
#  [array([212, 154, 125, ...,  44,  54,  71], dtype=uint8), 4],
#  [array([190, 160, 149, ...,  79,  76,  61], dtype=uint8), 2],
#  [array([ 52,  79,  75, ...,  79, 114, 117], dtype=uint8), 1],
#  [array([142, 142, 142, ...,   5,   5,   5], dtype=uint8), 5],
#  [array([30, 38, 38, ..., 14, 11, 20], dtype=uint8), 5],
#  [array([ 77,  45,  16, ..., 173, 167, 160], dtype=uint8), 2],
#  [array([23, 17, 10, ...,  7, 13, 20], dtype=uint8), 4],
#  [array([ 78, 132,  97, ...,  44,  47,  38], dtype=uint8), 5],
#  [array([139,  56,  24, ...,  96, 110, 168], dtype=uint8), 4],
#  [array([169, 169, 169, ...,  17,  17,  17], dtype=uint8), 1],
#  [array([230, 190, 171, ...,  87,  95,  94], dtype=uint8), 0],
#  [array([156, 156, 156, ...,  65,  71,  78], dtype=uint8), 2],
#  [array([ 59,  49,  25, ..., 187, 172, 140], dtype=uint8), 2],
#  [array([26, 26, 26, ..., 22, 22, 22], dtype=uint8), 5],
#  [array([239, 231, 232, ...,  34,  42,  41], dtype=uint8), 0],
#  [array([207, 185, 173, ...,  23,  23,  23], dtype=uint8), 4],
#  [array([232, 118,   1, ...,  86,  94,  93], dtype=uint8), 4],
#  [array([ 15,  23,  22, ..., 101, 109, 108], dtype=uint8), 5],
#  [array([244, 244, 244, ...,   0,   4,   3], dtype=uint8), 2],
#  [array([187, 118,  45, ...,  93, 107, 113], dtype=uint8), 4],
#  [array([13, 80, 53, ..., 24, 32, 31], dtype=uint8), 1],
#  [array([191, 173, 150, ..., 128, 124,  83], dtype=uint8), 2],
#  [array([151, 129, 117, ..., 125, 136, 126], dtype=uint8), 4],
#  [array([220, 207, 193, ...,  27,  33,  40], dtype=uint8), 3],
#  [array([66, 66, 66, ...,  8,  8,  8], dtype=uint8), 5],
#  [array([218, 251, 254, ...,  39,  45,  52], dtype=uint8), 4],
#  [array([ 66,  50,  44, ..., 200, 187, 173], dtype=uint8), 5],
#  [array([192, 128,  63, ...,  58,  64,  47], dtype=uint8), 3],
#  [array([125, 112, 114, ..., 140, 136, 171], dtype=uint8), 1],
#  [array([164, 148, 142, ...,  99,  93,  86], dtype=uint8), 2],
#  [array([103,  74,  70, ...,  66,  60,  53], dtype=uint8), 2],
#  [array([ 0, 44, 55, ..., 57, 51, 44], dtype=uint8), 0],
#  [array([219, 219, 219, ..., 119, 119, 119], dtype=uint8), 4],
#  [array([156, 167, 157, ..., 156, 156, 156], dtype=uint8), 5],
#  [array([85, 79, 72, ..., 22, 22, 22], dtype=uint8), 2],
#  [array([ 99,  86,  72, ..., 126, 153, 174], dtype=uint8), 0],
#  [array([145,  53,   0, ...,  15,   7,   8], dtype=uint8), 3],
#  [array([158, 171, 169, ...,  23,  15,  16], dtype=uint8), 0],
#  [array([106, 164, 163, ..., 111, 117, 124], dtype=uint8), 1],
#  [array([252, 252, 252, ...,   0,   0,   0], dtype=uint8), 0],
#  [array([251, 183, 106, ..., 111,  75,  57], dtype=uint8), 4],
#  [array([153, 105,  57, ...,  16,  15,  41], dtype=uint8), 0],
#  [array([229, 213, 207, ...,  49,  70,  85], dtype=uint8), 3],
#  [array([197, 111,  41, ...,  77,  55,  43], dtype=uint8), 0],
#  [array([37, 43, 50, ...,  7, 13, 20], dtype=uint8), 1],
#  [array([179, 171, 172, ...,  45,  77, 106], dtype=uint8), 4],
#  [array([ 98, 108, 125, ...,  16,  16,  16], dtype=uint8), 5],
#  [array([204, 194, 170, ...,  60,  60,  60], dtype=uint8), 2],
#  [array([240, 240, 240, ...,  26,  36,  53], dtype=uint8), 0],
#  [array([188, 172, 166, ..., 191, 173, 150], dtype=uint8), 2],
#  [array([47, 53, 42, ..., 12, 20, 19], dtype=uint8), 1],
#  [array([248, 248, 248, ..., 137, 152, 184], dtype=uint8), 0],
#  [array([142,  88,  47, ..., 157, 135, 123], dtype=uint8), 2],
#  [array([12,  6, 55, ..., 13, 69, 26], dtype=uint8), 0],
#  [array([218, 175, 148, ..., 129, 169, 181], dtype=uint8), 3],
#  [array([ 63, 111, 183, ..., 120, 104,  98], dtype=uint8), 5],
#  [array([167, 132, 112, ...,  19,  11,  12], dtype=uint8), 2],
#  [array([102, 135, 155, ...,  56,  70,  76], dtype=uint8), 5],
#  [array([ 21,  21,  21, ..., 187, 181, 174], dtype=uint8), 2],
#  [array([147,  66,  29, ...,  73, 118, 162], dtype=uint8), 4],
#  [array([42, 69, 90, ...,  0,  0,  0], dtype=uint8), 0],
#  [array([153,  99,  58, ..., 202, 194, 195], dtype=uint8), 3],
#  [array([45, 35, 28, ..., 21, 35, 41], dtype=uint8), 1],
#  [array([223, 171, 111, ...,  32,  38,  45], dtype=uint8), 2],
#  [array([252, 252, 252, ...,  43,  75, 104], dtype=uint8), 4],
#  [array([255, 255, 210, ..., 255, 255, 255], dtype=uint8), 4],
#  [array([178, 203, 177, ...,  49,  31,  60], dtype=uint8), 0],
#  [array([112, 115, 113, ..., 221, 210, 220], dtype=uint8), 5],
#  [array([227, 199,  98, ..., 110, 120, 137], dtype=uint8), 2],
#  [array([75, 63, 23, ...,  0, 14, 20], dtype=uint8), 4],
#  [array([252, 252, 252, ..., 215, 209, 202], dtype=uint8), 2],
#  [array([235, 229, 222, ..., 132, 105,  84], dtype=uint8), 4],
#  [array([236, 228, 238, ..., 207, 201, 194], dtype=uint8), 0],
#  [array([205, 211, 218, ...,  78,  70,  71], dtype=uint8), 5],
#  [array([228, 220, 221, ...,  81, 103, 108], dtype=uint8), 3],
#  [array([249, 217, 188, ...,  25,  44,  41], dtype=uint8), 0],
#  [array([196, 196, 196, ...,  54,  83, 120], dtype=uint8), 3],
#  [array([91, 88, 97, ..., 30, 38, 37], dtype=uint8), 5],
#  [array([248, 248, 248, ...,  56,  56,  56], dtype=uint8), 5],
#  [array([114,  90,  60, ..., 127, 109,  86], dtype=uint8), 0],
#  [array([243, 240, 225, ...,  24,  24,  24], dtype=uint8), 0],
#  [array([192, 125,  68, ...,   4,   4,   4], dtype=uint8), 2],
#  [array([114, 140, 140, ..., 222, 236, 242], dtype=uint8), 5],
#  [array([194, 158, 128, ...,   5,   5,   5], dtype=uint8), 3],
#  [array([196, 196, 196, ...,  54,  62,  61], dtype=uint8), 4],
#  [array([247, 241, 234, ..., 146, 138, 139], dtype=uint8), 0],
#  [array([200, 169, 160, ...,  72,  92,  39], dtype=uint8), 3],
#  [array([205, 180, 184, ..., 153, 161, 160], dtype=uint8), 0],
#  [array([199, 161,   0, ..., 148, 189, 214], dtype=uint8), 4],
#  [array([226, 183, 156, ...,  72,  86,  92], dtype=uint8), 2],
#  [array([46, 43, 52, ..., 47, 41, 34], dtype=uint8), 5],
#  [array([201, 169, 140, ..., 147, 115,  86], dtype=uint8), 2],
#  [array([ 54,  78, 108, ..., 202, 208, 215], dtype=uint8), 5],
#  [array([78, 78, 78, ..., 37, 37, 37], dtype=uint8), 5],
#  [array([187, 128,  78, ..., 205, 205, 205], dtype=uint8), 2],
#  [array([218, 191, 170, ..., 103,  90,  76], dtype=uint8), 2],
#  [array([193, 154,  92, ..., 101,  62,   0], dtype=uint8), 3],
#  [array([248, 238, 214, ..., 198, 198, 198], dtype=uint8), 0],
#  [array([243, 237, 230, ...,  73, 147, 153], dtype=uint8), 3],
#  [array([219, 213, 206, ...,  40,  40,  40], dtype=uint8), 2],
#  [array([55, 72, 69, ..., 52, 58, 65], dtype=uint8), 1],
#  [array([198, 253, 244, ...,   0,   0,   0], dtype=uint8), 4],
#  [array([247, 185, 145, ...,  13,  16,   7], dtype=uint8), 3],
#  [array([102,  99, 108, ..., 164, 166, 184], dtype=uint8), 2],
#  [array([ 35,  10,   6, ..., 164, 121,  94], dtype=uint8), 5],
#  [array([ 46,  66,  54, ..., 130, 136, 143], dtype=uint8), 1],
#  [array([85, 85, 85, ..., 20, 20, 20], dtype=uint8), 5],
#  [array([35, 33, 25, ...,  0,  3,  0], dtype=uint8), 0],
#  [array([66, 69, 60, ..., 60, 54, 47], dtype=uint8), 1],
#  [array([ 97, 105, 104, ...,  63,  71,  70], dtype=uint8), 5],
#  [array([224, 211, 209, ...,  33,  27,  20], dtype=uint8), 2],
#  [array([229, 230, 214, ...,  13,  27,  33], dtype=uint8), 3],
#  [array([11,  5,  0, ..., 17, 55, 67], dtype=uint8), 5],
#  [array([ 92, 105, 107, ...,  91, 105, 111], dtype=uint8), 5],
#  [array([229, 200, 163, ...,  41,  77,  71], dtype=uint8), 4],
#  [array([38, 32, 25, ...,  0,  5,  4], dtype=uint8), 4],
#  [array([242, 199, 172, ...,  12,  12,  12], dtype=uint8), 0],
#  [array([132,  78,  37, ...,  26,  43,  40], dtype=uint8), 3],
#  [array([192, 138,  97, ...,  10,  10,  10], dtype=uint8), 2],
#  [array([110,  83,  62, ...,  41,  51,  68], dtype=uint8), 4],
#  [array([243, 174, 101, ...,  61,  53,  54], dtype=uint8), 3],
#  [array([214, 177, 133, ..., 109,  84,  80], dtype=uint8), 3],
#  [array([224, 174, 122, ...,  32,  35,  26], dtype=uint8), 3],
#  [array([141, 149, 139, ...,  81, 132, 158], dtype=uint8), 1],
#  [array([141,  46,   2, ..., 134,  73,   0], dtype=uint8), 0],
#  [array([232, 187, 119, ...,  30, 102,  90], dtype=uint8), 2],
#  [array([165, 171, 178, ...,  99, 105, 112], dtype=uint8), 0],
#  [array([252, 188, 123, ..., 117, 120, 111], dtype=uint8), 2],
#  [array([162, 138, 108, ...,  64,  70,  77], dtype=uint8), 0],
#  [array([204, 205, 226, ..., 124, 142, 165], dtype=uint8), 3],
#  [array([19, 24,  9, ...,  2,  2,  2], dtype=uint8), 4],
#  [array([148, 148, 148, ..., 175, 175, 175], dtype=uint8), 5],
#  [array([ 4, 12, 11, ..., 10, 18, 17], dtype=uint8), 1],
#  [array([242, 212, 201, ...,  15,  27,  67], dtype=uint8), 2],
#  [array([ 80,  74,  67, ..., 128, 134, 117], dtype=uint8), 2],
#  [array([105,  67,  43, ..., 190, 204, 210], dtype=uint8), 3],
#  [array([112,  91,  76, ...,  48,  48,  48], dtype=uint8), 2],
#  [array([150, 167, 164, ...,   2,   8,  15], dtype=uint8), 4],
#  [array([ 30,   5,   0, ..., 167, 167, 167], dtype=uint8), 4],
#  [array([184, 168, 162, ...,  37,  45,  44], dtype=uint8), 2],
#  [array([226, 186, 151, ...,  67,  59,  60], dtype=uint8), 0],
#  [array([ 2, 41, 26, ..., 29, 37, 36], dtype=uint8), 1],
#  [array([212, 185, 164, ..., 128, 122, 115], dtype=uint8), 2],
#  [array([167, 148, 140, ...,  51,  57,  64], dtype=uint8), 0],
#  [array([ 0,  0,  0, ..., 70, 70, 70], dtype=uint8), 5],
#  [array([156, 130, 118, ...,  10,  40,  27], dtype=uint8), 3],
#  [array([241, 196, 153, ...,  31,  84,  75], dtype=uint8), 0],
#  [array([105, 105, 105, ...,  42,  42,  42], dtype=uint8), 5],
#  [array([ 58,  77, 112, ..., 144, 150, 157], dtype=uint8), 0],
#  [array([214, 178, 162, ...,  18,  35,  32], dtype=uint8), 0],
#  [array([101, 116, 118, ...,  51,  97, 108], dtype=uint8), 1],
#  [array([239, 233, 226, ...,  30,  38,  37], dtype=uint8), 3],
#  [array([129, 132, 123, ..., 114,  87,  66], dtype=uint8), 2],
#  [array([ 0,  0, 15, ..., 40, 41, 75], dtype=uint8), 1],
#  [array([43, 49, 56, ..., 41, 49, 48], dtype=uint8), 5],
#  [array([246, 209, 165, ...,  64,  58,  51], dtype=uint8), 0],
#  [array([156, 156, 156, ...,  23,  31,  30], dtype=uint8), 1],
#  [array([121, 123, 141, ..., 151, 161, 178], dtype=uint8), 5],
#  [array([187, 175, 173, ..., 145, 115, 104], dtype=uint8), 5],
#  [array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), 4],
#  [array([221, 192, 135, ...,   8,   8,   8], dtype=uint8), 0],
#  [array([ 44, 144, 146, ...,   0,  83, 153], dtype=uint8), 1],
#  [array([159,  97,  57, ..., 237, 234, 243], dtype=uint8), 2],
#  [array([255, 230, 226, ...,  15,  45,  32], dtype=uint8), 3],
#  [array([141, 108, 105, ..., 131, 106, 102], dtype=uint8), 2],
#  [array([135,  96,  87, ...,  52,  46,  39], dtype=uint8), 2],
#  [array([ 95,  58,  24, ..., 144, 138, 131], dtype=uint8), 2],
#  [array([187, 181, 174, ...,   9,  34,  38], dtype=uint8), 4],
#  [array([202, 111,   0, ..., 225, 231, 238], dtype=uint8), 4],
#  [array([116, 124, 123, ..., 106, 100,  93], dtype=uint8), 1],
#  [array([255, 199, 127, ...,  30,  55,  59], dtype=uint8), 0],
#  [array([84, 90, 97, ...,  7,  7,  7], dtype=uint8), 5],
#  [array([211, 189, 177, ...,  78, 111, 114], dtype=uint8), 4],
#  [array([82, 82, 82, ..., 40, 40, 40], dtype=uint8), 5],
#  [array([164, 164, 164, ...,   5,   5,   5], dtype=uint8), 5],
#  [array([40, 30, 23, ...,  5, 11, 18], dtype=uint8), 1],
#  [array([ 0,  4,  0, ..., 56, 59, 50], dtype=uint8), 5],
#  [array([223, 217, 210, ..., 135, 127, 128], dtype=uint8), 3],
#  [array([227, 205, 193, ..., 255, 255, 255], dtype=uint8), 3],
#  [array([28, 15, 17, ..., 32, 26, 19], dtype=uint8), 5],
#  [array([123, 117,  98, ..., 237, 243, 250], dtype=uint8), 4],
#  [array([145, 218, 240, ..., 143, 135, 128], dtype=uint8), 2],
#  [array([48, 48, 48, ...,  0,  0,  0], dtype=uint8), 5],
#  [array([220, 223, 214, ..., 129, 123, 116], dtype=uint8), 4],
#  [array([211, 168, 125, ..., 149, 114,  94], dtype=uint8), 2],
#  [array([ 42,  61,  96, ..., 217, 241, 255], dtype=uint8), 5],
#  [array([205, 157, 123, ..., 255, 253, 246], dtype=uint8), 3],
#  [array([47, 25, 13, ...,  0,  0,  0], dtype=uint8), 4],
#  [array([190, 163, 142, ..., 107, 126, 147], dtype=uint8), 2],
#  [array([231, 223, 224, ...,  96,  96,  96], dtype=uint8), 2],
#  [array([ 99, 105, 112, ...,  91,  97, 104], dtype=uint8), 1],
#  [array([17,  6, 16, ..., 69, 83, 65], dtype=uint8), 5],
#  [array([12, 12, 12, ..., 19, 19, 19], dtype=uint8), 1],
#  [array([191, 188, 173, ...,  38,  49,  39], dtype=uint8), 2],
#  [array([253, 199,  34, ..., 170, 178, 177], dtype=uint8), 0],
#  [array([255, 255, 255, ...,  71,  79,  78], dtype=uint8), 0],
#  [array([34, 25, 15, ..., 32, 18, 12], dtype=uint8), 5],
#  [array([147, 141, 134, ..., 217, 217, 217], dtype=uint8), 4],
#  [array([142, 142, 142, ...,  79,  79,  79], dtype=uint8), 4],
#  [array([255, 255, 231, ..., 225, 225, 225], dtype=uint8), 2],
#  [array([212, 212, 212, ...,   1,   1,   1], dtype=uint8), 4],
#  [array([223, 201, 189, ...,  22,  22,  22], dtype=uint8), 4],
#  [array([ 94, 100, 107, ...,  61,  76, 108], dtype=uint8), 1],
#  [array([172, 156, 150, ..., 139, 145, 152], dtype=uint8), 2],
#  [array([225, 160,  92, ...,  25,  42,  39], dtype=uint8), 4],
#  [array([72, 72, 72, ..., 54, 54, 54], dtype=uint8), 4],
#  [array([ 72, 107,  93, ...,  16,  26,  43], dtype=uint8), 1],
#  [array([255, 255, 255, ..., 120, 123, 114], dtype=uint8), 0],
#  [array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), 3],
#  [array([73, 57, 51, ..., 59, 59, 59], dtype=uint8), 5],
#  [array([106,  52,  35, ..., 190, 184, 177], dtype=uint8), 2],
#  [array([214, 171, 128, ...,   0,  12,  15], dtype=uint8), 3],
#  [array([ 0,  0,  0, ..., 80, 80, 80], dtype=uint8), 5],
#  [array([89, 54, 34, ..., 37, 31, 24], dtype=uint8), 0],
#  [array([167, 110,   1, ...,  15,   9,   2], dtype=uint8), 3],
#  [array([214, 197, 124, ..., 116, 104,  38], dtype=uint8), 2],
#  [array([223, 217, 210, ...,  59,  62,  53], dtype=uint8), 0],
#  [array([233, 191, 138, ...,  90,  82,  75], dtype=uint8), 4],
#  [array([247, 211, 103, ...,  63, 113,  11], dtype=uint8), 4],
#  [array([ 36, 108,  62, ..., 129, 144, 176], dtype=uint8), 1],
#  [array([102, 110, 109, ...,  58,  58,  58], dtype=uint8), 0],
#  [array([ 96,  80,  74, ..., 171, 171, 171], dtype=uint8), 3],
#  [array([106, 133, 154, ...,   0,   0,   0], dtype=uint8), 4],
#  [array([22, 60, 64, ..., 56, 66, 83], dtype=uint8), 5],
#  [array([196, 185, 165, ...,  45,  96, 122], dtype=uint8), 3],
#  [array([218, 216, 208, ..., 131, 131, 131], dtype=uint8), 2],
#  ...]

# %% [markdown]
# ### train data has been shuffled before here

# %%
features = []
labels = []

for feature, label in train_data:
    features.append(feature)
    labels.append(label)
    
labels
# Out:
# [4,
#  1,
#  2,
#  5,
#  5,
#  4,
#  4,
#  2,
#  2,
#  2,
#  5,
#  5,
#  4,
#  3,
#  3,
#  5,
#  3,
#  1,
#  5,
#  1,
#  5,
#  0,
#  2,
#  5,
#  2,
#  3,
#  5,
#  4,
#  3,
#  5,
#  3,
#  4,
#  0,
#  2,
#  4,
#  5,
#  4,
#  0,
#  0,
#  5,
#  0,
#  3,
#  2,
#  2,
#  0,
#  5,
#  5,
#  2,
#  2,
#  2,
#  5,
#  2,
#  1,
#  3,
#  0,
#  2,
#  0,
#  1,
#  5,
#  4,
#  3,
#  1,
#  4,
#  2,
#  4,
#  3,
#  2,
#  2,
#  0,
#  0,
#  5,
#  1,
#  5,
#  1,
#  2,
#  5,
#  2,
#  2,
#  0,
#  1,
#  2,
#  1,
#  4,
#  3,
#  4,
#  4,
#  5,
#  2,
#  2,
#  0,
#  3,
#  0,
#  2,
#  3,
#  5,
#  3,
#  3,
#  4,
#  2,
#  5,
#  5,
#  4,
#  0,
#  5,
#  5,
#  4,
#  4,
#  0,
#  0,
#  1,
#  3,
#  4,
#  5,
#  1,
#  4,
#  2,
#  4,
#  3,
#  1,
#  1,
#  3,
#  3,
#  0,
#  0,
#  5,
#  3,
#  4,
#  1,
#  3,
#  2,
#  5,
#  3,
#  1,
#  0,
#  3,
#  5,
#  2,
#  3,
#  1,
#  2,
#  0,
#  2,
#  0,
#  2,
#  1,
#  2,
#  3,
#  2,
#  4,
#  3,
#  2,
#  5,
#  5,
#  2,
#  1,
#  2,
#  3,
#  1,
#  5,
#  3,
#  5,
#  5,
#  2,
#  2,
#  3,
#  0,
#  0,
#  1,
#  5,
#  2,
#  0,
#  5,
#  1,
#  0,
#  3,
#  4,
#  5,
#  3,
#  3,
#  2,
#  3,
#  3,
#  5,
#  0,
#  4,
#  3,
#  0,
#  1,
#  3,
#  5,
#  0,
#  3,
#  4,
#  5,
#  3,
#  5,
#  4,
#  3,
#  5,
#  5,
#  0,
#  2,
#  0,
#  3,
#  0,
#  2,
#  2,
#  0,
#  0,
#  4,
#  5,
#  3,
#  4,
#  5,
#  5,
#  4,
#  5,
#  1,
#  2,
#  1,
#  1,
#  4,
#  2,
#  0,
#  0,
#  0,
#  4,
#  5,
#  4,
#  1,
#  4,
#  4,
#  1,
#  2,
#  4,
#  0,
#  0,
#  5,
#  5,
#  1,
#  5,
#  2,
#  4,
#  4,
#  4,
#  5,
#  2,
#  1,
#  1,
#  3,
#  5,
#  5,
#  4,
#  5,
#  5,
#  3,
#  0,
#  4,
#  2,
#  1,
#  5,
#  3,
#  5,
#  1,
#  0,
#  5,
#  1,
#  1,
#  2,
#  5,
#  2,
#  5,
#  3,
#  5,
#  4,
#  0,
#  1,
#  4,
#  0,
#  4,
#  4,
#  2,
#  1,
#  1,
#  2,
#  2,
#  1,
#  2,
#  1,
#  5,
#  2,
#  2,
#  1,
#  3,
#  5,
#  2,
#  5,
#  2,
#  2,
#  0,
#  2,
#  3,
#  5,
#  3,
#  2,
#  1,
#  3,
#  5,
#  5,
#  1,
#  1,
#  5,
#  0,
#  5,
#  4,
#  1,
#  5,
#  5,
#  5,
#  3,
#  2,
#  2,
#  1,
#  1,
#  5,
#  4,
#  5,
#  1,
#  0,
#  1,
#  4,
#  4,
#  4,
#  4,
#  2,
#  3,
#  4,
#  0,
#  4,
#  3,
#  3,
#  2,
#  1,
#  2,
#  1,
#  3,
#  5,
#  2,
#  0,
#  1,
#  3,
#  5,
#  3,
#  1,
#  2,
#  0,
#  4,
#  4,
#  2,
#  4,
#  0,
#  4,
#  4,
#  0,
#  4,
#  5,
#  2,
#  3,
#  5,
#  0,
#  5,
#  1,
#  2,
#  5,
#  1,
#  0,
#  5,
#  5,
#  5,
#  0,
#  4,
#  2,
#  5,
#  3,
#  2,
#  4,
#  1,
#  4,
#  1,
#  2,
#  3,
#  2,
#  0,
#  2,
#  1,
#  1,
#  3,
#  5,
#  2,
#  3,
#  1,
#  1,
#  4,
#  0,
#  5,
#  0,
#  0,
#  5,
#  3,
#  0,
#  5,
#  2,
#  5,
#  0,
#  2,
#  3,
#  5,
#  0,
#  1,
#  0,
#  4,
#  0,
#  3,
#  2,
#  5,
#  3,
#  0,
#  2,
#  4,
#  4,
#  5,
#  4,
#  1,
#  5,
#  4,
#  0,
#  0,
#  3,
#  2,
#  0,
#  4,
#  2,
#  2,
#  5,
#  1,
#  4,
#  1,
#  0,
#  3,
#  3,
#  1,
#  5,
#  3,
#  5,
#  5,
#  2,
#  2,
#  4,
#  4,
#  3,
#  2,
#  5,
#  0,
#  0,
#  2,
#  2,
#  3,
#  4,
#  5,
#  5,
#  4,
#  5,
#  4,
#  4,
#  1,
#  5,
#  3,
#  0,
#  0,
#  3,
#  1,
#  3,
#  2,
#  4,
#  5,
#  0,
#  4,
#  5,
#  0,
#  5,
#  2,
#  1,
#  5,
#  2,
#  2,
#  0,
#  3,
#  5,
#  0,
#  4,
#  3,
#  0,
#  3,
#  2,
#  5,
#  4,
#  3,
#  3,
#  5,
#  5,
#  3,
#  2,
#  3,
#  5,
#  4,
#  3,
#  4,
#  4,
#  3,
#  1,
#  1,
#  5,
#  4,
#  4,
#  2,
#  5,
#  2,
#  4,
#  4,
#  3,
#  5,
#  5,
#  5,
#  1,
#  3,
#  1,
#  1,
#  0,
#  5,
#  3,
#  3,
#  1,
#  0,
#  1,
#  4,
#  5,
#  4,
#  4,
#  3,
#  0,
#  2,
#  1,
#  1,
#  3,
#  2,
#  4,
#  2,
#  2,
#  3,
#  5,
#  3,
#  2,
#  0,
#  2,
#  1,
#  5,
#  0,
#  1,
#  0,
#  0,
#  2,
#  0,
#  0,
#  5,
#  2,
#  4,
#  1,
#  3,
#  1,
#  3,
#  0,
#  5,
#  2,
#  2,
#  2,
#  3,
#  2,
#  1,
#  0,
#  1,
#  3,
#  0,
#  2,
#  1,
#  1,
#  0,
#  4,
#  4,
#  2,
#  0,
#  4,
#  0,
#  3,
#  2,
#  3,
#  1,
#  2,
#  1,
#  3,
#  0,
#  4,
#  3,
#  5,
#  3,
#  3,
#  0,
#  3,
#  2,
#  3,
#  2,
#  1,
#  2,
#  0,
#  3,
#  1,
#  3,
#  2,
#  3,
#  1,
#  0,
#  1,
#  1,
#  4,
#  0,
#  2,
#  5,
#  0,
#  4,
#  5,
#  2,
#  2,
#  3,
#  1,
#  1,
#  2,
#  2,
#  3,
#  5,
#  4,
#  3,
#  1,
#  0,
#  3,
#  3,
#  1,
#  3,
#  0,
#  1,
#  3,
#  2,
#  3,
#  2,
#  5,
#  5,
#  0,
#  3,
#  5,
#  1,
#  1,
#  1,
#  4,
#  0,
#  1,
#  2,
#  3,
#  2,
#  1,
#  5,
#  5,
#  3,
#  5,
#  5,
#  0,
#  1,
#  1,
#  3,
#  4,
#  1,
#  5,
#  1,
#  5,
#  0,
#  0,
#  1,
#  1,
#  0,
#  5,
#  2,
#  2,
#  1,
#  3,
#  0,
#  4,
#  0,
#  3,
#  1,
#  5,
#  2,
#  0,
#  5,
#  5,
#  0,
#  0,
#  4,
#  5,
#  1,
#  5,
#  5,
#  1,
#  5,
#  4,
#  5,
#  3,
#  0,
#  4,
#  3,
#  3,
#  0,
#  5,
#  5,
#  3,
#  4,
#  1,
#  2,
#  2,
#  2,
#  2,
#  5,
#  2,
#  2,
#  0,
#  5,
#  3,
#  4,
#  5,
#  2,
#  2,
#  3,
#  5,
#  3,
#  2,
#  2,
#  1,
#  3,
#  4,
#  2,
#  2,
#  2,
#  5,
#  4,
#  2,
#  3,
#  1,
#  5,
#  3,
#  2,
#  0,
#  3,
#  3,
#  1,
#  0,
#  2,
#  4,
#  0,
#  4,
#  2,
#  1,
#  5,
#  5,
#  2,
#  4,
#  5,
#  4,
#  1,
#  0,
#  2,
#  2,
#  5,
#  0,
#  4,
#  4,
#  5,
#  2,
#  4,
#  1,
#  2,
#  4,
#  3,
#  5,
#  4,
#  5,
#  3,
#  1,
#  2,
#  2,
#  0,
#  4,
#  5,
#  2,
#  0,
#  3,
#  0,
#  1,
#  0,
#  4,
#  0,
#  3,
#  0,
#  1,
#  4,
#  5,
#  2,
#  0,
#  2,
#  1,
#  0,
#  2,
#  0,
#  3,
#  5,
#  2,
#  5,
#  2,
#  4,
#  0,
#  3,
#  1,
#  2,
#  4,
#  4,
#  0,
#  5,
#  2,
#  4,
#  2,
#  4,
#  0,
#  5,
#  3,
#  0,
#  3,
#  5,
#  5,
#  0,
#  0,
#  2,
#  5,
#  3,
#  4,
#  0,
#  3,
#  0,
#  4,
#  2,
#  5,
#  2,
#  5,
#  5,
#  2,
#  2,
#  3,
#  0,
#  3,
#  2,
#  1,
#  4,
#  3,
#  2,
#  5,
#  1,
#  5,
#  0,
#  1,
#  5,
#  2,
#  3,
#  5,
#  5,
#  4,
#  4,
#  0,
#  3,
#  2,
#  4,
#  3,
#  3,
#  3,
#  1,
#  0,
#  2,
#  0,
#  2,
#  0,
#  3,
#  4,
#  5,
#  1,
#  2,
#  2,
#  3,
#  2,
#  4,
#  4,
#  2,
#  0,
#  1,
#  2,
#  0,
#  5,
#  3,
#  0,
#  5,
#  0,
#  0,
#  1,
#  3,
#  2,
#  1,
#  5,
#  0,
#  1,
#  5,
#  5,
#  4,
#  0,
#  1,
#  2,
#  3,
#  2,
#  2,
#  2,
#  4,
#  4,
#  1,
#  0,
#  5,
#  4,
#  5,
#  5,
#  1,
#  5,
#  3,
#  3,
#  5,
#  4,
#  2,
#  5,
#  4,
#  2,
#  5,
#  3,
#  4,
#  2,
#  2,
#  1,
#  5,
#  1,
#  2,
#  0,
#  0,
#  5,
#  4,
#  4,
#  2,
#  4,
#  4,
#  1,
#  2,
#  4,
#  4,
#  1,
#  0,
#  3,
#  5,
#  2,
#  3,
#  5,
#  0,
#  3,
#  2,
#  0,
#  4,
#  4,
#  1,
#  0,
#  3,
#  4,
#  5,
#  3,
#  2,
#  ...]

# %%
np_features = np.array(features)
np_lables = np.array(labels)
np_features = np_features.astype(np.int32)
np_features
# Out:
# array([[145, 103,  50, ...,  70,  84,  90],
#        [ 63, 129, 110, ...,  42, 136, 112],
#        [135,  48,  28, ...,  64,  66,  84],
#        ...,
#        [206, 163, 124, ...,  65,  68,  59],
#        [191, 226, 222, ...,  93, 120, 141],
#        [178, 122,  51, ...,   0,   2,  19]])

# %%
print('total data shape: ',np_features.shape)
print('total labels shape: ', np_lables.shape)
# Out:
# total data shape:  (14338, 67500)
# total labels shape:  (14338,)

# %% [markdown]
# ## Dementionality reduction

# %%
from sklearn.decomposition import PCA 
pca_3600 = PCA(n_components=1800)
np_features_pca = pca_3600.fit_transform(np_features)
np_features_pca.shape
# Out:
# (14338, 3600)

# %%
print('total data shape after PCA: ',np_features_pca.shape)
print('total labels shape: ', np_lables.shape)
print('the numbers of features have been dropped by', ((len(np_features[1])-len(np_features_pca[1]))/len(np_features[1]))*100,'%')
# Out:
# total data shape after PCA:  (14338, 3600)
# total labels shape:  (14338,)
# the numbers of features have been dropped by 94.66666666666667 %

# %% [markdown]
# ## grid search

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(np_features_pca, np_lables, test_size=0.2510810433812247)

# %%
X_train
# Out:
# array([[-5.40117187e+03, -5.25155077e+03, -3.93845802e+03, ...,
#          9.00532002e+01, -3.84698586e+00,  2.80774828e+01],
#        [-7.00993994e+03,  1.34206900e+03,  5.62203856e+03, ...,
#          5.49296739e+01,  2.85657659e+01,  3.77685477e+00],
#        [ 1.73894856e+04, -1.21430634e+03,  6.28636062e+02, ...,
#          4.89561390e+01, -7.64377648e+01, -4.07757931e+01],
#        ...,
#        [-5.92950464e+03,  2.15278873e+03, -2.74287125e+03, ...,
#         -4.10040648e+01,  1.45290501e+02,  2.10787714e+01],
#        [-5.30415578e+03, -5.05306646e+03, -2.95702879e+03, ...,
#         -4.58807490e+01, -2.24680273e+01, -6.13290123e+01],
#        [-1.09941803e+04,  7.27047640e+03, -3.23583151e+02, ...,
#         -5.68069006e+01, -6.58415756e+01,  4.80478423e+01]])

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(svm.SVC(), {
    'C': [3,4,5],
    'kernel': ['rbf']
}, cv=3, return_train_score=False)
clf.fit(X_train, y_train)
clf.cv_results_
# Out:
# {'mean_fit_time': array([ 77.80751006,  84.87781286, 111.85832604]),
#  'std_fit_time': array([1.52255938, 1.79418935, 7.96990207]),
#  'mean_score_time': array([51.75535162, 52.15300528, 65.34602316]),
#  'std_score_time': array([0.62931529, 0.90904902, 2.89619944]),
#  'param_C': masked_array(data=[3, 4, 5],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'rbf', 'rbf'],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 3, 'kernel': 'rbf'},
#   {'C': 4, 'kernel': 'rbf'},
#   {'C': 5, 'kernel': 'rbf'}],
#  'split0_test_score': array([0.67346369, 0.67039106, 0.67150838]),
#  'split1_test_score': array([0.66359318, 0.65800503, 0.66079911]),
#  'split2_test_score': array([0.65241688, 0.65549036, 0.65409332]),
#  'mean_test_score': array([0.66315792, 0.66129548, 0.6621336 ]),
#  'std_test_score': array([0.00859784, 0.00651296, 0.00717202]),
#  'rank_test_score': array([1, 3, 2])}

# %%
import pandas as pd
df = pd.DataFrame(clf.cv_results_)
df['features'] = 3600
df['pic'] = 'low_res'
df['pic_size'] = '150x150'
df[['features','param_C','param_kernel','mean_test_score','pic','pic_size']]
# Out:
#    features param_C param_kernel  mean_test_score      pic pic_size
# 0      3600       3          rbf         0.663158  low_res  150x150
# 1      3600       4          rbf         0.661295  low_res  150x150
# 2      3600       5          rbf         0.662134  low_res  150x150

# %%
import pandas as pd
df = pd.DataFrame(clf.cv_results_)
df['features'] = 3600
df['pic'] = 'low_res'
df[['features','param_C','param_kernel','mean_test_score','pic']]
# Out:
#    features param_C param_kernel  mean_test_score      pic
# 0      3600       3          rbf         0.661016  low_res
# 1      3600       4          rbf         0.662692  low_res
# 2      3600       5          rbf         0.660829  low_res

# %%
import pandas as pd
df = pd.DataFrame(clf.cv_results_)
df['features'] = 3600
df[['features','param_C','param_kernel','mean_test_score']]
# Out:
#    features param_C param_kernel  mean_test_score
# 0      3600       2          rbf         0.666791
# 1      3600       3          rbf         0.668560
# 2      3600       4          rbf         0.668467
# 3      3600       5          rbf         0.666138
# 4      3600       6          rbf         0.665114
