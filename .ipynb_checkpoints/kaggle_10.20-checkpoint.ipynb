# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random

dir = 'C:\\Users\\Richie Lee\\Desktop\\College\\1 San Jose State University\\9 2021 fall semester\\CMPE 188\\hw2&hw3\\photos\\train_set'
train_dir = './datasets/train_set/'

targets = ['buildings','forest','glacier','mountain','sea','street']
train_data = []
#load train set
for target in targets:
    train_path = os.path.join(train_dir,target)
    label = targets.index(target)
    for img in os.listdir(train_path):
        train_imgpath = os.path.join(train_path, img) #train_imgpath = './xxx/xxx/xxx.jpg'
        train_img = cv2.imread(train_imgpath)
        try:
            train_img = cv2.resize(train_img,(150,150)) #**very impoertant step
            train_image = np.array(train_img).flatten()
            train_data.append([train_image,label])
        except Exception as e:
            pass

len(train_data)
# Out:
# 17354

# %%
random.shuffle(train_data)
train_data
# Out:
# [[array([219, 217, 216, ..., 157, 159, 159], dtype=uint8), 4],
#  [array([29, 27, 33, ..., 61, 75, 97], dtype=uint8), 0],
#  [array([217, 134,  83, ..., 136, 158, 169], dtype=uint8), 3],
#  [array([102,  85,  88, ..., 155, 150, 171], dtype=uint8), 1],
#  [array([225, 215, 197, ...,  97, 114, 127], dtype=uint8), 0],
#  [array([228, 238, 245, ...,  15,   8,   5], dtype=uint8), 3],
#  [array([200, 198, 187, ...,  98, 105, 102], dtype=uint8), 0],
#  [array([ 72,  72,  72, ..., 242, 242, 242], dtype=uint8), 1],
#  [array([187, 188, 162, ...,  69,  65,  46], dtype=uint8), 4],
#  [array([ 42,  36,  47, ..., 112, 123, 145], dtype=uint8), 1],
#  [array([169, 139, 128, ...,  64,  49,  46], dtype=uint8), 0],
#  [array([227, 199, 168, ..., 110, 112, 122], dtype=uint8), 0],
#  [array([227, 212, 203, ...,  72, 105, 151], dtype=uint8), 4],
#  [array([227, 225, 225, ...,  55,  57,  57], dtype=uint8), 5],
#  [array([227, 162, 117, ..., 162, 236, 146], dtype=uint8), 4],
#  [array([ 0, 99, 35, ...,  0, 19,  4], dtype=uint8), 1],
#  [array([239, 232, 229, ...,  30,  38,  51], dtype=uint8), 3],
#  [array([252, 244, 244, ..., 162, 161, 165], dtype=uint8), 0],
#  [array([ 15,  15,  15, ..., 122, 122, 122], dtype=uint8), 5],
#  [array([29, 66, 50, ..., 58, 68, 75], dtype=uint8), 5],
#  [array([231, 226, 217, ..., 205, 156,  88], dtype=uint8), 2],
#  [array([161, 174, 172, ...,  48,  55,  64], dtype=uint8), 0],
#  [array([  0,  29,   8, ...,  46, 137,  61], dtype=uint8), 1],
#  [array([153,  83,  23, ...,  24,  78,  48], dtype=uint8), 4],
#  [array([193, 193, 209, ...,   4,   0,   0], dtype=uint8), 4],
#  [array([194, 169, 153, ...,  34,  66,  79], dtype=uint8), 2],
#  [array([250, 252, 240, ...,  14,   9,   0], dtype=uint8), 5],
#  [array([57, 59, 60, ...,  0,  2,  6], dtype=uint8), 1],
#  [array([74, 74, 74, ..., 97, 89, 89], dtype=uint8), 5],
#  [array([193, 166, 129, ...,  77,  73,  48], dtype=uint8), 4],
#  [array([179, 170, 157, ..., 153, 134, 101], dtype=uint8), 2],
#  [array([255, 250, 236, ...,  19,  23,  42], dtype=uint8), 4],
#  [array([228, 209, 201, ...,   4,  14,   1], dtype=uint8), 2],
#  [array([157, 145, 139, ..., 227, 221, 208], dtype=uint8), 3],
#  [array([216, 154, 100, ...,  37,  88, 121], dtype=uint8), 4],
#  [array([211, 141,  74, ..., 156, 128,  87], dtype=uint8), 2],
#  [array([242, 218, 206, ..., 148, 181, 201], dtype=uint8), 4],
#  [array([235, 231, 230, ...,  25,  29,  30], dtype=uint8), 3],
#  [array([231, 200, 177, ...,  54,  33,  25], dtype=uint8), 2],
#  [array([17, 17, 17, ..., 75, 75, 75], dtype=uint8), 5],
#  [array([249, 242, 239, ..., 105, 127, 145], dtype=uint8), 0],
#  [array([220, 164,  83, ...,  24,  42,  65], dtype=uint8), 3],
#  [array([177, 143, 113, ...,  82, 148, 107], dtype=uint8), 3],
#  [array([247, 247, 247, ..., 152, 147, 144], dtype=uint8), 0],
#  [array([214, 198, 185, ...,  14,  18,  19], dtype=uint8), 3],
#  [array([ 79,  74,  76, ..., 179, 162, 141], dtype=uint8), 2],
#  [array([184, 144, 102, ...,  83,  71,  65], dtype=uint8), 0],
#  [array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), 0],
#  [array([250, 190, 154, ...,  28,  58,  53], dtype=uint8), 3],
#  [array([254, 254, 254, ...,   4,   9,   8], dtype=uint8), 0],
#  [array([175, 161, 133, ...,  85,  76,  62], dtype=uint8), 4],
#  [array([255, 255, 254, ...,  72,  67,  69], dtype=uint8), 4],
#  [array([167, 164, 160, ..., 132, 122, 112], dtype=uint8), 2],
#  [array([146,  85,  41, ..., 122, 114,  85], dtype=uint8), 2],
#  [array([43, 57, 76, ..., 54, 57, 62], dtype=uint8), 5],
#  [array([219, 220, 218, ...,  16,  28,  40], dtype=uint8), 2],
#  [array([107, 108, 112, ...,  12,  24,  30], dtype=uint8), 5],
#  [array([ 3,  0,  4, ..., 19, 13, 14], dtype=uint8), 5],
#  [array([82, 87, 86, ..., 24, 26, 50], dtype=uint8), 1],
#  [array([175, 204, 218, ...,   0,  19,  64], dtype=uint8), 0],
#  [array([  2,  12,  30, ...,  15,  69, 140], dtype=uint8), 0],
#  [array([249, 251, 252, ...,  85,  87,  88], dtype=uint8), 5],
#  [array([206, 175, 150, ...,  86,  92,  99], dtype=uint8), 3],
#  [array([ 64,  64,  64, ..., 158, 158, 158], dtype=uint8), 5],
#  [array([147,  80,  17, ..., 230, 226, 221], dtype=uint8), 2],
#  [array([252, 252, 252, ...,  11,  12,  10], dtype=uint8), 3],
#  [array([46, 81, 77, ...,  0, 16,  7], dtype=uint8), 1],
#  [array([128, 106,  94, ..., 160, 202, 237], dtype=uint8), 0],
#  [array([ 88, 217, 232, ...,  46,  93, 131], dtype=uint8), 1],
#  [array([232, 237, 236, ..., 191, 191, 185], dtype=uint8), 2],
#  [array([219, 200, 187, ..., 217, 196, 181], dtype=uint8), 2],
#  [array([5, 0, 2, ..., 7, 6, 8], dtype=uint8), 0],
#  [array([ 0, 33, 13, ...,  4,  7, 12], dtype=uint8), 1],
#  [array([142, 123, 118, ...,   6,  22,  29], dtype=uint8), 4],
#  [array([231, 190, 158, ..., 130, 134, 139], dtype=uint8), 5],
#  [array([133, 104,  59, ...,  25,  16,   7], dtype=uint8), 4],
#  [array([35, 36, 32, ..., 25, 28, 42], dtype=uint8), 1],
#  [array([222, 212, 195, ..., 103, 109, 114], dtype=uint8), 0],
#  [array([255, 121,  17, ..., 202, 233, 255], dtype=uint8), 0],
#  [array([253, 255, 255, ...,  30,  87, 109], dtype=uint8), 3],
#  [array([169, 156, 158, ...,  26,  32,  37], dtype=uint8), 1],
#  [array([200, 164, 126, ...,  83,  90,  93], dtype=uint8), 0],
#  [array([136, 138, 138, ..., 114, 126, 130], dtype=uint8), 5],
#  [array([177, 183, 188, ..., 111, 122, 130], dtype=uint8), 5],
#  [array([162, 162, 162, ...,   7,   7,   7], dtype=uint8), 5],
#  [array([194, 192, 191, ...,   2,   7,   8], dtype=uint8), 3],
#  [array([143, 116,  96, ..., 113, 118, 116], dtype=uint8), 5],
#  [array([114, 109, 106, ...,  83,  67,  60], dtype=uint8), 5],
#  [array([112, 112, 112, ..., 160, 160, 160], dtype=uint8), 5],
#  [array([ 97, 100,  78, ..., 135, 134, 130], dtype=uint8), 5],
#  [array([175, 175, 175, ...,   1,   1,   1], dtype=uint8), 3],
#  [array([179, 130,  84, ...,  42,  41,  57], dtype=uint8), 2],
#  [array([110, 112, 113, ...,  34,  23,  19], dtype=uint8), 5],
#  [array([201, 198, 190, ...,  32,  58, 104], dtype=uint8), 3],
#  [array([13, 99, 37, ...,  0, 50,  6], dtype=uint8), 1],
#  [array([171, 148, 126, ...,  87,  64,  32], dtype=uint8), 2],
#  [array([132, 138, 113, ...,  76,  98, 104], dtype=uint8), 4],
#  [array([147, 107,  82, ..., 135, 121, 109], dtype=uint8), 2],
#  [array([182, 125,  74, ..., 131, 153, 158], dtype=uint8), 2],
#  [array([119, 105, 106, ...,  46,  35,  31], dtype=uint8), 5],
#  [array([199, 182, 163, ...,  82, 144, 168], dtype=uint8), 4],
#  [array([243, 165, 118, ..., 181, 148, 133], dtype=uint8), 4],
#  [array([249, 246, 241, ...,  91,  97, 116], dtype=uint8), 5],
#  [array([217, 179, 144, ..., 220, 203, 200], dtype=uint8), 4],
#  [array([ 35,  43,  60, ...,  89, 115, 127], dtype=uint8), 5],
#  [array([ 45,  47,  47, ..., 122, 124, 124], dtype=uint8), 5],
#  [array([67, 75, 98, ..., 18, 15, 17], dtype=uint8), 5],
#  [array([ 30,  24,  25, ..., 212, 202, 192], dtype=uint8), 2],
#  [array([188, 185, 177, ...,   0,   8,   5], dtype=uint8), 2],
#  [array([ 1,  1,  1, ..., 33, 33, 33], dtype=uint8), 1],
#  [array([24, 41, 44, ..., 11, 39, 46], dtype=uint8), 1],
#  [array([172, 190, 197, ...,   0,   0,   0], dtype=uint8), 4],
#  [array([ 73,  83,  83, ..., 233, 231, 230], dtype=uint8), 2],
#  [array([141, 138, 134, ..., 149, 160, 158], dtype=uint8), 2],
#  [array([137, 124, 122, ..., 102, 176, 158], dtype=uint8), 3],
#  [array([157,  82,   3, ...,  44, 100, 111], dtype=uint8), 2],
#  [array([254, 253, 239, ...,  61,  86,  90], dtype=uint8), 4],
#  [array([169, 130,  98, ...,   5,  44,  52], dtype=uint8), 3],
#  [array([244, 208, 162, ...,  36,  40,  35], dtype=uint8), 3],
#  [array([146, 140, 133, ..., 181, 184, 182], dtype=uint8), 4],
#  [array([ 17,  23,  30, ...,  44,  90, 114], dtype=uint8), 1],
#  [array([253, 244, 211, ..., 187, 229, 248], dtype=uint8), 4],
#  [array([ 70,  71,  37, ..., 126,  91,  78], dtype=uint8), 2],
#  [array([211, 229, 240, ...,   4,   9,  12], dtype=uint8), 3],
#  [array([253, 247, 252, ...,  66,  68,  69], dtype=uint8), 0],
#  [array([192, 180, 178, ...,  25, 107, 219], dtype=uint8), 0],
#  [array([176, 188, 192, ...,  45,  59,  78], dtype=uint8), 1],
#  [array([211, 187, 163, ..., 124, 139, 155], dtype=uint8), 4],
#  [array([176, 148, 117, ..., 115,  99,  63], dtype=uint8), 4],
#  [array([250, 205, 162, ...,  22,  13,   0], dtype=uint8), 3],
#  [array([239, 199, 170, ...,  42, 144, 116], dtype=uint8), 3],
#  [array([201, 124,   2, ...,  18,  18,  24], dtype=uint8), 3],
#  [array([11,  0,  2, ...,  7, 16, 26], dtype=uint8), 0],
#  [array([ 0,  0,  0, ..., 17, 17, 17], dtype=uint8), 1],
#  [array([252, 232, 221, ...,  68,  50,  43], dtype=uint8), 0],
#  [array([253, 246, 243, ..., 106, 129, 175], dtype=uint8), 1],
#  [array([216, 211, 212, ...,  82,  89,  92], dtype=uint8), 0],
#  [array([245, 226, 115, ...,   0,   3,  20], dtype=uint8), 3],
#  [array([224, 219, 216, ..., 117, 117, 117], dtype=uint8), 5],
#  [array([199, 168, 143, ..., 142, 120,  78], dtype=uint8), 4],
#  [array([223, 180, 153, ...,  56,  62,  61], dtype=uint8), 2],
#  [array([152, 140, 136, ...,   1,   3,   3], dtype=uint8), 2],
#  [array([ 1,  1,  1, ..., 34, 34, 34], dtype=uint8), 5],
#  [array([223, 199, 199, ..., 137, 159, 177], dtype=uint8), 1],
#  [array([237, 212, 196, ..., 117,  62,  31], dtype=uint8), 3],
#  [array([216, 190, 178, ..., 131,  98,  83], dtype=uint8), 2],
#  [array([72, 72, 72, ..., 22, 22, 22], dtype=uint8), 4],
#  [array([254, 252, 252, ..., 151, 151, 137], dtype=uint8), 2],
#  [array([218, 205, 191, ..., 205, 198, 189], dtype=uint8), 2],
#  [array([251, 200, 157, ..., 108,  93,  84], dtype=uint8), 0],
#  [array([113,  55,  49, ...,  12,  10,  10], dtype=uint8), 1],
#  [array([ 62, 105, 126, ...,  27,  56,  83], dtype=uint8), 4],
#  [array([236, 217, 209, ...,  56,  56,  68], dtype=uint8), 0],
#  [array([235, 190,  15, ..., 134, 141, 161], dtype=uint8), 4],
#  [array([255, 253, 249, ...,  79,  78,  82], dtype=uint8), 2],
#  [array([ 55, 125,  78, ...,  92, 130, 108], dtype=uint8), 1],
#  [array([243, 231, 225, ..., 109, 110, 100], dtype=uint8), 0],
#  [array([147,  83,  42, ..., 210, 205, 196], dtype=uint8), 3],
#  [array([229, 213, 207, ...,  52,  82,  69], dtype=uint8), 3],
#  [array([255, 255, 255, ...,  26, 112, 104], dtype=uint8), 3],
#  [array([191, 185, 174, ..., 153, 153, 135], dtype=uint8), 2],
#  [array([ 88, 115, 136, ...,   5,  21,  44], dtype=uint8), 0],
#  [array([ 25,  10,   8, ..., 165, 145, 104], dtype=uint8), 2],
#  [array([198, 245, 236, ...,  45, 132, 104], dtype=uint8), 1],
#  [array([149, 185, 191, ..., 101, 113, 107], dtype=uint8), 4],
#  [array([24, 24, 42, ..., 56, 65, 74], dtype=uint8), 5],
#  [array([255, 255, 255, ...,  84,  79,  80], dtype=uint8), 5],
#  [array([169, 105,  57, ..., 125, 123, 115], dtype=uint8), 0],
#  [array([176, 179, 177, ..., 126,  77,   1], dtype=uint8), 0],
#  [array([18, 26, 16, ..., 79, 96, 87], dtype=uint8), 1],
#  [array([124,  54,  37, ...,  50,  41,  44], dtype=uint8), 3],
#  [array([227, 219, 219, ..., 133, 135, 136], dtype=uint8), 2],
#  [array([63, 61, 53, ...,  1,  5,  6], dtype=uint8), 4],
#  [array([254, 254, 254, ..., 185, 184, 186], dtype=uint8), 2],
#  [array([170, 169, 171, ...,  42,  56,  62], dtype=uint8), 4],
#  [array([ 28, 112, 117, ...,  25,  78,  64], dtype=uint8), 1],
#  [array([113, 164, 157, ...,  93,  65,  41], dtype=uint8), 1],
#  [array([193, 184, 181, ...,  32,  20,  20], dtype=uint8), 4],
#  [array([133, 121, 119, ...,  87,  94, 109], dtype=uint8), 4],
#  [array([249, 254, 255, ..., 248, 253, 252], dtype=uint8), 2],
#  [array([  0,   7,   5, ...,  92,  75, 108], dtype=uint8), 5],
#  [array([ 18,  13,  12, ...,  86, 187, 165], dtype=uint8), 1],
#  [array([178, 108,  68, ...,  80,  91,  88], dtype=uint8), 3],
#  [array([194, 190, 161, ..., 186, 178, 179], dtype=uint8), 2],
#  [array([59, 64, 73, ..., 47, 61, 80], dtype=uint8), 5],
#  [array([238, 235, 230, ..., 104, 139, 172], dtype=uint8), 4],
#  [array([127,  71,  16, ...,  15,  42,  33], dtype=uint8), 3],
#  [array([ 98, 143, 127, ..., 109, 142, 158], dtype=uint8), 1],
#  [array([ 82,  83, 103, ...,  71,  84,  82], dtype=uint8), 5],
#  [array([94, 60, 67, ..., 30, 38, 38], dtype=uint8), 2],
#  [array([46, 51, 49, ..., 77, 86, 99], dtype=uint8), 5],
#  [array([  0, 136,  76, ...,   0,   7,  81], dtype=uint8), 1],
#  [array([ 54,  82, 106, ..., 135, 142, 145], dtype=uint8), 5],
#  [array([198, 198, 198, ...,  49,  49,  49], dtype=uint8), 4],
#  [array([ 74,  90,  67, ..., 136, 160, 180], dtype=uint8), 1],
#  [array([ 15,  13,  13, ..., 196, 192, 168], dtype=uint8), 2],
#  [array([101,  37,  19, ...,  94,  66,  72], dtype=uint8), 4],
#  [array([61, 52, 48, ...,  0,  0,  0], dtype=uint8), 4],
#  [array([179, 157, 105, ..., 154, 137, 104], dtype=uint8), 2],
#  [array([79, 95, 94, ..., 55, 39, 26], dtype=uint8), 5],
#  [array([ 3,  1,  1, ..., 15, 20, 19], dtype=uint8), 5],
#  [array([255, 248, 215, ..., 125, 184, 210], dtype=uint8), 5],
#  [array([127, 149, 155, ..., 155, 168, 182], dtype=uint8), 5],
#  [array([169, 106,   2, ...,  38,  48,  42], dtype=uint8), 3],
#  [array([102, 111, 114, ..., 124, 126, 127], dtype=uint8), 0],
#  [array([98, 41, 16, ..., 62, 78, 85], dtype=uint8), 2],
#  [array([215, 210, 207, ...,  35,  53,  36], dtype=uint8), 3],
#  [array([134, 144, 132, ...,  91,  92,  88], dtype=uint8), 5],
#  [array([244, 185, 116, ...,   0,  47,  75], dtype=uint8), 3],
#  [array([236, 222, 216, ...,  48,  95,  92], dtype=uint8), 2],
#  [array([131,  83,  47, ..., 114,  90,  66], dtype=uint8), 2],
#  [array([183,  94,  43, ...,  56,  88, 111], dtype=uint8), 3],
#  [array([250, 242, 243, ..., 104, 132, 179], dtype=uint8), 0],
#  [array([131, 133, 133, ...,  32,  37,  36], dtype=uint8), 5],
#  [array([255, 253, 253, ...,   9,   9,   9], dtype=uint8), 0],
#  [array([214, 160,  95, ...,  21,  30,  40], dtype=uint8), 4],
#  [array([173,  88,  38, ..., 116,  91,  59], dtype=uint8), 2],
#  [array([223, 204, 196, ...,   7,   8,   0], dtype=uint8), 4],
#  [array([108, 107,  69, ..., 137, 132, 141], dtype=uint8), 2],
#  [array([179, 176, 172, ...,   3,  63,  23], dtype=uint8), 2],
#  [array([251, 194, 139, ..., 190, 222, 187], dtype=uint8), 0],
#  [array([139,  73,  44, ...,  47,  59,  65], dtype=uint8), 2],
#  [array([141, 141, 141, ...,  28,  28,  28], dtype=uint8), 1],
#  [array([152, 133, 126, ...,  65,  53,  49], dtype=uint8), 5],
#  [array([249, 244, 241, ..., 229, 211, 188], dtype=uint8), 2],
#  [array([184, 175, 171, ...,  80,  61,  56], dtype=uint8), 4],
#  [array([147, 138, 100, ..., 144, 229, 251], dtype=uint8), 4],
#  [array([236, 238, 239, ...,  40,  60,  48], dtype=uint8), 3],
#  [array([ 0, 23, 35, ..., 36, 41, 66], dtype=uint8), 1],
#  [array([154, 101,  68, ..., 122, 132, 139], dtype=uint8), 2],
#  [array([203, 217, 206, ...,  69,  90,  75], dtype=uint8), 2],
#  [array([228, 223, 224, ...,  29,  43,  61], dtype=uint8), 3],
#  [array([ 87, 137, 190, ...,   0,   1,   2], dtype=uint8), 4],
#  [array([241, 188, 138, ...,  27,  59,  48], dtype=uint8), 3],
#  [array([80, 77, 72, ..., 71, 67, 66], dtype=uint8), 1],
#  [array([182, 112,  52, ...,  72, 140, 163], dtype=uint8), 3],
#  [array([165,  88,   9, ...,  47, 100, 113], dtype=uint8), 2],
#  [array([156, 146, 139, ..., 116, 121, 124], dtype=uint8), 4],
#  [array([249, 175,  17, ..., 237, 196,  70], dtype=uint8), 0],
#  [array([34, 15,  7, ..., 62, 43, 30], dtype=uint8), 2],
#  [array([161,  87,  39, ..., 102,  66,  36], dtype=uint8), 2],
#  [array([ 99,  81,  74, ..., 106,  88,  77], dtype=uint8), 2],
#  [array([46, 29,  8, ...,  3,  1,  1], dtype=uint8), 1],
#  [array([209, 204, 201, ...,  58,  74,  80], dtype=uint8), 4],
#  [array([126, 104,  79, ..., 191, 203, 197], dtype=uint8), 4],
#  [array([  0,  15,  23, ..., 118, 138, 149], dtype=uint8), 5],
#  [array([91, 63, 52, ..., 34, 40, 35], dtype=uint8), 5],
#  [array([130, 122, 122, ...,  88,  88,  88], dtype=uint8), 4],
#  [array([119, 119, 119, ..., 100, 100, 100], dtype=uint8), 5],
#  [array([249, 254, 255, ...,  25, 148, 150], dtype=uint8), 3],
#  [array([  0, 116,  45, ...,  22,  44,  50], dtype=uint8), 1],
#  [array([178, 166, 156, ...,   0,   0,   0], dtype=uint8), 5],
#  [array([229, 224, 221, ..., 142, 182, 187], dtype=uint8), 3],
#  [array([203,  98,   1, ...,   0,   0,   0], dtype=uint8), 3],
#  [array([171, 133,  98, ..., 101,  97,  86], dtype=uint8), 2],
#  [array([187, 212, 252, ...,   4,  10,  15], dtype=uint8), 4],
#  [array([169, 149, 131, ..., 231, 234, 232], dtype=uint8), 4],
#  [array([12, 12, 12, ..., 83, 83, 83], dtype=uint8), 5],
#  [array([196, 175, 173, ..., 125, 120, 119], dtype=uint8), 2],
#  [array([145, 136, 116, ...,  54,  48,  43], dtype=uint8), 0],
#  [array([97, 72, 62, ..., 85, 75, 65], dtype=uint8), 5],
#  [array([112, 119, 188, ..., 124,  78,  44], dtype=uint8), 4],
#  [array([158, 136, 108, ...,  17,  19,  29], dtype=uint8), 3],
#  [array([ 55,  91, 131, ...,  15,  23,  30], dtype=uint8), 0],
#  [array([135, 100,  86, ...,  17,  39,  74], dtype=uint8), 3],
#  [array([164, 136,  95, ...,  69,  61,  44], dtype=uint8), 4],
#  [array([198, 184, 172, ...,  27,  29,  29], dtype=uint8), 2],
#  [array([ 88, 100, 110, ...,   9,  12,  16], dtype=uint8), 0],
#  [array([24, 24, 24, ..., 65, 65, 65], dtype=uint8), 5],
#  [array([ 7,  9, 10, ..., 26, 25, 27], dtype=uint8), 5],
#  [array([  6,  33,  84, ...,  40,  51, 103], dtype=uint8), 0],
#  [array([ 24,   5,   2, ..., 136, 133, 125], dtype=uint8), 0],
#  [array([207, 179, 144, ...,  27,  19,   2], dtype=uint8), 2],
#  [array([219, 213, 214, ...,  80,  64,  48], dtype=uint8), 2],
#  [array([ 30,  36,  31, ...,  76,  88, 106], dtype=uint8), 1],
#  [array([226, 224, 216, ...,  34,  73,  82], dtype=uint8), 0],
#  [array([ 6, 11, 26, ..., 69, 73, 91], dtype=uint8), 1],
#  [array([124,  82,  39, ...,  90,  95,  96], dtype=uint8), 2],
#  [array([171, 172, 168, ...,  18,  55,  81], dtype=uint8), 1],
#  [array([166, 102,  37, ...,  44,  27,  18], dtype=uint8), 2],
#  [array([214, 140,  82, ...,  21,  16,  15], dtype=uint8), 3],
#  [array([231, 236, 234, ...,  22,  13,  10], dtype=uint8), 4],
#  [array([255, 240, 229, ..., 166, 145, 100], dtype=uint8), 2],
#  [array([148, 148, 148, ...,  18,  18,  18], dtype=uint8), 5],
#  [array([129,  79,  59, ...,  67,  81,  93], dtype=uint8), 3],
#  [array([211, 159,  99, ..., 215, 222, 219], dtype=uint8), 4],
#  [array([24, 30, 35, ..., 24, 29, 32], dtype=uint8), 5],
#  [array([ 23,  26,  34, ...,  92, 143, 159], dtype=uint8), 1],
#  [array([225, 199, 192, ..., 167, 159, 142], dtype=uint8), 2],
#  [array([175, 175, 175, ...,  85,  85,  85], dtype=uint8), 5],
#  [array([233, 224, 210, ..., 186, 184, 176], dtype=uint8), 0],
#  [array([25, 34, 38, ..., 54, 49, 48], dtype=uint8), 0],
#  [array([ 32, 157,  83, ..., 127, 159, 170], dtype=uint8), 1],
#  [array([23, 38, 47, ...,  0,  4, 12], dtype=uint8), 1],
#  [array([250, 245, 246, ...,  57, 103,  97], dtype=uint8), 0],
#  [array([148, 162, 181, ...,  90,  99, 108], dtype=uint8), 5],
#  [array([251, 254, 252, ...,   0,   1,   1], dtype=uint8), 3],
#  [array([246, 241, 238, ...,  91,  61,  32], dtype=uint8), 2],
#  [array([ 75, 113, 125, ...,  75, 153, 189], dtype=uint8), 1],
#  [array([242, 231, 227, ..., 132, 128, 123], dtype=uint8), 5],
#  [array([192, 180, 178, ...,  15,  27,  29], dtype=uint8), 3],
#  [array([16, 18, 26, ..., 28, 46, 63], dtype=uint8), 1],
#  [array([184, 175, 166, ...,  41,  43,  44], dtype=uint8), 4],
#  [array([71, 71, 71, ..., 91, 91, 91], dtype=uint8), 5],
#  [array([121, 112,  98, ...,  21,  23,  24], dtype=uint8), 3],
#  [array([255, 244, 176, ..., 108, 166, 171], dtype=uint8), 3],
#  [array([249, 224, 184, ..., 100, 105, 104], dtype=uint8), 3],
#  [array([ 40, 107, 140, ...,  18,   9,   6], dtype=uint8), 0],
#  [array([244, 235, 226, ..., 181, 161, 130], dtype=uint8), 2],
#  [array([230, 166, 112, ...,  47,  54,  57], dtype=uint8), 3],
#  [array([254, 198,  73, ...,  67,  79,  79], dtype=uint8), 3],
#  [array([131, 132, 128, ...,   4,  39,  65], dtype=uint8), 3],
#  [array([ 7, 11,  5, ..., 19, 24, 23], dtype=uint8), 1],
#  [array([187, 157, 130, ...,  53,  47,  42], dtype=uint8), 2],
#  [array([172, 121,  78, ...,  74,  98, 120], dtype=uint8), 4],
#  [array([190, 122,  75, ..., 201, 183, 160], dtype=uint8), 2],
#  [array([255, 255, 255, ..., 100,  79,  57], dtype=uint8), 5],
#  [array([251, 201, 155, ...,  28,  44,  37], dtype=uint8), 3],
#  [array([144, 130,  88, ..., 253, 255, 255], dtype=uint8), 4],
#  [array([254, 245, 232, ..., 209, 183, 169], dtype=uint8), 3],
#  [array([ 55, 139, 110, ...,   6, 106,  41], dtype=uint8), 1],
#  [array([241, 243, 243, ...,  68,  77,  87], dtype=uint8), 5],
#  [array([52, 85, 71, ..., 63, 80, 93], dtype=uint8), 0],
#  [array([22, 38, 44, ...,  3, 51, 45], dtype=uint8), 1],
#  [array([  0,   2,  96, ..., 117, 117, 111], dtype=uint8), 5],
#  [array([ 28, 181, 130, ...,  54, 118, 123], dtype=uint8), 1],
#  [array([172, 126, 102, ...,  96, 108,  96], dtype=uint8), 0],
#  [array([238, 225, 211, ..., 150, 163, 171], dtype=uint8), 5],
#  [array([218, 196, 191, ...,  45,  31,  12], dtype=uint8), 2],
#  [array([ 0,  0,  0, ...,  6, 15, 53], dtype=uint8), 0],
#  [array([36, 17, 20, ..., 39, 34, 35], dtype=uint8), 5],
#  [array([ 4,  2,  2, ..., 18, 16, 15], dtype=uint8), 5],
#  [array([154, 134, 116, ...,   0,   1,   8], dtype=uint8), 4],
#  [array([142, 117,  97, ..., 102, 105,  90], dtype=uint8), 4],
#  [array([235, 246, 250, ...,   8,   6,   6], dtype=uint8), 3],
#  [array([219, 212, 217, ...,  16,  14,  14], dtype=uint8), 2],
#  [array([92, 34, 35, ..., 32, 32, 14], dtype=uint8), 2],
#  [array([139, 184, 197, ...,  77,  72,  74], dtype=uint8), 5],
#  [array([191, 148, 109, ..., 195, 199, 200], dtype=uint8), 3],
#  [array([170, 157, 149, ...,   6,   8,   8], dtype=uint8), 1],
#  [array([130, 141, 155, ..., 178, 166, 160], dtype=uint8), 5],
#  [array([161, 161, 161, ..., 235, 235, 235], dtype=uint8), 0],
#  [array([132, 128, 134, ...,  16,  19,  24], dtype=uint8), 0],
#  [array([234, 235, 225, ...,  17,  32,  18], dtype=uint8), 2],
#  [array([108,  99,  90, ..., 105, 114, 124], dtype=uint8), 5],
#  [array([204, 192, 182, ...,  13,  17,  12], dtype=uint8), 3],
#  [array([236, 236, 236, ...,  66,  66,  66], dtype=uint8), 0],
#  [array([ 92, 154, 132, ...,  91, 103, 121], dtype=uint8), 1],
#  [array([173, 138, 105, ..., 220, 206, 210], dtype=uint8), 0],
#  [array([44, 74, 91, ..., 16, 16, 16], dtype=uint8), 5],
#  [array([186, 178, 165, ...,  29,  67,  55], dtype=uint8), 3],
#  [array([11, 63, 45, ..., 25, 57, 33], dtype=uint8), 1],
#  [array([221, 227, 234, ...,  53, 141, 177], dtype=uint8), 1],
#  [array([ 40,  42,  36, ...,  91, 101, 118], dtype=uint8), 4],
#  [array([14,  5,  0, ..., 40, 45, 43], dtype=uint8), 5],
#  [array([ 54, 134, 117, ...,  17,  77,  53], dtype=uint8), 1],
#  [array([171,  93,  46, ..., 144, 154, 154], dtype=uint8), 3],
#  [array([31, 53, 65, ..., 55, 36, 21], dtype=uint8), 5],
#  [array([249, 255, 250, ..., 156, 178, 189], dtype=uint8), 0],
#  [array([222, 165, 174, ...,  16,  78,  86], dtype=uint8), 3],
#  [array([186, 160, 154, ..., 157, 193, 223], dtype=uint8), 4],
#  [array([  6,   1,   2, ...,  71,  83, 111], dtype=uint8), 0],
#  [array([204, 194, 177, ..., 109, 114, 113], dtype=uint8), 5],
#  [array([233, 228, 229, ...,  19,  19,  19], dtype=uint8), 3],
#  [array([221, 214, 195, ...,  80,  82,  63], dtype=uint8), 2],
#  [array([100, 102, 143, ...,  28,  30,  40], dtype=uint8), 5],
#  [array([193, 161, 148, ...,  75,  46,  39], dtype=uint8), 3],
#  [array([255, 255, 254, ..., 255, 255, 254], dtype=uint8), 5],
#  [array([233, 232, 236, ...,  29,  44,  36], dtype=uint8), 2],
#  [array([166, 153, 121, ..., 109,  83,  67], dtype=uint8), 2],
#  [array([250, 238, 234, ..., 109, 138, 169], dtype=uint8), 2],
#  [array([ 80, 139,  41, ...,  26,  52,  38], dtype=uint8), 1],
#  [array([145, 110,  96, ..., 126,  93,  77], dtype=uint8), 2],
#  [array([255, 255, 213, ..., 104, 145, 113], dtype=uint8), 1],
#  [array([121, 141, 112, ...,  24,  71,  79], dtype=uint8), 1],
#  [array([ 59,  99,  88, ..., 121, 130, 120], dtype=uint8), 1],
#  [array([124,  95,  80, ...,  26,  10,   4], dtype=uint8), 3],
#  [array([250, 237, 221, ...,  58,  63,  61], dtype=uint8), 0],
#  [array([179, 128,  72, ...,  50, 101, 111], dtype=uint8), 3],
#  [array([ 23, 124, 133, ...,   5,  11,  16], dtype=uint8), 1],
#  [array([251, 240, 232, ...,  58,  58,  58], dtype=uint8), 5],
#  [array([255, 217, 120, ...,  58, 110,  10], dtype=uint8), 4],
#  [array([67, 88, 96, ..., 69, 65, 60], dtype=uint8), 5],
#  [array([226, 191, 165, ..., 109, 168, 184], dtype=uint8), 2],
#  [array([162, 153, 140, ..., 107, 150, 169], dtype=uint8), 4],
#  [array([87, 71, 59, ..., 17, 16, 20], dtype=uint8), 4],
#  [array([ 1, 46, 57, ...,  0,  4,  0], dtype=uint8), 1],
#  [array([105,  93,  91, ..., 126, 131, 134], dtype=uint8), 1],
#  [array([237, 233, 232, ..., 170, 159, 151], dtype=uint8), 2],
#  [array([ 90,  88,  87, ...,  88, 103, 122], dtype=uint8), 4],
#  [array([174, 164, 154, ..., 143, 141, 123], dtype=uint8), 2],
#  [array([236, 222, 203, ...,  61,  69,  76], dtype=uint8), 5],
#  [array([36, 27,  0, ...,  5,  5,  5], dtype=uint8), 5],
#  [array([151, 181, 230, ...,  39,  29,  29], dtype=uint8), 3],
#  [array([134, 172, 112, ...,   4,  36,  19], dtype=uint8), 1],
#  [array([16, 16, 16, ..., 97, 97, 97], dtype=uint8), 5],
#  [array([149, 154, 139, ..., 222, 220, 219], dtype=uint8), 2],
#  [array([114,  95,  88, ..., 199, 192, 177], dtype=uint8), 2],
#  [array([255, 255, 255, ...,   0,  97,  82], dtype=uint8), 3],
#  [array([208, 153,  92, ...,  36,  26,  19], dtype=uint8), 3],
#  [array([133, 113, 102, ...,  53,  66,  68], dtype=uint8), 4],
#  [array([170, 186, 203, ..., 127, 129, 140], dtype=uint8), 5],
#  [array([128, 100,  83, ...,   7,   5,   4], dtype=uint8), 4],
#  [array([132, 157, 107, ...,  36,  47,  74], dtype=uint8), 4],
#  [array([122,  69,  19, ..., 219, 219, 219], dtype=uint8), 2],
#  [array([198, 156, 114, ..., 126, 117, 107], dtype=uint8), 2],
#  [array([236, 229, 220, ..., 163, 180, 206], dtype=uint8), 4],
#  [array([45, 40, 39, ..., 25, 21, 26], dtype=uint8), 4],
#  [array([215, 213, 202, ...,   0,   3,  20], dtype=uint8), 4],
#  [array([ 35,  24,  20, ..., 109,  84,  64], dtype=uint8), 2],
#  [array([177, 176, 186, ...,  66,  55,  57], dtype=uint8), 4],
#  [array([69, 94, 96, ..., 88, 84, 83], dtype=uint8), 2],
#  [array([236, 227, 224, ...,  28,  42,  54], dtype=uint8), 3],
#  [array([177,  99,  33, ...,  25,  49,  69], dtype=uint8), 4],
#  [array([237, 228, 208, ..., 157, 160, 135], dtype=uint8), 4],
#  [array([106, 109, 107, ..., 174, 165, 162], dtype=uint8), 5],
#  [array([197, 159, 124, ...,  56,  70,  76], dtype=uint8), 0],
#  [array([  5,   1,   0, ...,  90, 105,  73], dtype=uint8), 4],
#  [array([135,  69,  34, ...,  37,  44,  59], dtype=uint8), 5],
#  [array([ 87, 125, 107, ...,   0,   4,   0], dtype=uint8), 1],
#  [array([241, 239, 238, ..., 198, 186, 186], dtype=uint8), 0],
#  [array([38, 34, 29, ..., 80, 62, 45], dtype=uint8), 2],
#  [array([226, 130,  84, ..., 180, 191, 189], dtype=uint8), 2],
#  [array([158, 103,  64, ...,  99, 125, 149], dtype=uint8), 2],
#  [array([  0,  23,  12, ...,  73,  87, 106], dtype=uint8), 5],
#  [array([ 25,  23,  23, ..., 123, 136, 152], dtype=uint8), 5],
#  [array([ 78, 211, 249, ...,  23,  34,  38], dtype=uint8), 4],
#  [array([151, 135,  89, ..., 133, 119,  97], dtype=uint8), 2],
#  [array([125, 137, 141, ...,  53,  96, 115], dtype=uint8), 1],
#  [array([ 24,  36,  48, ..., 128, 145, 158], dtype=uint8), 5],
#  [array([ 7,  2,  1, ..., 17, 19,  7], dtype=uint8), 1],
#  [array([102,  67,  63, ...,  78,  65,  67], dtype=uint8), 2],
#  [array([ 96, 122, 134, ...,   2,   1,   3], dtype=uint8), 0],
#  [array([40, 43, 51, ..., 75, 73, 72], dtype=uint8), 5],
#  [array([177, 159, 142, ...,  45,  69,  67], dtype=uint8), 5],
#  [array([232, 226, 219, ...,   1,   3,   4], dtype=uint8), 1],
#  [array([12,  4,  4, ...,  2,  2,  2], dtype=uint8), 5],
#  [array([252, 224, 153, ...,  21,  26,  17], dtype=uint8), 3],
#  [array([ 73,  53,  48, ..., 114,  95,  80], dtype=uint8), 2],
#  [array([114, 123, 133, ..., 118, 101,  98], dtype=uint8), 5],
#  [array([0, 2, 7, ..., 0, 2, 3], dtype=uint8), 5],
#  [array([232, 224, 224, ...,  67,  62,  59], dtype=uint8), 4],
#  [array([193, 200, 195, ...,   0,   8,   0], dtype=uint8), 0],
#  [array([168, 163, 164, ..., 194, 190, 185], dtype=uint8), 5],
#  [array([172, 143, 112, ..., 204, 190, 178], dtype=uint8), 4],
#  [array([106,  33,   1, ..., 184, 124,  95], dtype=uint8), 3],
#  [array([161, 105,  50, ..., 213, 217, 211], dtype=uint8), 3],
#  [array([187, 152, 119, ..., 198, 196, 195], dtype=uint8), 4],
#  [array([11,  1,  1, ..., 55, 44, 40], dtype=uint8), 5],
#  [array([ 71, 105, 128, ...,  38,  54,  66], dtype=uint8), 1],
#  [array([241, 220, 192, ...,  79,  77,  67], dtype=uint8), 2],
#  [array([209, 222, 230, ...,  68,  60,  60], dtype=uint8), 0],
#  [array([188, 162, 145, ..., 141, 116,  54], dtype=uint8), 2],
#  [array([ 63,  89, 103, ...,   2,  19,  38], dtype=uint8), 4],
#  [array([209, 165, 112, ...,  99,  73,  49], dtype=uint8), 4],
#  [array([255, 253, 253, ..., 248, 248, 248], dtype=uint8), 4],
#  [array([ 30,  34,  35, ..., 192, 186, 175], dtype=uint8), 2],
#  [array([216, 142,  84, ...,  42,  39,  35], dtype=uint8), 2],
#  [array([101,  85,  73, ..., 137, 128, 114], dtype=uint8), 2],
#  [array([118,  99,  86, ..., 206, 188, 181], dtype=uint8), 5],
#  [array([191, 187, 186, ..., 148, 142, 135], dtype=uint8), 2],
#  [array([190, 172, 161, ...,  25,  64,  72], dtype=uint8), 3],
#  [array([207, 109,   1, ..., 136, 145, 155], dtype=uint8), 4],
#  [array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), 1],
#  [array([195, 137, 125, ...,  82,  30,  14], dtype=uint8), 4],
#  [array([129, 124, 123, ..., 153, 147, 148], dtype=uint8), 2],
#  [array([ 10, 128,  33, ...,   0,  41,  24], dtype=uint8), 1],
#  [array([224, 210, 222, ...,  13,   9,   8], dtype=uint8), 0],
#  [array([200, 151, 125, ...,  36,  49,  71], dtype=uint8), 2],
#  [array([215, 197, 156, ...,  36,  46,  64], dtype=uint8), 4],
#  [array([146, 144, 134, ..., 121, 118, 110], dtype=uint8), 3],
#  [array([202, 195, 202, ...,  44,  48,  49], dtype=uint8), 3],
#  [array([ 28,  66,  60, ...,  51, 100,  72], dtype=uint8), 1],
#  [array([104,  58,  50, ...,   9,  24,  57], dtype=uint8), 5],
#  [array([197, 185, 183, ...,   9,   9,   9], dtype=uint8), 3],
#  [array([ 57, 130, 158, ...,  52,  57,  60], dtype=uint8), 5],
#  [array([234, 220, 208, ..., 109, 111, 112], dtype=uint8), 0],
#  [array([48, 68, 63, ...,  0, 30, 32], dtype=uint8), 1],
#  [array([148, 114, 114, ...,  15,  13,  19], dtype=uint8), 0],
#  [array([233, 171, 101, ..., 173, 109,  74], dtype=uint8), 2],
#  [array([80, 80, 80, ..., 79, 79, 79], dtype=uint8), 5],
#  [array([144, 153, 167, ...,  58, 115, 140], dtype=uint8), 1],
#  [array([255, 232, 209, ...,  85,  86,  84], dtype=uint8), 2],
#  [array([69, 71, 51, ..., 79, 95, 94], dtype=uint8), 1],
#  [array([50, 42, 52, ..., 51, 44, 49], dtype=uint8), 5],
#  [array([157, 142, 126, ..., 181, 170, 166], dtype=uint8), 2],
#  [array([194, 196, 190, ..., 253, 255, 255], dtype=uint8), 5],
#  [array([0, 0, 4, ..., 0, 0, 0], dtype=uint8), 4],
#  [array([255, 255, 254, ...,  73,  77, 101], dtype=uint8), 0],
#  [array([43, 44, 54, ...,  3,  9,  8], dtype=uint8), 1],
#  [array([247, 247, 241, ...,  62,  43,  35], dtype=uint8), 2],
#  [array([ 82, 108, 120, ...,  97,  89,  89], dtype=uint8), 5],
#  [array([219, 219, 219, ...,  53,  42,  20], dtype=uint8), 3],
#  [array([251, 216, 160, ...,  77,  95, 102], dtype=uint8), 3],
#  [array([ 96, 118, 100, ...,  85,  83,  83], dtype=uint8), 1],
#  [array([95, 83, 77, ..., 46, 44, 36], dtype=uint8), 4],
#  [array([ 49,  62,  64, ..., 125, 121, 116], dtype=uint8), 0],
#  [array([ 97,  83,  87, ...,  97, 187, 157], dtype=uint8), 2],
#  [array([240, 235, 234, ..., 127, 146, 151], dtype=uint8), 2],
#  [array([198, 133,  64, ..., 111,  79,  36], dtype=uint8), 2],
#  [array([233, 215, 216, ...,  51,  59,  66], dtype=uint8), 1],
#  [array([222, 222, 222, ...,  77,  77,  77], dtype=uint8), 5],
#  [array([230, 226, 215, ..., 123, 140, 161], dtype=uint8), 5],
#  [array([182, 135,  91, ...,  86,  78,  65], dtype=uint8), 2],
#  [array([179, 131,  89, ...,   2,   7,   6], dtype=uint8), 3],
#  [array([195, 159, 141, ..., 174, 134, 105], dtype=uint8), 2],
#  [array([159, 132,  95, ...,   0,   0,   0], dtype=uint8), 0],
#  [array([154,  91,  33, ..., 166, 157, 130], dtype=uint8), 2],
#  [array([200, 174, 158, ...,  39,  77, 101], dtype=uint8), 4],
#  [array([227, 227, 211, ..., 194, 173, 146], dtype=uint8), 4],
#  [array([144,  87,  55, ...,  90,  78,  76], dtype=uint8), 3],
#  [array([227, 172, 145, ...,  69,  74,  72], dtype=uint8), 3],
#  [array([136, 107,  93, ...,  35,  29,  30], dtype=uint8), 3],
#  [array([15, 17, 52, ...,  0,  0,  0], dtype=uint8), 5],
#  [array([32, 41, 38, ..., 67, 71, 96], dtype=uint8), 1],
#  [array([56, 56, 56, ..., 60, 60, 60], dtype=uint8), 0],
#  [array([0, 0, 4, ..., 0, 0, 0], dtype=uint8), 4],
#  [array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), 5],
#  [array([178, 150, 116, ...,  56,  60,  61], dtype=uint8), 2],
#  [array([90, 90, 90, ..., 89, 89, 89], dtype=uint8), 5],
#  [array([240, 255, 224, ..., 107, 107, 107], dtype=uint8), 2],
#  [array([150, 134, 118, ..., 167, 151, 138], dtype=uint8), 2],
#  [array([197, 156, 107, ...,  50,  53,  58], dtype=uint8), 5],
#  [array([136, 139, 144, ..., 222, 224, 234], dtype=uint8), 5],
#  [array([252, 180,  96, ...,  67,  86,  83], dtype=uint8), 0],
#  [array([216, 121,  52, ..., 186, 178, 178], dtype=uint8), 3],
#  [array([  0,   1,   1, ...,  36,  98, 104], dtype=uint8), 1],
#  [array([223, 223, 209, ..., 174, 138,  90], dtype=uint8), 4],
#  [array([244, 195, 169, ...,   0,  50,  20], dtype=uint8), 3],
#  [array([167, 110,  79, ...,  51,  32,  25], dtype=uint8), 3],
#  [array([49, 52, 66, ...,  0,  0,  0], dtype=uint8), 5],
#  [array([127, 199, 187, ...,   1,  10,   0], dtype=uint8), 1],
#  [array([140, 159, 167, ...,  52,  80, 111], dtype=uint8), 5],
#  [array([ 0, 20, 46, ..., 23, 27, 38], dtype=uint8), 1],
#  [array([170,  93,  31, ..., 154, 150, 156], dtype=uint8), 0],
#  [array([170, 100,  46, ..., 109,  76,  30], dtype=uint8), 2],
#  [array([184, 128,  87, ...,   4,  21,  18], dtype=uint8), 0],
#  [array([174, 193, 200, ...,   0,   0,   0], dtype=uint8), 0],
#  [array([141, 141, 141, ..., 148, 148, 148], dtype=uint8), 5],
#  [array([73, 89, 78, ..., 43, 51, 58], dtype=uint8), 1],
#  [array([191, 180, 160, ..., 142, 120,  85], dtype=uint8), 2],
#  [array([137, 123, 104, ..., 148, 150, 150], dtype=uint8), 4],
#  [array([18, 18, 18, ...,  8,  8,  8], dtype=uint8), 5],
#  [array([ 94,  80,  58, ..., 125, 166, 168], dtype=uint8), 1],
#  [array([134,  64,  27, ...,  97,  82,  43], dtype=uint8), 2],
#  [array([210, 175, 149, ...,  27,  85,  61], dtype=uint8), 0],
#  [array([175, 154, 127, ..., 135, 111,  75], dtype=uint8), 4],
#  [array([209, 180, 141, ..., 153, 125,  95], dtype=uint8), 2],
#  [array([166,  86,   0, ..., 108, 173, 204], dtype=uint8), 2],
#  [array([21, 21, 21, ..., 23, 34, 26], dtype=uint8), 1],
#  [array([254, 249, 250, ...,   0,  17,   8], dtype=uint8), 3],
#  [array([ 31,  80,  90, ...,  41, 135, 131], dtype=uint8), 1],
#  [array([147, 109,  91, ...,   9,  13,   8], dtype=uint8), 3],
#  [array([165, 220, 235, ...,  77,  63,  40], dtype=uint8), 4],
#  [array([ 21, 174, 177, ...,  15,  48,  63], dtype=uint8), 1],
#  [array([179, 164,  32, ..., 133, 159,  52], dtype=uint8), 4],
#  [array([ 0, 10,  0, ...,  0,  0,  1], dtype=uint8), 1],
#  [array([234, 210, 190, ...,  84,  91,  78], dtype=uint8), 0],
#  [array([150, 109, 107, ...,  15,  10,  12], dtype=uint8), 3],
#  [array([217, 191, 174, ...,   0,  94, 120], dtype=uint8), 2],
#  [array([217, 252, 255, ...,  68,  61,  52], dtype=uint8), 4],
#  [array([ 38,  87, 109, ..., 132, 123, 113], dtype=uint8), 5],
#  [array([147, 139, 132, ..., 140, 142, 142], dtype=uint8), 5],
#  [array([12, 17, 15, ..., 85, 81, 86], dtype=uint8), 1],
#  [array([228, 152,  86, ..., 146,  88,  39], dtype=uint8), 3],
#  [array([ 94, 127, 143, ...,   7,  19,  25], dtype=uint8), 0],
#  [array([ 2,  0,  0, ..., 30, 37, 34], dtype=uint8), 0],
#  [array([181, 201, 202, ...,  78, 114, 108], dtype=uint8), 1],
#  [array([112, 118, 129, ...,  12,  10,  10], dtype=uint8), 5],
#  [array([106, 133, 129, ...,  32,  41,  55], dtype=uint8), 1],
#  [array([253, 252, 254, ...,   2,  28,  44], dtype=uint8), 1],
#  [array([98, 93, 92, ..., 80, 80, 80], dtype=uint8), 2],
#  [array([215, 154, 104, ...,  83, 103,  90], dtype=uint8), 3],
#  [array([143,  63,   0, ...,  61,  31,   6], dtype=uint8), 2],
#  [array([201, 147, 124, ...,  30,  18,  12], dtype=uint8), 5],
#  [array([ 7,  0,  0, ..., 12,  6,  7], dtype=uint8), 1],
#  [array([213, 122,  71, ..., 106,  84,   6], dtype=uint8), 3],
#  [array([196, 176, 165, ...,  24,  26,  26], dtype=uint8), 3],
#  [array([105, 163, 139, ...,  53,  81, 112], dtype=uint8), 1],
#  [array([252, 176,   0, ...,  38,  59,  56], dtype=uint8), 3],
#  [array([177, 135,  70, ..., 102, 122, 139], dtype=uint8), 4],
#  [array([139, 118,  67, ...,  24,  23,  19], dtype=uint8), 2],
#  [array([0, 0, 4, ..., 0, 0, 0], dtype=uint8), 3],
#  [array([ 0, 57, 31, ...,  0,  1, 10], dtype=uint8), 1],
#  [array([158, 148,  71, ...,  27,  60,  99], dtype=uint8), 4],
#  [array([204, 121,  46, ..., 162, 145, 112], dtype=uint8), 2],
#  [array([147, 107,  82, ..., 135, 121, 109], dtype=uint8), 2],
#  [array([203, 146,  95, ..., 170, 147, 121], dtype=uint8), 2],
#  [array([251, 251, 245, ..., 232, 232, 232], dtype=uint8), 5],
#  [array([ 72,  89,  86, ..., 114, 108, 109], dtype=uint8), 5],
#  [array([14, 18, 29, ...,  5,  5,  5], dtype=uint8), 5],
#  [array([221, 215, 204, ...,  32,  72,  60], dtype=uint8), 3],
#  [array([224, 217, 208, ...,   2,  13,  11], dtype=uint8), 3],
#  [array([129, 196, 221, ...,  55,  54,  40], dtype=uint8), 4],
#  [array([176, 143, 123, ...,   2,   8,  13], dtype=uint8), 4],
#  [array([185, 177, 170, ...,  66,  87,  95], dtype=uint8), 0],
#  [array([206, 188, 165, ..., 162, 145, 124], dtype=uint8), 4],
#  [array([205, 197, 160, ..., 128, 191, 205], dtype=uint8), 4],
#  [array([94, 75, 92, ...,  0,  0,  0], dtype=uint8), 5],
#  [array([242, 234, 245, ...,  95,  79,  73], dtype=uint8), 3],
#  [array([22, 22, 22, ..., 25, 25, 25], dtype=uint8), 5],
#  [array([121, 123, 123, ...,  91,  98, 107], dtype=uint8), 5],
#  [array([177, 160, 164, ...,  40,  32,  15], dtype=uint8), 3],
#  [array([155, 153, 153, ...,  40,  66,  80], dtype=uint8), 5],
#  [array([234, 202, 173, ...,  80,  90, 100], dtype=uint8), 4],
#  [array([154, 147, 138, ...,  32,  21,  23], dtype=uint8), 5],
#  [array([229, 173, 124, ..., 159, 118,  79], dtype=uint8), 2],
#  [array([176,  89,  15, ...,  63,  73,  80], dtype=uint8), 4],
#  [array([218, 177, 114, ...,  49,  54,  52], dtype=uint8), 5],
#  [array([176, 165, 161, ...,  69,  63,  56], dtype=uint8), 5],
#  [array([ 40,  46,  59, ...,  90, 108, 145], dtype=uint8), 0],
#  [array([50, 33,  0, ..., 21, 43, 38], dtype=uint8), 2],
#  [array([255, 250, 242, ..., 251, 253, 253], dtype=uint8), 0],
#  [array([ 6,  3,  5, ..., 40, 37, 33], dtype=uint8), 5],
#  [array([251, 248, 233, ..., 195, 148,  97], dtype=uint8), 2],
#  [array([216, 203, 189, ..., 228, 221, 218], dtype=uint8), 3],
#  [array([189, 123,  52, ...,   9,  19,  29], dtype=uint8), 5],
#  [array([1, 3, 4, ..., 0, 0, 0], dtype=uint8), 5],
#  [array([ 63,  87,  87, ...,  16, 102, 132], dtype=uint8), 1],
#  [array([173, 107,  59, ...,  42,  75,  90], dtype=uint8), 3],
#  [array([139, 102,  44, ..., 181, 171, 141], dtype=uint8), 2],
#  [array([193, 148,  97, ..., 255, 255, 255], dtype=uint8), 5],
#  [array([171, 169, 168, ...,  12,  39,  60], dtype=uint8), 2],
#  [array([ 39,  42,  33, ..., 156, 156, 132], dtype=uint8), 2],
#  [array([188, 149, 105, ...,  64,  56,  49], dtype=uint8), 2],
#  [array([ 53,  54,  50, ..., 120, 114,  95], dtype=uint8), 2],
#  [array([243, 236, 233, ...,  88,  87, 103], dtype=uint8), 3],
#  [array([220, 180, 155, ...,  17,  35,  52], dtype=uint8), 3],
#  [array([232, 225, 222, ..., 157, 152, 149], dtype=uint8), 2],
#  [array([  8,  22,  18, ..., 123,  74,  36], dtype=uint8), 2],
#  [array([214, 155, 110, ...,  22,  10,   4], dtype=uint8), 3],
#  [array([204, 167, 141, ...,  39,  43,  44], dtype=uint8), 2],
#  [array([248, 235, 233, ..., 147, 135, 129], dtype=uint8), 2],
#  [array([212, 196, 160, ...,  17,  26,  23], dtype=uint8), 4],
#  [array([222, 194, 187, ...,  56,  50,  51], dtype=uint8), 2],
#  [array([230, 221, 208, ...,  40,  45,  48], dtype=uint8), 0],
#  [array([110, 195, 151, ...,  20,  63,  36], dtype=uint8), 1],
#  [array([181, 169, 187, ...,  54,  60,  65], dtype=uint8), 0],
#  [array([255, 255, 241, ..., 251, 249, 248], dtype=uint8), 4],
#  [array([255, 255, 255, ...,   0,  16,  27], dtype=uint8), 3],
#  [array([9, 2, 9, ..., 0, 0, 9], dtype=uint8), 0],
#  [array([217, 196, 168, ...,   3,  12,  16], dtype=uint8), 0],
#  [array([21, 23, 24, ..., 18, 20, 21], dtype=uint8), 5],
#  [array([176, 162, 144, ..., 101, 135,  98], dtype=uint8), 3],
#  [array([ 3, 22, 25, ...,  0,  6,  8], dtype=uint8), 1],
#  [array([153, 177, 175, ...,  25,  37,   9], dtype=uint8), 1],
#  [array([196, 134,  74, ..., 144, 106,  64], dtype=uint8), 2],
#  [array([178, 146, 111, ...,  45,  46,  42], dtype=uint8), 0],
#  [array([253, 254, 255, ...,   0,  13,  11], dtype=uint8), 2],
#  [array([210, 149, 105, ...,  17,  22,  20], dtype=uint8), 0],
#  [array([180, 145, 111, ...,  48,  61,  75], dtype=uint8), 0],
#  [array([185, 190, 188, ...,  34, 103, 112], dtype=uint8), 0],
#  [array([217, 203, 174, ...,  50,  48,  38], dtype=uint8), 3],
#  [array([169, 200, 185, ...,  13,  18,  17], dtype=uint8), 0],
#  [array([ 0,  7,  4, ..., 36, 41, 42], dtype=uint8), 5],
#  [array([ 71, 161, 138, ...,  28,  70,  82], dtype=uint8), 1],
#  [array([193, 193, 193, ...,   0,   0,   0], dtype=uint8), 5],
#  [array([250, 244, 231, ..., 169, 158, 130], dtype=uint8), 2],
#  [array([243,  98,  30, ...,   0, 144,   8], dtype=uint8), 4],
#  [array([212, 200, 196, ...,  63,  58,  60], dtype=uint8), 2],
#  [array([21, 34, 48, ..., 48, 41, 32], dtype=uint8), 5],
#  [array([227, 212, 186, ..., 118,  89,  38], dtype=uint8), 2],
#  [array([205, 163, 116, ...,  65,  64,  66], dtype=uint8), 2],
#  [array([194, 141, 104, ..., 129, 113,  96], dtype=uint8), 2],
#  [array([255, 255, 255, ...,  74,  32,  25], dtype=uint8), 3],
#  [array([ 0, 17, 26, ...,  0, 12, 25], dtype=uint8), 1],
#  [array([59, 65, 78, ..., 67, 66, 56], dtype=uint8), 5],
#  [array([221, 189, 160, ..., 137, 149, 159], dtype=uint8), 3],
#  [array([140,  85,  46, ..., 234, 240, 235], dtype=uint8), 4],
#  [array([111, 122, 136, ...,  11,  10,  50], dtype=uint8), 5],
#  [array([137,  99,  65, ...,  57,  88, 119], dtype=uint8), 4],
#  [array([254, 254, 254, ...,  85,  82,  84], dtype=uint8), 5],
#  [array([156, 137, 100, ..., 238, 231, 214], dtype=uint8), 2],
#  [array([221, 197, 179, ..., 178, 147, 102], dtype=uint8), 2],
#  [array([240, 245, 243, ...,  60,  62,  72], dtype=uint8), 1],
#  [array([173, 157, 140, ...,  85,  90,  91], dtype=uint8), 4],
#  [array([26, 54, 34, ..., 37, 50, 42], dtype=uint8), 1],
#  [array([20, 28, 35, ..., 46, 67, 99], dtype=uint8), 0],
#  [array([228, 228, 228, ...,  60,  62,  26], dtype=uint8), 0],
#  [array([237, 186, 154, ...,  74, 129, 138], dtype=uint8), 4],
#  [array([65, 94, 99, ..., 25, 28, 36], dtype=uint8), 4],
#  [array([144, 146, 157, ...,  47,  49,  57], dtype=uint8), 0],
#  [array([91, 82, 73, ...,  6,  4,  4], dtype=uint8), 0],
#  [array([220, 193, 172, ..., 115, 132, 145], dtype=uint8), 4],
#  [array([ 62,  34,   0, ..., 115, 175, 217], dtype=uint8), 4],
#  [array([ 86,  81,  78, ...,  38, 113,  99], dtype=uint8), 1],
#  [array([161,  91,  37, ..., 225, 227, 235], dtype=uint8), 2],
#  [array([240, 229, 221, ...,  93,  97,  86], dtype=uint8), 2],
#  [array([ 99, 106,  93, ...,  96, 101, 116], dtype=uint8), 1],
#  [array([169, 183, 181, ..., 117,  99,  68], dtype=uint8), 4],
#  [array([183, 123,  93, ...,   2,  28,  22], dtype=uint8), 3],
#  [array([ 28,  85,  77, ...,  41,  75, 111], dtype=uint8), 1],
#  [array([125, 132, 135, ..., 207, 196, 188], dtype=uint8), 5],
#  [array([43, 33, 23, ..., 94, 96, 96], dtype=uint8), 4],
#  [array([32, 23, 10, ...,  6, 14,  4], dtype=uint8), 1],
#  [array([121,  86,  60, ...,  78,  97, 102], dtype=uint8), 2],
#  [array([1, 0, 2, ..., 1, 1, 1], dtype=uint8), 0],
#  [array([220, 181, 143, ...,  12,  19,  16], dtype=uint8), 3],
#  [array([235, 233, 223, ...,  63,  58,  57], dtype=uint8), 5],
#  [array([226, 237, 245, ...,   8,   8,   8], dtype=uint8), 3],
#  [array([ 24,  41,  68, ...,  45,  71, 107], dtype=uint8), 0],
#  [array([211, 176, 143, ...,  92,  79,  53], dtype=uint8), 4],
#  [array([149, 153, 211, ..., 180, 180, 192], dtype=uint8), 0],
#  [array([220, 214, 195, ...,  41, 130, 210], dtype=uint8), 2],
#  [array([254, 228, 204, ..., 166, 153, 151], dtype=uint8), 3],
#  [array([ 0,  0,  0, ...,  2,  6, 71], dtype=uint8), 5],
#  [array([57, 56, 60, ..., 43, 37, 38], dtype=uint8), 5],
#  [array([ 66, 171, 144, ...,   0,  41,  50], dtype=uint8), 1],
#  [array([ 19, 216,  94, ...,  41,  79,  91], dtype=uint8), 1],
#  [array([175, 153, 141, ..., 187, 196, 205], dtype=uint8), 2],
#  [array([202, 212, 219, ...,  79,  74,  73], dtype=uint8), 5],
#  [array([137, 156, 161, ...,  32,  44,  62], dtype=uint8), 4],
#  [array([148, 212, 170, ...,  31,  40,  73], dtype=uint8), 1],
#  [array([213, 216, 230, ...,  30,  22,  15], dtype=uint8), 4],
#  [array([ 32,  29,  25, ..., 173, 175, 163], dtype=uint8), 2],
#  [array([255, 254, 254, ...,  81,  99,  86], dtype=uint8), 3],
#  [array([182,  87,  37, ...,  26,  23,  25], dtype=uint8), 0],
#  [array([137, 217, 212, ...,  43, 135,  84], dtype=uint8), 1],
#  [array([167,  96,  39, ...,   4,  16,  18], dtype=uint8), 0],
#  [array([203, 189, 161, ..., 133, 135, 135], dtype=uint8), 0],
#  [array([ 9,  9,  9, ..., 45, 45, 45], dtype=uint8), 0],
#  [array([ 93, 138,  99, ...,  26,  65,  80], dtype=uint8), 1],
#  [array([186, 213, 239, ...,  16,  11,  10], dtype=uint8), 5],
#  [array([71, 29, 30, ..., 40, 50, 50], dtype=uint8), 1],
#  [array([148, 121, 101, ...,  14,  20,  15], dtype=uint8), 3],
#  [array([215, 213, 213, ...,   3,   9,   8], dtype=uint8), 2],
#  [array([59, 43, 37, ..., 31, 25, 30], dtype=uint8), 4],
#  [array([253, 106,  50, ...,  10,   4,   5], dtype=uint8), 0],
#  [array([  0,  19,   0, ...,  35, 110,  34], dtype=uint8), 1],
#  [array([ 63,  94, 103, ...,  75,  59,  47], dtype=uint8), 5],
#  [array([221, 222, 196, ...,  72,  56,  43], dtype=uint8), 4],
#  [array([170, 170, 170, ...,  96,  96,  96], dtype=uint8), 0],
#  [array([ 23, 101,  70, ...,  23,  50,  54], dtype=uint8), 1],
#  [array([246, 240, 233, ..., 201, 210, 220], dtype=uint8), 3],
#  [array([ 11,   7,  12, ...,  99, 109, 119], dtype=uint8), 5],
#  [array([185, 175, 157, ..., 122, 133, 125], dtype=uint8), 0],
#  [array([ 95,  64,  19, ..., 122, 118, 113], dtype=uint8), 2],
#  [array([ 14,  14,  14, ..., 118, 118, 118], dtype=uint8), 5],
#  [array([199, 190, 187, ...,  41,  42,  46], dtype=uint8), 4],
#  [array([237, 185, 149, ...,  17,  15,  14], dtype=uint8), 3],
#  [array([239, 210, 179, ...,  57,  41,  35], dtype=uint8), 3],
#  [array([222, 166, 177, ...,   0,  23,  26], dtype=uint8), 0],
#  [array([ 86, 106, 117, ...,  40,  47,  64], dtype=uint8), 1],
#  [array([19, 23, 51, ...,  5,  4,  8], dtype=uint8), 5],
#  [array([ 90,  97, 122, ...,  42,  31,  23], dtype=uint8), 5],
#  [array([167, 134, 115, ..., 164, 161, 156], dtype=uint8), 2],
#  [array([ 26, 102,  71, ...,  86, 153, 114], dtype=uint8), 1],
#  [array([209, 190, 175, ...,   4,   6,   7], dtype=uint8), 3],
#  [array([184, 136,  94, ...,  40,  39,  43], dtype=uint8), 2],
#  [array([172, 143, 112, ..., 204, 190, 178], dtype=uint8), 4],
#  [array([69, 52, 33, ..., 29, 25, 20], dtype=uint8), 4],
#  [array([71, 71, 71, ...,  0,  0,  0], dtype=uint8), 0],
#  [array([11, 43, 38, ...,  0, 82, 70], dtype=uint8), 1],
#  [array([115,  82,  56, ..., 101, 100,  79], dtype=uint8), 2],
#  [array([162, 106,  51, ..., 243, 239, 234], dtype=uint8), 3],
#  [array([18, 22, 50, ...,  9, 12, 17], dtype=uint8), 5],
#  [array([222, 221, 195, ..., 115,  77,  43], dtype=uint8), 4],
#  [array([87, 72, 53, ..., 42, 39, 34], dtype=uint8), 0],
#  [array([168, 123,  90, ..., 142, 142, 142], dtype=uint8), 0],
#  [array([180, 163, 174, ...,  16,   7,  17], dtype=uint8), 5],
#  [array([22, 97, 75, ..., 12,  8, 13], dtype=uint8), 1],
#  [array([ 0, 37, 75, ..., 21, 68, 90], dtype=uint8), 4],
#  [array([255, 255, 255, ...,  36,  40,  34], dtype=uint8), 4],
#  [array([194, 125,  76, ...,  86,  75,  55], dtype=uint8), 3],
#  [array([37, 34, 29, ..., 30, 29, 25], dtype=uint8), 2],
#  [array([251, 242, 222, ...,  86,  88,  76], dtype=uint8), 0],
#  [array([96, 96, 96, ..., 13, 13, 13], dtype=uint8), 4],
#  [array([239, 236, 228, ...,  24,  27,  31], dtype=uint8), 3],
#  [array([ 45, 110,  88, ...,   0,  10,   7], dtype=uint8), 1],
#  [array([ 55, 104, 130, ...,   2,  18,  24], dtype=uint8), 1],
#  [array([215, 195, 190, ...,   7,  26,  39], dtype=uint8), 1],
#  [array([143,  73,  26, ...,  51,  59,  72], dtype=uint8), 3],
#  [array([232, 254, 255, ..., 231, 250, 255], dtype=uint8), 1],
#  [array([228, 192, 156, ...,   8,  19,  11], dtype=uint8), 4],
#  [array([132, 181, 165, ...,  16,  49,  69], dtype=uint8), 1],
#  [array([ 80,  82,  82, ..., 172, 168, 163], dtype=uint8), 5],
#  [array([178, 131, 103, ...,  28,  57,  78], dtype=uint8), 2],
#  [array([209, 171, 136, ...,  63,  52,  38], dtype=uint8), 4],
#  [array([ 60,  74, 103, ...,  22,  50,  85], dtype=uint8), 5],
#  [array([255, 255, 255, ...,   7,  71,  41], dtype=uint8), 0],
#  [array([150, 150, 150, ..., 104, 104, 104], dtype=uint8), 1],
#  [array([46, 49, 47, ..., 43, 45, 45], dtype=uint8), 5],
#  [array([166, 161, 160, ...,  47,  51,  62], dtype=uint8), 3],
#  [array([21, 21, 21, ..., 37, 37, 37], dtype=uint8), 1],
#  [array([216, 208, 201, ...,  51,  60,  73], dtype=uint8), 4],
#  [array([211, 163, 135, ...,  30,  22,  22], dtype=uint8), 3],
#  [array([166, 133, 107, ..., 159, 151, 138], dtype=uint8), 3],
#  [array([211, 202, 193, ...,  75,  70,  71], dtype=uint8), 5],
#  [array([122,  68,  38, ..., 185, 176, 167], dtype=uint8), 3],
#  [array([224, 208, 195, ..., 164, 215, 247], dtype=uint8), 4],
#  [array([225, 218, 209, ...,  19,  34,   3], dtype=uint8), 4],
#  [array([ 90, 113, 189, ...,  30,  32,  43], dtype=uint8), 0],
#  [array([244, 219, 203, ...,  20,  75, 106], dtype=uint8), 3],
#  [array([195, 161, 148, ...,  25,  30,  33], dtype=uint8), 4],
#  [array([255, 253, 255, ..., 255, 255, 255], dtype=uint8), 2],
#  [array([189, 170, 155, ...,  15,  11,  10], dtype=uint8), 3],
#  [array([197, 196, 200, ..., 173, 157, 134], dtype=uint8), 2],
#  [array([225, 198, 184, ..., 187, 156, 133], dtype=uint8), 2],
#  [array([251, 253, 254, ...,   0,   0,   0], dtype=uint8), 4],
#  [array([218, 219, 215, ...,  59,  66,  63], dtype=uint8), 5],
#  [array([249, 244, 245, ...,  68,  88, 105], dtype=uint8), 3],
#  [array([239, 212, 191, ..., 104, 111, 126], dtype=uint8), 3],
#  [array([216, 180, 142, ...,  74,  34,   5], dtype=uint8), 3],
#  [array([122,  52,  15, ..., 150, 143, 146], dtype=uint8), 2],
#  [array([220, 194, 154, ...,  36,  37,  51], dtype=uint8), 0],
#  [array([227, 225, 224, ...,  25,  31,  30], dtype=uint8), 0],
#  [array([255, 237, 224, ..., 220, 208, 204], dtype=uint8), 0],
#  [array([ 1,  1,  1, ..., 99, 99, 99], dtype=uint8), 5],
#  [array([232, 218, 189, ..., 172, 167, 158], dtype=uint8), 2],
#  [array([217, 130,  96, ...,  44,  47,  55], dtype=uint8), 3],
#  [array([242, 214, 167, ..., 167, 180, 202], dtype=uint8), 3],
#  [array([216, 106,  40, ...,  15,  65,  53], dtype=uint8), 4],
#  [array([251, 255, 255, ...,  23,  15,  15], dtype=uint8), 4],
#  [array([ 60,  18,   0, ..., 228, 223, 220], dtype=uint8), 3],
#  [array([255, 255, 255, ..., 255, 255, 255], dtype=uint8), 0],
#  [array([ 15,  16,   6, ..., 201, 185, 186], dtype=uint8), 5],
#  [array([203, 214, 228, ...,  10,  21,  29], dtype=uint8), 5],
#  [array([214, 201, 185, ..., 148, 155, 170], dtype=uint8), 0],
#  [array([109, 114,  69, ...,  10,  20,  50], dtype=uint8), 1],
#  [array([203, 178, 138, ...,  49,  42,  25], dtype=uint8), 3],
#  [array([205, 187, 210, ..., 244, 228, 246], dtype=uint8), 0],
#  [array([253, 255, 255, ..., 255, 255, 255], dtype=uint8), 4],
#  [array([46, 55, 64, ..., 80, 90, 97], dtype=uint8), 5],
#  [array([30, 25, 22, ..., 30, 30, 30], dtype=uint8), 4],
#  [array([182, 144, 126, ...,  25,   5,   0], dtype=uint8), 2],
#  [array([222, 203, 182, ...,  10,   8,   8], dtype=uint8), 0],
#  [array([171, 228, 173, ...,  15,  55,   0], dtype=uint8), 1],
#  [array([166, 113,  62, ...,   0,  28,  50], dtype=uint8), 3],
#  [array([182, 148, 125, ..., 199, 187, 187], dtype=uint8), 4],
#  [array([ 8, 15, 32, ...,  6, 15, 28], dtype=uint8), 5],
#  [array([111, 136, 146, ..., 152, 176, 194], dtype=uint8), 0],
#  [array([24, 37, 51, ...,  9, 73, 37], dtype=uint8), 1],
#  [array([46, 63, 72, ..., 68, 87, 92], dtype=uint8), 2],
#  [array([160, 145, 126, ...,  66,  64,  46], dtype=uint8), 4],
#  [array([179, 183, 194, ...,  84,  99, 115], dtype=uint8), 5],
#  [array([135,  70,  32, ..., 149, 139, 139], dtype=uint8), 2],
#  [array([253, 253, 253, ...,  76,  80,  75], dtype=uint8), 3],
#  [array([ 48,  82, 112, ...,  31,  29,  19], dtype=uint8), 4],
#  [array([139, 116, 108, ..., 101,  83,  72], dtype=uint8), 2],
#  [array([218, 169, 113, ...,  92,  79,  57], dtype=uint8), 3],
#  [array([112, 105,  62, ..., 114, 118,  69], dtype=uint8), 4],
#  [array([171, 133, 103, ..., 106,  81,  47], dtype=uint8), 4],
#  [array([243, 206, 172, ..., 184, 153, 128], dtype=uint8), 2],
#  [array([10, 17,  2, ..., 10, 18,  7], dtype=uint8), 1],
#  [array([147, 129, 112, ..., 215, 205, 195], dtype=uint8), 2],
#  [array([244, 225, 192, ...,  23,  32,  46], dtype=uint8), 4],
#  [array([177, 210, 196, ...,  59,  63,  82], dtype=uint8), 1],
#  [array([150, 175, 115, ...,  64, 132, 115], dtype=uint8), 1],
#  [array([18, 19, 17, ..., 21, 26, 29], dtype=uint8), 4],
#  [array([123, 146, 162, ...,   0,   5,  14], dtype=uint8), 0],
#  [array([195,  90,  11, ...,  87,  88,  86], dtype=uint8), 2],
#  [array([129, 103,  63, ...,  42,   6,   0], dtype=uint8), 3],
#  [array([170, 123,  91, ...,  94, 103, 113], dtype=uint8), 5],
#  [array([ 43,  51,  44, ..., 102, 106, 111], dtype=uint8), 1],
#  [array([248, 245, 241, ..., 176, 135, 102], dtype=uint8), 2],
#  [array([164, 120,  91, ...,  84,  68,  75], dtype=uint8), 2],
#  [array([200, 196, 191, ...,  43,  86,  83], dtype=uint8), 3],
#  [array([145,  96,  40, ..., 102,  71,   0], dtype=uint8), 4],
#  [array([127, 113,  91, ..., 224, 228, 229], dtype=uint8), 4],
#  [array([170, 224, 217, ...,   4,  19,  35], dtype=uint8), 1],
#  [array([ 19,  25,  38, ...,  90,  97, 112], dtype=uint8), 4],
#  [array([174,  91,  36, ..., 133,  60,  30], dtype=uint8), 3],
#  [array([250, 164,  94, ...,  13,  11,  10], dtype=uint8), 0],
#  [array([231, 212, 204, ...,   3,  12,  21], dtype=uint8), 4],
#  [array([ 45, 146, 131, ...,   0,  46,  30], dtype=uint8), 1],
#  [array([35, 52, 41, ..., 26, 43, 62], dtype=uint8), 1],
#  [array([198, 127,  63, ..., 143, 100,  57], dtype=uint8), 2],
#  [array([90, 73, 77, ..., 25, 27, 27], dtype=uint8), 5],
#  [array([192, 189, 184, ..., 137, 133, 122], dtype=uint8), 2],
#  [array([205, 207, 215, ..., 187, 187, 187], dtype=uint8), 2],
#  [array([194, 179, 176, ...,   5,   0,   0], dtype=uint8), 2],
#  [array([220, 178, 155, ..., 117,  99, 106], dtype=uint8), 0],
#  [array([236, 210, 204, ..., 205, 186, 171], dtype=uint8), 2],
#  [array([226, 216, 199, ...,   0,   0,  38], dtype=uint8), 5],
#  [array([ 50,  73,  89, ...,  79, 103, 123], dtype=uint8), 0],
#  [array([169, 116,  73, ..., 188, 190, 190], dtype=uint8), 3],
#  [array([ 38,  64, 101, ...,  57,  63,  70], dtype=uint8), 0],
#  [array([ 71,  71,  71, ..., 101, 101, 101], dtype=uint8), 0],
#  [array([ 24,   8,   0, ..., 165, 149, 120], dtype=uint8), 2],
#  [array([210, 196, 144, ...,  92,  80,  22], dtype=uint8), 2],
#  [array([196, 125,  62, ..., 183, 159, 137], dtype=uint8), 2],
#  [array([ 91, 137, 131, ...,  37,  59,  87], dtype=uint8), 1],
#  [array([199, 182, 169, ...,  10,  13,  11], dtype=uint8), 4],
#  [array([195, 205, 222, ...,  39,  56,  82], dtype=uint8), 5],
#  [array([221, 149,  71, ..., 126, 131, 130], dtype=uint8), 0],
#  [array([217, 183, 137, ...,  33,  47,  70], dtype=uint8), 3],
#  [array([228, 197, 158, ...,  64, 137, 129], dtype=uint8), 3],
#  [array([104, 146, 165, ...,  94, 106, 124], dtype=uint8), 4],
#  [array([127, 115, 121, ...,  47,  38,  34], dtype=uint8), 2],
#  [array([134, 112,  84, ..., 169, 178, 175], dtype=uint8), 4],
#  [array([114,  55,  15, ...,  51,  49,  49], dtype=uint8), 0],
#  [array([247, 247, 247, ...,  55,  55,  55], dtype=uint8), 0],
#  [array([179, 179, 179, ...,  74,  74,  74], dtype=uint8), 5],
#  [array([247, 247, 235, ..., 181, 132, 100], dtype=uint8), 2],
#  [array([155, 129, 105, ..., 117, 113,  89], dtype=uint8), 4],
#  [array([243, 221, 203, ...,  21,  10,   6], dtype=uint8), 2],
#  [array([178, 157, 142, ...,  17,  13,  12], dtype=uint8), 3],
#  [array([206, 185, 183, ...,  38,  33,  34], dtype=uint8), 5],
#  [array([253, 255, 254, ..., 246, 251, 250], dtype=uint8), 0],
#  [array([224, 219, 210, ...,  24,  25,  23], dtype=uint8), 1],
#  [array([231, 188, 145, ..., 202, 201, 197], dtype=uint8), 3],
#  [array([124,  67,   0, ..., 167, 161, 156], dtype=uint8), 2],
#  [array([252, 243, 205, ...,  97, 107,  91], dtype=uint8), 3],
#  [array([240, 219, 204, ...,  63, 108,  81], dtype=uint8), 3],
#  [array([187, 123,  59, ..., 200, 193, 190], dtype=uint8), 2],
#  [array([ 1,  4, 18, ..., 13, 56, 59], dtype=uint8), 1],
#  [array([221, 108,  52, ..., 111, 136, 156], dtype=uint8), 0],
#  [array([238, 163, 101, ..., 213, 218, 219], dtype=uint8), 0],
#  [array([55, 46, 37, ...,  8,  8,  8], dtype=uint8), 0],
#  [array([162,  62,   3, ...,   7,  96,  93], dtype=uint8), 3],
#  [array([196, 183, 169, ...,  25,  54,  68], dtype=uint8), 2],
#  [array([252, 255, 253, ..., 123, 142, 147], dtype=uint8), 0],
#  [array([158, 163, 164, ...,  89, 100, 144], dtype=uint8), 5],
#  [array([121,  69,  28, ...,  21,  19,  18], dtype=uint8), 3],
#  [array([51, 71, 76, ...,  8,  1,  8], dtype=uint8), 1],
#  [array([150, 153, 151, ..., 133, 142, 152], dtype=uint8), 0],
#  [array([55, 47, 48, ..., 67, 71, 66], dtype=uint8), 1],
#  [array([ 65, 104,  83, ..., 112, 125, 117], dtype=uint8), 4],
#  [array([249, 215, 199, ..., 234, 236, 236], dtype=uint8), 4],
#  [array([25, 39, 61, ...,  8,  8,  8], dtype=uint8), 0],
#  [array([202, 116,  56, ..., 117, 133, 140], dtype=uint8), 2],
#  [array([173, 186, 188, ...,  86,  89,  93], dtype=uint8), 5],
#  [array([242, 228, 205, ..., 128, 138, 178], dtype=uint8), 3],
#  [array([ 16,  85, 104, ...,  29,  50,  47], dtype=uint8), 1],
#  [array([156,  78,  32, ...,  15,  24,  27], dtype=uint8), 4],
#  [array([82, 79, 75, ..., 98, 80, 63], dtype=uint8), 5],
#  [array([238, 229, 219, ...,  72,  71,  73], dtype=uint8), 5],
#  [array([143, 142, 132, ..., 112,  90,  65], dtype=uint8), 2],
#  [array([181, 175, 168, ...,   0,   5,  69], dtype=uint8), 3],
#  [array([ 25,  22,  14, ..., 190, 181, 171], dtype=uint8), 5],
#  [array([28, 31, 29, ..., 13, 13, 13], dtype=uint8), 0],
#  [array([150, 124, 110, ...,  62,  55,  46], dtype=uint8), 2],
#  [array([133, 141, 131, ..., 101,  96,  95], dtype=uint8), 0],
#  [array([189, 181, 181, ...,  96, 109, 117], dtype=uint8), 3],
#  [array([ 29,  67,  39, ...,  63, 110,  77], dtype=uint8), 1],
#  [array([30, 24, 17, ..., 61, 53, 46], dtype=uint8), 1],
#  [array([183, 106,  73, ...,  55,  60,  61], dtype=uint8), 2],
#  [array([210, 185, 169, ...,  85, 111, 117], dtype=uint8), 4],
#  [array([199, 152, 120, ..., 255, 251, 247], dtype=uint8), 3],
#  [array([195, 196, 194, ...,   1,   3,   3], dtype=uint8), 3],
#  [array([46, 73, 69, ..., 36, 48, 52], dtype=uint8), 5],
#  [array([ 82, 224, 231, ...,   3,  33,  44], dtype=uint8), 1],
#  [array([251, 251, 237, ...,  77,  82,  83], dtype=uint8), 0],
#  [array([143, 104,  49, ..., 113, 127, 145], dtype=uint8), 0],
#  [array([204, 183, 168, ...,  41,  88, 119], dtype=uint8), 3],
#  [array([149, 127, 116, ..., 173, 158, 139], dtype=uint8), 2],
#  [array([27, 30, 34, ..., 66, 62, 57], dtype=uint8), 5],
#  [array([128,  97,  72, ..., 134, 132, 131], dtype=uint8), 2],
#  [array([191, 181, 181, ...,  60,  60,  76], dtype=uint8), 4],
#  [array([ 4,  0,  3, ..., 10,  9, 11], dtype=uint8), 1],
#  [array([169, 187, 174, ...,  55,  69,  68], dtype=uint8), 3],
#  [array([204,  90,   0, ...,  26,   4,   0], dtype=uint8), 3],
#  [array([153, 134, 101, ...,  59,  63,  11], dtype=uint8), 4],
#  [array([ 99, 130, 121, ...,  44,  39,  48], dtype=uint8), 1],
#  [array([39, 99, 68, ...,  8, 21, 19], dtype=uint8), 1],
#  [array([ 86,  86,  86, ..., 188, 188, 188], dtype=uint8), 5],
#  [array([164, 170, 169, ...,  66,  64,  63], dtype=uint8), 3],
#  [array([247, 232, 230, ...,  45,  50,  49], dtype=uint8), 5],
#  [array([214, 216, 210, ..., 122, 118, 113], dtype=uint8), 2],
#  [array([0, 1, 1, ..., 0, 0, 0], dtype=uint8), 4],
#  [array([249, 249, 249, ...,  50,  67,  54], dtype=uint8), 3],
#  [array([138, 141, 149, ...,   5,   7,   8], dtype=uint8), 5],
#  [array([208,  92,   3, ...,  32,  40,  53], dtype=uint8), 5],
#  [array([ 99, 104,  95, ...,   0,   1,   0], dtype=uint8), 4],
#  [array([255, 124,  58, ...,  30,  24,  19], dtype=uint8), 0],
#  [array([242, 233, 220, ...,   0,  56,  36], dtype=uint8), 2],
#  [array([176, 183, 186, ..., 171, 178, 175], dtype=uint8), 2],
#  [array([15, 44, 48, ..., 22, 43, 41], dtype=uint8), 5],
#  [array([144, 125, 122, ...,  93,  74,  69], dtype=uint8), 2],
#  [array([ 66, 120,  50, ..., 163, 143, 155], dtype=uint8), 1],
#  [array([ 15,  21,  26, ..., 146, 139, 146], dtype=uint8), 1],
#  [array([45, 52, 55, ...,  0,  0,  0], dtype=uint8), 0],
#  [array([ 36, 110,  46, ...,  19,  77,  99], dtype=uint8), 1],
#  [array([  8,   4,   3, ..., 173, 174, 154], dtype=uint8), 5],
#  [array([198, 139,  83, ..., 147, 106,  57], dtype=uint8), 3],
#  [array([31, 66, 70, ..., 28, 66, 71], dtype=uint8), 0],
#  [array([222, 184, 136, ...,  92,  76,  63], dtype=uint8), 5],
#  [array([113,  87,  71, ...,  72,  61,  53], dtype=uint8), 2],
#  [array([ 10,  34,  32, ..., 114, 161, 175], dtype=uint8), 1],
#  [array([94, 86, 87, ...,  5, 26, 28], dtype=uint8), 3],
#  [array([21, 73, 90, ..., 10, 67, 93], dtype=uint8), 1],
#  [array([238, 160,  70, ..., 154, 157, 155], dtype=uint8), 3],
#  [array([181, 176, 178, ...,  60,  46,  17], dtype=uint8), 4],
#  [array([192, 183, 170, ..., 116, 111,  90], dtype=uint8), 2],
#  [array([126, 114, 104, ..., 134, 129, 128], dtype=uint8), 4],
#  [array([251, 231, 196, ...,  91, 149, 208], dtype=uint8), 4],
#  [array([14,  2,  8, ..., 10, 12, 12], dtype=uint8), 1],
#  [array([40, 57, 48, ..., 36, 60, 52], dtype=uint8), 1],
#  [array([148, 124, 106, ...,  86,  94,  93], dtype=uint8), 2],
#  [array([104,  80,  68, ...,  46,  45,  54], dtype=uint8), 5],
#  [array([254, 254, 254, ...,  71, 201, 176], dtype=uint8), 3],
#  [array([20, 23, 21, ...,  1,  4,  8], dtype=uint8), 1],
#  [array([206, 197, 183, ...,  83,  87,  82], dtype=uint8), 2],
#  [array([199, 169, 150, ...,  40, 109,  96], dtype=uint8), 3],
#  [array([177, 168, 165, ...,  81,  79,  79], dtype=uint8), 5],
#  [array([244, 243, 239, ...,  35,  38,  22], dtype=uint8), 3],
#  [array([ 5, 36, 15, ...,  3,  1,  1], dtype=uint8), 1],
#  [array([226, 213, 211, ...,   0,  20,  27], dtype=uint8), 4],
#  [array([175, 134,  85, ..., 132, 119, 133], dtype=uint8), 4],
#  [array([225, 227, 227, ...,   6,  11,  10], dtype=uint8), 3],
#  ...]

# %% [markdown]
# ### train data has been shuffled before here

# %%
features = []
labels = []

for feature, label in train_data:
    features.append(feature)
    labels.append(label)
    
labels
# Out:
# [4,
#  0,
#  3,
#  1,
#  0,
#  3,
#  0,
#  1,
#  4,
#  1,
#  0,
#  0,
#  4,
#  5,
#  4,
#  1,
#  3,
#  0,
#  5,
#  5,
#  2,
#  0,
#  1,
#  4,
#  4,
#  2,
#  5,
#  1,
#  5,
#  4,
#  2,
#  4,
#  2,
#  3,
#  4,
#  2,
#  4,
#  3,
#  2,
#  5,
#  0,
#  3,
#  3,
#  0,
#  3,
#  2,
#  0,
#  0,
#  3,
#  0,
#  4,
#  4,
#  2,
#  2,
#  5,
#  2,
#  5,
#  5,
#  1,
#  0,
#  0,
#  5,
#  3,
#  5,
#  2,
#  3,
#  1,
#  0,
#  1,
#  2,
#  2,
#  0,
#  1,
#  4,
#  5,
#  4,
#  1,
#  0,
#  0,
#  3,
#  1,
#  0,
#  5,
#  5,
#  5,
#  3,
#  5,
#  5,
#  5,
#  5,
#  3,
#  2,
#  5,
#  3,
#  1,
#  2,
#  4,
#  2,
#  2,
#  5,
#  4,
#  4,
#  5,
#  4,
#  5,
#  5,
#  5,
#  2,
#  2,
#  1,
#  1,
#  4,
#  2,
#  2,
#  3,
#  2,
#  4,
#  3,
#  3,
#  4,
#  1,
#  4,
#  2,
#  3,
#  0,
#  0,
#  1,
#  4,
#  4,
#  3,
#  3,
#  3,
#  0,
#  1,
#  0,
#  1,
#  0,
#  3,
#  5,
#  4,
#  2,
#  2,
#  5,
#  1,
#  3,
#  2,
#  4,
#  2,
#  2,
#  0,
#  1,
#  4,
#  0,
#  4,
#  2,
#  1,
#  0,
#  3,
#  3,
#  3,
#  2,
#  0,
#  2,
#  1,
#  4,
#  5,
#  5,
#  0,
#  0,
#  1,
#  3,
#  2,
#  4,
#  2,
#  4,
#  1,
#  1,
#  4,
#  4,
#  2,
#  5,
#  1,
#  3,
#  2,
#  5,
#  4,
#  3,
#  1,
#  5,
#  2,
#  5,
#  1,
#  5,
#  4,
#  1,
#  2,
#  4,
#  4,
#  2,
#  5,
#  5,
#  5,
#  5,
#  3,
#  0,
#  2,
#  3,
#  5,
#  3,
#  2,
#  2,
#  3,
#  0,
#  5,
#  0,
#  4,
#  2,
#  4,
#  2,
#  2,
#  0,
#  2,
#  1,
#  5,
#  2,
#  4,
#  4,
#  3,
#  1,
#  2,
#  2,
#  3,
#  4,
#  3,
#  1,
#  3,
#  2,
#  4,
#  0,
#  2,
#  2,
#  2,
#  1,
#  4,
#  4,
#  5,
#  5,
#  4,
#  5,
#  3,
#  1,
#  5,
#  3,
#  3,
#  2,
#  4,
#  4,
#  5,
#  2,
#  0,
#  5,
#  4,
#  3,
#  0,
#  3,
#  4,
#  2,
#  0,
#  5,
#  5,
#  0,
#  0,
#  2,
#  2,
#  1,
#  0,
#  1,
#  2,
#  1,
#  2,
#  3,
#  4,
#  2,
#  5,
#  3,
#  4,
#  5,
#  1,
#  2,
#  5,
#  0,
#  0,
#  1,
#  1,
#  0,
#  5,
#  3,
#  2,
#  1,
#  5,
#  3,
#  1,
#  4,
#  5,
#  3,
#  3,
#  3,
#  0,
#  2,
#  3,
#  3,
#  3,
#  1,
#  2,
#  4,
#  2,
#  5,
#  3,
#  4,
#  3,
#  1,
#  5,
#  0,
#  1,
#  5,
#  1,
#  0,
#  5,
#  2,
#  0,
#  5,
#  5,
#  4,
#  4,
#  3,
#  2,
#  2,
#  5,
#  3,
#  1,
#  5,
#  0,
#  0,
#  2,
#  5,
#  3,
#  0,
#  1,
#  0,
#  5,
#  3,
#  1,
#  1,
#  4,
#  5,
#  1,
#  3,
#  5,
#  0,
#  3,
#  4,
#  0,
#  5,
#  3,
#  2,
#  5,
#  3,
#  5,
#  2,
#  2,
#  2,
#  1,
#  2,
#  1,
#  1,
#  1,
#  3,
#  0,
#  3,
#  1,
#  5,
#  4,
#  5,
#  2,
#  4,
#  4,
#  1,
#  1,
#  2,
#  4,
#  2,
#  5,
#  5,
#  3,
#  1,
#  5,
#  2,
#  2,
#  3,
#  3,
#  4,
#  5,
#  4,
#  4,
#  2,
#  2,
#  4,
#  4,
#  4,
#  2,
#  4,
#  2,
#  3,
#  4,
#  4,
#  5,
#  0,
#  4,
#  5,
#  1,
#  0,
#  2,
#  2,
#  2,
#  5,
#  5,
#  4,
#  2,
#  1,
#  5,
#  1,
#  2,
#  0,
#  5,
#  5,
#  1,
#  5,
#  3,
#  2,
#  5,
#  5,
#  4,
#  0,
#  5,
#  4,
#  3,
#  3,
#  4,
#  5,
#  1,
#  2,
#  0,
#  2,
#  4,
#  4,
#  4,
#  2,
#  2,
#  2,
#  5,
#  2,
#  3,
#  4,
#  1,
#  4,
#  2,
#  1,
#  0,
#  2,
#  4,
#  3,
#  3,
#  1,
#  5,
#  3,
#  5,
#  0,
#  1,
#  0,
#  2,
#  5,
#  1,
#  2,
#  1,
#  5,
#  2,
#  5,
#  4,
#  0,
#  1,
#  2,
#  5,
#  3,
#  3,
#  1,
#  4,
#  0,
#  2,
#  2,
#  2,
#  1,
#  5,
#  5,
#  2,
#  3,
#  2,
#  0,
#  2,
#  4,
#  4,
#  3,
#  3,
#  3,
#  5,
#  1,
#  0,
#  4,
#  5,
#  2,
#  5,
#  2,
#  2,
#  5,
#  5,
#  0,
#  3,
#  1,
#  4,
#  3,
#  3,
#  5,
#  1,
#  5,
#  1,
#  0,
#  2,
#  0,
#  0,
#  5,
#  1,
#  2,
#  4,
#  5,
#  1,
#  2,
#  0,
#  4,
#  2,
#  2,
#  1,
#  3,
#  1,
#  3,
#  4,
#  1,
#  4,
#  1,
#  0,
#  3,
#  2,
#  4,
#  5,
#  5,
#  1,
#  3,
#  0,
#  0,
#  1,
#  5,
#  1,
#  1,
#  2,
#  3,
#  2,
#  5,
#  1,
#  3,
#  3,
#  1,
#  3,
#  4,
#  2,
#  3,
#  1,
#  4,
#  2,
#  2,
#  2,
#  5,
#  5,
#  5,
#  3,
#  3,
#  4,
#  4,
#  0,
#  4,
#  4,
#  5,
#  3,
#  5,
#  5,
#  3,
#  5,
#  4,
#  5,
#  2,
#  4,
#  5,
#  5,
#  0,
#  2,
#  0,
#  5,
#  2,
#  3,
#  5,
#  5,
#  1,
#  3,
#  2,
#  5,
#  2,
#  2,
#  2,
#  2,
#  3,
#  3,
#  2,
#  2,
#  3,
#  2,
#  2,
#  4,
#  2,
#  0,
#  1,
#  0,
#  4,
#  3,
#  0,
#  0,
#  5,
#  3,
#  1,
#  1,
#  2,
#  0,
#  2,
#  0,
#  0,
#  0,
#  3,
#  0,
#  5,
#  1,
#  5,
#  2,
#  4,
#  2,
#  5,
#  2,
#  2,
#  2,
#  3,
#  1,
#  5,
#  3,
#  4,
#  5,
#  4,
#  5,
#  2,
#  2,
#  1,
#  4,
#  1,
#  0,
#  0,
#  4,
#  4,
#  0,
#  0,
#  4,
#  4,
#  1,
#  2,
#  2,
#  1,
#  4,
#  3,
#  1,
#  5,
#  4,
#  1,
#  2,
#  0,
#  3,
#  5,
#  3,
#  0,
#  4,
#  0,
#  2,
#  3,
#  5,
#  5,
#  1,
#  1,
#  2,
#  5,
#  4,
#  1,
#  4,
#  2,
#  3,
#  0,
#  1,
#  0,
#  0,
#  0,
#  1,
#  5,
#  1,
#  3,
#  2,
#  4,
#  0,
#  1,
#  5,
#  4,
#  0,
#  1,
#  3,
#  5,
#  0,
#  2,
#  5,
#  4,
#  3,
#  3,
#  0,
#  1,
#  5,
#  5,
#  2,
#  1,
#  3,
#  2,
#  4,
#  4,
#  0,
#  1,
#  2,
#  3,
#  5,
#  4,
#  0,
#  0,
#  5,
#  1,
#  4,
#  4,
#  3,
#  2,
#  0,
#  4,
#  3,
#  1,
#  1,
#  1,
#  3,
#  1,
#  4,
#  1,
#  5,
#  2,
#  4,
#  5,
#  0,
#  1,
#  5,
#  3,
#  1,
#  4,
#  3,
#  3,
#  5,
#  3,
#  4,
#  4,
#  0,
#  3,
#  4,
#  2,
#  3,
#  2,
#  2,
#  4,
#  5,
#  3,
#  3,
#  3,
#  2,
#  0,
#  0,
#  0,
#  5,
#  2,
#  3,
#  3,
#  4,
#  4,
#  3,
#  0,
#  5,
#  5,
#  0,
#  1,
#  3,
#  0,
#  4,
#  5,
#  4,
#  2,
#  0,
#  1,
#  3,
#  4,
#  5,
#  0,
#  1,
#  2,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  3,
#  4,
#  4,
#  2,
#  1,
#  2,
#  4,
#  1,
#  1,
#  4,
#  0,
#  2,
#  3,
#  5,
#  1,
#  2,
#  2,
#  3,
#  4,
#  4,
#  1,
#  4,
#  3,
#  0,
#  4,
#  1,
#  1,
#  2,
#  5,
#  2,
#  2,
#  2,
#  0,
#  2,
#  5,
#  0,
#  3,
#  0,
#  0,
#  2,
#  2,
#  2,
#  1,
#  4,
#  5,
#  0,
#  3,
#  3,
#  4,
#  2,
#  4,
#  0,
#  0,
#  5,
#  2,
#  4,
#  2,
#  3,
#  5,
#  0,
#  1,
#  3,
#  2,
#  3,
#  3,
#  2,
#  1,
#  0,
#  0,
#  0,
#  3,
#  2,
#  0,
#  5,
#  3,
#  1,
#  0,
#  1,
#  4,
#  4,
#  0,
#  2,
#  5,
#  3,
#  1,
#  4,
#  5,
#  5,
#  2,
#  3,
#  5,
#  0,
#  2,
#  0,
#  3,
#  1,
#  1,
#  2,
#  4,
#  3,
#  3,
#  5,
#  1,
#  0,
#  0,
#  3,
#  2,
#  5,
#  2,
#  4,
#  1,
#  3,
#  3,
#  4,
#  1,
#  1,
#  5,
#  3,
#  5,
#  2,
#  4,
#  3,
#  5,
#  5,
#  4,
#  0,
#  2,
#  2,
#  5,
#  2,
#  1,
#  1,
#  0,
#  1,
#  5,
#  3,
#  0,
#  5,
#  2,
#  1,
#  3,
#  1,
#  3,
#  4,
#  2,
#  4,
#  4,
#  1,
#  1,
#  2,
#  5,
#  3,
#  1,
#  2,
#  3,
#  5,
#  3,
#  1,
#  4,
#  4,
#  3,
#  ...]

# %%
np_features = np.array(features)
np_lables = np.array(labels)

# %%
np_features = np_features.astype(np.int32)

# %%
np_features
# Out:
# array([[219, 217, 216, ..., 157, 159, 159],
#        [ 29,  27,  33, ...,  61,  75,  97],
#        [217, 134,  83, ..., 136, 158, 169],
#        ...,
#        [ 80,  99, 114, ...,  69,  70,  84],
#        [117, 115, 191, ...,   8,   8,   8],
#        [185, 110,  32, ..., 185, 201, 214]])

# %%
print('total data shape: ',np_features.shape)
print('total labels shape: ', np_lables.shape)
# Out:
# total data shape:  (17354, 67500)
# total labels shape:  (17354,)

# %% [markdown]
# ## Dementionality reduction

# %%
from sklearn.decomposition import PCA 
pca_3600 = PCA(n_components=3600)
np_features_pca = pca_3600.fit_transform(np_features)

# %%
np_features_pca.shape
# Out:
# (17354, 3600)

# %%
print('total data shape after PCA: ',np_features_pca.shape)
print('total labels shape: ', np_lables.shape)
# Out:
# total data shape after PCA:  (17354, 3600)
# total labels shape:  (17354,)

# %%
print('the numbers of features have been dropped by', ((len(np_features[1])-len(np_features_pca[1]))/len(np_features[1]))*100,'%')
# Out:
# the numbers of features have been dropped by 94.66666666666667 %

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(np_features_pca, np_lables, test_size=0.17)

# %%
X_train.shape
# Out:
# (14403, 3600)

# %%
np_features_pca.shape
# Out:
# (17354, 3600)

# %% [markdown]
# ## Applying GridsearchCV & Cross-validation for svm

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
clf = GridSearchCV(svm.SVC(gamma='auto'), {
    'C': [1,10,20],
    'kernel': ['rbf','linear']
}, cv=5, return_train_score=False)
clf.fit(np_features_pca, np_lables)
clf.cv_results_
# Out:
# {'mean_fit_time': array([312.77512493, 249.71128678, 335.63347673, 261.17545252,
#         343.58180594, 263.25737019]),
#  'std_fit_time': array([ 1.92147989, 13.16734555, 10.61571275, 11.08636315,  6.81464167,
#          6.43603076]),
#  'mean_score_time': array([85.19174771, 36.18529143, 96.20823684, 38.33147783, 83.72925396,
#         38.51222501]),
#  'std_score_time': array([11.64672577,  0.7837059 , 19.03379362,  1.65711819,  1.91749653,
#          1.8536868 ]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear'],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'}],
#  'split0_test_score': array([0.2235007 , 0.46338912, 0.2235007 , 0.46338912, 0.2235007 ,
#         0.46338912]),
#  'split1_test_score': array([0.21861925, 0.43584379, 0.21861925, 0.43584379, 0.21861925,
#         0.43584379]),
#  'split2_test_score': array([0.2193166, 0.4511855, 0.2193166, 0.4511855, 0.2193166, 0.4511855]),
#  'split3_test_score': array([0.21520753, 0.44611092, 0.21520753, 0.44611092, 0.21520753,
#         0.44611092]),
#  'split4_test_score': array([0.22009069, 0.44506453, 0.22009069, 0.44506453, 0.22009069,
#         0.44506453]),
#  'mean_test_score': array([0.21934695, 0.44831877, 0.21934695, 0.44831877, 0.21934695,
#         0.44831877]),
#  'std_test_score': array([0.00266353, 0.0090158 , 0.00266353, 0.0090158 , 0.00266353,
#         0.0090158 ]),
#  'rank_test_score': array([4, 1, 4, 1, 4, 1])}

# %%
clf_C = GridSearchCV(svm.SVC(gamma='auto'), {
    'C': [200,500],
    'kernel': ['rbf']
}, cv=2, return_train_score=False)
clf_C.fit(np_features_pca, np_lables)
clf_C.cv_results_
# Out:
# {'mean_fit_time': array([116.13888967, 118.05938911]),
#  'std_fit_time': array([2.09857619, 0.47964382]),
#  'mean_score_time': array([132.13365996, 119.42439389]),
#  'std_score_time': array([15.36980999,  0.21228814]),
#  'param_C': masked_array(data=[200, 500],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'rbf'],
#               mask=[False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 200, 'kernel': 'rbf'}, {'C': 500, 'kernel': 'rbf'}],
#  'split0_test_score': array([0.20965267, 0.20965267]),
#  'split1_test_score': array([0.20895522, 0.20895522]),
#  'mean_test_score': array([0.20930395, 0.20930395]),
#  'std_test_score': array([0.00034872, 0.00034872]),
#  'rank_test_score': array([1, 1])}

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
clf_C_135 = GridSearchCV(svm.SVC(), {
    'C': [1,3,5],
    'kernel': ['rbf']
}, cv=3, return_train_score=False)
clf_C_135.fit(np_features_pca, np_lables)
clf_C_135.cv_results_
# Out:
# {'mean_fit_time': array([116.51370144, 136.217954  , 146.35602649]),
#  'std_fit_time': array([1.65754119, 0.04390556, 4.20291625]),
#  'mean_score_time': array([91.78611771, 97.07998451, 92.14324609]),
#  'std_score_time': array([6.37503297, 8.53647581, 2.88359949]),
#  'param_C': masked_array(data=[1, 3, 5],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_kernel': masked_array(data=['rbf', 'rbf', 'rbf'],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 3, 'kernel': 'rbf'},
#   {'C': 5, 'kernel': 'rbf'}],
#  'split0_test_score': array([0.65523013, 0.66861925, 0.6665272 ]),
#  'split1_test_score': array([0.66059845, 0.68110483, 0.67712911]),
#  'split2_test_score': array([0.65515798, 0.67419962, 0.67273488]),
#  'mean_test_score': array([0.65699552, 0.67464123, 0.67213039]),
#  'std_test_score': array([0.00254783, 0.00510678, 0.00434927]),
#  'rank_test_score': array([3, 1, 2])}

# %%
import pandas as pd
df = pd.DataFrame(clf_C_135.cv_results_)
df[['param_C','param_kernel','mean_test_score']]
# Out:
#   param_C param_kernel  mean_test_score
# 0       1          rbf         0.656996
# 1       3          rbf         0.674641
# 2       5          rbf         0.672130

# %% [markdown]
# * svm has its highest accuracy as 0.674641 when usinng rbf kernal and C = 3

# %% [markdown]
# ## Applying GridsearchCV & Cross-validation for k-nn

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
clf_nn = GridSearchCV(KNeighborsClassifier(), {
    'n_neighbors': [1,2,3,4,5],
}, cv=5, return_train_score=False)
clf_nn.fit(np_features_pca, np_lables)
clf_nn.cv_results_
# Out:
# {'mean_fit_time': array([0.11903977, 0.12629099, 0.1203197 , 0.11813312, 0.11955128]),
#  'std_fit_time': array([0.00412718, 0.0054918 , 0.00156083, 0.00306848, 0.00429199]),
#  'mean_score_time': array([1.26897206, 1.46239386, 1.47947431, 1.59414907, 1.58798342]),
#  'std_score_time': array([0.02701923, 0.02832398, 0.03985029, 0.03878916, 0.04912124]),
#  'param_n_neighbors': masked_array(data=[1, 2, 3, 4, 5],
#               mask=[False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'n_neighbors': 1},
#   {'n_neighbors': 2},
#   {'n_neighbors': 3},
#   {'n_neighbors': 4},
#   {'n_neighbors': 5}],
#  'split0_test_score': array([0.41945607, 0.41875872, 0.43723849, 0.42956764, 0.43235704]),
#  'split1_test_score': array([0.42050209, 0.41631799, 0.43200837, 0.41666667, 0.41631799]),
#  'split2_test_score': array([0.41701534, 0.41213389, 0.43340307, 0.42608089, 0.42468619]),
#  'split3_test_score': array([0.40844088, 0.396233  , 0.41611441, 0.41192885, 0.4066969 ]),
#  'split4_test_score': array([0.40704569, 0.39797698, 0.42274154, 0.41297524, 0.40809208]),
#  'mean_test_score': array([0.41449201, 0.40828412, 0.42830118, 0.41944386, 0.41763004]),
#  'std_test_score': array([0.00564259, 0.00938667, 0.00773402, 0.00710736, 0.00978674]),
#  'rank_test_score': array([4, 5, 1, 2, 3])}

# %%
df = pd.DataFrame(clf_nn.cv_results_)
df[['param_n_neighbors','mean_test_score']]
# Out:
#   param_n_neighbors  mean_test_score
# 0                 1         0.414492
# 1                 2         0.408284
# 2                 3         0.428301
# 3                 4         0.419444
# 4                 5         0.417630

# %% [markdown]
# * k-nn has its highest accuracy as 0.428301 when usinng n = 3

# %% [markdown]
# ## We chose svm as classifier

# %% [markdown]
# * training the support vectorclassifier

# %%
from sklearn.svm import SVC
model = SVC(C=3)
model.fit(np_features_pca,np_lables)
# Out:
# SVC(C=3)

# %%
test_dir = './datasets/test_set/'
test_data = []
#load test set
for img in os.listdir(test_dir):
    path = os.path.join(test_dir, img)
    test_img = cv2.imread(path)
    
    try:
        test_img = cv2.resize(test_img,(150,150))
        image = np.array(test_img).flatten()
        test_data.append([image,img])
    except Exception as e:
        pass

# %%
len(test_data)
# Out:
# 3600

# %%
test_features = []
image_ids = []

for test_feature, image_id in test_data:
    test_features.append(test_feature)
    image_ids.append(image_id)

# %%
test_features
# Out:
# [array([  4,   7,  21, ..., 109,  88,  86], dtype=uint8),
#  array([222, 194, 160, ...,  75, 107, 126], dtype=uint8),
#  array([250, 250, 250, ...,  59,  63,  74], dtype=uint8),
#  array([104,  94,  47, ...,  67,  70,  78], dtype=uint8),
#  array([241, 246, 244, ..., 124, 101, 109], dtype=uint8),
#  array([153, 106,  44, ...,  30,  20,  20], dtype=uint8),
#  array([230, 199, 146, ...,  80, 198, 179], dtype=uint8),
#  array([95, 78, 69, ..., 42, 45, 59], dtype=uint8),
#  array([ 0,  6,  4, ..., 13,  6, 13], dtype=uint8),
#  array([ 30,  30,  30, ..., 100, 100, 100], dtype=uint8),
#  array([ 53,  32,   4, ..., 122,  99,  73], dtype=uint8),
#  array([ 95,  46,  14, ...,  56,  92, 116], dtype=uint8),
#  array([162, 162, 162, ...,   7,   7,   7], dtype=uint8),
#  array([ 63,  67,  72, ..., 148, 159, 167], dtype=uint8),
#  array([243, 241, 240, ...,  99,  98, 107], dtype=uint8),
#  array([163, 163, 163, ...,  56,  56,  56], dtype=uint8),
#  array([100,  93, 120, ...,  76,  93, 120], dtype=uint8),
#  array([217, 200, 197, ...,   9,  24,  27], dtype=uint8),
#  array([203, 203, 203, ..., 234, 234, 234], dtype=uint8),
#  array([231, 190, 158, ..., 130, 134, 139], dtype=uint8),
#  array([239, 228, 238, ...,  25,  41,  87], dtype=uint8),
#  array([191, 155, 117, ...,  28,  94, 119], dtype=uint8),
#  array([191, 155, 117, ...,  28,  94, 119], dtype=uint8),
#  array([213, 199, 187, ...,   4,   6,   7], dtype=uint8),
#  array([195, 154, 115, ...,  46,  47,  43], dtype=uint8),
#  array([  3,   8,  23, ..., 105, 144, 172], dtype=uint8),
#  array([62, 46, 47, ...,  0,  1,  1], dtype=uint8),
#  array([  0,   7,   5, ...,  92,  75, 108], dtype=uint8),
#  array([ 14,  13,  17, ..., 139, 141, 151], dtype=uint8),
#  array([121,  76,   3, ..., 101, 110, 113], dtype=uint8),
#  array([ 22,  22,  22, ..., 143, 143, 143], dtype=uint8),
#  array([112, 112, 112, ..., 160, 160, 160], dtype=uint8),
#  array([209, 200, 191, ...,  34,  35,  55], dtype=uint8),
#  array([223, 221, 210, ...,  93,  90,  85], dtype=uint8),
#  array([195, 205, 222, ...,  39,  56,  82], dtype=uint8),
#  array([254, 254, 254, ..., 196, 187, 178], dtype=uint8),
#  array([230, 228, 234, ..., 118, 106, 106], dtype=uint8),
#  array([145, 164, 185, ...,   4,  19,  15], dtype=uint8),
#  array([212, 203, 194, ..., 161, 149, 145], dtype=uint8),
#  array([24, 24, 24, ...,  9,  9,  9], dtype=uint8),
#  array([190, 149, 116, ..., 157, 168, 176], dtype=uint8),
#  array([205, 231, 225, ...,  46, 135, 139], dtype=uint8),
#  array([177, 168, 165, ...,  81,  79,  79], dtype=uint8),
#  array([175, 181, 186, ...,  20,  41,  63], dtype=uint8),
#  array([202, 212, 219, ...,  79,  74,  73], dtype=uint8),
#  array([135, 107,  96, ..., 175, 165, 165], dtype=uint8),
#  array([189, 150, 118, ...,  16,  42,  42], dtype=uint8),
#  array([166, 153, 121, ..., 109,  83,  67], dtype=uint8),
#  array([180, 139,  94, ...,   1,   5,   0], dtype=uint8),
#  array([167, 156, 148, ..., 121, 119, 101], dtype=uint8),
#  array([242, 242, 254, ...,  97,  86,  58], dtype=uint8),
#  array([176, 158, 121, ..., 205, 196, 192], dtype=uint8),
#  array([255, 247, 243, ..., 121, 170, 180], dtype=uint8),
#  array([255, 247, 243, ..., 121, 170, 180], dtype=uint8),
#  array([144, 126, 119, ..., 106, 118, 120], dtype=uint8),
#  array([202, 166, 142, ..., 214, 190, 184], dtype=uint8),
#  array([183, 121,  51, ..., 125, 107,  66], dtype=uint8),
#  array([171,  94,   1, ..., 196, 186, 168], dtype=uint8),
#  array([157, 157, 151, ..., 148, 145, 114], dtype=uint8),
#  array([150, 150, 150, ..., 134, 134, 134], dtype=uint8),
#  array([89, 89, 77, ...,  0, 10,  0], dtype=uint8),
#  array([ 51,  13,   8, ..., 177, 179, 187], dtype=uint8),
#  array([204, 168, 138, ..., 179, 149, 120], dtype=uint8),
#  array([161, 123,  93, ..., 187, 178, 168], dtype=uint8),
#  array([217, 178, 150, ...,  34,  26,  13], dtype=uint8),
#  array([242, 242, 206, ...,  26,  36,  24], dtype=uint8),
#  array([185,  89,  49, ...,  43,  44,  42], dtype=uint8),
#  array([ 51,  28,   2, ..., 194, 148,  84], dtype=uint8),
#  array([239, 244, 245, ..., 249, 249, 249], dtype=uint8),
#  array([212, 130,  75, ...,  20,   9,   5], dtype=uint8),
#  array([224, 236, 248, ..., 119,  95,  77], dtype=uint8),
#  array([66, 44, 39, ..., 69, 54, 51], dtype=uint8),
#  array([130, 131, 127, ...,  19,  25,  32], dtype=uint8),
#  array([155, 141, 119, ...,   0,   0,   0], dtype=uint8),
#  array([237, 135, 113, ..., 126, 202, 208], dtype=uint8),
#  array([223, 213, 206, ...,  58,  53,  54], dtype=uint8),
#  array([225, 191, 167, ..., 186, 139,  95], dtype=uint8),
#  array([229, 223, 212, ..., 154, 182, 217], dtype=uint8),
#  array([185, 173, 149, ...,  72, 120, 132], dtype=uint8),
#  array([112, 192, 133, ...,   9,  85,  31], dtype=uint8),
#  array([255, 190, 151, ...,  13,  39,  51], dtype=uint8),
#  array([188, 149, 110, ...,  68,  46,  18], dtype=uint8),
#  array([ 66, 198, 161, ...,  22,  96,  92], dtype=uint8),
#  array([ 9, 14, 12, ..., 15, 22, 17], dtype=uint8),
#  array([ 61, 161, 133, ...,  20,  69,  47], dtype=uint8),
#  array([57, 39,  0, ..., 41, 49, 66], dtype=uint8),
#  array([218, 137,  69, ...,  31,   7,   1], dtype=uint8),
#  array([226, 224, 223, ...,   4,   9,  10], dtype=uint8),
#  array([216, 212, 201, ...,  47,  42,  44], dtype=uint8),
#  array([253, 249, 225, ..., 101, 103, 104], dtype=uint8),
#  array([246, 241, 238, ...,  91,  61,  32], dtype=uint8),
#  array([249, 237, 235, ..., 149, 144, 135], dtype=uint8),
#  array([61, 64, 68, ...,  3, 15, 17], dtype=uint8),
#  array([216, 167, 111, ...,  38,  64,  64], dtype=uint8),
#  array([158, 156, 132, ...,  80,  81,  61], dtype=uint8),
#  array([219, 139, 114, ...,  58,  77, 138], dtype=uint8),
#  array([ 26,   8,  21, ..., 228, 225, 227], dtype=uint8),
#  array([ 59,  45,  39, ..., 143, 109,  80], dtype=uint8),
#  array([106, 107, 105, ...,  72,  72,  72], dtype=uint8),
#  array([207, 201, 188, ...,   6,  11,  10], dtype=uint8),
#  array([252, 212, 164, ...,  95, 104, 117], dtype=uint8),
#  array([252, 212, 164, ...,  95, 104, 117], dtype=uint8),
#  array([218, 202, 185, ...,  49,  45,  44], dtype=uint8),
#  array([170, 134,  96, ...,  76,  69,  76], dtype=uint8),
#  array([249, 234, 215, ...,  77, 131, 101], dtype=uint8),
#  array([198, 222, 210, ...,   8,  50,  62], dtype=uint8),
#  array([ 19,  56,  52, ..., 224, 214, 230], dtype=uint8),
#  array([122, 158, 188, ...,   6,   8,   9], dtype=uint8),
#  array([149, 156, 153, ...,  25, 120,  93], dtype=uint8),
#  array([ 6,  6,  6, ..., 11, 20, 29], dtype=uint8),
#  array([179, 114,  69, ..., 196, 197, 195], dtype=uint8),
#  array([183, 164, 156, ..., 213, 206, 203], dtype=uint8),
#  array([158, 142, 130, ...,   0,   0,   0], dtype=uint8),
#  array([158, 136, 125, ..., 168, 180, 186], dtype=uint8),
#  array([22, 25, 29, ...,  0, 31, 27], dtype=uint8),
#  array([ 4, 55,  0, ..., 25, 38, 22], dtype=uint8),
#  array([102,  52,  24, ..., 193, 198, 197], dtype=uint8),
#  array([114,  87,   0, ..., 156, 142,  84], dtype=uint8),
#  array([204, 153,  90, ...,  52,  85, 111], dtype=uint8),
#  array([70, 29, 66, ..., 52, 12, 37], dtype=uint8),
#  array([213, 201, 189, ..., 228, 211, 198], dtype=uint8),
#  array([210, 183, 146, ...,  68,  53,  44], dtype=uint8),
#  array([251, 244, 205, ..., 212, 180, 127], dtype=uint8),
#  array([117, 116,  96, ..., 135, 140, 101], dtype=uint8),
#  array([188, 186, 175, ..., 118, 126, 116], dtype=uint8),
#  array([ 13,  11,  10, ..., 180, 178, 177], dtype=uint8),
#  array([ 46,  77,  78, ...,  97,  97, 103], dtype=uint8),
#  array([216, 216, 216, ...,  56,  58,  59], dtype=uint8),
#  array([254, 254, 254, ...,   5,   5,   5], dtype=uint8),
#  array([192, 135,  83, ...,  62,  58,  47], dtype=uint8),
#  array([77, 70, 75, ..., 56, 67, 65], dtype=uint8),
#  array([139,  67,  60, ...,  33,  42,  75], dtype=uint8),
#  array([ 2,  3,  7, ..., 33, 36, 11], dtype=uint8),
#  array([255, 228, 207, ...,  30,  49,  54], dtype=uint8),
#  array([ 90,  90,  90, ..., 121, 121, 121], dtype=uint8),
#  array([248, 206, 169, ...,  84,  88,  83], dtype=uint8),
#  array([153, 131,  95, ...,  18,  37,  18], dtype=uint8),
#  array([122,  96,  84, ..., 223, 201, 183], dtype=uint8),
#  array([178, 167, 187, ...,  20,  21,  35], dtype=uint8),
#  array([221, 209, 199, ..., 161, 149, 149], dtype=uint8),
#  array([44, 74, 91, ..., 16, 16, 16], dtype=uint8),
#  array([40, 51, 55, ..., 46, 49, 64], dtype=uint8),
#  array([ 31,  32,  30, ...,  84,  87, 115], dtype=uint8),
#  array([128, 157, 154, ...,   7,   7,   7], dtype=uint8),
#  array([167,  96,  39, ...,   4,  16,  18], dtype=uint8),
#  array([19, 24, 22, ..., 70, 72, 72], dtype=uint8),
#  array([236, 195, 146, ..., 110, 107, 103], dtype=uint8),
#  array([124, 124, 124, ..., 222, 222, 222], dtype=uint8),
#  array([128, 132, 133, ...,  34,  35,  45], dtype=uint8),
#  array([172, 105,  60, ...,   9,  18,  86], dtype=uint8),
#  array([ 90,  97, 114, ..., 142, 136, 117], dtype=uint8),
#  array([197, 159, 124, ...,  56,  70,  76], dtype=uint8),
#  array([152, 255, 255, ...,  12,  72,  71], dtype=uint8),
#  array([189, 219, 190, ...,   0,  12,   8], dtype=uint8),
#  array([191, 226, 216, ...,  63, 119, 106], dtype=uint8),
#  array([ 42,  31,  34, ..., 104, 173, 182], dtype=uint8),
#  array([123, 125, 126, ...,   1,   1,   1], dtype=uint8),
#  array([255, 255, 229, ...,  71,  77,  76], dtype=uint8),
#  array([157, 159, 130, ...,  95, 121,  68], dtype=uint8),
#  array([157, 134, 108, ...,  58,  49,  46], dtype=uint8),
#  array([149,  76,   8, ...,  79,  82,  43], dtype=uint8),
#  array([204, 198, 193, ...,  47,  47,  47], dtype=uint8),
#  array([205, 186, 173, ...,  16,  11,  13], dtype=uint8),
#  array([ 30,  28,  34, ..., 118, 101,  62], dtype=uint8),
#  array([165, 161, 143, ...,  88,  70,  59], dtype=uint8),
#  array([ 0, 31, 36, ..., 50, 70, 75], dtype=uint8),
#  array([49, 63, 57, ..., 42, 55, 57], dtype=uint8),
#  array([ 0, 47, 48, ...,  0, 10,  9], dtype=uint8),
#  array([175, 100,   2, ..., 209, 195, 176], dtype=uint8),
#  array([210, 198, 194, ..., 188, 181, 178], dtype=uint8),
#  array([73, 90, 69, ...,  6,  5, 14], dtype=uint8),
#  array([37, 65, 59, ...,  2, 49, 40], dtype=uint8),
#  array([62, 64, 52, ..., 50, 64, 53], dtype=uint8),
#  array([92, 78, 56, ..., 46, 52, 59], dtype=uint8),
#  array([216, 221, 230, ...,   0,  43,  88], dtype=uint8),
#  array([244, 237, 234, ...,  10,  19,  29], dtype=uint8),
#  array([110,  97,  89, ...,  51,  58,  67], dtype=uint8),
#  array([206, 176, 147, ...,  64,  57,  60], dtype=uint8),
#  array([124, 124, 124, ...,  97,  97,  97], dtype=uint8),
#  array([43, 37, 30, ...,  9, 21, 49], dtype=uint8),
#  array([237, 214, 152, ...,  27,  22,  21], dtype=uint8),
#  array([204, 207, 212, ...,   9,  57,  61], dtype=uint8),
#  array([191, 191, 191, ...,  87,  88,  86], dtype=uint8),
#  array([203, 199, 194, ...,  28,  26,  56], dtype=uint8),
#  array([147, 146, 150, ...,  19,  17,  16], dtype=uint8),
#  array([23, 11,  5, ..., 11,  9,  9], dtype=uint8),
#  array([231, 211, 194, ..., 158, 153, 150], dtype=uint8),
#  array([21, 27, 32, ..., 27, 60, 75], dtype=uint8),
#  array([255, 255, 255, ...,  63,  58,  60], dtype=uint8),
#  array([  0,  20,  45, ..., 160, 167, 187], dtype=uint8),
#  array([18, 18, 18, ..., 18, 18, 18], dtype=uint8),
#  array([ 75,  75,  75, ..., 154, 154, 154], dtype=uint8),
#  array([ 47,  45,  34, ..., 111, 122, 112], dtype=uint8),
#  array([248, 253, 254, ...,  17,  17,  17], dtype=uint8),
#  array([147, 153, 158, ...,  42,  36,  23], dtype=uint8),
#  array([ 93, 143, 143, ...,  13,  17,  18], dtype=uint8),
#  array([232, 227, 229, ...,  52,  67,  76], dtype=uint8),
#  array([241, 222, 189, ..., 176, 180, 155], dtype=uint8),
#  array([ 22, 179,  65, ...,  18,  35,  31], dtype=uint8),
#  array([13,  5,  5, ..., 15, 16, 14], dtype=uint8),
#  array([203, 224, 202, ...,  18,  24,  59], dtype=uint8),
#  array([239, 223, 200, ..., 174, 184, 202], dtype=uint8),
#  array([ 81, 127,  91, ...,  29,  36,  39], dtype=uint8),
#  array([113, 183, 152, ...,  52,  92, 134], dtype=uint8),
#  array([254, 213, 180, ...,  79, 178, 168], dtype=uint8),
#  array([199, 202, 200, ...,   0,  13,  11], dtype=uint8),
#  array([ 50,  50,  68, ...,  97, 151, 192], dtype=uint8),
#  array([32, 32, 32, ...,  4,  4,  4], dtype=uint8),
#  array([213, 202, 198, ...,  44,  47,  52], dtype=uint8),
#  array([221, 137,  61, ...,  24, 106,  88], dtype=uint8),
#  array([215, 208, 189, ...,  39,  61,  96], dtype=uint8),
#  array([0, 0, 1, ..., 0, 0, 0], dtype=uint8),
#  array([153, 216, 190, ..., 201, 182, 201], dtype=uint8),
#  array([252, 251, 247, ...,  42,  37,  28], dtype=uint8),
#  array([13, 20, 15, ..., 39, 49, 43], dtype=uint8),
#  array([65, 46, 63, ..., 63, 76, 98], dtype=uint8),
#  array([ 0, 21, 15, ..., 23, 55, 50], dtype=uint8),
#  array([126, 102,  90, ...,   0,  92,  21], dtype=uint8),
#  array([ 67,  78, 128, ...,   3,   5,  16], dtype=uint8),
#  array([239, 242, 240, ..., 200, 180, 169], dtype=uint8),
#  array([244, 244, 244, ...,  23,  22,  26], dtype=uint8),
#  array([201, 145,  96, ...,  72,  75,  60], dtype=uint8),
#  array([186, 132,  67, ...,  25,   5,   0], dtype=uint8),
#  array([222, 183, 128, ...,  33,  51,  52], dtype=uint8),
#  array([  7,   7,   7, ..., 171, 171, 171], dtype=uint8),
#  array([224, 236, 242, ..., 204, 211, 214], dtype=uint8),
#  array([103,  75,  64, ...,  71,  85,  57], dtype=uint8),
#  array([186, 132, 102, ...,  88,  58,  39], dtype=uint8),
#  array([149, 153, 211, ..., 180, 180, 192], dtype=uint8),
#  array([196, 119,   3, ...,  17,   7,   0], dtype=uint8),
#  array([255, 255, 255, ..., 254, 254, 254], dtype=uint8),
#  array([125, 125, 125, ...,  34,  34,  34], dtype=uint8),
#  array([2, 2, 2, ..., 1, 2, 0], dtype=uint8),
#  array([16, 15, 17, ..., 54, 49, 50], dtype=uint8),
#  array([190, 105,  57, ...,  37,  42,  51], dtype=uint8),
#  array([211, 154,  31, ...,   0,   0,  10], dtype=uint8),
#  array([ 8,  8, 14, ..., 40, 44, 49], dtype=uint8),
#  array([185, 147, 112, ...,  21,  36,  45], dtype=uint8),
#  array([ 49,  42,  15, ...,  88,  97, 107], dtype=uint8),
#  array([178, 136, 101, ...,  25,  15,  21], dtype=uint8),
#  array([22, 33, 31, ..., 40, 44, 45], dtype=uint8),
#  array([242, 240, 240, ...,  57,  70,  72], dtype=uint8),
#  array([254, 254, 254, ..., 255, 255, 255], dtype=uint8),
#  array([130, 104,  90, ...,  38,  50,  54], dtype=uint8),
#  array([ 1,  1,  1, ..., 17, 15, 34], dtype=uint8),
#  array([174, 108,  55, ...,  56,  74,  97], dtype=uint8),
#  array([217, 102,  52, ..., 144,  85,  65], dtype=uint8),
#  array([ 94,  79,  53, ..., 161, 192, 213], dtype=uint8),
#  array([91, 82, 73, ...,  6,  4,  4], dtype=uint8),
#  array([28, 36, 36, ..., 20, 23, 31], dtype=uint8),
#  array([  7, 162,  88, ...,  16,  34,  27], dtype=uint8),
#  array([24, 83, 52, ..., 19, 40, 37], dtype=uint8),
#  array([4, 4, 4, ..., 3, 4, 2], dtype=uint8),
#  array([158, 158, 158, ..., 102, 102, 102], dtype=uint8),
#  array([ 0, 17,  5, ..., 12, 48, 12], dtype=uint8),
#  array([251, 255, 255, ...,  23, 106,  97], dtype=uint8),
#  array([222, 223, 219, ...,  16,  28,  38], dtype=uint8),
#  array([222, 221, 211, ...,  61, 121, 127], dtype=uint8),
#  array([179, 209, 220, ..., 156, 208, 238], dtype=uint8),
#  array([236, 217, 209, ...,  52,  52,  52], dtype=uint8),
#  array([234, 223, 219, ...,  17,  28,  25], dtype=uint8),
#  array([ 32,  45,  37, ...,  35,  59, 111], dtype=uint8),
#  array([200, 176, 156, ...,  15,  34,  37], dtype=uint8),
#  array([156, 104,  64, ...,  64,  42,  14], dtype=uint8),
#  array([69, 56, 48, ..., 13, 12,  8], dtype=uint8),
#  array([214, 177, 151, ..., 157, 152, 137], dtype=uint8),
#  array([254, 241, 225, ..., 187, 182, 191], dtype=uint8),
#  array([ 62, 117, 108, ...,  21,  58,  62], dtype=uint8),
#  array([136, 139, 144, ..., 222, 224, 234], dtype=uint8),
#  array([231, 231, 231, ...,  82,  82,  82], dtype=uint8),
#  array([157,  69,  23, ..., 158, 167, 164], dtype=uint8),
#  array([175, 142,  92, ...,  98, 114,  96], dtype=uint8),
#  array([129,  88,  33, ...,  53,  53,  53], dtype=uint8),
#  array([186, 186, 186, ...,  22,  10,  10], dtype=uint8),
#  array([213, 118,   1, ..., 123, 122, 108], dtype=uint8),
#  array([  9, 111,  16, ...,  23,  62,  17], dtype=uint8),
#  array([105,  74,  41, ...,   4,   4,   4], dtype=uint8),
#  array([153,  92,  48, ..., 173, 186, 194], dtype=uint8),
#  array([157,  94,  73, ...,   4,   4,   4], dtype=uint8),
#  array([159, 159, 159, ...,  26,  26,  26], dtype=uint8),
#  array([255, 255, 251, ...,  58,  62,  67], dtype=uint8),
#  array([182, 117,  73, ..., 100, 108, 108], dtype=uint8),
#  array([120, 118, 154, ..., 127, 122, 123], dtype=uint8),
#  array([152, 127, 107, ..., 174, 158, 145], dtype=uint8),
#  array([117, 117, 117, ...,  51,  52,  50], dtype=uint8),
#  array([179, 153, 116, ...,  61,  66,  65], dtype=uint8),
#  array([169,  79,  49, ..., 217, 238, 253], dtype=uint8),
#  array([237, 194, 185, ...,  97, 104, 107], dtype=uint8),
#  array([35, 36, 34, ..., 27, 32, 30], dtype=uint8),
#  array([133, 138,  17, ...,  10,  18,   0], dtype=uint8),
#  array([195, 137,  72, ..., 106, 116, 110], dtype=uint8),
#  array([213, 164, 124, ..., 100,  61,   0], dtype=uint8),
#  array([222, 219, 211, ...,   1,  42,  45], dtype=uint8),
#  array([246, 252, 251, ...,  35,  44,  48], dtype=uint8),
#  array([ 37,  41,  30, ..., 115, 114, 124], dtype=uint8),
#  array([174, 119,  92, ..., 251, 241, 234], dtype=uint8),
#  array([248, 245, 231, ..., 142, 140, 132], dtype=uint8),
#  array([136, 129, 120, ...,  98,  95,  80], dtype=uint8),
#  array([222, 182, 110, ..., 148, 153, 126], dtype=uint8),
#  array([247, 233, 227, ...,  34,  45,  49], dtype=uint8),
#  array([195, 147, 113, ...,  49,  52,  56], dtype=uint8),
#  array([238, 173, 145, ...,  37,  46,  36], dtype=uint8),
#  array([ 23,  65, 108, ..., 118, 144, 130], dtype=uint8),
#  array([159, 190, 205, ...,  22,  26,  31], dtype=uint8),
#  array([170,  96,  48, ..., 138, 137, 139], dtype=uint8),
#  array([ 10,  10,  10, ..., 181, 181, 181], dtype=uint8),
#  array([ 57,  79, 114, ...,  17,  21,  16], dtype=uint8),
#  array([169, 113,  84, ...,  36,  28,  29], dtype=uint8),
#  array([214, 147,  60, ...,  65,  87, 112], dtype=uint8),
#  array([145,  81,  40, ...,  17,  18,  22], dtype=uint8),
#  array([191, 188, 180, ...,  16,  73,  64], dtype=uint8),
#  array([ 4, 31, 22, ..., 40, 35, 34], dtype=uint8),
#  array([144,  90,  79, ...,  18,  58, 164], dtype=uint8),
#  array([210, 177, 157, ...,  91,  75,  58], dtype=uint8),
#  array([239, 158,  97, ...,  29,  83,  70], dtype=uint8),
#  array([13,  4,  0, ...,  9,  6,  2], dtype=uint8),
#  array([ 63,  86, 101, ...,  89,  95, 100], dtype=uint8),
#  array([201, 109,  74, ...,   2,   2,   2], dtype=uint8),
#  array([122, 163, 158, ...,  74, 134, 128], dtype=uint8),
#  array([255, 255, 255, ..., 126, 128, 146], dtype=uint8),
#  array([136, 167, 166, ...,  43,  38,  39], dtype=uint8),
#  array([255, 255, 254, ...,  68,  85,  82], dtype=uint8),
#  array([178, 153, 157, ...,  94,  61,  35], dtype=uint8),
#  array([148, 148, 148, ...,  85,  85,  85], dtype=uint8),
#  array([  2,  21,  12, ...,  91, 137, 161], dtype=uint8),
#  array([ 99, 111, 121, ...,  46,  42,  41], dtype=uint8),
#  array([90, 96, 91, ..., 15, 20, 19], dtype=uint8),
#  array([250, 234, 228, ..., 144, 130, 111], dtype=uint8),
#  array([216, 211, 208, ...,   0,   0,   0], dtype=uint8),
#  array([221, 149,  71, ..., 126, 131, 130], dtype=uint8),
#  array([ 51,  57,  46, ..., 148, 159, 126], dtype=uint8),
#  array([119, 121, 129, ..., 102, 101, 110], dtype=uint8),
#  array([30, 91, 33, ...,  0, 44,  4], dtype=uint8),
#  array([163, 124,  79, ...,  94,  89,  90], dtype=uint8),
#  array([124, 134,  74, ...,  31,  31,  31], dtype=uint8),
#  array([191, 186, 187, ...,  91,  91,  97], dtype=uint8),
#  array([168, 120,  78, ...,  27,  56,  61], dtype=uint8),
#  array([ 8, 62, 49, ..., 15, 27, 31], dtype=uint8),
#  array([187, 139, 103, ...,  26,  36,  36], dtype=uint8),
#  array([211, 199, 193, ...,  42,  46,  47], dtype=uint8),
#  array([249, 215, 199, ..., 234, 236, 236], dtype=uint8),
#  array([158, 152, 139, ...,   0,   4,   3], dtype=uint8),
#  array([ 62,  83, 105, ..., 160, 135, 119], dtype=uint8),
#  array([212, 196, 184, ...,  43,  50,  53], dtype=uint8),
#  array([137,  26,   0, ...,  75,  51,  63], dtype=uint8),
#  array([225, 220, 219, ...,  54,  63,  73], dtype=uint8),
#  array([246, 251, 250, ...,   0,   7,  10], dtype=uint8),
#  array([252, 205, 151, ...,  90, 157, 172], dtype=uint8),
#  array([141, 107,  83, ..., 117,  77,  52], dtype=uint8),
#  array([178, 182, 206, ..., 128, 130, 148], dtype=uint8),
#  array([ 2,  6,  0, ..., 59, 54, 75], dtype=uint8),
#  array([228, 233, 234, ...,   3,   8,   6], dtype=uint8),
#  array([235, 239, 244, ..., 168, 194, 211], dtype=uint8),
#  array([242, 169,  89, ...,  97, 109, 111], dtype=uint8),
#  array([ 35, 114, 147, ...,   0,   0,  35], dtype=uint8),
#  array([244, 244, 244, ..., 162, 167, 170], dtype=uint8),
#  array([ 52,  81, 102, ...,  75,  80,  79], dtype=uint8),
#  array([236, 218, 187, ..., 111, 148, 138], dtype=uint8),
#  array([188, 148, 119, ...,   9,  10,   8], dtype=uint8),
#  array([148, 137, 115, ..., 134, 121,  95], dtype=uint8),
#  array([242, 247, 248, ...,  46,  41,  43], dtype=uint8),
#  array([64, 87, 89, ..., 35, 26, 23], dtype=uint8),
#  array([ 95, 123, 123, ..., 232, 237, 240], dtype=uint8),
#  array([222, 222, 222, ..., 217, 217, 217], dtype=uint8),
#  array([ 59, 150,  95, ...,   0, 112,  14], dtype=uint8),
#  array([95, 75, 80, ..., 85, 82, 97], dtype=uint8),
#  array([251, 216, 143, ...,  16,  16,  10], dtype=uint8),
#  array([228, 223, 224, ...,  41,  51,  68], dtype=uint8),
#  array([188, 177, 163, ..., 110, 145, 159], dtype=uint8),
#  array([38, 49, 76, ..., 40, 80, 99], dtype=uint8),
#  array([ 72,  72,  72, ..., 242, 242, 242], dtype=uint8),
#  array([163,  91,  57, ..., 162, 132, 121], dtype=uint8),
#  array([  4,  11,   8, ..., 125, 161, 207], dtype=uint8),
#  array([ 6,  4, 10, ...,  1, 10, 20], dtype=uint8),
#  array([185,  97,  43, ...,  36,  30,  25], dtype=uint8),
#  array([1, 0, 2, ..., 6, 6, 6], dtype=uint8),
#  array([139, 136, 128, ..., 177, 201, 223], dtype=uint8),
#  array([124, 130, 129, ...,   9,  17,  17], dtype=uint8),
#  array([141, 131, 101, ...,  10,   9,  13], dtype=uint8),
#  array([189, 147, 104, ...,  37,  22,   6], dtype=uint8),
#  array([123,  56,  29, ...,  46,  39,  36], dtype=uint8),
#  array([109,  92,  83, ..., 191, 179, 177], dtype=uint8),
#  array([167, 108,  52, ..., 176, 189, 197], dtype=uint8),
#  array([ 45, 104,  76, ...,  44,  65,  96], dtype=uint8),
#  array([111, 125, 137, ...,  18,  11,   8], dtype=uint8),
#  array([66, 57, 60, ..., 51, 72, 63], dtype=uint8),
#  array([240, 192, 144, ...,  14,  30,  19], dtype=uint8),
#  array([160, 191, 212, ...,  37,  37,  37], dtype=uint8),
#  array([124, 145, 160, ...,  26,  45,  60], dtype=uint8),
#  array([255, 253, 249, ...,  79,  78,  82], dtype=uint8),
#  array([190, 199, 202, ...,  27,  31,  32], dtype=uint8),
#  array([21, 21, 21, ..., 16, 16, 16], dtype=uint8),
#  array([56, 60, 61, ..., 56, 56, 56], dtype=uint8),
#  array([ 47,  15,   2, ..., 109, 136, 127], dtype=uint8),
#  array([ 1,  0, 10, ...,  7, 21, 19], dtype=uint8),
#  array([137,  86,  46, ..., 187, 178, 165], dtype=uint8),
#  array([125,  81,  40, ...,   6,   4,   4], dtype=uint8),
#  array([130, 122, 122, ...,  88,  88,  88], dtype=uint8),
#  array([ 43,  40,  35, ..., 137, 136, 138], dtype=uint8),
#  array([ 51, 106, 149, ...,  63,  59,  64], dtype=uint8),
#  array([81, 54, 33, ..., 35, 30, 29], dtype=uint8),
#  array([ 76,  79,  83, ..., 216, 216, 216], dtype=uint8),
#  array([216, 142,  84, ...,  42,  39,  35], dtype=uint8),
#  array([196, 125,  62, ..., 183, 159, 137], dtype=uint8),
#  array([175,  65,   0, ...,   2,   6,  11], dtype=uint8),
#  array([0, 2, 0, ..., 3, 5, 5], dtype=uint8),
#  array([118, 132, 138, ...,  80,  83,  88], dtype=uint8),
#  array([195, 157, 153, ..., 213, 192, 190], dtype=uint8),
#  array([253, 236, 249, ...,  56,  68,  70], dtype=uint8),
#  array([184, 165, 157, ...,  89,  88,  74], dtype=uint8),
#  array([31, 10, 43, ..., 35, 12, 34], dtype=uint8),
#  array([239, 244, 245, ..., 146, 142, 177], dtype=uint8),
#  array([ 92, 135, 184, ...,  94,  96,  96], dtype=uint8),
#  array([123, 150, 184, ...,  91,  71,  66], dtype=uint8),
#  array([  0, 156,  83, ...,   4,  67,  27], dtype=uint8),
#  array([232, 222, 222, ...,  12,  37,  39], dtype=uint8),
#  array([182, 125,  74, ..., 131, 153, 158], dtype=uint8),
#  array([164, 151, 149, ..., 123, 141, 164], dtype=uint8),
#  array([22, 38, 51, ..., 22, 55, 74], dtype=uint8),
#  array([179, 135,  94, ..., 129, 132, 130], dtype=uint8),
#  array([ 0,  0, 30, ..., 26, 36, 43], dtype=uint8),
#  array([226, 222, 227, ...,  43,  50,  53], dtype=uint8),
#  array([114, 123, 133, ..., 118, 101,  98], dtype=uint8),
#  array([130, 116, 104, ...,  67,  65,  64], dtype=uint8),
#  array([2, 2, 2, ..., 6, 8, 8], dtype=uint8),
#  array([178, 126,  96, ...,  34,  46,  48], dtype=uint8),
#  array([234, 224, 236, ..., 222, 214, 225], dtype=uint8),
#  array([137, 125, 115, ..., 145, 139, 156], dtype=uint8),
#  array([207, 158, 108, ..., 116,  88,  53], dtype=uint8),
#  array([192, 149, 106, ...,  98, 110, 116], dtype=uint8),
#  array([210, 210, 210, ..., 144, 144, 144], dtype=uint8),
#  array([154, 137, 116, ...,  25,  21,   0], dtype=uint8),
#  array([133,  64,  25, ..., 159, 133,  97], dtype=uint8),
#  array([5, 3, 3, ..., 4, 6, 6], dtype=uint8),
#  array([ 60, 192, 125, ...,  10, 188, 121], dtype=uint8),
#  array([225, 154,  90, ..., 195, 134,  72], dtype=uint8),
#  array([231, 244, 242, ..., 251, 251, 251], dtype=uint8),
#  array([57, 58, 62, ..., 64, 66, 76], dtype=uint8),
#  array([170, 116,  55, ..., 170, 164, 157], dtype=uint8),
#  array([17, 18, 38, ...,  0, 13, 81], dtype=uint8),
#  array([ 26, 121, 107, ...,  16,  19,  17], dtype=uint8),
#  array([76, 88, 88, ..., 10,  0,  4], dtype=uint8),
#  array([40, 20,  2, ...,  2,  2,  2], dtype=uint8),
#  array([244, 204, 152, ..., 145, 130,  91], dtype=uint8),
#  array([ 35,  86, 178, ..., 186, 176, 182], dtype=uint8),
#  array([130, 118, 108, ..., 118, 116, 115], dtype=uint8),
#  array([ 90,  88,  88, ..., 177, 174, 176], dtype=uint8),
#  array([43, 43, 43, ...,  0,  0,  0], dtype=uint8),
#  array([ 1,  6, 67, ...,  6,  8,  8], dtype=uint8),
#  array([129,  85,   1, ...,  67, 104, 148], dtype=uint8),
#  array([232, 231, 227, ...,  28,  27,  31], dtype=uint8),
#  array([176, 120,  65, ..., 104, 111, 120], dtype=uint8),
#  array([18, 16, 16, ...,  4,  4,  4], dtype=uint8),
#  array([194, 149, 106, ...,  42,  32,  22], dtype=uint8),
#  array([248, 248, 248, ...,  23,  26,  24], dtype=uint8),
#  array([253, 221, 186, ..., 112, 107,  98], dtype=uint8),
#  array([224, 159,  98, ...,  65,  39,  22], dtype=uint8),
#  array([250, 230, 213, ...,  27,  41,  39], dtype=uint8),
#  array([219, 197, 186, ...,  12,  10,   9], dtype=uint8),
#  array([224, 230, 229, ...,  33,  65,  88], dtype=uint8),
#  array([107,  87,  82, ...,  20,  23,  21], dtype=uint8),
#  array([81, 56, 46, ..., 58, 58, 58], dtype=uint8),
#  array([ 64,  92, 230, ...,   6,  10, 128], dtype=uint8),
#  array([152, 125,  91, ...,  92, 106, 128], dtype=uint8),
#  array([215, 206, 202, ...,  96, 115, 136], dtype=uint8),
#  array([183, 100,  78, ...,  56,  54,  73], dtype=uint8),
#  array([166, 159, 142, ...,  75,  98,  94], dtype=uint8),
#  array([37, 37, 37, ..., 49, 53, 81], dtype=uint8),
#  array([254, 143,  43, ...,  62,  57,  58], dtype=uint8),
#  array([165, 192, 188, ...,  55,  61,  74], dtype=uint8),
#  array([212, 212, 212, ...,  49,  49,  49], dtype=uint8),
#  array([183, 187, 198, ..., 143, 147, 166], dtype=uint8),
#  array([175, 131, 114, ...,   2,  22,  33], dtype=uint8),
#  array([174, 167, 158, ...,  33,  38,  37], dtype=uint8),
#  array([46, 65, 86, ..., 56, 79, 74], dtype=uint8),
#  array([238, 234, 240, ..., 231, 225, 220], dtype=uint8),
#  array([191, 146,  95, ...,  70,  76,  89], dtype=uint8),
#  array([151, 120,  97, ..., 250, 247, 242], dtype=uint8),
#  array([24, 41, 44, ..., 11, 39, 46], dtype=uint8),
#  array([141, 141, 141, ...,  83,  83,  83], dtype=uint8),
#  array([86, 79, 76, ..., 40, 29, 31], dtype=uint8),
#  array([249, 255, 243, ...,   0,  63,  52], dtype=uint8),
#  array([246, 195, 155, ...,  55,  36,  21], dtype=uint8),
#  array([251, 228, 196, ..., 139, 186, 207], dtype=uint8),
#  array([151, 151, 151, ...,  90,  90,  90], dtype=uint8),
#  array([ 3,  3,  3, ...,  0, 32, 19], dtype=uint8),
#  array([202, 172, 161, ..., 193, 184, 181], dtype=uint8),
#  array([ 11,  19,  19, ...,  39, 190, 145], dtype=uint8),
#  array([ 40,  30,  23, ..., 107,  96,  82], dtype=uint8),
#  array([245, 244, 246, ...,  99, 147, 151], dtype=uint8),
#  array([147, 147, 147, ...,  45,  45,  45], dtype=uint8),
#  array([141, 100,  67, ..., 127, 130, 138], dtype=uint8),
#  array([153, 147, 142, ...,  14,  19,  18], dtype=uint8),
#  array([ 0,  3, 12, ..., 62, 68, 79], dtype=uint8),
#  array([41, 51, 39, ..., 49, 38, 30], dtype=uint8),
#  array([213, 170, 131, ...,  13,  10,   6], dtype=uint8),
#  array([231, 223, 216, ...,  60,  74,  86], dtype=uint8),
#  array([37, 43, 72, ...,  4,  2,  2], dtype=uint8),
#  array([255, 247, 255, ..., 196, 186, 198], dtype=uint8),
#  array([14,  2,  8, ...,  2,  9, 24], dtype=uint8),
#  array([254, 254, 254, ...,  68,  99, 124], dtype=uint8),
#  array([228, 255, 235, ..., 106, 108, 118], dtype=uint8),
#  array([129, 212, 210, ..., 114, 120, 109], dtype=uint8),
#  array([196, 192, 187, ...,  21,  21,  21], dtype=uint8),
#  array([94, 84, 90, ..., 20, 14,  9], dtype=uint8),
#  array([215, 221, 234, ..., 170, 157, 149], dtype=uint8),
#  array([210, 171, 126, ...,  21,   1,   0], dtype=uint8),
#  array([94, 90, 89, ...,  1,  1,  1], dtype=uint8),
#  array([152, 112,  83, ...,  26,  24,  14], dtype=uint8),
#  array([208, 177, 156, ...,  37,  27,  27], dtype=uint8),
#  array([171, 149, 124, ...,  29,  27,  39], dtype=uint8),
#  array([186, 167, 154, ...,  46,  58,  62], dtype=uint8),
#  array([ 88,  48,   0, ..., 184, 179, 170], dtype=uint8),
#  array([3, 3, 0, ..., 2, 0, 0], dtype=uint8),
#  array([160, 133, 119, ...,  17,  18,  16], dtype=uint8),
#  array([24, 30, 35, ..., 24, 29, 32], dtype=uint8),
#  array([162, 127, 117, ..., 188, 179, 176], dtype=uint8),
#  array([219, 190, 183, ...,  16,  19,  17], dtype=uint8),
#  array([24, 24, 42, ..., 56, 65, 74], dtype=uint8),
#  array([ 0,  0, 11, ..., 10, 14, 15], dtype=uint8),
#  array([146, 100,  69, ...,  40,  37,  33], dtype=uint8),
#  array([ 0, 13, 20, ..., 43, 56, 64], dtype=uint8),
#  array([181, 176, 178, ...,  60,  46,  17], dtype=uint8),
#  array([157, 142, 126, ..., 181, 170, 166], dtype=uint8),
#  array([122,  52,  15, ..., 150, 143, 146], dtype=uint8),
#  array([ 0,  3,  1, ..., 38, 31, 22], dtype=uint8),
#  array([150, 135,  63, ...,  30,  19,  11], dtype=uint8),
#  array([106,  93, 101, ..., 111, 113, 114], dtype=uint8),
#  array([217, 205, 187, ..., 108,  93,  84], dtype=uint8),
#  array([186, 163, 125, ...,  10,   2,   3], dtype=uint8),
#  array([ 72,  55, 152, ..., 164, 196, 225], dtype=uint8),
#  array([ 32, 157,  83, ..., 127, 159, 170], dtype=uint8),
#  array([108,  74,  45, ..., 164, 141, 115], dtype=uint8),
#  array([111,  96,  63, ...,  37, 142, 156], dtype=uint8),
#  array([ 9,  4,  5, ..., 13, 32, 37], dtype=uint8),
#  array([ 19,  25,  38, ...,  90,  97, 112], dtype=uint8),
#  array([252, 197, 158, ...,  80,  59,  51], dtype=uint8),
#  array([206, 179, 153, ...,  45,  80,  83], dtype=uint8),
#  array([ 46,  44,  34, ..., 197, 201, 189], dtype=uint8),
#  array([253, 255, 254, ..., 119, 121, 122], dtype=uint8),
#  array([252, 167,  75, ...,  84, 106, 147], dtype=uint8),
#  array([255, 255, 255, ...,  11,  66,  47], dtype=uint8),
#  array([217, 201, 184, ...,  67,  72,  71], dtype=uint8),
#  array([72, 72, 72, ..., 39, 39, 39], dtype=uint8),
#  array([153, 147, 140, ...,  35,  59,  81], dtype=uint8),
#  array([129,  85,  56, ...,  11,   4,   7], dtype=uint8),
#  array([106, 107, 105, ..., 125, 130, 131], dtype=uint8),
#  array([146, 137, 127, ..., 146, 143, 135], dtype=uint8),
#  array([146, 108,  76, ..., 108, 104,  93], dtype=uint8),
#  array([197, 197, 197, ..., 103, 103,  97], dtype=uint8),
#  array([62, 56, 27, ..., 15, 46, 37], dtype=uint8),
#  array([41, 44, 29, ..., 29, 26, 18], dtype=uint8),
#  array([184, 165, 160, ..., 139, 125, 103], dtype=uint8),
#  array([215, 195, 190, ...,   7,  26,  39], dtype=uint8),
#  array([11, 37, 49, ...,  0, 18, 31], dtype=uint8),
#  array([212, 204, 197, ..., 102,  96,  77], dtype=uint8),
#  array([247, 236, 216, ...,  70,  89,  97], dtype=uint8),
#  array([169, 155, 137, ...,  10,  15,  14], dtype=uint8),
#  array([135,  97,  55, ..., 136, 148, 142], dtype=uint8),
#  array([225, 210, 194, ...,  52, 127, 125], dtype=uint8),
#  array([254, 201, 191, ...,  22,  53,  56], dtype=uint8),
#  array([169,  91,  44, ..., 136, 142, 141], dtype=uint8),
#  array([242, 242, 242, ...,  39,  39,  39], dtype=uint8),
#  array([79, 83, 94, ..., 35, 33, 32], dtype=uint8),
#  array([99, 96, 98, ..., 60, 58, 58], dtype=uint8),
#  array([208, 206, 196, ..., 157, 150, 131], dtype=uint8),
#  array([214, 203, 205, ...,  32,  61,  58], dtype=uint8),
#  array([154,  78,  36, ...,   9,   6,   2], dtype=uint8),
#  array([251, 252, 248, ...,  40, 107, 134], dtype=uint8),
#  array([11, 35, 33, ..., 11, 17, 24], dtype=uint8),
#  array([255, 255, 255, ...,  62,  78,  90], dtype=uint8),
#  array([39, 38, 40, ..., 18, 25, 28], dtype=uint8),
#  array([221, 224, 229, ...,  59,  61,  71], dtype=uint8),
#  array([126,  30,  14, ...,  39,  49,  33], dtype=uint8),
#  array([215, 209, 180, ...,  20,  27,  12], dtype=uint8),
#  array([ 21,  60,  35, ...,  26, 100,  70], dtype=uint8),
#  array([ 24,  37,  29, ...,  86,  95, 104], dtype=uint8),
#  array([114,  47,  22, ...,  60,  68,  67], dtype=uint8),
#  array([222, 182, 123, ...,  68, 106, 118], dtype=uint8),
#  array([233, 231, 223, ...,  68,  81,  95], dtype=uint8),
#  array([126,  61,   0, ...,   3,  20,  11], dtype=uint8),
#  array([178, 140, 110, ...,  83,  59,  39], dtype=uint8),
#  array([ 59,  63,  64, ..., 112, 107, 104], dtype=uint8),
#  array([123,  78,  75, ...,  26,  19,  32], dtype=uint8),
#  array([183, 177, 172, ...,  23,  21,  27], dtype=uint8),
#  array([119,  85,  56, ..., 158, 167, 180], dtype=uint8),
#  array([227, 221, 226, ...,  12,   6,   0], dtype=uint8),
#  array([165, 168, 173, ...,  44,  38,  33], dtype=uint8),
#  array([136,  67,  28, ..., 178, 169, 165], dtype=uint8),
#  array([211, 102,   0, ..., 148, 162, 128], dtype=uint8),
#  array([222, 187, 153, ...,   6,   1,   2], dtype=uint8),
#  array([223, 225, 219, ...,  88, 113, 133], dtype=uint8),
#  array([180,  98,  63, ...,  42,  48,  47], dtype=uint8),
#  array([107,  90,  39, ...,  50,  66,  78], dtype=uint8),
#  array([170, 154, 155, ..., 179, 175, 164], dtype=uint8),
#  array([248, 224, 212, ...,   0,  21,  23], dtype=uint8),
#  array([131, 131, 131, ...,  68,  68,  68], dtype=uint8),
#  array([146,  84,  20, ...,  37,  49,  49], dtype=uint8),
#  array([204, 192, 186, ...,  66,  67,  65], dtype=uint8),
#  array([ 3, 34, 25, ...,  0,  0,  7], dtype=uint8),
#  array([32, 29, 21, ..., 18, 23, 21], dtype=uint8),
#  array([250, 251, 255, ...,  74,  73,  77], dtype=uint8),
#  array([239, 241, 242, ..., 157, 163, 162], dtype=uint8),
#  array([232, 218, 189, ..., 172, 167, 158], dtype=uint8),
#  array([ 33,  68,  54, ..., 208, 210, 210], dtype=uint8),
#  array([16, 18, 19, ..., 50, 66, 65], dtype=uint8),
#  array([201, 124, 128, ...,   0,   0,   8], dtype=uint8),
#  array([152, 118,  95, ..., 206, 199, 196], dtype=uint8),
#  array([231, 208, 163, ...,  10,  15,  13], dtype=uint8),
#  array([77, 77, 77, ..., 26, 26, 26], dtype=uint8),
#  array([ 43,  54,  62, ...,  61, 102, 104], dtype=uint8),
#  array([ 43,  53,  63, ...,  69, 121, 157], dtype=uint8),
#  array([ 89,  99, 106, ..., 192, 194, 194], dtype=uint8),
#  array([ 32,  45,  43, ..., 155, 176, 143], dtype=uint8),
#  array([145,  61,  33, ...,  14,  36,  24], dtype=uint8),
#  array([255, 255, 246, ...,  87,  91,  66], dtype=uint8),
#  array([208, 199, 190, ..., 168, 157, 153], dtype=uint8),
#  array([166,  93,  33, ...,   0,   3,   3], dtype=uint8),
#  array([155, 153, 153, ...,  40,  66,  80], dtype=uint8),
#  array([119,  63,   4, ..., 236, 234, 234], dtype=uint8),
#  array([234, 222, 210, ..., 135, 156, 183], dtype=uint8),
#  array([41, 46, 44, ...,  8,  3,  0], dtype=uint8),
#  array([217,  90,   0, ...,  66,  42,  44], dtype=uint8),
#  array([219, 154,  86, ...,   0,   1,   5], dtype=uint8),
#  array([233, 211, 193, ..., 130, 118, 106], dtype=uint8),
#  array([194, 117,  55, ..., 145, 156, 176], dtype=uint8),
#  array([213, 194,  65, ...,   7,  37,  78], dtype=uint8),
#  array([200, 129,  79, ...,  48,  24,  18], dtype=uint8),
#  array([17, 40, 32, ...,  0,  4,  0], dtype=uint8),
#  array([213, 213, 213, ...,   2,   2,   2], dtype=uint8),
#  array([237, 199, 175, ...,  92,  97,  96], dtype=uint8),
#  array([255, 255, 255, ..., 174, 191, 204], dtype=uint8),
#  array([254, 255, 253, ..., 255, 255, 255], dtype=uint8),
#  array([50, 33,  0, ..., 21, 43, 38], dtype=uint8),
#  array([191, 154, 110, ..., 189, 183, 178], dtype=uint8),
#  array([209, 111,   0, ..., 159, 191, 204], dtype=uint8),
#  array([ 2, 11,  8, ..., 24, 35, 32], dtype=uint8),
#  array([232, 212, 201, ..., 136, 146, 153], dtype=uint8),
#  array([250, 245, 246, ...,  57, 103,  97], dtype=uint8),
#  array([243, 188, 161, ...,   0,   0,   0], dtype=uint8),
#  array([194, 155, 123, ...,   9,  19,   3], dtype=uint8),
#  array([53, 26, 12, ..., 46, 49, 53], dtype=uint8),
#  array([187, 175, 147, ...,  69,  76,  91], dtype=uint8),
#  array([242, 246, 247, ..., 251, 251, 251], dtype=uint8),
#  array([170, 224, 217, ...,   4,  19,  35], dtype=uint8),
#  array([90, 90, 90, ..., 52, 52, 52], dtype=uint8),
#  array([234, 233, 235, ...,  44,  54,  54], dtype=uint8),
#  array([142, 125,  86, ...,  38,  31,  16], dtype=uint8),
#  array([255, 255, 255, ...,  22,  22,  22], dtype=uint8),
#  array([35, 36, 32, ..., 25, 28, 42], dtype=uint8),
#  array([ 2,  2,  2, ..., 76, 76, 76], dtype=uint8),
#  array([101,  53,  29, ...,  86,  74,  62], dtype=uint8),
#  array([ 35,  17,   6, ..., 209, 199, 182], dtype=uint8),
#  array([231, 226, 217, ..., 205, 156,  88], dtype=uint8),
#  array([ 65, 101, 111, ...,  26,  75,  91], dtype=uint8),
#  array([ 82,  66,  59, ..., 186, 197, 205], dtype=uint8),
#  array([204, 167, 139, ...,  63,  61,  67], dtype=uint8),
#  array([184, 168, 145, ..., 139, 148, 152], dtype=uint8),
#  array([ 0,  2,  2, ..., 10,  9,  5], dtype=uint8),
#  array([147,  74,  36, ..., 232, 222, 212], dtype=uint8),
#  array([193, 163, 144, ...,  37,  28,  19], dtype=uint8),
#  array([222, 200, 188, ..., 114, 145, 178], dtype=uint8),
#  array([225, 184, 129, ...,  88, 111, 107], dtype=uint8),
#  array([177, 193, 205, ...,  40,  41,  45], dtype=uint8),
#  array([17, 50, 16, ...,  2,  2,  2], dtype=uint8),
#  array([194, 199, 202, ...,   6,  19,  17], dtype=uint8),
#  array([218, 199, 184, ...,  18,  50,  33], dtype=uint8),
#  array([152, 133, 126, ...,  65,  53,  49], dtype=uint8),
#  array([249, 228, 206, ...,  32, 112,  89], dtype=uint8),
#  array([198, 174, 168, ...,  67, 112, 116], dtype=uint8),
#  array([203, 202, 192, ...,  27,  37,  44], dtype=uint8),
#  array([ 4,  4,  4, ..., 19, 19, 19], dtype=uint8),
#  array([ 22,  29,  22, ..., 162, 166, 160], dtype=uint8),
#  array([208, 142,  94, ...,  16,  43,  87], dtype=uint8),
#  array([166, 214, 208, ...,  11,  18,  11], dtype=uint8),
#  array([143,  98,  60, ...,   0,  14,   8], dtype=uint8),
#  array([254, 254, 254, ..., 175, 163, 115], dtype=uint8),
#  array([169, 124,  90, ...,  34,  31,  26], dtype=uint8),
#  array([221, 148,  96, ...,  82,  77,  74], dtype=uint8),
#  array([ 11,   4,  11, ..., 107, 110, 115], dtype=uint8),
#  array([231, 229, 219, ...,  89,  96,  81], dtype=uint8),
#  array([56, 62, 81, ...,  9, 27, 26], dtype=uint8),
#  array([210, 221, 218, ...,   0,   0,   0], dtype=uint8),
#  array([226, 254, 254, ...,  54,  41,  39], dtype=uint8),
#  array([241, 239, 238, ..., 198, 186, 186], dtype=uint8),
#  array([122,  94,  70, ...,  47,  23,   5], dtype=uint8),
#  array([192, 199, 202, ...,  20,  37,  63], dtype=uint8),
#  array([35, 31, 42, ...,  3,  3,  3], dtype=uint8),
#  array([218, 203, 184, ...,  67,  90, 105], dtype=uint8),
#  array([233, 135,  47, ...,  11,  28,  24], dtype=uint8),
#  array([ 59, 148, 145, ...,  26,  73, 117], dtype=uint8),
#  array([177, 231, 188, ..., 118, 144,  98], dtype=uint8),
#  array([ 19,  66, 104, ...,  15,  44,  53], dtype=uint8),
#  array([ 24,  89, 103, ...,   4,  13,  27], dtype=uint8),
#  array([176, 110,  62, ...,  39,  83,  77], dtype=uint8),
#  array([255, 255, 213, ..., 191, 214, 240], dtype=uint8),
#  array([210,  57,   2, ..., 100, 112, 124], dtype=uint8),
#  array([245, 230, 234, ...,  45,  44,  46], dtype=uint8),
#  array([213, 194, 167, ...,   9,  38,  42], dtype=uint8),
#  array([251, 255, 254, ...,  83,  98,  94], dtype=uint8),
#  array([245, 243, 208, ...,   5,   5,   5], dtype=uint8),
#  array([221, 192, 171, ..., 116,  87,  72], dtype=uint8),
#  array([61, 68, 77, ...,  9,  7,  7], dtype=uint8),
#  array([245, 231, 212, ..., 226, 220, 201], dtype=uint8),
#  array([255, 255, 251, ..., 167, 179, 173], dtype=uint8),
#  array([ 76,  67,  64, ...,  55, 103,  45], dtype=uint8),
#  array([80, 53, 39, ..., 35, 23, 11], dtype=uint8),
#  array([225, 207, 196, ...,   8,   9,  13], dtype=uint8),
#  array([97, 86, 78, ..., 81, 83, 93], dtype=uint8),
#  array([179, 162, 159, ..., 224, 224, 224], dtype=uint8),
#  array([184, 190, 197, ...,   0,   2,   3], dtype=uint8),
#  array([207, 195, 185, ...,   4,  26,  51], dtype=uint8),
#  array([244, 244, 244, ..., 166, 166, 166], dtype=uint8),
#  array([228, 229, 249, ..., 223, 236, 252], dtype=uint8),
#  array([128, 114,  72, ..., 105,  96,  92], dtype=uint8),
#  array([45, 41, 40, ..., 18, 18, 18], dtype=uint8),
#  array([236, 227, 223, ...,  77,  76,  85], dtype=uint8),
#  array([100, 125, 141, ...,  19,  22,  27], dtype=uint8),
#  array([239, 209, 190, ..., 130, 115, 119], dtype=uint8),
#  array([2, 1, 0, ..., 3, 1, 1], dtype=uint8),
#  array([253, 172,  97, ..., 112, 115, 120], dtype=uint8),
#  array([164, 117,  85, ..., 191, 173, 166], dtype=uint8),
#  array([157, 139, 132, ...,  73, 175, 223], dtype=uint8),
#  array([123,  69,   9, ..., 238, 232, 227], dtype=uint8),
#  array([200, 114,  92, ...,   4,   9,   7], dtype=uint8),
#  array([118,  94,  76, ...,  77,  79,  87], dtype=uint8),
#  array([ 19,  19,  19, ..., 117, 117, 117], dtype=uint8),
#  array([197, 209, 203, ...,  12,  54,  77], dtype=uint8),
#  array([170, 163, 166, ..., 180, 181, 185], dtype=uint8),
#  array([52, 46, 33, ...,  6,  1,  0], dtype=uint8),
#  array([147,  92,  47, ..., 101,  74,  60], dtype=uint8),
#  array([153, 152, 156, ...,   7,   8,  12], dtype=uint8),
#  array([30, 14,  7, ..., 15, 20, 21], dtype=uint8),
#  array([151, 140, 136, ...,  17,  12,  11], dtype=uint8),
#  array([255, 255, 254, ...,  59,  52,  43], dtype=uint8),
#  array([190, 167,   5, ..., 135, 136,   8], dtype=uint8),
#  array([ 0,  0,  0, ..., 21, 40, 53], dtype=uint8),
#  array([206, 148, 106, ...,  98, 102,  97], dtype=uint8),
#  array([17, 17, 31, ..., 55, 57, 68], dtype=uint8),
#  array([196, 154, 117, ...,  77,  56,  48], dtype=uint8),
#  array([129, 126,  81, ...,  52,  56,  37], dtype=uint8),
#  array([10,  3, 18, ..., 17, 28, 50], dtype=uint8),
#  array([ 92,  15,   0, ..., 201,  74,  65], dtype=uint8),
#  array([137,  88,  38, ..., 101, 119, 136], dtype=uint8),
#  array([243, 242, 244, ...,  85,  91, 110], dtype=uint8),
#  array([221, 200, 203, ...,   9,  40,  33], dtype=uint8),
#  array([213, 189, 161, ...,  32,  43,  40], dtype=uint8),
#  array([218, 232, 238, ..., 146, 159, 161], dtype=uint8),
#  array([4, 3, 0, ..., 0, 0, 0], dtype=uint8),
#  array([202, 249, 211, ..., 105, 131, 145], dtype=uint8),
#  array([232, 223, 214, ...,  39,  79,  67], dtype=uint8),
#  array([235, 182, 131, ..., 113, 149, 135], dtype=uint8),
#  array([102,  97,  58, ..., 110, 110,  74], dtype=uint8),
#  array([255, 253, 238, ...,  58,  39,  31], dtype=uint8),
#  array([ 0,  0,  0, ..., 32, 27, 18], dtype=uint8),
#  array([164, 167, 172, ...,  21,  15,  20], dtype=uint8),
#  array([192, 193, 184, ...,  23,  40,  43], dtype=uint8),
#  array([112,  59,  38, ...,  66,  62,  61], dtype=uint8),
#  array([216, 122,  46, ..., 163, 146, 113], dtype=uint8),
#  array([205, 209, 227, ...,   0,  24,  25], dtype=uint8),
#  array([ 55,  88,  31, ...,  38, 120,  78], dtype=uint8),
#  array([11, 36, 26, ...,  0, 53, 47], dtype=uint8),
#  array([ 77, 131, 164, ..., 139, 122, 125], dtype=uint8),
#  array([186, 180, 161, ..., 122, 137, 129], dtype=uint8),
#  array([230, 209, 187, ...,   3,  19,  26], dtype=uint8),
#  array([244, 164, 105, ...,  72,  87,  90], dtype=uint8),
#  array([196, 185, 165, ...,  82, 132, 132], dtype=uint8),
#  array([196, 165, 134, ..., 158, 125,  76], dtype=uint8),
#  array([31, 44, 22, ..., 64, 88, 86], dtype=uint8),
#  array([117,  82,  56, ...,  23,  31,  31], dtype=uint8),
#  array([ 88, 204, 135, ...,  21,  54,  40], dtype=uint8),
#  array([179, 167, 165, ...,  36,  37,  41], dtype=uint8),
#  array([242, 240, 239, ..., 102, 102, 118], dtype=uint8),
#  array([2, 3, 7, ..., 0, 0, 0], dtype=uint8),
#  array([ 83, 101,  62, ...,  66,  81,  90], dtype=uint8),
#  array([248, 229, 196, ...,  86,  99, 101], dtype=uint8),
#  array([187, 129,  70, ...,  89,  61,  44], dtype=uint8),
#  array([167, 140, 119, ...,  95,  83,  73], dtype=uint8),
#  array([189, 148, 123, ...,  18,  70,  77], dtype=uint8),
#  array([161, 145, 138, ...,  57,  67,  84], dtype=uint8),
#  array([147,  97,  55, ..., 165, 162, 164], dtype=uint8),
#  array([202, 129,  55, ...,   8,  56,  58], dtype=uint8),
#  array([232, 215, 206, ...,  82,  84,  84], dtype=uint8),
#  array([  8,  14,  33, ...,  91, 122, 191], dtype=uint8),
#  array([ 84, 101, 114, ...,  87, 103, 119], dtype=uint8),
#  array([227, 212, 210, ..., 141, 132,  99], dtype=uint8),
#  array([253, 250, 246, ..., 136, 132, 127], dtype=uint8),
#  array([76, 64, 54, ..., 21, 27, 16], dtype=uint8),
#  array([ 0,  8,  8, ...,  0, 19, 19], dtype=uint8),
#  array([ 56,  76,  77, ..., 106, 104, 116], dtype=uint8),
#  array([162, 142, 124, ...,  29,  24,  15], dtype=uint8),
#  array([239, 214, 188, ..., 228, 191, 157], dtype=uint8),
#  array([ 48,  43,  40, ..., 115, 188, 126], dtype=uint8),
#  array([177, 136,  74, ...,  90,  96, 103], dtype=uint8),
#  array([215, 186, 159, ..., 165, 160, 157], dtype=uint8),
#  array([222, 218, 160, ...,  40,  31,  27], dtype=uint8),
#  array([109, 100,  96, ...,  67,  64,  56], dtype=uint8),
#  array([247, 202, 168, ...,  22,  28,  35], dtype=uint8),
#  array([215, 208, 191, ...,  58, 110, 123], dtype=uint8),
#  array([ 84,  68,  55, ..., 103, 141, 173], dtype=uint8),
#  array([144, 115,  84, ...,  16,  39,  47], dtype=uint8),
#  array([ 50,  59,  93, ...,  53, 109, 120], dtype=uint8),
#  array([  0, 136,  76, ...,   0,   7,  81], dtype=uint8),
#  array([236, 191, 130, ...,  52,  50,  50], dtype=uint8),
#  array([124, 121, 130, ...,  19,  22,  30], dtype=uint8),
#  array([16, 33, 29, ..., 20, 61, 56], dtype=uint8),
#  array([255, 255, 255, ...,  45,  75,  80], dtype=uint8),
#  array([200, 255, 192, ..., 238, 249, 223], dtype=uint8),
#  array([207, 200, 175, ..., 141,  97,  74], dtype=uint8),
#  array([ 58, 113,  50, ...,  39,  53,  49], dtype=uint8),
#  array([219, 167, 121, ...,  95,  97,  97], dtype=uint8),
#  array([ 45,  99,  69, ...,  55,  75, 100], dtype=uint8),
#  array([75, 56, 19, ...,  4,  0,  0], dtype=uint8),
#  array([ 98, 116, 133, ..., 161, 154, 157], dtype=uint8),
#  array([184, 128,  87, ...,   4,  21,  18], dtype=uint8),
#  array([145, 188, 185, ...,  26,  59,  74], dtype=uint8),
#  array([ 0, 13, 22, ...,  0,  0, 22], dtype=uint8),
#  array([160, 142, 131, ..., 160, 133, 112], dtype=uint8),
#  array([179, 191, 195, ...,   0,   9,   3], dtype=uint8),
#  array([255, 255, 255, ...,  42,  50,  57], dtype=uint8),
#  array([110, 130, 135, ..., 196, 207, 205], dtype=uint8),
#  array([60, 74, 72, ...,  7,  0,  0], dtype=uint8),
#  array([207, 205, 171, ...,  56,  65,  52], dtype=uint8),
#  array([253, 252, 248, ..., 128, 123, 124], dtype=uint8),
#  array([205, 187, 180, ...,  42,  46,  47], dtype=uint8),
#  array([11, 13, 13, ...,  6,  8,  8], dtype=uint8),
#  array([26, 36, 53, ..., 34, 36, 36], dtype=uint8),
#  array([109, 110,  78, ..., 222, 220, 209], dtype=uint8),
#  array([ 70,  76,  53, ..., 108,  81,  60], dtype=uint8),
#  array([ 6,  6,  6, ...,  2,  3, 31], dtype=uint8),
#  array([204, 217, 203, ..., 169, 176, 173], dtype=uint8),
#  array([134,  49,  27, ..., 222, 173, 163], dtype=uint8),
#  array([193, 180, 182, ..., 124, 121, 123], dtype=uint8),
#  array([108, 100,  83, ...,   8,  17,  21], dtype=uint8),
#  array([28, 28, 28, ..., 40, 40, 40], dtype=uint8),
#  array([28, 31, 29, ..., 13, 13, 13], dtype=uint8),
#  array([252, 242, 225, ...,  47,  52,  53], dtype=uint8),
#  array([25,  9, 10, ..., 25, 53, 33], dtype=uint8),
#  array([188, 222, 246, ..., 134, 136, 136], dtype=uint8),
#  array([113, 108, 109, ...,   8,  40,  29], dtype=uint8),
#  array([202, 203, 201, ..., 210, 211, 207], dtype=uint8),
#  array([ 37,  41,  52, ..., 106,  95,  91], dtype=uint8),
#  array([106, 111, 136, ...,  76,  65,  67], dtype=uint8),
#  array([215, 199, 176, ...,   8,   8,   8], dtype=uint8),
#  array([244, 239, 224, ...,  88,  67,  40], dtype=uint8),
#  array([ 73,  55,  38, ..., 212, 207, 206], dtype=uint8),
#  array([ 16,  32,  49, ...,  80, 100, 125], dtype=uint8),
#  array([177, 168, 155, ..., 122, 113,  79], dtype=uint8),
#  array([93, 93, 93, ...,  5,  5,  5], dtype=uint8),
#  array([245, 207, 153, ...,  61,  62,  53], dtype=uint8),
#  array([127, 144, 157, ...,   8,  12,  13], dtype=uint8),
#  array([174, 168, 169, ...,   0,   4,   5], dtype=uint8),
#  array([214, 132,  67, ...,  21, 104,  65], dtype=uint8),
#  array([69, 70, 74, ..., 72, 71, 51], dtype=uint8),
#  array([210, 209, 211, ...,  92,  90,  82], dtype=uint8),
#  array([139,  99,  70, ..., 203, 218, 227], dtype=uint8),
#  array([125, 125, 125, ...,  89,  89,  89], dtype=uint8),
#  array([141,  83,  34, ..., 202, 187, 184], dtype=uint8),
#  array([104, 104, 104, ..., 168, 168, 168], dtype=uint8),
#  array([203, 112,  67, ..., 102, 109, 118], dtype=uint8),
#  array([252, 252, 252, ...,  36,  32,  31], dtype=uint8),
#  array([222, 173, 127, ...,   7,  23,  30], dtype=uint8),
#  array([199, 182, 161, ..., 199, 189, 179], dtype=uint8),
#  array([165, 163, 155, ...,  12,  32,  37], dtype=uint8),
#  array([214, 218, 223, ...,   0,   2,   0], dtype=uint8),
#  array([230, 219, 215, ...,  11,  20,  29], dtype=uint8),
#  array([206, 216, 210, ..., 108, 112, 100], dtype=uint8),
#  array([163, 159, 154, ..., 206, 203, 158], dtype=uint8),
#  array([152, 173, 164, ...,   8,   7,   3], dtype=uint8),
#  array([226, 227, 225, ...,  72, 102, 119], dtype=uint8),
#  array([247, 219, 165, ..., 109, 103, 108], dtype=uint8),
#  array([131, 144, 130, ...,   3,   9,  14], dtype=uint8),
#  array([255, 244, 241, ...,  81,  69,  41], dtype=uint8),
#  array([215, 189, 153, ..., 158, 167, 171], dtype=uint8),
#  array([18, 38, 19, ..., 16, 16, 16], dtype=uint8),
#  array([117,  69,  33, ..., 204, 208, 209], dtype=uint8),
#  array([28, 31, 29, ..., 55, 61, 66], dtype=uint8),
#  array([189, 136,  99, ...,  57,  12,   0], dtype=uint8),
#  array([205, 154, 114, ...,  40,  64,  52], dtype=uint8),
#  array([244, 244, 244, ..., 158, 158, 158], dtype=uint8),
#  array([111, 111, 111, ...,  53,  53,  53], dtype=uint8),
#  array([51, 59, 58, ...,  9,  0,  0], dtype=uint8),
#  array([255, 255, 255, ...,  48,  60,  64], dtype=uint8),
#  array([153, 127, 115, ..., 157, 144, 130], dtype=uint8),
#  array([253, 250, 245, ...,  92,  98,  97], dtype=uint8),
#  array([238, 207, 182, ..., 117, 128, 132], dtype=uint8),
#  array([ 21,  15,  16, ..., 136, 141, 132], dtype=uint8),
#  array([67, 76, 56, ..., 17, 20, 24], dtype=uint8),
#  array([ 45,  47,  47, ..., 122, 124, 124], dtype=uint8),
#  array([254, 255, 253, ..., 159, 165, 146], dtype=uint8),
#  array([129, 118, 110, ...,  95, 101, 106], dtype=uint8),
#  array([188, 153, 110, ..., 139, 129, 112], dtype=uint8),
#  array([169,  55,  15, ...,   4,   4,   4], dtype=uint8),
#  array([154, 112,  59, ...,  57, 119, 159], dtype=uint8),
#  array([152, 112,  77, ...,  12,  19,  14], dtype=uint8),
#  array([193, 182, 178, ..., 109, 108,  87], dtype=uint8),
#  array([216, 178, 144, ..., 124, 125,  75], dtype=uint8),
#  array([ 26,  13,  59, ..., 118, 119, 123], dtype=uint8),
#  array([139, 175, 163, ...,   0,  86,  40], dtype=uint8),
#  array([ 92,  35,  10, ..., 146, 120,  84], dtype=uint8),
#  array([249, 254, 252, ..., 107, 113, 102], dtype=uint8),
#  array([58, 47, 43, ..., 29, 21, 21], dtype=uint8),
#  array([141, 141, 135, ...,  26,  28,  38], dtype=uint8),
#  array([241, 244, 248, ...,  25,  33,  33], dtype=uint8),
#  array([ 0, 10,  0, ..., 54, 54, 60], dtype=uint8),
#  array([211, 175, 137, ...,  70,  65,  56], dtype=uint8),
#  array([125, 202, 165, ...,  88, 147, 103], dtype=uint8),
#  array([246, 242, 241, ..., 154, 150, 149], dtype=uint8),
#  array([ 5,  5,  5, ..., 35, 35, 35], dtype=uint8),
#  array([ 5, 36, 15, ...,  3,  1,  1], dtype=uint8),
#  array([ 2,  0,  0, ..., 77, 74, 76], dtype=uint8),
#  array([175, 165, 148, ...,  91,  82,  72], dtype=uint8),
#  array([119, 119, 119, ..., 100, 100, 100], dtype=uint8),
#  array([ 0,  0,  0, ..., 30, 34, 63], dtype=uint8),
#  array([ 65,  86,  88, ..., 162, 131, 140], dtype=uint8),
#  array([ 22, 122,  40, ...,   0,  33,  18], dtype=uint8),
#  array([130,  73,  51, ..., 133,  91,  72], dtype=uint8),
#  array([151, 151, 151, ...,  40,  40,  40], dtype=uint8),
#  array([106,   0,   0, ..., 176,   0,   0], dtype=uint8),
#  array([193, 190, 185, ..., 143, 143, 137], dtype=uint8),
#  array([96, 57, 29, ..., 53, 62, 75], dtype=uint8),
#  array([159, 133, 121, ..., 139, 191, 168], dtype=uint8),
#  array([179, 163, 156, ...,  94,  97, 101], dtype=uint8),
#  array([245, 233, 227, ..., 144, 136, 119], dtype=uint8),
#  array([168,  95,  43, ..., 195, 179, 172], dtype=uint8),
#  array([254, 254, 254, ...,  65,  77,  81], dtype=uint8),
#  array([249, 148,  96, ..., 132, 121, 124], dtype=uint8),
#  array([87, 87, 71, ...,  1,  7,  6], dtype=uint8),
#  array([173, 165, 166, ...,  72,  78,  85], dtype=uint8),
#  array([216, 214, 213, ...,   5,   8,  16], dtype=uint8),
#  array([165, 134, 109, ..., 207, 206, 208], dtype=uint8),
#  array([ 13,  23,  17, ..., 113, 113, 113], dtype=uint8),
#  array([197, 162, 129, ...,  70, 110,  98], dtype=uint8),
#  array([225, 204, 196, ..., 136, 147, 151], dtype=uint8),
#  array([60, 53, 50, ..., 66, 68, 68], dtype=uint8),
#  array([48, 40, 40, ..., 24, 40, 46], dtype=uint8),
#  array([106, 106, 106, ..., 104, 104, 104], dtype=uint8),
#  array([1, 2, 0, ..., 0, 0, 0], dtype=uint8),
#  array([177, 177, 177, ...,  16,  16,  16], dtype=uint8),
#  array([155, 155, 155, ...,   7,  29,  35], dtype=uint8),
#  array([28,  9, 26, ..., 59, 57, 63], dtype=uint8),
#  array([179,  99,  38, ...,  61,  66,  65], dtype=uint8),
#  array([233, 220, 204, ...,  46,  66,  83], dtype=uint8),
#  array([135,  96,  51, ...,  10,  40,  41], dtype=uint8),
#  array([ 25,  36,  33, ...,  84, 103,  94], dtype=uint8),
#  array([203, 128,  60, ...,  68,  97, 136], dtype=uint8),
#  array([67, 32, 28, ..., 14,  9, 10], dtype=uint8),
#  array([190, 163, 129, ...,  82, 109, 136], dtype=uint8),
#  array([166, 109,  83, ..., 189, 194, 193], dtype=uint8),
#  array([ 96, 109, 117, ..., 152, 141, 137], dtype=uint8),
#  array([199, 191, 184, ..., 110, 105, 104], dtype=uint8),
#  array([176, 162, 144, ..., 101, 135,  98], dtype=uint8),
#  array([223, 205, 198, ..., 148, 152, 153], dtype=uint8),
#  array([63, 39, 17, ..., 24, 18, 19], dtype=uint8),
#  array([167, 110,  31, ...,  44, 165, 121], dtype=uint8),
#  array([195, 204, 191, ...,   0,   0,   0], dtype=uint8),
#  array([20, 29, 26, ..., 91, 96, 94], dtype=uint8),
#  array([148, 148, 148, ...,  60,  60,  60], dtype=uint8),
#  array([ 93, 138,  99, ...,  26,  65,  80], dtype=uint8),
#  array([242, 241, 237, ...,  89,  88,  68], dtype=uint8),
#  array([165, 105,  53, ...,  91,  91,  91], dtype=uint8),
#  array([231, 221, 221, ..., 251, 254, 252], dtype=uint8),
#  array([ 28, 143,  64, ...,  13,  58,  25], dtype=uint8),
#  array([160, 176, 188, ..., 104, 100, 106], dtype=uint8),
#  array([69, 63, 56, ...,  0,  0,  0], dtype=uint8),
#  array([39, 36, 32, ..., 72, 77, 80], dtype=uint8),
#  array([128, 124, 113, ...,  77,  66,  44], dtype=uint8),
#  array([188,  94,  41, ..., 135, 156, 194], dtype=uint8),
#  array([166, 143,  43, ...,   0,   0,  56], dtype=uint8),
#  array([189, 103,  57, ...,  13,  11,  10], dtype=uint8),
#  array([162, 203, 212, ...,   3,   5,  23], dtype=uint8),
#  array([ 59, 171,  77, ...,  53, 172,  57], dtype=uint8),
#  array([249, 245, 240, ...,  69,  41,  24], dtype=uint8),
#  array([ 0, 55,  0, ...,  2, 18,  7], dtype=uint8),
#  array([218, 161, 140, ...,  21,  39,  40], dtype=uint8),
#  array([16, 18, 26, ..., 28, 46, 63], dtype=uint8),
#  array([209, 180, 173, ..., 219, 208, 204], dtype=uint8),
#  array([183, 126,  87, ...,   8,  39,  24], dtype=uint8),
#  array([213, 191, 166, ...,  84,  73,  43], dtype=uint8),
#  array([220, 220, 220, ...,  23,  29,  28], dtype=uint8),
#  array([158, 201, 222, ...,   0,   1,   2], dtype=uint8),
#  array([168, 173, 174, ...,  38,  47,  50], dtype=uint8),
#  array([205, 157,  79, ...,  45,  35,  17], dtype=uint8),
#  array([158, 236, 252, ...,  24,  23,  27], dtype=uint8),
#  array([182, 175, 172, ..., 123, 136, 138], dtype=uint8),
#  array([183, 104,  55, ...,  82, 114, 133], dtype=uint8),
#  array([228, 205, 183, ...,  80, 102, 108], dtype=uint8),
#  array([237, 221, 204, ...,  29,  31,  31], dtype=uint8),
#  array([192, 138,  78, ...,  40,  40,  40], dtype=uint8),
#  array([129,  82,  38, ...,  68,  53,  34], dtype=uint8),
#  array([217, 211, 216, ...,  28,  34,  39], dtype=uint8),
#  array([105,  64,   0, ...,   3,  20,  23], dtype=uint8),
#  array([81, 81, 87, ..., 21, 27, 38], dtype=uint8),
#  array([165, 156, 152, ...,   0,   0,   6], dtype=uint8),
#  array([255, 255, 249, ..., 140, 136,  87], dtype=uint8),
#  array([6, 1, 3, ..., 0, 0, 8], dtype=uint8),
#  array([ 74,  43,  18, ..., 164, 155, 142], dtype=uint8),
#  array([13, 31, 14, ...,  2, 40, 52], dtype=uint8),
#  array([249, 202, 150, ...,  73,  83,  83], dtype=uint8),
#  array([ 7,  0, 10, ...,  2,  0,  1], dtype=uint8),
#  ...]

# %%
np_test_features = np.array(test_features)
np_test_features = np_test_features.astype(np.int32)
np_test_features.shape
# Out:
# (3600, 67500)

# %%
print('total test data shape: ',np_test_features.shape)
# Out:
# total test data shape:  (3600, 67500)

# %% [markdown]
# ## Dementionality reduction for test data
# ## using same eigenvalue

# %%
np_test_features_pca = pca_3600.transform(np_test_features)
np_test_features_pca.shape
# Out:
# (3600, 3600)

# %%
svm_predict_result = model.predict(np_test_features_pca)

# %%
svm_predict_result
# Out:
# array([5, 0, 0, ..., 2, 1, 2])

# %%
import pandas as pd
df_pca_svm = pd.DataFrame()

df_pca_svm['Id'] = image_ids
df_pca_svm['Category'] = svm_predict_result
df_pca_svm.to_csv('PCA(3600)_svm_prediction_v1.4.csv')

# %%
import pandas as pd
csv = pd.read_csv('PCA(3600)_svm_prediction_v1.4.csv')
#csv = csv.drop(columns=['AB'])

# %%
csv
# Out:
#                               Id  Category
# 0         1000 - Copy - Copy.jpg         5
# 1                      10113.jpg         0
# 2                      10144.jpg         0
# 3                      10151.jpg         4
# 4                      10161.jpg         0
# ...                          ...       ...
# 3595              991 - Copy.jpg         0
# 3596  9943 - Copy (2) - Copy.jpg         2
# 3597  9951 - Copy (2) - Copy.jpg         2
# 3598                     997.jpg         1
# 3599   998 - Copy (2) - Copy.jpg         2
#
# [3600 rows x 2 columns]

# %% [markdown]
# # the kaggle prediction result is 0.69722
